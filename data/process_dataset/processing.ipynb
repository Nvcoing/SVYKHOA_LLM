# %% [markdown]
# ### diagnosis icd 10

# %%
import pandas as pd
df = pd.read_excel("SVYKHOA_dataset_diagnosis.xlsx")
df
# Out:
#                                               intruction icd_10  \
# 0      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 1      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 2      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 3      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 4      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# ...                                                  ...    ...
# 30261  Chatbot y khoa chuyên về y khoa, cung cấp thôn...    T62
# 30262  Chatbot y khoa chuyên về y khoa, cung cấp thôn...    T62
# 30263  Chatbot y khoa chuyên về y khoa, cung cấp thôn...    T62
# 30264  Chatbot y khoa chuyên về y khoa, cung cấp thôn...    T62
# 30265  Chatbot y khoa chuyên về y khoa, cung cấp thôn...    T62
#
#                                      icd_10/title  \
# 0      Tiểu không kiểm soát do gắng sức ở nữ giới
# 1      Tiểu không kiểm soát do gắng sức ở nữ giới
# 2      Tiểu không kiểm soát do gắng sức ở nữ giới
# 3                     Són tiểu gắng sức ở nữ giới
# 4                     Són tiểu gắng sức ở nữ giới
# ...                                           ...
# 30261                                         NaN
# 30262                                         NaN
# 30263                                         NaN
# 30264                                         NaN
# 30265                                         NaN
#
#                                                 question  \
# 0      Các triệu chứng điển hình của tiểu không kiểm ...
# 1      Những chỉ định lâm sàng nào cho phẫu thuật TOT...
# 2      Tiểu không kiểm soát là gì, tần suất mắc bệnh ...
# 3      Són tiểu gắng sức ở nữ giới là gì và phẫu thuậ...
# 4      Những chỉ định và chống chỉ định cụ thể cho ph...
# ...                                                  ...
# 30261  Tôi bị các triệu chứng như buồn nôn, nôn mửa v...
# 30262  Những dấu hiệu cảnh báo nào cho thấy tình trạn...
# 30263  Khi bị ngộ độc thực phẩm nhẹ, tôi nên tự chăm ...
# 30264  Ngộ độc thực phẩm do vi khuẩn Salmonella thườn...
# 30265  Làm thế nào để phòng ngừa ngộ độc thực phẩm mộ...
#
#                                                  symptom  \
# 0      Các triệu chứng và dấu hiệu lâm sàng bao gồm: ...
# 1      Các triệu chứng gợi ý chỉ định phẫu thuật TOT ...
# 2      Tiểu không kiểm soát, theo định nghĩa của Hiệp...
# 3      Bệnh nhân có biểu hiện rò rỉ nước tiểu không c...
# 4      Bệnh nhân đã được chẩn đoán xác nhận mắc són t...
# ...                                                  ...
# 30261  Các triệu chứng khởi phát cấp tính bao gồm buồ...
# 30262  Các dấu hiệu cảnh báo nghiêm trọng bao gồm: số...
# 30263  Các triệu chứng nhẹ bao gồm: buồn nôn thoáng q...
# 30264  Ngộ độc thực phẩm do Salmonella (có thể thuộc ...
# 30265  Đây là câu hỏi về phòng ngừa, không liên quan ...
#
#                                                diagnosis  \
# 0      Chẩn đoán tiểu không kiểm soát do gắng sức ở n...
# 1      Chỉ định phẫu thuật TOT được cân nhắc cho nhữn...
# 2      Tiểu không kiểm soát do gắng sức là một tình t...
# 3      Chẩn đoán són tiểu gắng sức ở nữ giới (ICD-10:...
# 4      Chẩn đoán són tiểu gắng sức (ICD-10: N39.3) là...
# ...                                                  ...
# 30261  Chẩn đoán lâm sàng nghi ngờ ngộ độc chất độc d...
# 30262  Chẩn đoán mức độ nặng của ngộ độc thực phẩm (I...
# 30263  Đối với ngộ độc thực phẩm mức độ nhẹ (ICD-10: ...
# 30264  Chẩn đoán xác định ngộ độc thực phẩm do Salmon...
# 30265  Đây là câu hỏi về phòng ngừa, không liên quan ...
#
#                                           document/title  \
# 0      Hướng dẫn chẩn đoán và quản lý tiểu không kiểm...
# 1      Nghiên cứu về chỉ định phẫu thuật TOT trong đi...
# 2      Dịch tễ học và tác động của tiểu không kiểm so...
# 3      Nghiên cứu về chỉ định phẫu thuật TOT điều trị...
# 4      Chỉ định phẫu thuật TOT trong điều trị són tiể...
# ...                                                  ...
# 30261  Hướng dẫn chẩn đoán và xử trí ngộ độc thực phẩ...
# 30262  Hướng dẫn chẩn đoán, điều trị và phòng ngừa cá...
# 30263       Chăm sóc và xử trí ngộ độc thực phẩm tại nhà
# 30264    Phác đồ điều trị bệnh do Salmonella của Bộ Y tế
# 30265    10 nguyên tắc vàng về an toàn thực phẩm của WHO
#
#                                     document/description  \
# 0      Tài liệu này cung cấp các tiêu chí chẩn đoán t...
# 1      Tài liệu này trình bày các phát hiện từ một ng...
# 2      Tài liệu này nghiên cứu sâu về định nghĩa, phạ...
# 3      Tài liệu này trình bày kết quả của một nghiên ...
# 4      Tài liệu này tổng hợp các hướng dẫn lâm sàng v...
# ...                                                  ...
# 30261  Tài liệu này cung cấp các phác đồ chẩn đoán, đ...
# 30262  Tài liệu này từ WHO và Bộ Y tế Việt Nam cung c...
# 30263  Tài liệu hướng dẫn chi tiết về các biện pháp t...
# 30264  Tài liệu hướng dẫn chi tiết về phác đồ chẩn đo...
# 30265  Tài liệu của Tổ chức Y tế Thế giới (WHO) đưa r...
#
#                                                cme/title  \
# 0      Cập nhật chẩn đoán phân biệt và nguyên nhân gâ...
# 1      Kỹ thuật phẫu thuật TOT và quản lý biến chứng ...
# 2      Phân tích gánh nặng bệnh tật và tác động tâm l...
# 3      Cập nhật chẩn đoán và điều trị són tiểu gắng s...
# 4      Phẫu thuật nâng đỡ niệu đạo giữa: Kỹ thuật TOT...
# ...                                                  ...
# 30261  Cập nhật kiến thức về ngộ độc thực phẩm và quả...
# 30262  Quản lý cấp cứu ngộ độc thực phẩm nặng và biến...
# 30263  Tư vấn dinh dưỡng và bù dịch trong ngộ độc thự...
# 30264  Kiểm soát nhiễm khuẩn và phòng ngừa ngộ độc th...
# 30265  Vệ sinh an toàn thực phẩm và phòng ngừa ngộ độ...
#
#                                          cme/description
# 0      Khóa học đào tạo y khoa liên tục này nhằm nâng...
# 1      Khóa học này cung cấp kiến thức chuyên sâu về ...
# 2      Khóa học này tập trung vào việc đánh giá gánh ...
# 3      Khóa học CME này cung cấp kiến thức toàn diện ...
# 4      Khóa học này tập trung chuyên sâu vào kỹ thuật...
# ...                                                  ...
# 30261  Khóa học trang bị cho các bác sĩ và nhân viên ...
# 30262  Khóa học tập trung vào việc nhận diện sớm các ...
# 30263  Khóa học dành cho nhân viên y tế và tư vấn viê...
# 30264  Khóa học cung cấp kiến thức chuyên sâu về dịch...
# 30265  Khóa học cung cấp kiến thức toàn diện về vệ si...
#
# [30266 rows x 10 columns]

# %%
# đếm số NaN
nan_count = df['intruction'].isna().sum()
print("Số NaN:", nan_count)

# đếm số chuỗi rỗng ''
empty_str_count = (df['intruction'] == '').sum()
print("Số chuỗi rỗng:", empty_str_count)

# tổng cộng giá trị rỗng
total_missing = nan_count + empty_str_count
print("Tổng số giá trị rỗng:", total_missing)
# Out:
# Số NaN: 1130
# Số chuỗi rỗng: 0
# Tổng số giá trị rỗng: 1130

# %%
most_common = df['intruction'].value_counts().idxmax()
count = df['intruction'].value_counts().max()

print("Giá trị xuất hiện nhiều nhất:", most_common)
print("Số lần xuất hiện:", count)
# Out:
# Giá trị xuất hiện nhiều nhất: Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.
# Số lần xuất hiện: 25956

# %%
# thay NaN và chuỗi rỗng bằng most_common
df['intruction'] = df['intruction'].fillna(most_common)

# %%
df_diagnosis = df
df_diagnosis
# Out:
#                                               intruction icd_10  \
# 0      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 1      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 2      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 3      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 4      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# ...                                                  ...    ...
# 30261  Chatbot y khoa chuyên về y khoa, cung cấp thôn...    T62
# 30262  Chatbot y khoa chuyên về y khoa, cung cấp thôn...    T62
# 30263  Chatbot y khoa chuyên về y khoa, cung cấp thôn...    T62
# 30264  Chatbot y khoa chuyên về y khoa, cung cấp thôn...    T62
# 30265  Chatbot y khoa chuyên về y khoa, cung cấp thôn...    T62
#
#                                      icd_10/title  \
# 0      Tiểu không kiểm soát do gắng sức ở nữ giới
# 1      Tiểu không kiểm soát do gắng sức ở nữ giới
# 2      Tiểu không kiểm soát do gắng sức ở nữ giới
# 3                     Són tiểu gắng sức ở nữ giới
# 4                     Són tiểu gắng sức ở nữ giới
# ...                                           ...
# 30261                                         NaN
# 30262                                         NaN
# 30263                                         NaN
# 30264                                         NaN
# 30265                                         NaN
#
#                                                 question  \
# 0      Các triệu chứng điển hình của tiểu không kiểm ...
# 1      Những chỉ định lâm sàng nào cho phẫu thuật TOT...
# 2      Tiểu không kiểm soát là gì, tần suất mắc bệnh ...
# 3      Són tiểu gắng sức ở nữ giới là gì và phẫu thuậ...
# 4      Những chỉ định và chống chỉ định cụ thể cho ph...
# ...                                                  ...
# 30261  Tôi bị các triệu chứng như buồn nôn, nôn mửa v...
# 30262  Những dấu hiệu cảnh báo nào cho thấy tình trạn...
# 30263  Khi bị ngộ độc thực phẩm nhẹ, tôi nên tự chăm ...
# 30264  Ngộ độc thực phẩm do vi khuẩn Salmonella thườn...
# 30265  Làm thế nào để phòng ngừa ngộ độc thực phẩm mộ...
#
#                                                  symptom  \
# 0      Các triệu chứng và dấu hiệu lâm sàng bao gồm: ...
# 1      Các triệu chứng gợi ý chỉ định phẫu thuật TOT ...
# 2      Tiểu không kiểm soát, theo định nghĩa của Hiệp...
# 3      Bệnh nhân có biểu hiện rò rỉ nước tiểu không c...
# 4      Bệnh nhân đã được chẩn đoán xác nhận mắc són t...
# ...                                                  ...
# 30261  Các triệu chứng khởi phát cấp tính bao gồm buồ...
# 30262  Các dấu hiệu cảnh báo nghiêm trọng bao gồm: số...
# 30263  Các triệu chứng nhẹ bao gồm: buồn nôn thoáng q...
# 30264  Ngộ độc thực phẩm do Salmonella (có thể thuộc ...
# 30265  Đây là câu hỏi về phòng ngừa, không liên quan ...
#
#                                                diagnosis  \
# 0      Chẩn đoán tiểu không kiểm soát do gắng sức ở n...
# 1      Chỉ định phẫu thuật TOT được cân nhắc cho nhữn...
# 2      Tiểu không kiểm soát do gắng sức là một tình t...
# 3      Chẩn đoán són tiểu gắng sức ở nữ giới (ICD-10:...
# 4      Chẩn đoán són tiểu gắng sức (ICD-10: N39.3) là...
# ...                                                  ...
# 30261  Chẩn đoán lâm sàng nghi ngờ ngộ độc chất độc d...
# 30262  Chẩn đoán mức độ nặng của ngộ độc thực phẩm (I...
# 30263  Đối với ngộ độc thực phẩm mức độ nhẹ (ICD-10: ...
# 30264  Chẩn đoán xác định ngộ độc thực phẩm do Salmon...
# 30265  Đây là câu hỏi về phòng ngừa, không liên quan ...
#
#                                           document/title  \
# 0      Hướng dẫn chẩn đoán và quản lý tiểu không kiểm...
# 1      Nghiên cứu về chỉ định phẫu thuật TOT trong đi...
# 2      Dịch tễ học và tác động của tiểu không kiểm so...
# 3      Nghiên cứu về chỉ định phẫu thuật TOT điều trị...
# 4      Chỉ định phẫu thuật TOT trong điều trị són tiể...
# ...                                                  ...
# 30261  Hướng dẫn chẩn đoán và xử trí ngộ độc thực phẩ...
# 30262  Hướng dẫn chẩn đoán, điều trị và phòng ngừa cá...
# 30263       Chăm sóc và xử trí ngộ độc thực phẩm tại nhà
# 30264    Phác đồ điều trị bệnh do Salmonella của Bộ Y tế
# 30265    10 nguyên tắc vàng về an toàn thực phẩm của WHO
#
#                                     document/description  \
# 0      Tài liệu này cung cấp các tiêu chí chẩn đoán t...
# 1      Tài liệu này trình bày các phát hiện từ một ng...
# 2      Tài liệu này nghiên cứu sâu về định nghĩa, phạ...
# 3      Tài liệu này trình bày kết quả của một nghiên ...
# 4      Tài liệu này tổng hợp các hướng dẫn lâm sàng v...
# ...                                                  ...
# 30261  Tài liệu này cung cấp các phác đồ chẩn đoán, đ...
# 30262  Tài liệu này từ WHO và Bộ Y tế Việt Nam cung c...
# 30263  Tài liệu hướng dẫn chi tiết về các biện pháp t...
# 30264  Tài liệu hướng dẫn chi tiết về phác đồ chẩn đo...
# 30265  Tài liệu của Tổ chức Y tế Thế giới (WHO) đưa r...
#
#                                                cme/title  \
# 0      Cập nhật chẩn đoán phân biệt và nguyên nhân gâ...
# 1      Kỹ thuật phẫu thuật TOT và quản lý biến chứng ...
# 2      Phân tích gánh nặng bệnh tật và tác động tâm l...
# 3      Cập nhật chẩn đoán và điều trị són tiểu gắng s...
# 4      Phẫu thuật nâng đỡ niệu đạo giữa: Kỹ thuật TOT...
# ...                                                  ...
# 30261  Cập nhật kiến thức về ngộ độc thực phẩm và quả...
# 30262  Quản lý cấp cứu ngộ độc thực phẩm nặng và biến...
# 30263  Tư vấn dinh dưỡng và bù dịch trong ngộ độc thự...
# 30264  Kiểm soát nhiễm khuẩn và phòng ngừa ngộ độc th...
# 30265  Vệ sinh an toàn thực phẩm và phòng ngừa ngộ độ...
#
#                                          cme/description
# 0      Khóa học đào tạo y khoa liên tục này nhằm nâng...
# 1      Khóa học này cung cấp kiến thức chuyên sâu về ...
# 2      Khóa học này tập trung vào việc đánh giá gánh ...
# 3      Khóa học CME này cung cấp kiến thức toàn diện ...
# 4      Khóa học này tập trung chuyên sâu vào kỹ thuật...
# ...                                                  ...
# 30261  Khóa học trang bị cho các bác sĩ và nhân viên ...
# 30262  Khóa học tập trung vào việc nhận diện sớm các ...
# 30263  Khóa học dành cho nhân viên y tế và tư vấn viê...
# 30264  Khóa học cung cấp kiến thức chuyên sâu về dịch...
# 30265  Khóa học cung cấp kiến thức toàn diện về vệ si...
#
# [30266 rows x 10 columns]

# %%
df = pd.read_excel("../icd-10/icd10_processed.xlsx")
df
# Out:
#       STT CHƯƠNG MÃ CHƯƠNG                               TÊN NHÓM CHÍNH  \
# 0              I   A00-B99                  Bệnh nhiễm trùng đường ruột
# 1              I   A00-B99                  Bệnh nhiễm trùng đường ruột
# 2              I   A00-B99                  Bệnh nhiễm trùng đường ruột
# 3              I   A00-B99                  Bệnh nhiễm trùng đường ruột
# 4              I   A00-B99                  Bệnh nhiễm trùng đường ruột
# ...          ...       ...                                          ...
# 12214       XXII   U00-U99  Kháng các thuốc kháng sinh và chống ung thư
# 12215       XXII   U00-U99  Kháng các thuốc kháng sinh và chống ung thư
# 12216       XXII   U00-U99  Kháng các thuốc kháng sinh và chống ung thư
# 12217       XXII   U00-U99  Kháng các thuốc kháng sinh và chống ung thư
# 12218       XXII   U00-U99  Kháng các thuốc kháng sinh và chống ung thư
#
#       MÃ BỆNH                                           TÊN BỆNH
# 0         A00                                            Bệnh tả
# 1       A00.0  Bệnh tả do Vibrio cholerae 01, typ sinh học ch...
# 2       A00.1  Bệnh tả do Vibrio cholerae 01, typ sinh học eltor
# 3       A00.9                            Bệnh tả, không đặc hiệu
# 4         A01                  Bệnh thương hàn và phó thương hàn
# ...       ...                                                ...
# 12214   U84.3                        Kháng (các) thuốc chống lao
# 12215   U84.7                   Kháng đa thuốc kháng vi sinh vật
# 12216   U84.8        Kháng thuốc kháng vi sinh vật xác định khác
# 12217   U84.9   Kháng các thuốc kháng vi sinh vật không xác định
# 12218     U85                      Kháng các thuốc kháng ung thư
#
# [12219 rows x 5 columns]

# %%
merged = df.merge(
    df_diagnosis,
    how="outer",
    left_on="MÃ BỆNH",
    right_on="icd_10"
)

# %%
df = merged.drop(columns=["icd_10", "icd_10/title"])

# %%
df = df.dropna(subset=['MÃ CHƯƠNG'])
df
# Out:
#       STT CHƯƠNG MÃ CHƯƠNG                                     TÊN NHÓM CHÍNH  \
# 0              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 1              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 2              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 3              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 4              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# ...          ...       ...                                                ...
# 38550        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 38551        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 38552        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 38555        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 38556        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
#
#       MÃ BỆNH                                    TÊN BỆNH  \
# 0         A00                                     Bệnh tả
# 1         A00                                     Bệnh tả
# 2         A00                                     Bệnh tả
# 3         A00                                     Bệnh tả
# 4         A00                                     Bệnh tả
# ...       ...                                         ...
# 38550   Z99.2                Phụ thuộc chạy thận nhân tạo
# 38551   Z99.2                Phụ thuộc chạy thận nhân tạo
# 38552   Z99.2                Phụ thuộc chạy thận nhân tạo
# 38555   Z99.8  Phụ thuộc vào các thiết bị và dụng cụ khác
# 38556   Z99.8  Phụ thuộc vào các thiết bị và dụng cụ khác
#
#                                               intruction  \
# 0      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 1      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 2      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 3      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 4      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# ...                                                  ...
# 38550  Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 38551  Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 38552  Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 38555  Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 38556  Chatbot y khoa chuyên về y khoa, cung cấp thôn...
#
#                                                 question  \
# 0      Một bệnh nhân đến khám với triệu chứng tiêu ch...
# 1      Làm thế nào để nhận biết và chẩn đoán bệnh tả ...
# 2      Những xét nghiệm cận lâm sàng nào cần được thự...
# 3      Nguyên tắc điều trị bệnh tả là gì, đặc biệt tr...
# 4      Các biện pháp phòng ngừa và kiểm soát dịch bện...
# ...                                                  ...
# 38550  Các chỉ số siêu âm tim nào được sử dụng để đán...
# 38551  Mối quan hệ giữa thể tích siêu lọc và sự thay ...
# 38552  Những yếu tố nào liên quan đến suy dinh dưỡng ...
# 38555  Kỹ thuật ECMO (Oxy hóa máu qua màng ngoài cơ t...
# 38556  Những nhóm bệnh nhân nào có nguy cơ cao mắc nh...
#
#                                                  symptom  \
# 0      Bệnh nhân có khởi phát đột ngột tiêu chảy nhiề...
# 1      Bệnh nhân có tiêu chảy liên tục (>5 lần/giờ), ...
# 2      Bệnh nhân có triệu chứng lâm sàng nghi ngờ tả ...
# 3      Bệnh nhân được chẩn đoán xác định hoặc nghi ng...
# 4      Không có triệu chứng lâm sàng cụ thể của bệnh ...
# ...                                                  ...
# 38550  Các chỉ số siêu âm tim quan trọng để đánh giá ...
# 38551  Nghiên cứu đánh giá mối tương quan giữa thể tí...
# 38552  Người bệnh lọc máu chu kỳ thường đối mặt với s...
# 38555  Các triệu chứng lâm sàng cho thấy bệnh nhân cầ...
# 38556  Các bệnh nhân có nguy cơ cao mắc nhiễm khuẩn b...
#
#                                                diagnosis  \
# 0      Nghi ngờ lâm sàng Bệnh tả (ICD-10 A00 - Choler...
# 1      Bệnh tả có mất nước nặng (ICD-10 A00.0 - Chole...
# 2      Xác định chẩn đoán Bệnh tả (ICD-10 A00) bằng p...
# 3      Nguyên tắc điều trị Bệnh tả (ICD-10 A00) bao g...
# 4      Các biện pháp phòng ngừa và kiểm soát Bệnh tả ...
# ...                                                  ...
# 38550  Đánh giá chức năng tâm thu và tâm trương thất ...
# 38551  Ở bệnh nhân lọc máu chu kỳ, thể tích siêu lọc ...
# 38552  Chẩn đoán suy dinh dưỡng ở người bệnh phụ thuộ...
# 38555  ECMO (Extracorporeal Membrane Oxygenation) là ...
# 38556  Các bệnh nhân tại khoa hồi sức tích cực được c...
#
#                                           document/title  \
# 0      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 1      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 2      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 3      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 4      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# ...                                                  ...
# 38550  Nghiên cứu về tỷ lệ E/e’ và thể tích nhĩ trái ...
# 38551  Quy trình kỹ thuật Lọc máu chu kỳ và Quản lý t...
# 38552  TÌNH TRẠNG DINH DƯỠNG VÀ MỘT SỐ YẾU TỐ LIÊN QU...
# 38555  Kỹ thuật Oxy hóa máu qua màng ngoài cơ thể (EC...
# 38556  THỰC TRẠNG NHIỄM KHUẨN BỆNH VIỆN TẠI CÁC KHOA ...
#
#                                     document/description  \
# 0      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 1      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 2      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 3      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 4      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# ...                                                  ...
# 38550  Nghiên cứu này cung cấp dữ liệu định lượng về ...
# 38551  Tài liệu này mô tả chi tiết các quy trình kỹ t...
# 38552  Nghiên cứu này trình bày kết quả về tỷ lệ suy ...
# 38555  Tổng quan về nguyên lý hoạt động, phân loại (V...
# 38556  Nghiên cứu này làm rõ các yếu tố nguy cơ và bố...
#
#                                                cme/title  \
# 0      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 1      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 2      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 3      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 4      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# ...                                                  ...
# 38550  Siêu âm tim nâng cao: Kỹ thuật và diễn giải cá...
# 38551  Chiến lược Tối ưu hóa Siêu lọc và Giám sát Huy...
# 38552  Chiến lược can thiệp dinh dưỡng dựa trên yếu t...
# 38555  ECMO cơ bản: Nguyên lý và thực hành lâm sàng t...
# 38556  An toàn người bệnh và phòng ngừa nhiễm khuẩn t...
#
#                                          cme/description
# 0      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 1      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 2      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 3      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 4      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# ...                                                  ...
# 38550  Khóa học trang bị kiến thức chuyên sâu về kỹ t...
# 38551  Khóa học này cung cấp kiến thức nâng cao về cá...
# 38552  Khóa học này khám phá các yếu tố nguy cơ gây s...
# 38555  Khóa học này cung cấp kiến thức nền tảng về kỹ...
# 38556  Khóa học cung cấp kiến thức và kỹ năng về các ...
#
# [27350 rows x 13 columns]

# %%
df.to_excel("svykhoa_icd10_processed.xlsx", index=False)

# %%
df_generated = pd.read_excel("gen_SVYKHOA_dataset_diagnosis.xlsx")

# %%
merged = merged.merge(
    df_generated,
    how="outer",
    left_on="MÃ BỆNH",
    right_on="icd10"
)
merged['TÊN BỆNH'] = merged['icd_10'].combine_first(merged['TÊN BỆNH'])

# %%
merged
# Out:
#       STT CHƯƠNG MÃ CHƯƠNG               TÊN NHÓM CHÍNH MÃ BỆNH TÊN BỆNH  \
# 0              I   A00-B99  Bệnh nhiễm trùng đường ruột     A00  Bệnh tả
# 1              I   A00-B99  Bệnh nhiễm trùng đường ruột     A00  Bệnh tả
# 2              I   A00-B99  Bệnh nhiễm trùng đường ruột     A00  Bệnh tả
# 3              I   A00-B99  Bệnh nhiễm trùng đường ruột     A00  Bệnh tả
# 4              I   A00-B99  Bệnh nhiễm trùng đường ruột     A00  Bệnh tả
# ...          ...       ...                          ...     ...      ...
# 40499        NaN       NaN                          NaN     NaN   Z98.89
# 40500        NaN       NaN                          NaN     NaN   Z98.89
# 40501        NaN       NaN                          NaN     NaN   Z98.89
# 40502        NaN       NaN                          NaN     NaN   Z98.89
# 40503        NaN       NaN                          NaN     NaN      NaN
#
#                                             intruction_x  icd_10  \
# 0                                                    NaN     NaN
# 1                                                    NaN     NaN
# 2                                                    NaN     NaN
# 3                                                    NaN     NaN
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 40499  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z98.89
# 40500  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z98.89
# 40501  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z98.89
# 40502  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z98.89
# 40503  Chatbot y khoa chuyên về y khoa, cung cấp thôn...     NaN
#
#                                             icd_10/title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40499  Các tình trạng sau thủ thuật khác được xác địn...
# 40500     Các tình trạng sau phẫu thuật đã xác định khác
# 40501  Các tình trạng phẫu thuật đặc hiệu khác sau th...
# 40502            Trạng thái sau phẫu thuật đặc hiệu khác
# 40503                                                NaN
#
#                                               question_x  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40499  Những rủi ro và thách thức về mặt thẩm mỹ đối ...
# 40500  Việc sử dụng vạt đùi trước ngoài (ALT flap) để...
# 40501  Dung dịch Chlorhexidine 2% này có nồng độ và đ...
# 40502  Các chỉ số về thời gian phục hồi và biến chứng...
# 40503                                                NaN
#
#                                                symptom_x  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                                                    NaN  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 40499  Nguy cơ tiềm ẩn bao gồm những thay đổi khó lườ...  ...
# 40500  Khuyết hổng phần mềm lớn vùng mặt cổ sau phẫu ...  ...
# 40501  Sau các thủ thuật phẫu thuật miệng như nhổ răn...  ...
# 40502  Bệnh nhân sau phẫu thuật nội soi ung thư trực ...  ...
# 40503                                                NaN  ...
#
#                                        cme/description_x  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40499  Khóa học tập trung vào các kỹ thuật tiên tiến ...
# 40500  Khóa học đào tạo y khoa liên tục về các chiến ...
# 40501  Khóa học này thảo luận về việc sử dụng Chlorhe...
# 40502  Khóa học tập trung vào các phương pháp chăm só...
# 40503  Khóa học này trang bị cho bác sĩ kiến thức về ...
#
#                                             intruction_y  \
# 0      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 1      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 2      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 3      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 4      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# ...                                                  ...
# 40499                                                NaN
# 40500                                                NaN
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
#
#                                               question_y icd10  \
# 0      Một bệnh nhân đến khám với triệu chứng tiêu ch...   A00
# 1      Làm thế nào để nhận biết và chẩn đoán bệnh tả ...   A00
# 2      Những xét nghiệm cận lâm sàng nào cần được thự...   A00
# 3      Nguyên tắc điều trị bệnh tả là gì, đặc biệt tr...   A00
# 4      Các biện pháp phòng ngừa và kiểm soát dịch bện...   A00
# ...                                                  ...   ...
# 40499                                                NaN   NaN
# 40500                                                NaN   NaN
# 40501                                                NaN   NaN
# 40502                                                NaN   NaN
# 40503                                                NaN   NaN
#
#                                                symptom_y  \
# 0      Bệnh nhân có khởi phát đột ngột tiêu chảy nhiề...
# 1      Bệnh nhân có tiêu chảy liên tục (>5 lần/giờ), ...
# 2      Bệnh nhân có triệu chứng lâm sàng nghi ngờ tả ...
# 3      Bệnh nhân được chẩn đoán xác định hoặc nghi ng...
# 4      Không có triệu chứng lâm sàng cụ thể của bệnh ...
# ...                                                  ...
# 40499                                                NaN
# 40500                                                NaN
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
#
#                                              diagnosis_y  \
# 0      Nghi ngờ lâm sàng Bệnh tả (ICD-10 A00 - Choler...
# 1      Bệnh tả có mất nước nặng (ICD-10 A00.0 - Chole...
# 2      Xác định chẩn đoán Bệnh tả (ICD-10 A00) bằng p...
# 3      Nguyên tắc điều trị Bệnh tả (ICD-10 A00) bao g...
# 4      Các biện pháp phòng ngừa và kiểm soát Bệnh tả ...
# ...                                                  ...
# 40499                                                NaN
# 40500                                                NaN
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
#
#                                         document/title_y  \
# 0      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 1      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 2      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 3      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 4      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# ...                                                  ...
# 40499                                                NaN
# 40500                                                NaN
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
#
#                                   document/description_y  \
# 0      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 1      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 2      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 3      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 4      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# ...                                                  ...
# 40499                                                NaN
# 40500                                                NaN
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
#
#                                              cme/title_y  \
# 0      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 1      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 2      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 3      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 4      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# ...                                                  ...
# 40499                                                NaN
# 40500                                                NaN
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
#
#                                        cme/description_y
# 0      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 1      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 2      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 3      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 4      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# ...                                                  ...
# 40499                                                NaN
# 40500                                                NaN
# 40501                                                NaN
# 40502                                                NaN
# 40503                                                NaN
#
# [40504 rows x 24 columns]

# %%
df = merged.dropna(subset=['MÃ BỆNH'])

# %%
df
# Out:
#       STT CHƯƠNG MÃ CHƯƠNG                                     TÊN NHÓM CHÍNH  \
# 0              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 1              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 2              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 3              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 4              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# ...          ...       ...                                                ...
# 37565        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 37566        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 37567        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 37568        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 37569        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
#
#       MÃ BỆNH                                          TÊN BỆNH  \
# 0         A00                                           Bệnh tả
# 1         A00                                           Bệnh tả
# 2         A00                                           Bệnh tả
# 3         A00                                           Bệnh tả
# 4         A00                                           Bệnh tả
# ...       ...                                               ...
# 37565   Z99.3                              Phụ thuộc vào xe lăn
# 37566   Z99.4                         Lệ thuộc vào tim nhân tạo
# 37567   Z99.8                                             Z99.8
# 37568   Z99.8                                             Z99.8
# 37569   Z99.9  Phụ thuộc vào thiết bị và dụng cụ không xác định
#
#                                             intruction_x icd_10  \
# 0                                                    NaN    NaN
# 1                                                    NaN    NaN
# 2                                                    NaN    NaN
# 3                                                    NaN    NaN
# 4                                                    NaN    NaN
# ...                                                  ...    ...
# 37565                                                NaN    NaN
# 37566                                                NaN    NaN
# 37567  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z99.8
# 37568  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z99.8
# 37569                                                NaN    NaN
#
#                                             icd_10/title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567      Phụ thuộc vào các máy và thiết bị hỗ trợ khác
# 37568  Phụ thuộc vào các máy và thiết bị hỗ trợ khác,...
# 37569                                                NaN
#
#                                               question_x  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567  Kỹ thuật ECMO (Oxy hóa máu qua màng ngoài cơ t...
# 37568  Những nhóm bệnh nhân nào có nguy cơ cao mắc nh...
# 37569                                                NaN
#
#                                                symptom_x  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                                                    NaN  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 37565                                                NaN  ...
# 37566                                                NaN  ...
# 37567  Các triệu chứng lâm sàng cho thấy bệnh nhân cầ...  ...
# 37568  Các bệnh nhân có nguy cơ cao mắc nhiễm khuẩn b...  ...
# 37569                                                NaN  ...
#
#                                        cme/description_x  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567  Khóa học này cung cấp kiến thức nền tảng về kỹ...
# 37568  Khóa học cung cấp kiến thức và kỹ năng về các ...
# 37569                                                NaN
#
#                                             intruction_y  \
# 0      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 1      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 2      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 3      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 4      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567                                                NaN
# 37568                                                NaN
# 37569                                                NaN
#
#                                               question_y icd10  \
# 0      Một bệnh nhân đến khám với triệu chứng tiêu ch...   A00
# 1      Làm thế nào để nhận biết và chẩn đoán bệnh tả ...   A00
# 2      Những xét nghiệm cận lâm sàng nào cần được thự...   A00
# 3      Nguyên tắc điều trị bệnh tả là gì, đặc biệt tr...   A00
# 4      Các biện pháp phòng ngừa và kiểm soát dịch bện...   A00
# ...                                                  ...   ...
# 37565                                                NaN   NaN
# 37566                                                NaN   NaN
# 37567                                                NaN   NaN
# 37568                                                NaN   NaN
# 37569                                                NaN   NaN
#
#                                                symptom_y  \
# 0      Bệnh nhân có khởi phát đột ngột tiêu chảy nhiề...
# 1      Bệnh nhân có tiêu chảy liên tục (>5 lần/giờ), ...
# 2      Bệnh nhân có triệu chứng lâm sàng nghi ngờ tả ...
# 3      Bệnh nhân được chẩn đoán xác định hoặc nghi ng...
# 4      Không có triệu chứng lâm sàng cụ thể của bệnh ...
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567                                                NaN
# 37568                                                NaN
# 37569                                                NaN
#
#                                              diagnosis_y  \
# 0      Nghi ngờ lâm sàng Bệnh tả (ICD-10 A00 - Choler...
# 1      Bệnh tả có mất nước nặng (ICD-10 A00.0 - Chole...
# 2      Xác định chẩn đoán Bệnh tả (ICD-10 A00) bằng p...
# 3      Nguyên tắc điều trị Bệnh tả (ICD-10 A00) bao g...
# 4      Các biện pháp phòng ngừa và kiểm soát Bệnh tả ...
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567                                                NaN
# 37568                                                NaN
# 37569                                                NaN
#
#                                         document/title_y  \
# 0      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 1      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 2      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 3      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 4      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567                                                NaN
# 37568                                                NaN
# 37569                                                NaN
#
#                                   document/description_y  \
# 0      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 1      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 2      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 3      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 4      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567                                                NaN
# 37568                                                NaN
# 37569                                                NaN
#
#                                              cme/title_y  \
# 0      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 1      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 2      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 3      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 4      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567                                                NaN
# 37568                                                NaN
# 37569                                                NaN
#
#                                        cme/description_y
# 0      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 1      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 2      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 3      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 4      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567                                                NaN
# 37568                                                NaN
# 37569                                                NaN
#
# [37570 rows x 24 columns]

# %%
df = merged.dropna(subset=['MÃ BỆNH'])

# %%
df
# Out:
#       STT CHƯƠNG MÃ CHƯƠNG                                     TÊN NHÓM CHÍNH  \
# 0              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 1              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 2              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 3              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 4              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# ...          ...       ...                                                ...
# 37565        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 37566        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 37567        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 37568        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 37569        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
#
#       MÃ BỆNH                                          TÊN BỆNH  \
# 0         A00                                           Bệnh tả
# 1         A00                                           Bệnh tả
# 2         A00                                           Bệnh tả
# 3         A00                                           Bệnh tả
# 4         A00                                           Bệnh tả
# ...       ...                                               ...
# 37565   Z99.3                              Phụ thuộc vào xe lăn
# 37566   Z99.4                         Lệ thuộc vào tim nhân tạo
# 37567   Z99.8                                             Z99.8
# 37568   Z99.8                                             Z99.8
# 37569   Z99.9  Phụ thuộc vào thiết bị và dụng cụ không xác định
#
#                                             intruction_x icd_10  \
# 0                                                    NaN    NaN
# 1                                                    NaN    NaN
# 2                                                    NaN    NaN
# 3                                                    NaN    NaN
# 4                                                    NaN    NaN
# ...                                                  ...    ...
# 37565                                                NaN    NaN
# 37566                                                NaN    NaN
# 37567  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z99.8
# 37568  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z99.8
# 37569                                                NaN    NaN
#
#                                             icd_10/title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567      Phụ thuộc vào các máy và thiết bị hỗ trợ khác
# 37568  Phụ thuộc vào các máy và thiết bị hỗ trợ khác,...
# 37569                                                NaN
#
#                                               question_x  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567  Kỹ thuật ECMO (Oxy hóa máu qua màng ngoài cơ t...
# 37568  Những nhóm bệnh nhân nào có nguy cơ cao mắc nh...
# 37569                                                NaN
#
#                                                symptom_x  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                                                    NaN  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 37565                                                NaN  ...
# 37566                                                NaN  ...
# 37567  Các triệu chứng lâm sàng cho thấy bệnh nhân cầ...  ...
# 37568  Các bệnh nhân có nguy cơ cao mắc nhiễm khuẩn b...  ...
# 37569                                                NaN  ...
#
#                                        cme/description_x  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567  Khóa học này cung cấp kiến thức nền tảng về kỹ...
# 37568  Khóa học cung cấp kiến thức và kỹ năng về các ...
# 37569                                                NaN
#
#                                             intruction_y  \
# 0      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 1      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 2      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 3      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 4      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567                                                NaN
# 37568                                                NaN
# 37569                                                NaN
#
#                                               question_y icd10  \
# 0      Một bệnh nhân đến khám với triệu chứng tiêu ch...   A00
# 1      Làm thế nào để nhận biết và chẩn đoán bệnh tả ...   A00
# 2      Những xét nghiệm cận lâm sàng nào cần được thự...   A00
# 3      Nguyên tắc điều trị bệnh tả là gì, đặc biệt tr...   A00
# 4      Các biện pháp phòng ngừa và kiểm soát dịch bện...   A00
# ...                                                  ...   ...
# 37565                                                NaN   NaN
# 37566                                                NaN   NaN
# 37567                                                NaN   NaN
# 37568                                                NaN   NaN
# 37569                                                NaN   NaN
#
#                                                symptom_y  \
# 0      Bệnh nhân có khởi phát đột ngột tiêu chảy nhiề...
# 1      Bệnh nhân có tiêu chảy liên tục (>5 lần/giờ), ...
# 2      Bệnh nhân có triệu chứng lâm sàng nghi ngờ tả ...
# 3      Bệnh nhân được chẩn đoán xác định hoặc nghi ng...
# 4      Không có triệu chứng lâm sàng cụ thể của bệnh ...
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567                                                NaN
# 37568                                                NaN
# 37569                                                NaN
#
#                                              diagnosis_y  \
# 0      Nghi ngờ lâm sàng Bệnh tả (ICD-10 A00 - Choler...
# 1      Bệnh tả có mất nước nặng (ICD-10 A00.0 - Chole...
# 2      Xác định chẩn đoán Bệnh tả (ICD-10 A00) bằng p...
# 3      Nguyên tắc điều trị Bệnh tả (ICD-10 A00) bao g...
# 4      Các biện pháp phòng ngừa và kiểm soát Bệnh tả ...
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567                                                NaN
# 37568                                                NaN
# 37569                                                NaN
#
#                                         document/title_y  \
# 0      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 1      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 2      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 3      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 4      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567                                                NaN
# 37568                                                NaN
# 37569                                                NaN
#
#                                   document/description_y  \
# 0      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 1      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 2      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 3      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 4      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567                                                NaN
# 37568                                                NaN
# 37569                                                NaN
#
#                                              cme/title_y  \
# 0      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 1      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 2      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 3      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 4      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567                                                NaN
# 37568                                                NaN
# 37569                                                NaN
#
#                                        cme/description_y
# 0      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 1      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 2      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 3      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 4      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# ...                                                  ...
# 37565                                                NaN
# 37566                                                NaN
# 37567                                                NaN
# 37568                                                NaN
# 37569                                                NaN
#
# [37570 rows x 24 columns]

# %%
# df = df[df.isna().any(axis=1)]
df_missing = df[df['icd10'].isna() & df['icd_10'].isna()]

# %%
df.to_excel("SVYKHOA_dataset_diagnosis_cleaned.xlsx", index=False)

# %%
df_missing
# Out:
#       STT CHƯƠNG MÃ CHƯƠNG                                     TÊN NHÓM CHÍNH  \
# 1244           I   A00-B99                              Bệnh nhiễm khuẩn khác
# 1245           I   A00-B99                              Bệnh nhiễm khuẩn khác
# 1246           I   A00-B99                              Bệnh nhiễm khuẩn khác
# 1247           I   A00-B99                              Bệnh nhiễm khuẩn khác
# 1248           I   A00-B99                              Bệnh nhiễm khuẩn khác
# ...          ...       ...                                                ...
# 36581        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36582        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36593        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36594        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36597        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
#
#       MÃ BỆNH                                           TÊN BỆNH intruction_x  \
# 1244      A38                               Bệnh tinh hồng nhiệt          NaN
# 1245      A39                          Nhiễm trùng do não mô cầu          NaN
# 1246   A39.0†                 Viêm màng não do não mô cầu (G01*)          NaN
# 1247   A39.1†         Hội chứng Waterhouse-Friderichsen (E35.1*)          NaN
# 1248    A39.2              Nhiễm khuẩn huyết não mô cầu cấp tính          NaN
# ...       ...                                                ...          ...
# 36581     Z99  Tình trạng phụ thuộc vào các thiết bị và dụng ...          NaN
# 36582   Z99.0                                  Phụ thuộc máy hút          NaN
# 36593   Z99.3                               Phụ thuộc vào xe lăn          NaN
# 36594   Z99.4                          Lệ thuộc vào tim nhân tạo          NaN
# 36597   Z99.9   Phụ thuộc vào thiết bị và dụng cụ không xác định          NaN
#
#       icd_10 icd_10/title question_x symptom_x  ... cme/description_x  \
# 1244     NaN          NaN        NaN       NaN  ...               NaN
# 1245     NaN          NaN        NaN       NaN  ...               NaN
# 1246     NaN          NaN        NaN       NaN  ...               NaN
# 1247     NaN          NaN        NaN       NaN  ...               NaN
# 1248     NaN          NaN        NaN       NaN  ...               NaN
# ...      ...          ...        ...       ...  ...               ...
# 36581    NaN          NaN        NaN       NaN  ...               NaN
# 36582    NaN          NaN        NaN       NaN  ...               NaN
# 36593    NaN          NaN        NaN       NaN  ...               NaN
# 36594    NaN          NaN        NaN       NaN  ...               NaN
# 36597    NaN          NaN        NaN       NaN  ...               NaN
#
#       intruction_y question_y icd10 symptom_y diagnosis_y document/title_y  \
# 1244           NaN        NaN   NaN       NaN         NaN              NaN
# 1245           NaN        NaN   NaN       NaN         NaN              NaN
# 1246           NaN        NaN   NaN       NaN         NaN              NaN
# 1247           NaN        NaN   NaN       NaN         NaN              NaN
# 1248           NaN        NaN   NaN       NaN         NaN              NaN
# ...            ...        ...   ...       ...         ...              ...
# 36581          NaN        NaN   NaN       NaN         NaN              NaN
# 36582          NaN        NaN   NaN       NaN         NaN              NaN
# 36593          NaN        NaN   NaN       NaN         NaN              NaN
# 36594          NaN        NaN   NaN       NaN         NaN              NaN
# 36597          NaN        NaN   NaN       NaN         NaN              NaN
#
#       document/description_y cme/title_y cme/description_y
# 1244                     NaN         NaN               NaN
# 1245                     NaN         NaN               NaN
# 1246                     NaN         NaN               NaN
# 1247                     NaN         NaN               NaN
# 1248                     NaN         NaN               NaN
# ...                      ...         ...               ...
# 36581                    NaN         NaN               NaN
# 36582                    NaN         NaN               NaN
# 36593                    NaN         NaN               NaN
# 36594                    NaN         NaN               NaN
# 36597                    NaN         NaN               NaN
#
# [8518 rows x 24 columns]

# %%
import pandas as pd
import google.generativeai as genai
import time
import os
from tqdm import tqdm
import json
# Cấu hình API Key
genai.configure(api_key="AIzaSyBwVaHGxXZpSXgOz7GFcQKXZ72HeOwsKlc")  # <-- Nhớ điền API key ở đây

# Khởi tạo model
model = genai.GenerativeModel(model_name='models/gemini-2.5-flash')

# File input và output
input_file = "SVYKHOA_dataset_diagnosis_cleaned.xlsx"
output_file = "gen_SVYKHOA_dataset_diagnosis.xlsx"

# Đọc dữ liệu đầu vào
try:
    df_input = pd.read_excel(input_file)
    df_input = df_input[['TÊN NHÓM CHÍNH','MÃ BỆNH','TÊN BỆNH']].dropna().reset_index(drop=True)
    print(f"Đã đọc file Excel với {len(df_input)} dòng văn bản.")
except Exception as e:
    print(f"Lỗi khi đọc file Excel: {str(e)}")
    exit()

# Tạo DataFrame kết quả
result_columns = [
    "intruction", "question", "symptom", "diagnosis",
    "document/title",  "document/description",
    "cme/title", "cme/description"
]
if os.path.exists(output_file):
    df_result = pd.read_excel(output_file)
else:
    df_result = pd.DataFrame(columns=result_columns)

# Prompt Template mới
prompt_template = """
Bạn là một chuyên gia y tế chuyên về y khoa. Nhiệm vụ của bạn là tạo dữ liệu huấn luyện dành cho một **chatbot y khoa chuyên về y khoa** nhằm giúp chatbot phản hồi người dùng một cách chính xác, khoa học và đáng tin cậy theo chuẩn ICD-10 của Bộ Y tế Việt Nam.
Dựa vào các thông tin sau:
- TÊN NHÓM CHÍNH: {group_name}
- MÃ BỆNH: {disease_code}
- TÊN BỆNH: {disease_name}
Biết: 
- Tên nhóm chính là nhóm bệnh đại diện cho mã icd10 và loại bệnh đấy
- Mã bệnh là mã icd10 chính xác cho loại bệnh đấy
- Tên bệnh là tên bệnh chính xác cho loại bệnh đấy
Hãy sinh ra một **DANH SÁCH GỒM 5 ĐỐI TƯỢNG JSON** chứa đầy đủ TẤT CẢ các trường dưới đây. Tuyệt đối không được bỏ trống bất kỳ trường nào. Nếu đoạn văn không nêu rõ thông tin, bạn được phép **bổ sung hợp lý dựa trên kiến thức y khoa chính thống**, nhưng KHÔNG được bịa đặt hoặc sử dụng thông tin sai sự thật.
**Mục tiêu**: Dữ liệu được tạo ra sẽ được dùng để huấn luyện một **mô hình chatbot y tế**, vì vậy tất cả thông tin cần:
- Chính xác về mặt y học.
- Bám sát nội dung đoạn văn hoặc kiến thức y khoa phổ biến đã được xác thực (ví dụ: WHO, Bộ Y tế, giáo trình nha khoa).
- Có giá trị hướng dẫn, giải thích rõ ràng, có thể dùng để **tư vấn lâm sàng cho người dùng cuối**.
**Yêu cầu đặc biệt**:
- Nếu đoạn văn có đề cập đến các **chỉ số lâm sàng** như độ sâu túi lợi, chỉ số mảng bám, số răng tổn thương, mức độ đau... thì **phải đưa các con số và dữ liệu đó vào `symptom` và `diagnosis`** để tăng độ chính xác cho chatbot.
- `symptom` và `diagnosis` phải viết theo ngôn ngữ chuyên môn, **khoa học, cụ thể, không chung chung**, đủ để một bác sĩ hoặc chatbot sử dụng để diễn giải cho người bệnh.
Các trường cần điền:
- "intruction": Mô tả ngắn gọn về nhiệm vụ của chatbot, ví dụ: "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10."
- "question": Một câu hỏi y khoa phù hợp với **nội dung bài viết và câu trả lời**, tập trung vào chẩn đoán hoặc điều trị y khoa (giống như người dùng hay bác sỹ trẻ hỏi chatbot).
- "symptom": Các triệu chứng hoặc dấu hiệu lâm sàng được nêu trong bài, hoặc suy luận có cơ sở khoa học. **Bao gồm cả các chỉ số định lượng nếu có** như: túi nha chu 6mm, PI=2.2, v.v.
- "diagnosis": Chẩn đoán nha khoa chi tiết, có thể phân loại theo mức độ bệnh hoặc giai đoạn nếu phù hợp. **Phải có cơ sở y khoa vững chắc** và dùng thông số hỗ trợ chẩn đoán nếu có.
- "document/title": Tiêu đề tài liệu y khoa liên quan đến nội dung đoạn văn.
- "document/description": Mô tả ngắn gọn tài liệu tham khảo, nêu rõ mục đích hoặc giá trị ứng dụng.
- "cme/title": Tiêu đề khóa học đào tạo y khoa liên tục (CME) liên quan đến chủ đề trong đoạn văn.
- "cme/description": Mô tả ngắn về khóa học CME, giúp chatbot hiểu và phản hồi như một trợ lý học thuật chuyên ngành.
Lưu ý:- Chỉ xuất đầu ra dưới dạng đối tượng JSON hợp lệ. KHÔNG thêm bất kỳ mô tả, lời giải thích hoặc đoạn văn nào khác bên ngoài JSON.
      - Không được bổ trống bất kỳ trường nào trong đối tượng JSON.
"""



# Hàm sinh dữ liệu
def generate_with_retry(prompt, max_retries=3):
    for attempt in range(max_retries):
        try:
            response = model.generate_content(prompt)
            if response.text:
                return response
        except Exception as e:
            if attempt < max_retries - 1:
                wait_time = (attempt + 1) * 5
                print(f"Lỗi, thử lại sau {wait_time}s... (Lần {attempt + 1})")
                time.sleep(wait_time)
            else:
                print(f"Lỗi sau {max_retries} lần thử: {str(e)}")
                return None
    return None

# Hàm xử lý và lưu
def process_and_save(response, disease_code):
    try:
        cleaned = response.text.replace('```json', '').replace('```', '').strip()
        data_list = json.loads(cleaned)

        if not isinstance(data_list, list):
            raise ValueError("Kết quả không phải là danh sách JSON.")

        global df_result
        for data in data_list:
            new_row = {
                "intruction": data.get("intruction", ""),
                "question": data.get("question", ""),
                "icd10": disease_code,
                "symptom": data.get("symptom", ""),
                "diagnosis": data.get("diagnosis", ""),
                "document/title": data.get("document/title", ""),
                "document/description": data.get("document/description", ""),
                "cme/title": data.get("cme/title", ""),
                "cme/description": data.get("cme/description", "")
            }
            df_result.loc[len(df_result)] = new_row
        return True
    except Exception as e:
        print(f"\nLỗi xử lý response: {str(e)}")
        print(f"Response gốc: {response.text[:200]}...")
        return False

# Thiết lập số dòng xử lý
start_row = len(df_result)
end_row = len(df_input)
processed_count = 0
start_time = time.time()

# Vòng lặp xử lý
for index in tqdm(range(start_row, end_row)):
    row = df_input.iloc[index]
    retries = 0

    while retries < 3:
        try:
            group_name = row['TÊN NHÓM CHÍNH'].strip()
            disease_code = row['MÃ BỆNH'].strip()
            disease_name = row['TÊN BỆNH'].strip()
            prompt = prompt_template.format(
                group_name=group_name,
                disease_code=disease_code,
                disease_name=disease_name
            )
            response = generate_with_retry(prompt)

            if response and process_and_save(response, disease_code):
                processed_count += 1
                df_result.to_excel(output_file, index=False)
                time.sleep(2)
                break
            else:
                retries += 1
                print(f"Retry dòng {index} - Lần {retries}")
                time.sleep(3)

        except Exception as e:
            print(f"\nLỗi dòng {index}: {str(e)}")
            retries += 1
            time.sleep(3)

# Lưu cuốil
df_result.to_excel(output_file, index=False)
total_time = (time.time() - start_time) / 60
print(f"\nHoàn thành! Đã xử lý {processed_count} dòng.")
print(f"Thời gian chạy: {total_time:.2f} phút")
print(f"File kết quả: {output_file}")
# Out:
# Đã đọc file Excel với 10214 dòng văn bản.
#   0%|          | 0/1813 [00:00<?, ?it/s]
# Lỗi xử lý response: Invalid control character at: line 15 column 88 (char 2219)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "Xin chào, mắt tôi bị dính hóa chất tẩy rửa. Mắt tôi rất đau,...
# Retry dòng 8401 - Lần 1
#
# Lỗi xử lý response: Invalid control character at: line 46 column 279 (char 9580)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "Xin hỏi về các triệu chứng và chẩn đoán ban đầu của tình trạ...
# Retry dòng 8401 - Lần 2
#   0%|          | 5/1813 [07:04<40:44:29, 81.12s/it]
# Lỗi xử lý response: Invalid control character at: line 26 column 295 (char 5490)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "Triệu chứng ban đầu của ăn mòn thanh quản, khí quản và phổi ...
# Retry dòng 8406 - Lần 1
#   2%|▏         | 41/1813 [57:06<38:30:33, 78.24s/it]
# Lỗi xử lý response: Invalid control character at: line 45 column 70 (char 8465)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "Những dấu hiệu lâm sàng nào đặc trưng cho ăn mòn tổn thương ...
# Retry dòng 8442 - Lần 1
#   4%|▍         | 75/1813 [1:33:20<22:19:01, 46.23s/it]
# Lỗi xử lý response: Invalid control character at: line 45 column 30 (char 6841)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "Các dấu hiệu và triệu chứng ban đầu của tổn thương do cóng l...
# Retry dòng 8476 - Lần 1
#   9%|▉         | 159/1813 [2:58:10<28:56:03, 62.98s/it]
# Lỗi xử lý response: Illegal trailing comma before end of object: line 10 column 205 (char 2097)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "Các triệu chứng lâm sàng thường gặp của ngộ độc enzyme (T45....
# Retry dòng 8560 - Lần 1
#  12%|█▏        | 221/1813 [4:00:58<21:02:06, 47.57s/it]
# Lỗi xử lý response: Invalid control character at: line 26 column 545 (char 6468)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "Tôi có các triệu chứng như đau đầu, chóng mặt sau khi làm vi...
# Retry dòng 8622 - Lần 1
#  13%|█▎        | 229/1813 [4:08:22<21:22:07, 48.57s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
#  13%|█▎        | 231/1813 [4:10:12<22:35:10, 51.40s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 5.577713011s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 5
# }
# ]
# Retry dòng 8632 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 47.266136315s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Retry dòng 8632 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 28.974691492s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
# Retry dòng 8632 - Lần 3
#  13%|█▎        | 232/1813 [4:11:07<23:03:24, 52.50s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 10.676664123s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 10
# }
# ]
# Retry dòng 8633 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
#  13%|█▎        | 235/1813 [4:14:04<24:54:24, 56.82s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 13.606810126s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 13
# }
# ]
# Retry dòng 8636 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 55.302417745s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Retry dòng 8636 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 36.014058454s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# Retry dòng 8636 - Lần 3
#  13%|█▎        | 236/1813 [4:15:00<24:47:14, 56.58s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
#  13%|█▎        | 237/1813 [4:16:10<26:30:38, 60.56s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
#  13%|█▎        | 238/1813 [4:16:57<24:41:02, 56.42s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 20.453891261s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 20
# }
# ]
# Retry dòng 8639 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 1.931901383s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
# Retry dòng 8639 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 43.647814488s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# Retry dòng 8639 - Lần 3
#  13%|█▎        | 239/1813 [4:17:52<24:35:02, 56.23s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 25.365263569s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
# Retry dòng 8640 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 7.101334013s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 7
# }
# ]
# Retry dòng 8640 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 48.613001404s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 48
# }
# ]
# Retry dòng 8640 - Lần 3
#  13%|█▎        | 240/1813 [4:18:48<24:25:45, 55.91s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
#  13%|█▎        | 241/1813 [4:20:45<32:24:34, 74.22s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 33.061697267s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]
# Retry dòng 8642 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 14.771507485s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 14
# }
# ]
# Retry dòng 8642 - Lần 2
#  13%|█▎        | 242/1813 [4:22:10<33:47:28, 77.43s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
#  13%|█▎        | 243/1813 [4:22:56<29:47:00, 68.29s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 20.902642651s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 20
# }
# ]
# Retry dòng 8644 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 2.061468505s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 2
# }
# ]
# Retry dòng 8644 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
#  14%|█▎        | 245/1813 [4:26:01<33:28:23, 76.85s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 16.003513722s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 16
# }
# ]
# Retry dòng 8646 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 57.18927902s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 57
# }
# ]
# Retry dòng 8646 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 38.379883492s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 38
# }
# ]
# Retry dòng 8646 - Lần 3
#  14%|█▎        | 246/1813 [4:26:58<30:47:55, 70.76s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
#  14%|█▎        | 247/1813 [4:27:48<28:07:48, 64.67s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 29.525405405s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# Retry dòng 8648 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 11.237612226s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 11
# }
# ]
# Retry dòng 8648 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 52.942397563s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Retry dòng 8648 - Lần 3
#  14%|█▎        | 248/1813 [4:28:43<26:50:24, 61.74s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 34.649947867s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 34
# }
# ]
# Retry dòng 8649 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 16.361463341s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 16
# }
# ]
# Retry dòng 8649 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 57.720999063s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 57
# }
# ]
# Retry dòng 8649 - Lần 3
#  14%|█▎        | 249/1813 [4:29:38<25:58:57, 59.81s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 38.918398816s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 38
# }
# ]
# Retry dòng 8650 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 20.080886145s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 20
# }
# ]
# Retry dòng 8650 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 1.248381973s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
# Retry dòng 8650 - Lần 3
#  14%|█▍        | 250/1813 [4:30:35<25:31:19, 58.78s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 42.971032588s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# Retry dòng 8651 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 24.672661438s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# Retry dòng 8651 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 6.388509084s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 6
# }
# ]
# Retry dòng 8651 - Lần 3
#  14%|█▍        | 251/1813 [4:31:30<24:59:45, 57.61s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 48.057550559s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 48
# }
# ]
# Retry dòng 8652 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 29.77914348s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# Retry dòng 8652 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 11.490813634s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 11
# }
# ]
# Retry dòng 8652 - Lần 3
#  14%|█▍        | 252/1813 [4:32:25<24:37:33, 56.79s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 53.082319889s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# Retry dòng 8653 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 34.21869545s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 34
# }
# ]
# Retry dòng 8653 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 15.408861468s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 15
# }
# ]
# Retry dòng 8653 - Lần 3
#  14%|█▍        | 253/1813 [4:33:21<24:31:40, 56.60s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 56.616634858s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 56
# }
# ]
# Retry dòng 8654 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 37.815523385s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# Retry dòng 8654 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 19.288926773s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 19
# }
# ]
# Retry dòng 8654 - Lần 3
#  14%|█▍        | 254/1813 [4:34:17<24:26:24, 56.44s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 1.023279331s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
# Retry dòng 8655 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 42.748005629s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# Retry dòng 8655 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 24.461658711s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# Retry dòng 8655 - Lần 3
#  14%|█▍        | 255/1813 [4:35:12<24:12:54, 55.95s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 6.176504904s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 6
# }
# ]
# Retry dòng 8656 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 47.895619894s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Retry dòng 8656 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 29.60794427s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# Retry dòng 8656 - Lần 3
#  14%|█▍        | 256/1813 [4:36:07<24:03:25, 55.62s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 10.958482233s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 10
# }
# ]
# Retry dòng 8657 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# ...
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 50
# }
# ]
# Retry dòng 8701 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 31.561071887s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 31
# }
# ]
# Retry dòng 8701 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 12.843198751s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 12
# }
# ]
# Retry dòng 8701 - Lần 3
#  17%|█▋        | 301/1813 [5:18:23<23:22:25, 55.65s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 54.571329541s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
# Retry dòng 8702 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 36.297237129s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# Retry dòng 8702 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 18.035799877s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 18
# }
# ]
# Retry dòng 8702 - Lần 3
#  17%|█▋        | 302/1813 [5:19:18<23:15:08, 55.40s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 59.736309566s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 59
# }
# ]
# Retry dòng 8703 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 41.474302758s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# Retry dòng 8703 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 23.207736381s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 23
# }
# ]
# Retry dòng 8703 - Lần 3
#  17%|█▋        | 303/1813 [5:20:13<23:09:53, 55.23s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 4.557013788s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
# Retry dòng 8704 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 45.739512785s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Retry dòng 8704 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 27.160505435s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 27
# }
# ]
# Retry dòng 8704 - Lần 3
#  17%|█▋        | 304/1813 [5:21:09<23:15:09, 55.47s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
#  17%|█▋        | 304/1813 [5:21:14<26:34:35, 63.40s/it]
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[171], line 75, in generate_with_retry(prompt, max_retries)
#      74 try:
# ---> 75     response = model.generate_content(prompt)
#      76     if response.text:
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     330 else:
# --> 331     response = self._client.generate_content(
#     332         request,
#     333         **request_options,
#     334     )
#     335     return generation_types.GenerateContentResponse.from_response(response)
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146 try:
# --> 147     result = target()
#     148     if inspect.isawaitable(result):
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 24.068402638s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[171], line 138
#     132 disease_name = row['TÊN BỆNH'].strip()
#     133 prompt = prompt_template.format(
#     134     group_name=group_name,
#     135     disease_code=disease_code,
#     136     disease_name=disease_name
#     137 )
# --> 138 response = generate_with_retry(prompt)
#     140 if response and process_and_save(response, disease_code):
#     141     processed_count += 1
#
# Cell In[171], line 82, in generate_with_retry(prompt, max_retries)
#      80     wait_time = (attempt + 1) * 5
#      81     print(f"Lỗi, thử lại sau {wait_time}s... (Lần {attempt + 1})")
# ---> 82     time.sleep(wait_time)
#      83 else:
#      84     print(f"Lỗi sau {max_retries} lần thử: {str(e)}")
#
# KeyboardInterrupt:
