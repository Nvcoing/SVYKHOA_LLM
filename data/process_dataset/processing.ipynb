# %% [markdown]
# ### diagnosis icd 10

# %%
import pandas as pd
df = pd.read_excel("../generate_dataset/SVYKHOA_dataset_diagnosis.xlsx")
df
# Out:
#                                               intruction icd_10  \
# 0      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 1      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 2      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 3      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 4      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# ...                                                  ...    ...
# 20645  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  D76.3
# 20646  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  D76.3
# 20647                                                NaN  D76.3
# 20648                                                NaN  D76.3
# 20649                                                NaN  D76.3
#
#                                      icd_10/title  \
# 0      Tiểu không kiểm soát do gắng sức ở nữ giới
# 1      Tiểu không kiểm soát do gắng sức ở nữ giới
# 2      Tiểu không kiểm soát do gắng sức ở nữ giới
# 3                     Són tiểu gắng sức ở nữ giới
# 4                     Són tiểu gắng sức ở nữ giới
# ...                                           ...
# 20645                   Các hội chứng mô bào khác
# 20646                   Các hội chứng mô bào khác
# 20647                   Các hội chứng mô bào khác
# 20648                   Các hội chứng mô bào khác
# 20649                   Các hội chứng mô bào khác
#
#                                                 question  \
# 0      Các triệu chứng điển hình của tiểu không kiểm ...
# 1      Những chỉ định lâm sàng nào cho phẫu thuật TOT...
# 2      Tiểu không kiểm soát là gì, tần suất mắc bệnh ...
# 3      Són tiểu gắng sức ở nữ giới là gì và phẫu thuậ...
# 4      Những chỉ định và chống chỉ định cụ thể cho ph...
# ...                                                  ...
# 20645  Đặc điểm mô bệnh học và các dấu ấn hóa mô miễn...
# 20646  Bệnh Rosai-Dorfman nguyên phát của da thường đ...
# 20647  Làm thế nào để chẩn đoán bệnh Rosai-Dorfman ng...
# 20648  Bệnh Rosai-Dorfman nguyên phát ở da khác biệt ...
# 20649  Sau khi chẩn đoán bệnh Rosai-Dorfman nguyên ph...
#
#                                                  symptom  \
# 0      Các triệu chứng và dấu hiệu lâm sàng bao gồm: ...
# 1      Các triệu chứng gợi ý chỉ định phẫu thuật TOT ...
# 2      Tiểu không kiểm soát, theo định nghĩa của Hiệp...
# 3      Bệnh nhân có biểu hiện rò rỉ nước tiểu không c...
# 4      Bệnh nhân đã được chẩn đoán xác nhận mắc són t...
# ...                                                  ...
# 20645  Bệnh nhân nam, 54 tuổi, có tổn thương nốt đỏ b...
# 20646  Bệnh nhân nam 54 tuổi với tổn thương dạng nốt ...
# 20647  Tổn thương da (nốt, mảng, sẩn) ảnh hưởng lớp b...
# 20648  Đối với Rosai-Dorfman nguyên phát ở da: tuổi t...
# 20649  Bệnh nhân có tổn thương da dạng nốt, mảng hoặc...
#
#                                                diagnosis  \
# 0      Chẩn đoán tiểu không kiểm soát do gắng sức ở n...
# 1      Chỉ định phẫu thuật TOT được cân nhắc cho nhữn...
# 2      Tiểu không kiểm soát do gắng sức là một tình t...
# 3      Chẩn đoán són tiểu gắng sức ở nữ giới (ICD-10:...
# 4      Chẩn đoán són tiểu gắng sức (ICD-10: N39.3) là...
# ...                                                  ...
# 20645  Chẩn đoán bệnh Rosai-Dorfman nguyên phát của d...
# 20646  Sau khi chẩn đoán xác định bệnh Rosai-Dorfman ...
# 20647  Chẩn đoán xác định bệnh Rosai-Dorfman nguyên p...
# 20648  Bệnh Rosai-Dorfman nguyên phát ở da được phân ...
# 20649  Chẩn đoán bệnh Rosai-Dorfman nguyên phát ở da ...
#
#                                           document/title  \
# 0      Hướng dẫn chẩn đoán và quản lý tiểu không kiểm...
# 1      Nghiên cứu về chỉ định phẫu thuật TOT trong đi...
# 2      Dịch tễ học và tác động của tiểu không kiểm so...
# 3      Nghiên cứu về chỉ định phẫu thuật TOT điều trị...
# 4      Chỉ định phẫu thuật TOT trong điều trị són tiể...
# ...                                                  ...
# 20645  BỆNH ROSAI -DORFMAN NGUYÊN PHÁT CỦA DA VÙNG LƯ...
# 20646  BỆNH ROSAI -DORFMAN NGUYÊN PHÁT CỦA DA VÙNG LƯ...
# 20647  Đặc điểm mô bệnh học và hóa mô miễn dịch trong...
# 20648  Phân loại và đặc điểm dịch tễ, lâm sàng của cá...
# 20649  Kết quả điều trị phẫu thuật và tiên lượng bệnh...
#
#                                     document/description  \
# 0      Tài liệu này cung cấp các tiêu chí chẩn đoán t...
# 1      Tài liệu này trình bày các phát hiện từ một ng...
# 2      Tài liệu này nghiên cứu sâu về định nghĩa, phạ...
# 3      Tài liệu này trình bày kết quả của một nghiên ...
# 4      Tài liệu này tổng hợp các hướng dẫn lâm sàng v...
# ...                                                  ...
# 20645  Bài báo cáo trường hợp lâm sàng về bệnh Rosai-...
# 20646  Báo cáo trường hợp lâm sàng minh họa một ca bệ...
# 20647  Tài liệu này trình bày chi tiết các tiêu chí c...
# 20648  Tài liệu này phân tích sự khác biệt về dịch tễ...
# 20649  Bài báo mô tả trường hợp bệnh Rosai-Dorfman ng...
#
#                                                cme/title  \
# 0      Cập nhật chẩn đoán phân biệt và nguyên nhân gâ...
# 1      Kỹ thuật phẫu thuật TOT và quản lý biến chứng ...
# 2      Phân tích gánh nặng bệnh tật và tác động tâm l...
# 3      Cập nhật chẩn đoán và điều trị són tiểu gắng s...
# 4      Phẫu thuật nâng đỡ niệu đạo giữa: Kỹ thuật TOT...
# ...                                                  ...
# 20645  Ứng dụng hóa mô miễn dịch trong chẩn đoán phân...
# 20646  Tiếp cận điều trị và tiên lượng các thể bệnh R...
# 20647  Tiếp cận chẩn đoán mô bệnh học và hóa mô miễn ...
# 20648  Cập nhật phân loại và chiến lược chẩn đoán phâ...
# 20649  Quản lý điều trị và theo dõi dài hạn bệnh Rosa...
#
#                                          cme/description
# 0      Khóa học đào tạo y khoa liên tục này nhằm nâng...
# 1      Khóa học này cung cấp kiến thức chuyên sâu về ...
# 2      Khóa học này tập trung vào việc đánh giá gánh ...
# 3      Khóa học CME này cung cấp kiến thức toàn diện ...
# 4      Khóa học này tập trung chuyên sâu vào kỹ thuật...
# ...                                                  ...
# 20645  Khóa học này cung cấp cái nhìn tổng quan và ch...
# 20646  Khóa học này khám phá các phương pháp điều trị...
# 20647  Khóa học đào tạo y khoa liên tục này cung cấp ...
# 20648  Khóa học cung cấp cái nhìn tổng quan về hệ thố...
# 20649  Khóa học này tập trung vào các lựa chọn điều t...
#
# [20650 rows x 10 columns]

# %%
# đếm số NaN
nan_count = df['intruction'].isna().sum()
print("Số NaN:", nan_count)

# đếm số chuỗi rỗng ''
empty_str_count = (df['intruction'] == '').sum()
print("Số chuỗi rỗng:", empty_str_count)

# tổng cộng giá trị rỗng
total_missing = nan_count + empty_str_count
print("Tổng số giá trị rỗng:", total_missing)
# Out:
# Số NaN: 1105
# Số chuỗi rỗng: 0
# Tổng số giá trị rỗng: 1105

# %%
most_common = df['intruction'].value_counts().idxmax()
count = df['intruction'].value_counts().max()

print("Giá trị xuất hiện nhiều nhất:", most_common)
print("Số lần xuất hiện:", count)
# Out:
# Giá trị xuất hiện nhiều nhất: Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.
# Số lần xuất hiện: 16740

# %%
# thay NaN và chuỗi rỗng bằng most_common
df['intruction'] = df['intruction'].fillna(most_common)

# %%
df_diagnosis = df
df_diagnosis
# Out:
#                                               intruction icd_10  \
# 0      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 1      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 2      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 3      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 4      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# ...                                                  ...    ...
# 20645  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  D76.3
# 20646  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  D76.3
# 20647  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  D76.3
# 20648  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  D76.3
# 20649  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  D76.3
#
#                                      icd_10/title  \
# 0      Tiểu không kiểm soát do gắng sức ở nữ giới
# 1      Tiểu không kiểm soát do gắng sức ở nữ giới
# 2      Tiểu không kiểm soát do gắng sức ở nữ giới
# 3                     Són tiểu gắng sức ở nữ giới
# 4                     Són tiểu gắng sức ở nữ giới
# ...                                           ...
# 20645                   Các hội chứng mô bào khác
# 20646                   Các hội chứng mô bào khác
# 20647                   Các hội chứng mô bào khác
# 20648                   Các hội chứng mô bào khác
# 20649                   Các hội chứng mô bào khác
#
#                                                 question  \
# 0      Các triệu chứng điển hình của tiểu không kiểm ...
# 1      Những chỉ định lâm sàng nào cho phẫu thuật TOT...
# 2      Tiểu không kiểm soát là gì, tần suất mắc bệnh ...
# 3      Són tiểu gắng sức ở nữ giới là gì và phẫu thuậ...
# 4      Những chỉ định và chống chỉ định cụ thể cho ph...
# ...                                                  ...
# 20645  Đặc điểm mô bệnh học và các dấu ấn hóa mô miễn...
# 20646  Bệnh Rosai-Dorfman nguyên phát của da thường đ...
# 20647  Làm thế nào để chẩn đoán bệnh Rosai-Dorfman ng...
# 20648  Bệnh Rosai-Dorfman nguyên phát ở da khác biệt ...
# 20649  Sau khi chẩn đoán bệnh Rosai-Dorfman nguyên ph...
#
#                                                  symptom  \
# 0      Các triệu chứng và dấu hiệu lâm sàng bao gồm: ...
# 1      Các triệu chứng gợi ý chỉ định phẫu thuật TOT ...
# 2      Tiểu không kiểm soát, theo định nghĩa của Hiệp...
# 3      Bệnh nhân có biểu hiện rò rỉ nước tiểu không c...
# 4      Bệnh nhân đã được chẩn đoán xác nhận mắc són t...
# ...                                                  ...
# 20645  Bệnh nhân nam, 54 tuổi, có tổn thương nốt đỏ b...
# 20646  Bệnh nhân nam 54 tuổi với tổn thương dạng nốt ...
# 20647  Tổn thương da (nốt, mảng, sẩn) ảnh hưởng lớp b...
# 20648  Đối với Rosai-Dorfman nguyên phát ở da: tuổi t...
# 20649  Bệnh nhân có tổn thương da dạng nốt, mảng hoặc...
#
#                                                diagnosis  \
# 0      Chẩn đoán tiểu không kiểm soát do gắng sức ở n...
# 1      Chỉ định phẫu thuật TOT được cân nhắc cho nhữn...
# 2      Tiểu không kiểm soát do gắng sức là một tình t...
# 3      Chẩn đoán són tiểu gắng sức ở nữ giới (ICD-10:...
# 4      Chẩn đoán són tiểu gắng sức (ICD-10: N39.3) là...
# ...                                                  ...
# 20645  Chẩn đoán bệnh Rosai-Dorfman nguyên phát của d...
# 20646  Sau khi chẩn đoán xác định bệnh Rosai-Dorfman ...
# 20647  Chẩn đoán xác định bệnh Rosai-Dorfman nguyên p...
# 20648  Bệnh Rosai-Dorfman nguyên phát ở da được phân ...
# 20649  Chẩn đoán bệnh Rosai-Dorfman nguyên phát ở da ...
#
#                                           document/title  \
# 0      Hướng dẫn chẩn đoán và quản lý tiểu không kiểm...
# 1      Nghiên cứu về chỉ định phẫu thuật TOT trong đi...
# 2      Dịch tễ học và tác động của tiểu không kiểm so...
# 3      Nghiên cứu về chỉ định phẫu thuật TOT điều trị...
# 4      Chỉ định phẫu thuật TOT trong điều trị són tiể...
# ...                                                  ...
# 20645  BỆNH ROSAI -DORFMAN NGUYÊN PHÁT CỦA DA VÙNG LƯ...
# 20646  BỆNH ROSAI -DORFMAN NGUYÊN PHÁT CỦA DA VÙNG LƯ...
# 20647  Đặc điểm mô bệnh học và hóa mô miễn dịch trong...
# 20648  Phân loại và đặc điểm dịch tễ, lâm sàng của cá...
# 20649  Kết quả điều trị phẫu thuật và tiên lượng bệnh...
#
#                                     document/description  \
# 0      Tài liệu này cung cấp các tiêu chí chẩn đoán t...
# 1      Tài liệu này trình bày các phát hiện từ một ng...
# 2      Tài liệu này nghiên cứu sâu về định nghĩa, phạ...
# 3      Tài liệu này trình bày kết quả của một nghiên ...
# 4      Tài liệu này tổng hợp các hướng dẫn lâm sàng v...
# ...                                                  ...
# 20645  Bài báo cáo trường hợp lâm sàng về bệnh Rosai-...
# 20646  Báo cáo trường hợp lâm sàng minh họa một ca bệ...
# 20647  Tài liệu này trình bày chi tiết các tiêu chí c...
# 20648  Tài liệu này phân tích sự khác biệt về dịch tễ...
# 20649  Bài báo mô tả trường hợp bệnh Rosai-Dorfman ng...
#
#                                                cme/title  \
# 0      Cập nhật chẩn đoán phân biệt và nguyên nhân gâ...
# 1      Kỹ thuật phẫu thuật TOT và quản lý biến chứng ...
# 2      Phân tích gánh nặng bệnh tật và tác động tâm l...
# 3      Cập nhật chẩn đoán và điều trị són tiểu gắng s...
# 4      Phẫu thuật nâng đỡ niệu đạo giữa: Kỹ thuật TOT...
# ...                                                  ...
# 20645  Ứng dụng hóa mô miễn dịch trong chẩn đoán phân...
# 20646  Tiếp cận điều trị và tiên lượng các thể bệnh R...
# 20647  Tiếp cận chẩn đoán mô bệnh học và hóa mô miễn ...
# 20648  Cập nhật phân loại và chiến lược chẩn đoán phâ...
# 20649  Quản lý điều trị và theo dõi dài hạn bệnh Rosa...
#
#                                          cme/description
# 0      Khóa học đào tạo y khoa liên tục này nhằm nâng...
# 1      Khóa học này cung cấp kiến thức chuyên sâu về ...
# 2      Khóa học này tập trung vào việc đánh giá gánh ...
# 3      Khóa học CME này cung cấp kiến thức toàn diện ...
# 4      Khóa học này tập trung chuyên sâu vào kỹ thuật...
# ...                                                  ...
# 20645  Khóa học này cung cấp cái nhìn tổng quan và ch...
# 20646  Khóa học này khám phá các phương pháp điều trị...
# 20647  Khóa học đào tạo y khoa liên tục này cung cấp ...
# 20648  Khóa học cung cấp cái nhìn tổng quan về hệ thố...
# 20649  Khóa học này tập trung vào các lựa chọn điều t...
#
# [20650 rows x 10 columns]

# %%
df = pd.read_excel("../icd-10/icd10_processed.xlsx")
df
# Out:
#       STT CHƯƠNG MÃ CHƯƠNG                               TÊN NHÓM CHÍNH  \
# 0              I   A00-B99                  Bệnh nhiễm trùng đường ruột
# 1              I   A00-B99                  Bệnh nhiễm trùng đường ruột
# 2              I   A00-B99                  Bệnh nhiễm trùng đường ruột
# 3              I   A00-B99                  Bệnh nhiễm trùng đường ruột
# 4              I   A00-B99                  Bệnh nhiễm trùng đường ruột
# ...          ...       ...                                          ...
# 12214       XXII   U00-U99  Kháng các thuốc kháng sinh và chống ung thư
# 12215       XXII   U00-U99  Kháng các thuốc kháng sinh và chống ung thư
# 12216       XXII   U00-U99  Kháng các thuốc kháng sinh và chống ung thư
# 12217       XXII   U00-U99  Kháng các thuốc kháng sinh và chống ung thư
# 12218       XXII   U00-U99  Kháng các thuốc kháng sinh và chống ung thư
#
#       MÃ BỆNH                                           TÊN BỆNH
# 0         A00                                            Bệnh tả
# 1       A00.0  Bệnh tả do Vibrio cholerae 01, typ sinh học ch...
# 2       A00.1  Bệnh tả do Vibrio cholerae 01, typ sinh học eltor
# 3       A00.9                            Bệnh tả, không đặc hiệu
# 4         A01                  Bệnh thương hàn và phó thương hàn
# ...       ...                                                ...
# 12214   U84.3                        Kháng (các) thuốc chống lao
# 12215   U84.7                   Kháng đa thuốc kháng vi sinh vật
# 12216   U84.8        Kháng thuốc kháng vi sinh vật xác định khác
# 12217   U84.9   Kháng các thuốc kháng vi sinh vật không xác định
# 12218     U85                      Kháng các thuốc kháng ung thư
#
# [12219 rows x 5 columns]

# %%
merged = df.merge(
    df_diagnosis,
    how="outer",
    left_on="MÃ BỆNH",
    right_on="icd_10"
)

# %%
merged
# Out:
#       STT CHƯƠNG MÃ CHƯƠNG                                     TÊN NHÓM CHÍNH  \
# 0              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 1              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 2              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 3              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 4              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# ...          ...       ...                                                ...
# 30855        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 30856        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 30857        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 30858        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 30859        NaN       NaN                                                NaN
#
#       MÃ BỆNH                                           TÊN BỆNH  \
# 0         A00                                            Bệnh tả
# 1       A00.0  Bệnh tả do Vibrio cholerae 01, typ sinh học ch...
# 2       A00.1  Bệnh tả do Vibrio cholerae 01, typ sinh học eltor
# 3       A00.9                            Bệnh tả, không đặc hiệu
# 4         A01                  Bệnh thương hàn và phó thương hàn
# ...       ...                                                ...
# 30855   Z99.4                          Lệ thuộc vào tim nhân tạo
# 30856   Z99.8         Phụ thuộc vào các thiết bị và dụng cụ khác
# 30857   Z99.8         Phụ thuộc vào các thiết bị và dụng cụ khác
# 30858   Z99.9   Phụ thuộc vào thiết bị và dụng cụ không xác định
# 30859     NaN                                                NaN
#
#                                               intruction icd_10  \
# 0                                                    NaN    NaN
# 1                                                    NaN    NaN
# 2                                                    NaN    NaN
# 3                                                    NaN    NaN
# 4                                                    NaN    NaN
# ...                                                  ...    ...
# 30855                                                NaN    NaN
# 30856  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z99.8
# 30857  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z99.8
# 30858                                                NaN    NaN
# 30859  Chatbot y khoa chuyên về y khoa, cung cấp thôn...    NaN
#
#                                             icd_10/title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30855                                                NaN
# 30856      Phụ thuộc vào các máy và thiết bị hỗ trợ khác
# 30857  Phụ thuộc vào các máy và thiết bị hỗ trợ khác,...
# 30858                                                NaN
# 30859                                                NaN
#
#                                                 question  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30855                                                NaN
# 30856  Kỹ thuật ECMO (Oxy hóa máu qua màng ngoài cơ t...
# 30857  Những nhóm bệnh nhân nào có nguy cơ cao mắc nh...
# 30858                                                NaN
# 30859                                                NaN
#
#                                                  symptom  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30855                                                NaN
# 30856  Các triệu chứng lâm sàng cho thấy bệnh nhân cầ...
# 30857  Các bệnh nhân có nguy cơ cao mắc nhiễm khuẩn b...
# 30858                                                NaN
# 30859                                                NaN
#
#                                                diagnosis  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30855                                                NaN
# 30856  ECMO (Extracorporeal Membrane Oxygenation) là ...
# 30857  Các bệnh nhân tại khoa hồi sức tích cực được c...
# 30858                                                NaN
# 30859  Việc chẩn đoán AML sau hóa trị đòi hỏi sự cảnh...
#
#                                           document/title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30855                                                NaN
# 30856  Kỹ thuật Oxy hóa máu qua màng ngoài cơ thể (EC...
# 30857  THỰC TRẠNG NHIỄM KHUẨN BỆNH VIỆN TẠI CÁC KHOA ...
# 30858                                                NaN
# 30859  BỆNH BẠCH CẦU TỦY CẤP TÍNH SAU HÓA TRỊ: BÁO CÁ...
#
#                                     document/description  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30855                                                NaN
# 30856  Tổng quan về nguyên lý hoạt động, phân loại (V...
# 30857  Nghiên cứu này làm rõ các yếu tố nguy cơ và bố...
# 30858                                                NaN
# 30859  Bài báo này cung cấp các báo cáo ca lâm sàng t...
#
#                                                cme/title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30855                                                NaN
# 30856  ECMO cơ bản: Nguyên lý và thực hành lâm sàng t...
# 30857  An toàn người bệnh và phòng ngừa nhiễm khuẩn t...
# 30858                                                NaN
# 30859  Chiến lược sàng lọc và theo dõi bệnh bạch cầu ...
#
#                                          cme/description
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30855                                                NaN
# 30856  Khóa học này cung cấp kiến thức nền tảng về kỹ...
# 30857  Khóa học cung cấp kiến thức và kỹ năng về các ...
# 30858                                                NaN
# 30859  Khóa học này trang bị cho bác sĩ kiến thức về ...
#
# [30860 rows x 15 columns]

# %%
df = merged.dropna(subset=['MÃ BỆNH'])
df = df[df.isna().any(axis=1)]

# %%
df.to_excel("SVYKHOA_dataset_diagnosis_cleaned.xlsx", index=False)

# %%
df
# Out:
#       STT CHƯƠNG MÃ CHƯƠNG                                     TÊN NHÓM CHÍNH  \
# 0              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 1              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 2              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 3              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 4              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# ...          ...       ...                                                ...
# 30842        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 30843        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 30854        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 30855        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 30858        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
#
#       MÃ BỆNH                                           TÊN BỆNH intruction  \
# 0         A00                                            Bệnh tả        NaN
# 1       A00.0  Bệnh tả do Vibrio cholerae 01, typ sinh học ch...        NaN
# 2       A00.1  Bệnh tả do Vibrio cholerae 01, typ sinh học eltor        NaN
# 3       A00.9                            Bệnh tả, không đặc hiệu        NaN
# 4         A01                  Bệnh thương hàn và phó thương hàn        NaN
# ...       ...                                                ...        ...
# 30842     Z99  Tình trạng phụ thuộc vào các thiết bị và dụng ...        NaN
# 30843   Z99.0                                  Phụ thuộc máy hút        NaN
# 30854   Z99.3                               Phụ thuộc vào xe lăn        NaN
# 30855   Z99.4                          Lệ thuộc vào tim nhân tạo        NaN
# 30858   Z99.9   Phụ thuộc vào thiết bị và dụng cụ không xác định        NaN
#
#       icd_10 icd_10/title question symptom diagnosis document/title  \
# 0        NaN          NaN      NaN     NaN       NaN            NaN
# 1        NaN          NaN      NaN     NaN       NaN            NaN
# 2        NaN          NaN      NaN     NaN       NaN            NaN
# 3        NaN          NaN      NaN     NaN       NaN            NaN
# 4        NaN          NaN      NaN     NaN       NaN            NaN
# ...      ...          ...      ...     ...       ...            ...
# 30842    NaN          NaN      NaN     NaN       NaN            NaN
# 30843    NaN          NaN      NaN     NaN       NaN            NaN
# 30854    NaN          NaN      NaN     NaN       NaN            NaN
# 30855    NaN          NaN      NaN     NaN       NaN            NaN
# 30858    NaN          NaN      NaN     NaN       NaN            NaN
#
#       document/description cme/title cme/description
# 0                      NaN       NaN             NaN
# 1                      NaN       NaN             NaN
# 2                      NaN       NaN             NaN
# 3                      NaN       NaN             NaN
# 4                      NaN       NaN             NaN
# ...                    ...       ...             ...
# 30842                  NaN       NaN             NaN
# 30843                  NaN       NaN             NaN
# 30854                  NaN       NaN             NaN
# 30855                  NaN       NaN             NaN
# 30858                  NaN       NaN             NaN
#
# [10214 rows x 15 columns]

# %%
import pandas as pd
import google.generativeai as genai
import time
import os
from tqdm import tqdm
import json
# Cấu hình API Key
genai.configure(api_key="AIzaSyDACh169FpAdWuCzw6r181Wx7tlEdXlcdU")  # <-- Nhớ điền API key ở đây

# Khởi tạo model
model = genai.GenerativeModel(model_name='models/gemini-2.5-flash')

# File input và output
input_file = "SVYKHOA_dataset_diagnosis_cleaned.xlsx"
output_file = "gen_SVYKHOA_dataset_diagnosis.xlsx"

# Đọc dữ liệu đầu vào
try:
    df_input = pd.read_excel(input_file)
    df_input = df_input[['TÊN NHÓM CHÍNH','MÃ BỆNH','TÊN BỆNH']].dropna().reset_index(drop=True)
    print(f"Đã đọc file Excel với {len(df_input)} dòng văn bản.")
except Exception as e:
    print(f"Lỗi khi đọc file Excel: {str(e)}")
    exit()

# Tạo DataFrame kết quả
result_columns = [
    "intruction", "question", "symptom", "diagnosis",
    "document/title",  "document/description",
    "cme/title", "cme/description"
]
if os.path.exists(output_file):
    df_result = pd.read_excel(output_file)
else:
    df_result = pd.DataFrame(columns=result_columns)

# Prompt Template mới
prompt_template = """
Bạn là một chuyên gia y tế chuyên về y khoa. Nhiệm vụ của bạn là tạo dữ liệu huấn luyện dành cho một **chatbot y khoa chuyên về y khoa** nhằm giúp chatbot phản hồi người dùng một cách chính xác, khoa học và đáng tin cậy theo chuẩn ICD-10 của Bộ Y tế Việt Nam.
Dựa vào các thông tin sau:
- TÊN NHÓM CHÍNH: {group_name}
- MÃ BỆNH: {disease_code}
- TÊN BỆNH: {disease_name}
Biết: 
- Tên nhóm chính là nhóm bệnh đại diện cho mã icd10 và loại bệnh đấy
- Mã bệnh là mã icd10 chính xác cho loại bệnh đấy
- Tên bệnh là tên bệnh chính xác cho loại bệnh đấy
Hãy sinh ra một **DANH SÁCH GỒM 5 ĐỐI TƯỢNG JSON** chứa đầy đủ TẤT CẢ các trường dưới đây. Tuyệt đối không được bỏ trống bất kỳ trường nào. Nếu đoạn văn không nêu rõ thông tin, bạn được phép **bổ sung hợp lý dựa trên kiến thức y khoa chính thống**, nhưng KHÔNG được bịa đặt hoặc sử dụng thông tin sai sự thật.
**Mục tiêu**: Dữ liệu được tạo ra sẽ được dùng để huấn luyện một **mô hình chatbot y tế**, vì vậy tất cả thông tin cần:
- Chính xác về mặt y học.
- Bám sát nội dung đoạn văn hoặc kiến thức y khoa phổ biến đã được xác thực (ví dụ: WHO, Bộ Y tế, giáo trình nha khoa).
- Có giá trị hướng dẫn, giải thích rõ ràng, có thể dùng để **tư vấn lâm sàng cho người dùng cuối**.
**Yêu cầu đặc biệt**:
- Nếu đoạn văn có đề cập đến các **chỉ số lâm sàng** như độ sâu túi lợi, chỉ số mảng bám, số răng tổn thương, mức độ đau... thì **phải đưa các con số và dữ liệu đó vào `symptom` và `diagnosis`** để tăng độ chính xác cho chatbot.
- `symptom` và `diagnosis` phải viết theo ngôn ngữ chuyên môn, **khoa học, cụ thể, không chung chung**, đủ để một bác sĩ hoặc chatbot sử dụng để diễn giải cho người bệnh.
Các trường cần điền:
- "intruction": Mô tả ngắn gọn về nhiệm vụ của chatbot, ví dụ: "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10."
- "question": Một câu hỏi y khoa phù hợp với **nội dung bài viết và câu trả lời**, tập trung vào chẩn đoán hoặc điều trị y khoa (giống như người dùng hay bác sỹ trẻ hỏi chatbot).
- "symptom": Các triệu chứng hoặc dấu hiệu lâm sàng được nêu trong bài, hoặc suy luận có cơ sở khoa học. **Bao gồm cả các chỉ số định lượng nếu có** như: túi nha chu 6mm, PI=2.2, v.v.
- "diagnosis": Chẩn đoán nha khoa chi tiết, có thể phân loại theo mức độ bệnh hoặc giai đoạn nếu phù hợp. **Phải có cơ sở y khoa vững chắc** và dùng thông số hỗ trợ chẩn đoán nếu có.
- "document/title": Tiêu đề tài liệu y khoa liên quan đến nội dung đoạn văn.
- "document/description": Mô tả ngắn gọn tài liệu tham khảo, nêu rõ mục đích hoặc giá trị ứng dụng.
- "cme/title": Tiêu đề khóa học đào tạo y khoa liên tục (CME) liên quan đến chủ đề trong đoạn văn.
- "cme/description": Mô tả ngắn về khóa học CME, giúp chatbot hiểu và phản hồi như một trợ lý học thuật chuyên ngành.
Lưu ý:- Chỉ xuất đầu ra dưới dạng đối tượng JSON hợp lệ. KHÔNG thêm bất kỳ mô tả, lời giải thích hoặc đoạn văn nào khác bên ngoài JSON.
      - Không được bổ trống bất kỳ trường nào trong đối tượng JSON.
"""



# Hàm sinh dữ liệu
def generate_with_retry(prompt, max_retries=3):
    for attempt in range(max_retries):
        try:
            response = model.generate_content(prompt)
            if response.text:
                return response
        except Exception as e:
            if attempt < max_retries - 1:
                wait_time = (attempt + 1) * 5
                print(f"Lỗi, thử lại sau {wait_time}s... (Lần {attempt + 1})")
                time.sleep(wait_time)
            else:
                print(f"Lỗi sau {max_retries} lần thử: {str(e)}")
                return None
    return None

# Hàm xử lý và lưu
def process_and_save(response, disease_code):
    try:
        cleaned = response.text.replace('```json', '').replace('```', '').strip()
        data_list = json.loads(cleaned)

        if not isinstance(data_list, list):
            raise ValueError("Kết quả không phải là danh sách JSON.")

        global df_result
        for data in data_list:
            new_row = {
                "intruction": data.get("intruction", ""),
                "question": data.get("question", ""),
                "icd10": disease_code,
                "symptom": data.get("symptom", ""),
                "diagnosis": data.get("diagnosis", ""),
                "document/title": data.get("document/title", ""),
                "document/description": data.get("document/description", ""),
                "cme/title": data.get("cme/title", ""),
                "cme/description": data.get("cme/description", "")
            }
            df_result.loc[len(df_result)] = new_row
        return True
    except Exception as e:
        print(f"\nLỗi xử lý response: {str(e)}")
        print(f"Response gốc: {response.text[:200]}...")
        return False

# Thiết lập số dòng xử lý
start_row = len(df_result)
end_row = len(df_input)
processed_count = 0
start_time = time.time()

# Vòng lặp xử lý
for index in tqdm(range(start_row, end_row)):
    row = df_input.iloc[index]
    retries = 0

    while retries < 3:
        try:
            group_name = row['TÊN NHÓM CHÍNH'].strip()
            disease_code = row['MÃ BỆNH'].strip()
            disease_name = row['TÊN BỆNH'].strip()
            prompt = prompt_template.format(
                group_name=group_name,
                disease_code=disease_code,
                disease_name=disease_name
            )
            response = generate_with_retry(prompt)

            if response and process_and_save(response, disease_code):
                processed_count += 1
                df_result.to_excel(output_file, index=False)
                time.sleep(2)
                break
            else:
                retries += 1
                print(f"Retry dòng {index} - Lần {retries}")
                time.sleep(3)

        except Exception as e:
            print(f"\nLỗi dòng {index}: {str(e)}")
            retries += 1
            time.sleep(3)

# Lưu cuốil
df_result.to_excel(output_file, index=False)
total_time = (time.time() - start_time) / 60
print(f"\nHoàn thành! Đã xử lý {processed_count} dòng.")
print(f"Thời gian chạy: {total_time:.2f} phút")
print(f"File kết quả: {output_file}")
# Out:
# Đã đọc file Excel với 10214 dòng văn bản.
#   0%|          | 40/9044 [46:40<140:16:23, 56.08s/it]
# Lỗi xử lý response: Invalid control character at: line 26 column 155 (char 5130)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "Bệnh bạch cầu dạng tiền nguyên tiểu cầu cấp (APL) có những t...
# Retry dòng 1210 - Lần 1
#   1%|          | 59/9044 [1:06:07<134:34:20, 53.92s/it]
# Lỗi xử lý response: Invalid control character at: line 26 column 206 (char 5628)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "Sarcom tổ chức bào (C96.8) là bệnh gì và có những triệu chứn...
# Retry dòng 1229 - Lần 1
#   1%|          | 76/9044 [1:28:22<193:00:52, 77.48s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
#   1%|          | 88/9044 [1:50:20<155:11:01, 62.38s/it]
# Lỗi xử lý response: Invalid control character at: line 36 column 285 (char 7402)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "U hắc tố tại chỗ của vị trí khác (mã D03.8) thường có những ...
# Retry dòng 1258 - Lần 1
#   1%|          | 111/9044 [2:16:17<180:36:59, 72.79s/it]
# Lỗi xử lý response: Invalid control character at: line 36 column 253 (char 7479)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "Triệu chứng và phương pháp chẩn đoán Ung thư biểu mô tại chỗ...
# Retry dòng 1281 - Lần 1
#   1%|▏         | 118/9044 [2:24:38<167:19:57, 67.49s/it]
# Lỗi xử lý response: Invalid control character at: line 16 column 99 (char 3180)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "Ung thư biểu mô tại chỗ của bàng quang (ICD-10: D09.0) là gì...
# Retry dòng 1288 - Lần 1
#
# Lỗi xử lý response: Extra data: line 55 column 1 (char 10600)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "Triệu chứng lâm sàng nào thường gặp ở bệnh nhân ung thư biểu...
# Retry dòng 1288 - Lần 2
#   2%|▏         | 143/9044 [2:50:22<135:39:20, 54.87s/it]
# Lỗi xử lý response: Invalid control character at: line 28 column 281 (char 5771)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "Người bệnh có u lành tính ruột non (D13.3) thường có những t...
# Retry dòng 1313 - Lần 1
#   2%|▏         | 178/9044 [3:21:40<129:12:32, 52.46s/it]
# Lỗi xử lý response: Invalid control character at: line 40 column 258 (char 8125)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "U lành trung mô không xác định (Mã ICD-10: D19.9) là gì và n...
# Retry dòng 1348 - Lần 1
#
# Lỗi xử lý response: Expecting ',' delimiter: line 25 column 513 (char 5260)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "Thông tin về U lành trung mô không xác định (D19.9) là gì và...
# Retry dòng 1348 - Lần 2
#   2%|▏         | 179/9044 [3:24:06<197:57:53, 80.39s/it]
# Lỗi xử lý response: Invalid control character at: line 16 column 113 (char 3015)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10 về các bệnh lý u lành tính, đặc biệt là u lành mô mềm sau phúc mạc và phúc mạc (...
# Retry dòng 1349 - Lần 1
#   2%|▏         | 193/9044 [3:36:11<129:04:53, 52.50s/it]
# Lỗi xử lý response: Invalid control character at: line 46 column 120 (char 7520)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "Nốt ruồi ở chi trên và vai (mã D22.6) là gì và có những đặc ...
# Retry dòng 1363 - Lần 1
#   2%|▏         | 207/9044 [3:48:28<128:10:39, 52.22s/it]
# Lỗi xử lý response: Invalid control character at: line 16 column 63 (char 2142)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.",
#     "question": "U cơ trơn dưới thanh mạc tử cung là gì và dấu hiệu nhận biết...
# Retry dòng 1377 - Lần 1
#   3%|▎         | 238/9044 [4:15:19<108:22:48, 44.31s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 50.588920089s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 50
# }
# ]
# Retry dòng 1408 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 32.296070318s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 32
# }
# ]
# Retry dòng 1408 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 14.015255014s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 14
# }
# ]
# Retry dòng 1408 - Lần 3
#   3%|▎         | 239/9044 [4:16:14<116:08:37, 47.49s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 55.697103314s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Retry dòng 1409 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 37.421218121s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# Retry dòng 1409 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 19.131645259s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 19
# }
# ]
# Retry dòng 1409 - Lần 3
#   3%|▎         | 240/9044 [4:17:09<121:32:57, 49.70s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 875.457899ms. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# Retry dòng 1410 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 42.600052571s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# Retry dòng 1410 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 24.342638231s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# Retry dòng 1410 - Lần 3
#   3%|▎         | 241/9044 [4:18:04<125:16:13, 51.23s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 6.098798463s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 6
# }
# ]
# Retry dòng 1411 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 47.842589809s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Retry dòng 1411 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 29.565600396s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# Retry dòng 1411 - Lần 3
#   3%|▎         | 242/9044 [4:18:59<127:51:33, 52.29s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 11.305078967s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 11
# }
# ]
# Retry dòng 1412 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 53.056364235s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# Retry dòng 1412 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 34.806308146s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 34
# }
# ]
# Retry dòng 1412 - Lần 3
#   3%|▎         | 243/9044 [4:19:53<129:39:01, 53.03s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 16.542268105s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 16
# }
# ]
# Retry dòng 1413 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 58.254638203s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 58
# }
# ]
# Retry dòng 1413 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 39.983651564s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# Retry dòng 1413 - Lần 3
#   3%|▎         | 244/9044 [4:20:48<130:56:50, 53.57s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 21.741700691s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ]
# Retry dòng 1414 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 3.489347628s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
# Retry dòng 1414 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 45.254068804s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Retry dòng 1414 - Lần 3
#   3%|▎         | 245/9044 [4:21:43<131:46:50, 53.92s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 26.996860182s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 26
# }
# ]
# Retry dòng 1415 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 8.747716305s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 8
# }
# ]
# Retry dòng 1415 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 50.490793605s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 50
# }
# ]
# Retry dòng 1415 - Lần 3
#   3%|▎         | 246/9044 [4:22:38<132:23:13, 54.17s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 32.255451552s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 32
# }
# ]
# Retry dòng 1416 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 14.000400091s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 14
# }
# ]
# Retry dòng 1416 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 55.75093873s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Retry dòng 1416 - Lần 3
#   3%|▎         | 247/9044 [4:23:32<132:47:32, 54.34s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 37.471594461s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# Retry dòng 1417 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 19.231574171s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 19
# }
# ]
# Retry dòng 1417 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 999.625551ms. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# Retry dòng 1417 - Lần 3
#   3%|▎         | 248/9044 [4:24:27<133:04:28, 54.46s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 42.760334893s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# Retry dòng 1418 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 24.497945343s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
# Retry dòng 1418 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 6.252770626s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 6
# }
# ]
# Retry dòng 1418 - Lần 3
#   3%|▎         | 249/9044 [4:25:22<133:15:50, 54.55s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 47.96359528s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Retry dòng 1419 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 29.718135226s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# Retry dòng 1419 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 11.469625611s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 11
# }
# ]
# Retry dòng 1419 - Lần 3
#   3%|▎         | 250/9044 [4:26:17<133:25:33, 54.62s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 53.209303815s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# Retry dòng 1420 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 34.941648058s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 34
# }
# ]
# Retry dòng 1420 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 16.708524455s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 16
# }
# ]
# Retry dòng 1420 - Lần 3
#   3%|▎         | 251/9044 [4:27:11<133:30:56, 54.66s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 58.458428431s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 58
# }
# ]
# Retry dòng 1421 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 40.216952821s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ]
# Retry dòng 1421 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 21.972016472s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ]
# Retry dòng 1421 - Lần 3
#   3%|▎         | 252/9044 [4:28:06<133:33:02, 54.68s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 3.714013797s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
# Retry dòng 1422 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 45.460869755s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# Retry dòng 1422 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 27.231867476s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 27
# }
# ]
# Retry dòng 1422 - Lần 3
#   3%|▎         | 253/9044 [4:29:01<133:34:54, 54.70s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 8.990399371s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 8
# }
# ]
# Retry dòng 1423 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 50.762032511s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 50
# }
# ]
# Retry dòng 1423 - Lần 2
# ...
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 6
# }
# ]
# Retry dòng 1955 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 47.773684801s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Retry dòng 1955 - Lần 3
#   9%|▊         | 786/9044 [12:53:41<127:51:46, 55.74s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 29.441470774s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# Retry dòng 1956 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 11.087558942s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 11
# }
# ]
# Retry dòng 1956 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 52.344651098s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Retry dòng 1956 - Lần 3
#   9%|▊         | 787/9044 [12:54:36<127:37:58, 55.65s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 32.617325988s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 32
# }
# ]
# Retry dòng 1957 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 13.768442878s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 13
# }
# ]
# Retry dòng 1957 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 54.966415625s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
# Retry dòng 1957 - Lần 3
#   9%|▊         | 788/9044 [12:55:33<128:51:47, 56.19s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 36.123067028s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# Retry dòng 1958 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 17.650971727s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ]
# Retry dòng 1958 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 59.356044266s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 59
# }
# ]
# Retry dòng 1958 - Lần 3
#   9%|▊         | 789/9044 [12:56:29<128:23:56, 55.99s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 40.724076264s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ]
# Retry dòng 1959 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 21.711287743s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ]
# Retry dòng 1959 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 35.454707272s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 35
# }
# ]
# Retry dòng 1959 - Lần 3
#   9%|▊         | 790/9044 [12:57:53<147:37:34, 64.39s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 16.652303218s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 16
# }
# ]
# Retry dòng 1960 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 57.865360362s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 57
# }
# ]
# Retry dòng 1960 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 38.807278162s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 38
# }
# ]
# Retry dòng 1960 - Lần 3
#   9%|▊         | 791/9044 [12:58:50<142:17:30, 62.07s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 19.9810448s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 19
# }
# ]
# Retry dòng 1961 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
