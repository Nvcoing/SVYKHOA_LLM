# %% [markdown]
# ### diagnosis icd 10

# %%
import pandas as pd
df = pd.read_excel("../generate_dataset/SVYKHOA_dataset_diagnosis.xlsx")
df
# Out:
#                                               intruction icd_10  \
# 0      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 1      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 2      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 3      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 4      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# ...                                                  ...    ...
# 20645  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  D76.3
# 20646  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  D76.3
# 20647                                                NaN  D76.3
# 20648                                                NaN  D76.3
# 20649                                                NaN  D76.3
#
#                                      icd_10/title  \
# 0      Tiểu không kiểm soát do gắng sức ở nữ giới
# 1      Tiểu không kiểm soát do gắng sức ở nữ giới
# 2      Tiểu không kiểm soát do gắng sức ở nữ giới
# 3                     Són tiểu gắng sức ở nữ giới
# 4                     Són tiểu gắng sức ở nữ giới
# ...                                           ...
# 20645                   Các hội chứng mô bào khác
# 20646                   Các hội chứng mô bào khác
# 20647                   Các hội chứng mô bào khác
# 20648                   Các hội chứng mô bào khác
# 20649                   Các hội chứng mô bào khác
#
#                                                 question  \
# 0      Các triệu chứng điển hình của tiểu không kiểm ...
# 1      Những chỉ định lâm sàng nào cho phẫu thuật TOT...
# 2      Tiểu không kiểm soát là gì, tần suất mắc bệnh ...
# 3      Són tiểu gắng sức ở nữ giới là gì và phẫu thuậ...
# 4      Những chỉ định và chống chỉ định cụ thể cho ph...
# ...                                                  ...
# 20645  Đặc điểm mô bệnh học và các dấu ấn hóa mô miễn...
# 20646  Bệnh Rosai-Dorfman nguyên phát của da thường đ...
# 20647  Làm thế nào để chẩn đoán bệnh Rosai-Dorfman ng...
# 20648  Bệnh Rosai-Dorfman nguyên phát ở da khác biệt ...
# 20649  Sau khi chẩn đoán bệnh Rosai-Dorfman nguyên ph...
#
#                                                  symptom  \
# 0      Các triệu chứng và dấu hiệu lâm sàng bao gồm: ...
# 1      Các triệu chứng gợi ý chỉ định phẫu thuật TOT ...
# 2      Tiểu không kiểm soát, theo định nghĩa của Hiệp...
# 3      Bệnh nhân có biểu hiện rò rỉ nước tiểu không c...
# 4      Bệnh nhân đã được chẩn đoán xác nhận mắc són t...
# ...                                                  ...
# 20645  Bệnh nhân nam, 54 tuổi, có tổn thương nốt đỏ b...
# 20646  Bệnh nhân nam 54 tuổi với tổn thương dạng nốt ...
# 20647  Tổn thương da (nốt, mảng, sẩn) ảnh hưởng lớp b...
# 20648  Đối với Rosai-Dorfman nguyên phát ở da: tuổi t...
# 20649  Bệnh nhân có tổn thương da dạng nốt, mảng hoặc...
#
#                                                diagnosis  \
# 0      Chẩn đoán tiểu không kiểm soát do gắng sức ở n...
# 1      Chỉ định phẫu thuật TOT được cân nhắc cho nhữn...
# 2      Tiểu không kiểm soát do gắng sức là một tình t...
# 3      Chẩn đoán són tiểu gắng sức ở nữ giới (ICD-10:...
# 4      Chẩn đoán són tiểu gắng sức (ICD-10: N39.3) là...
# ...                                                  ...
# 20645  Chẩn đoán bệnh Rosai-Dorfman nguyên phát của d...
# 20646  Sau khi chẩn đoán xác định bệnh Rosai-Dorfman ...
# 20647  Chẩn đoán xác định bệnh Rosai-Dorfman nguyên p...
# 20648  Bệnh Rosai-Dorfman nguyên phát ở da được phân ...
# 20649  Chẩn đoán bệnh Rosai-Dorfman nguyên phát ở da ...
#
#                                           document/title  \
# 0      Hướng dẫn chẩn đoán và quản lý tiểu không kiểm...
# 1      Nghiên cứu về chỉ định phẫu thuật TOT trong đi...
# 2      Dịch tễ học và tác động của tiểu không kiểm so...
# 3      Nghiên cứu về chỉ định phẫu thuật TOT điều trị...
# 4      Chỉ định phẫu thuật TOT trong điều trị són tiể...
# ...                                                  ...
# 20645  BỆNH ROSAI -DORFMAN NGUYÊN PHÁT CỦA DA VÙNG LƯ...
# 20646  BỆNH ROSAI -DORFMAN NGUYÊN PHÁT CỦA DA VÙNG LƯ...
# 20647  Đặc điểm mô bệnh học và hóa mô miễn dịch trong...
# 20648  Phân loại và đặc điểm dịch tễ, lâm sàng của cá...
# 20649  Kết quả điều trị phẫu thuật và tiên lượng bệnh...
#
#                                     document/description  \
# 0      Tài liệu này cung cấp các tiêu chí chẩn đoán t...
# 1      Tài liệu này trình bày các phát hiện từ một ng...
# 2      Tài liệu này nghiên cứu sâu về định nghĩa, phạ...
# 3      Tài liệu này trình bày kết quả của một nghiên ...
# 4      Tài liệu này tổng hợp các hướng dẫn lâm sàng v...
# ...                                                  ...
# 20645  Bài báo cáo trường hợp lâm sàng về bệnh Rosai-...
# 20646  Báo cáo trường hợp lâm sàng minh họa một ca bệ...
# 20647  Tài liệu này trình bày chi tiết các tiêu chí c...
# 20648  Tài liệu này phân tích sự khác biệt về dịch tễ...
# 20649  Bài báo mô tả trường hợp bệnh Rosai-Dorfman ng...
#
#                                                cme/title  \
# 0      Cập nhật chẩn đoán phân biệt và nguyên nhân gâ...
# 1      Kỹ thuật phẫu thuật TOT và quản lý biến chứng ...
# 2      Phân tích gánh nặng bệnh tật và tác động tâm l...
# 3      Cập nhật chẩn đoán và điều trị són tiểu gắng s...
# 4      Phẫu thuật nâng đỡ niệu đạo giữa: Kỹ thuật TOT...
# ...                                                  ...
# 20645  Ứng dụng hóa mô miễn dịch trong chẩn đoán phân...
# 20646  Tiếp cận điều trị và tiên lượng các thể bệnh R...
# 20647  Tiếp cận chẩn đoán mô bệnh học và hóa mô miễn ...
# 20648  Cập nhật phân loại và chiến lược chẩn đoán phâ...
# 20649  Quản lý điều trị và theo dõi dài hạn bệnh Rosa...
#
#                                          cme/description
# 0      Khóa học đào tạo y khoa liên tục này nhằm nâng...
# 1      Khóa học này cung cấp kiến thức chuyên sâu về ...
# 2      Khóa học này tập trung vào việc đánh giá gánh ...
# 3      Khóa học CME này cung cấp kiến thức toàn diện ...
# 4      Khóa học này tập trung chuyên sâu vào kỹ thuật...
# ...                                                  ...
# 20645  Khóa học này cung cấp cái nhìn tổng quan và ch...
# 20646  Khóa học này khám phá các phương pháp điều trị...
# 20647  Khóa học đào tạo y khoa liên tục này cung cấp ...
# 20648  Khóa học cung cấp cái nhìn tổng quan về hệ thố...
# 20649  Khóa học này tập trung vào các lựa chọn điều t...
#
# [20650 rows x 10 columns]

# %%
# đếm số NaN
nan_count = df['intruction'].isna().sum()
print("Số NaN:", nan_count)

# đếm số chuỗi rỗng ''
empty_str_count = (df['intruction'] == '').sum()
print("Số chuỗi rỗng:", empty_str_count)

# tổng cộng giá trị rỗng
total_missing = nan_count + empty_str_count
print("Tổng số giá trị rỗng:", total_missing)
# Out:
# Số NaN: 1105
# Số chuỗi rỗng: 0
# Tổng số giá trị rỗng: 1105

# %%
most_common = df['intruction'].value_counts().idxmax()
count = df['intruction'].value_counts().max()

print("Giá trị xuất hiện nhiều nhất:", most_common)
print("Số lần xuất hiện:", count)
# Out:
# Giá trị xuất hiện nhiều nhất: Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10.
# Số lần xuất hiện: 16740

# %%
# thay NaN và chuỗi rỗng bằng most_common
df['intruction'] = df['intruction'].fillna(most_common)

# %%
df_diagnosis = df
df_diagnosis
# Out:
#                                               intruction icd_10  \
# 0      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 1      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 2      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 3      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# 4      Chatbot y khoa chuyên về y khoa, cung cấp thôn...  N39.3
# ...                                                  ...    ...
# 20645  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  D76.3
# 20646  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  D76.3
# 20647  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  D76.3
# 20648  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  D76.3
# 20649  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  D76.3
#
#                                      icd_10/title  \
# 0      Tiểu không kiểm soát do gắng sức ở nữ giới
# 1      Tiểu không kiểm soát do gắng sức ở nữ giới
# 2      Tiểu không kiểm soát do gắng sức ở nữ giới
# 3                     Són tiểu gắng sức ở nữ giới
# 4                     Són tiểu gắng sức ở nữ giới
# ...                                           ...
# 20645                   Các hội chứng mô bào khác
# 20646                   Các hội chứng mô bào khác
# 20647                   Các hội chứng mô bào khác
# 20648                   Các hội chứng mô bào khác
# 20649                   Các hội chứng mô bào khác
#
#                                                 question  \
# 0      Các triệu chứng điển hình của tiểu không kiểm ...
# 1      Những chỉ định lâm sàng nào cho phẫu thuật TOT...
# 2      Tiểu không kiểm soát là gì, tần suất mắc bệnh ...
# 3      Són tiểu gắng sức ở nữ giới là gì và phẫu thuậ...
# 4      Những chỉ định và chống chỉ định cụ thể cho ph...
# ...                                                  ...
# 20645  Đặc điểm mô bệnh học và các dấu ấn hóa mô miễn...
# 20646  Bệnh Rosai-Dorfman nguyên phát của da thường đ...
# 20647  Làm thế nào để chẩn đoán bệnh Rosai-Dorfman ng...
# 20648  Bệnh Rosai-Dorfman nguyên phát ở da khác biệt ...
# 20649  Sau khi chẩn đoán bệnh Rosai-Dorfman nguyên ph...
#
#                                                  symptom  \
# 0      Các triệu chứng và dấu hiệu lâm sàng bao gồm: ...
# 1      Các triệu chứng gợi ý chỉ định phẫu thuật TOT ...
# 2      Tiểu không kiểm soát, theo định nghĩa của Hiệp...
# 3      Bệnh nhân có biểu hiện rò rỉ nước tiểu không c...
# 4      Bệnh nhân đã được chẩn đoán xác nhận mắc són t...
# ...                                                  ...
# 20645  Bệnh nhân nam, 54 tuổi, có tổn thương nốt đỏ b...
# 20646  Bệnh nhân nam 54 tuổi với tổn thương dạng nốt ...
# 20647  Tổn thương da (nốt, mảng, sẩn) ảnh hưởng lớp b...
# 20648  Đối với Rosai-Dorfman nguyên phát ở da: tuổi t...
# 20649  Bệnh nhân có tổn thương da dạng nốt, mảng hoặc...
#
#                                                diagnosis  \
# 0      Chẩn đoán tiểu không kiểm soát do gắng sức ở n...
# 1      Chỉ định phẫu thuật TOT được cân nhắc cho nhữn...
# 2      Tiểu không kiểm soát do gắng sức là một tình t...
# 3      Chẩn đoán són tiểu gắng sức ở nữ giới (ICD-10:...
# 4      Chẩn đoán són tiểu gắng sức (ICD-10: N39.3) là...
# ...                                                  ...
# 20645  Chẩn đoán bệnh Rosai-Dorfman nguyên phát của d...
# 20646  Sau khi chẩn đoán xác định bệnh Rosai-Dorfman ...
# 20647  Chẩn đoán xác định bệnh Rosai-Dorfman nguyên p...
# 20648  Bệnh Rosai-Dorfman nguyên phát ở da được phân ...
# 20649  Chẩn đoán bệnh Rosai-Dorfman nguyên phát ở da ...
#
#                                           document/title  \
# 0      Hướng dẫn chẩn đoán và quản lý tiểu không kiểm...
# 1      Nghiên cứu về chỉ định phẫu thuật TOT trong đi...
# 2      Dịch tễ học và tác động của tiểu không kiểm so...
# 3      Nghiên cứu về chỉ định phẫu thuật TOT điều trị...
# 4      Chỉ định phẫu thuật TOT trong điều trị són tiể...
# ...                                                  ...
# 20645  BỆNH ROSAI -DORFMAN NGUYÊN PHÁT CỦA DA VÙNG LƯ...
# 20646  BỆNH ROSAI -DORFMAN NGUYÊN PHÁT CỦA DA VÙNG LƯ...
# 20647  Đặc điểm mô bệnh học và hóa mô miễn dịch trong...
# 20648  Phân loại và đặc điểm dịch tễ, lâm sàng của cá...
# 20649  Kết quả điều trị phẫu thuật và tiên lượng bệnh...
#
#                                     document/description  \
# 0      Tài liệu này cung cấp các tiêu chí chẩn đoán t...
# 1      Tài liệu này trình bày các phát hiện từ một ng...
# 2      Tài liệu này nghiên cứu sâu về định nghĩa, phạ...
# 3      Tài liệu này trình bày kết quả của một nghiên ...
# 4      Tài liệu này tổng hợp các hướng dẫn lâm sàng v...
# ...                                                  ...
# 20645  Bài báo cáo trường hợp lâm sàng về bệnh Rosai-...
# 20646  Báo cáo trường hợp lâm sàng minh họa một ca bệ...
# 20647  Tài liệu này trình bày chi tiết các tiêu chí c...
# 20648  Tài liệu này phân tích sự khác biệt về dịch tễ...
# 20649  Bài báo mô tả trường hợp bệnh Rosai-Dorfman ng...
#
#                                                cme/title  \
# 0      Cập nhật chẩn đoán phân biệt và nguyên nhân gâ...
# 1      Kỹ thuật phẫu thuật TOT và quản lý biến chứng ...
# 2      Phân tích gánh nặng bệnh tật và tác động tâm l...
# 3      Cập nhật chẩn đoán và điều trị són tiểu gắng s...
# 4      Phẫu thuật nâng đỡ niệu đạo giữa: Kỹ thuật TOT...
# ...                                                  ...
# 20645  Ứng dụng hóa mô miễn dịch trong chẩn đoán phân...
# 20646  Tiếp cận điều trị và tiên lượng các thể bệnh R...
# 20647  Tiếp cận chẩn đoán mô bệnh học và hóa mô miễn ...
# 20648  Cập nhật phân loại và chiến lược chẩn đoán phâ...
# 20649  Quản lý điều trị và theo dõi dài hạn bệnh Rosa...
#
#                                          cme/description
# 0      Khóa học đào tạo y khoa liên tục này nhằm nâng...
# 1      Khóa học này cung cấp kiến thức chuyên sâu về ...
# 2      Khóa học này tập trung vào việc đánh giá gánh ...
# 3      Khóa học CME này cung cấp kiến thức toàn diện ...
# 4      Khóa học này tập trung chuyên sâu vào kỹ thuật...
# ...                                                  ...
# 20645  Khóa học này cung cấp cái nhìn tổng quan và ch...
# 20646  Khóa học này khám phá các phương pháp điều trị...
# 20647  Khóa học đào tạo y khoa liên tục này cung cấp ...
# 20648  Khóa học cung cấp cái nhìn tổng quan về hệ thố...
# 20649  Khóa học này tập trung vào các lựa chọn điều t...
#
# [20650 rows x 10 columns]

# %%
df = pd.read_excel("../icd-10/icd10_processed.xlsx")
df
# Out:
#       STT CHƯƠNG MÃ CHƯƠNG                               TÊN NHÓM CHÍNH  \
# 0              I   A00-B99                  Bệnh nhiễm trùng đường ruột
# 1              I   A00-B99                  Bệnh nhiễm trùng đường ruột
# 2              I   A00-B99                  Bệnh nhiễm trùng đường ruột
# 3              I   A00-B99                  Bệnh nhiễm trùng đường ruột
# 4              I   A00-B99                  Bệnh nhiễm trùng đường ruột
# ...          ...       ...                                          ...
# 12214       XXII   U00-U99  Kháng các thuốc kháng sinh và chống ung thư
# 12215       XXII   U00-U99  Kháng các thuốc kháng sinh và chống ung thư
# 12216       XXII   U00-U99  Kháng các thuốc kháng sinh và chống ung thư
# 12217       XXII   U00-U99  Kháng các thuốc kháng sinh và chống ung thư
# 12218       XXII   U00-U99  Kháng các thuốc kháng sinh và chống ung thư
#
#       MÃ BỆNH                                           TÊN BỆNH
# 0         A00                                            Bệnh tả
# 1       A00.0  Bệnh tả do Vibrio cholerae 01, typ sinh học ch...
# 2       A00.1  Bệnh tả do Vibrio cholerae 01, typ sinh học eltor
# 3       A00.9                            Bệnh tả, không đặc hiệu
# 4         A01                  Bệnh thương hàn và phó thương hàn
# ...       ...                                                ...
# 12214   U84.3                        Kháng (các) thuốc chống lao
# 12215   U84.7                   Kháng đa thuốc kháng vi sinh vật
# 12216   U84.8        Kháng thuốc kháng vi sinh vật xác định khác
# 12217   U84.9   Kháng các thuốc kháng vi sinh vật không xác định
# 12218     U85                      Kháng các thuốc kháng ung thư
#
# [12219 rows x 5 columns]

# %%
merged = df.merge(
    df_diagnosis,
    how="outer",
    left_on="MÃ BỆNH",
    right_on="icd_10"
)

# %%
df_generated = pd.read_excel("gen_SVYKHOA_dataset_diagnosis.xlsx")

# %%
merged = merged.merge(
    df_generated,
    how="outer",
    left_on="MÃ BỆNH",
    right_on="icd10"
)
merged['TÊN BỆNH'] = merged['icd_10'].combine_first(merged['TÊN BỆNH'])

# %%
merged
# Out:
#       STT CHƯƠNG MÃ CHƯƠNG               TÊN NHÓM CHÍNH MÃ BỆNH TÊN BỆNH  \
# 0              I   A00-B99  Bệnh nhiễm trùng đường ruột     A00  Bệnh tả
# 1              I   A00-B99  Bệnh nhiễm trùng đường ruột     A00  Bệnh tả
# 2              I   A00-B99  Bệnh nhiễm trùng đường ruột     A00  Bệnh tả
# 3              I   A00-B99  Bệnh nhiễm trùng đường ruột     A00  Bệnh tả
# 4              I   A00-B99  Bệnh nhiễm trùng đường ruột     A00  Bệnh tả
# ...          ...       ...                          ...     ...      ...
# 39527        NaN       NaN                          NaN     NaN   Z98.89
# 39528        NaN       NaN                          NaN     NaN   Z98.89
# 39529        NaN       NaN                          NaN     NaN   Z98.89
# 39530        NaN       NaN                          NaN     NaN   Z98.89
# 39531        NaN       NaN                          NaN     NaN      NaN
#
#                                             intruction_x  icd_10  \
# 0                                                    NaN     NaN
# 1                                                    NaN     NaN
# 2                                                    NaN     NaN
# 3                                                    NaN     NaN
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 39527  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z98.89
# 39528  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z98.89
# 39529  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z98.89
# 39530  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z98.89
# 39531  Chatbot y khoa chuyên về y khoa, cung cấp thôn...     NaN
#
#                                             icd_10/title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 39527  Các tình trạng sau thủ thuật khác được xác địn...
# 39528     Các tình trạng sau phẫu thuật đã xác định khác
# 39529  Các tình trạng phẫu thuật đặc hiệu khác sau th...
# 39530            Trạng thái sau phẫu thuật đặc hiệu khác
# 39531                                                NaN
#
#                                               question_x  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 39527  Những rủi ro và thách thức về mặt thẩm mỹ đối ...
# 39528  Việc sử dụng vạt đùi trước ngoài (ALT flap) để...
# 39529  Dung dịch Chlorhexidine 2% này có nồng độ và đ...
# 39530  Các chỉ số về thời gian phục hồi và biến chứng...
# 39531                                                NaN
#
#                                                symptom_x  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                                                    NaN  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 39527  Nguy cơ tiềm ẩn bao gồm những thay đổi khó lườ...  ...
# 39528  Khuyết hổng phần mềm lớn vùng mặt cổ sau phẫu ...  ...
# 39529  Sau các thủ thuật phẫu thuật miệng như nhổ răn...  ...
# 39530  Bệnh nhân sau phẫu thuật nội soi ung thư trực ...  ...
# 39531                                                NaN  ...
#
#                                        cme/description_x  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 39527  Khóa học tập trung vào các kỹ thuật tiên tiến ...
# 39528  Khóa học đào tạo y khoa liên tục về các chiến ...
# 39529  Khóa học này thảo luận về việc sử dụng Chlorhe...
# 39530  Khóa học tập trung vào các phương pháp chăm só...
# 39531  Khóa học này trang bị cho bác sĩ kiến thức về ...
#
#                                             intruction_y  \
# 0      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 1      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 2      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 3      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 4      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# ...                                                  ...
# 39527                                                NaN
# 39528                                                NaN
# 39529                                                NaN
# 39530                                                NaN
# 39531                                                NaN
#
#                                               question_y icd10  \
# 0      Một bệnh nhân đến khám với triệu chứng tiêu ch...   A00
# 1      Làm thế nào để nhận biết và chẩn đoán bệnh tả ...   A00
# 2      Những xét nghiệm cận lâm sàng nào cần được thự...   A00
# 3      Nguyên tắc điều trị bệnh tả là gì, đặc biệt tr...   A00
# 4      Các biện pháp phòng ngừa và kiểm soát dịch bện...   A00
# ...                                                  ...   ...
# 39527                                                NaN   NaN
# 39528                                                NaN   NaN
# 39529                                                NaN   NaN
# 39530                                                NaN   NaN
# 39531                                                NaN   NaN
#
#                                                symptom_y  \
# 0      Bệnh nhân có khởi phát đột ngột tiêu chảy nhiề...
# 1      Bệnh nhân có tiêu chảy liên tục (>5 lần/giờ), ...
# 2      Bệnh nhân có triệu chứng lâm sàng nghi ngờ tả ...
# 3      Bệnh nhân được chẩn đoán xác định hoặc nghi ng...
# 4      Không có triệu chứng lâm sàng cụ thể của bệnh ...
# ...                                                  ...
# 39527                                                NaN
# 39528                                                NaN
# 39529                                                NaN
# 39530                                                NaN
# 39531                                                NaN
#
#                                              diagnosis_y  \
# 0      Nghi ngờ lâm sàng Bệnh tả (ICD-10 A00 - Choler...
# 1      Bệnh tả có mất nước nặng (ICD-10 A00.0 - Chole...
# 2      Xác định chẩn đoán Bệnh tả (ICD-10 A00) bằng p...
# 3      Nguyên tắc điều trị Bệnh tả (ICD-10 A00) bao g...
# 4      Các biện pháp phòng ngừa và kiểm soát Bệnh tả ...
# ...                                                  ...
# 39527                                                NaN
# 39528                                                NaN
# 39529                                                NaN
# 39530                                                NaN
# 39531                                                NaN
#
#                                         document/title_y  \
# 0      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 1      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 2      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 3      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 4      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# ...                                                  ...
# 39527                                                NaN
# 39528                                                NaN
# 39529                                                NaN
# 39530                                                NaN
# 39531                                                NaN
#
#                                   document/description_y  \
# 0      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 1      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 2      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 3      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 4      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# ...                                                  ...
# 39527                                                NaN
# 39528                                                NaN
# 39529                                                NaN
# 39530                                                NaN
# 39531                                                NaN
#
#                                              cme/title_y  \
# 0      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 1      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 2      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 3      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 4      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# ...                                                  ...
# 39527                                                NaN
# 39528                                                NaN
# 39529                                                NaN
# 39530                                                NaN
# 39531                                                NaN
#
#                                        cme/description_y
# 0      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 1      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 2      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 3      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 4      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# ...                                                  ...
# 39527                                                NaN
# 39528                                                NaN
# 39529                                                NaN
# 39530                                                NaN
# 39531                                                NaN
#
# [39532 rows x 24 columns]

# %%
df = merged.dropna(subset=['MÃ BỆNH'])

# %%
df
# Out:
#       STT CHƯƠNG MÃ CHƯƠNG                                     TÊN NHÓM CHÍNH  \
# 0              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 1              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 2              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 3              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 4              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# ...          ...       ...                                                ...
# 36593        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36594        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36595        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36596        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36597        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
#
#       MÃ BỆNH                                          TÊN BỆNH  \
# 0         A00                                           Bệnh tả
# 1         A00                                           Bệnh tả
# 2         A00                                           Bệnh tả
# 3         A00                                           Bệnh tả
# 4         A00                                           Bệnh tả
# ...       ...                                               ...
# 36593   Z99.3                              Phụ thuộc vào xe lăn
# 36594   Z99.4                         Lệ thuộc vào tim nhân tạo
# 36595   Z99.8                                             Z99.8
# 36596   Z99.8                                             Z99.8
# 36597   Z99.9  Phụ thuộc vào thiết bị và dụng cụ không xác định
#
#                                             intruction_x icd_10  \
# 0                                                    NaN    NaN
# 1                                                    NaN    NaN
# 2                                                    NaN    NaN
# 3                                                    NaN    NaN
# 4                                                    NaN    NaN
# ...                                                  ...    ...
# 36593                                                NaN    NaN
# 36594                                                NaN    NaN
# 36595  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z99.8
# 36596  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z99.8
# 36597                                                NaN    NaN
#
#                                             icd_10/title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595      Phụ thuộc vào các máy và thiết bị hỗ trợ khác
# 36596  Phụ thuộc vào các máy và thiết bị hỗ trợ khác,...
# 36597                                                NaN
#
#                                               question_x  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595  Kỹ thuật ECMO (Oxy hóa máu qua màng ngoài cơ t...
# 36596  Những nhóm bệnh nhân nào có nguy cơ cao mắc nh...
# 36597                                                NaN
#
#                                                symptom_x  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                                                    NaN  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 36593                                                NaN  ...
# 36594                                                NaN  ...
# 36595  Các triệu chứng lâm sàng cho thấy bệnh nhân cầ...  ...
# 36596  Các bệnh nhân có nguy cơ cao mắc nhiễm khuẩn b...  ...
# 36597                                                NaN  ...
#
#                                        cme/description_x  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595  Khóa học này cung cấp kiến thức nền tảng về kỹ...
# 36596  Khóa học cung cấp kiến thức và kỹ năng về các ...
# 36597                                                NaN
#
#                                             intruction_y  \
# 0      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 1      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 2      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 3      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 4      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595                                                NaN
# 36596                                                NaN
# 36597                                                NaN
#
#                                               question_y icd10  \
# 0      Một bệnh nhân đến khám với triệu chứng tiêu ch...   A00
# 1      Làm thế nào để nhận biết và chẩn đoán bệnh tả ...   A00
# 2      Những xét nghiệm cận lâm sàng nào cần được thự...   A00
# 3      Nguyên tắc điều trị bệnh tả là gì, đặc biệt tr...   A00
# 4      Các biện pháp phòng ngừa và kiểm soát dịch bện...   A00
# ...                                                  ...   ...
# 36593                                                NaN   NaN
# 36594                                                NaN   NaN
# 36595                                                NaN   NaN
# 36596                                                NaN   NaN
# 36597                                                NaN   NaN
#
#                                                symptom_y  \
# 0      Bệnh nhân có khởi phát đột ngột tiêu chảy nhiề...
# 1      Bệnh nhân có tiêu chảy liên tục (>5 lần/giờ), ...
# 2      Bệnh nhân có triệu chứng lâm sàng nghi ngờ tả ...
# 3      Bệnh nhân được chẩn đoán xác định hoặc nghi ng...
# 4      Không có triệu chứng lâm sàng cụ thể của bệnh ...
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595                                                NaN
# 36596                                                NaN
# 36597                                                NaN
#
#                                              diagnosis_y  \
# 0      Nghi ngờ lâm sàng Bệnh tả (ICD-10 A00 - Choler...
# 1      Bệnh tả có mất nước nặng (ICD-10 A00.0 - Chole...
# 2      Xác định chẩn đoán Bệnh tả (ICD-10 A00) bằng p...
# 3      Nguyên tắc điều trị Bệnh tả (ICD-10 A00) bao g...
# 4      Các biện pháp phòng ngừa và kiểm soát Bệnh tả ...
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595                                                NaN
# 36596                                                NaN
# 36597                                                NaN
#
#                                         document/title_y  \
# 0      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 1      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 2      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 3      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 4      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595                                                NaN
# 36596                                                NaN
# 36597                                                NaN
#
#                                   document/description_y  \
# 0      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 1      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 2      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 3      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 4      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595                                                NaN
# 36596                                                NaN
# 36597                                                NaN
#
#                                              cme/title_y  \
# 0      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 1      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 2      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 3      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 4      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595                                                NaN
# 36596                                                NaN
# 36597                                                NaN
#
#                                        cme/description_y
# 0      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 1      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 2      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 3      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 4      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595                                                NaN
# 36596                                                NaN
# 36597                                                NaN
#
# [36598 rows x 24 columns]

# %%
df = merged.dropna(subset=['MÃ BỆNH'])

# %%
df
# Out:
#       STT CHƯƠNG MÃ CHƯƠNG                                     TÊN NHÓM CHÍNH  \
# 0              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 1              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 2              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 3              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# 4              I   A00-B99                        Bệnh nhiễm trùng đường ruột
# ...          ...       ...                                                ...
# 36593        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36594        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36595        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36596        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36597        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
#
#       MÃ BỆNH                                          TÊN BỆNH  \
# 0         A00                                           Bệnh tả
# 1         A00                                           Bệnh tả
# 2         A00                                           Bệnh tả
# 3         A00                                           Bệnh tả
# 4         A00                                           Bệnh tả
# ...       ...                                               ...
# 36593   Z99.3                              Phụ thuộc vào xe lăn
# 36594   Z99.4                         Lệ thuộc vào tim nhân tạo
# 36595   Z99.8                                             Z99.8
# 36596   Z99.8                                             Z99.8
# 36597   Z99.9  Phụ thuộc vào thiết bị và dụng cụ không xác định
#
#                                             intruction_x icd_10  \
# 0                                                    NaN    NaN
# 1                                                    NaN    NaN
# 2                                                    NaN    NaN
# 3                                                    NaN    NaN
# 4                                                    NaN    NaN
# ...                                                  ...    ...
# 36593                                                NaN    NaN
# 36594                                                NaN    NaN
# 36595  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z99.8
# 36596  Chatbot y khoa chuyên về y khoa, cung cấp thôn...  Z99.8
# 36597                                                NaN    NaN
#
#                                             icd_10/title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595      Phụ thuộc vào các máy và thiết bị hỗ trợ khác
# 36596  Phụ thuộc vào các máy và thiết bị hỗ trợ khác,...
# 36597                                                NaN
#
#                                               question_x  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595  Kỹ thuật ECMO (Oxy hóa máu qua màng ngoài cơ t...
# 36596  Những nhóm bệnh nhân nào có nguy cơ cao mắc nh...
# 36597                                                NaN
#
#                                                symptom_x  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                                                    NaN  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 36593                                                NaN  ...
# 36594                                                NaN  ...
# 36595  Các triệu chứng lâm sàng cho thấy bệnh nhân cầ...  ...
# 36596  Các bệnh nhân có nguy cơ cao mắc nhiễm khuẩn b...  ...
# 36597                                                NaN  ...
#
#                                        cme/description_x  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595  Khóa học này cung cấp kiến thức nền tảng về kỹ...
# 36596  Khóa học cung cấp kiến thức và kỹ năng về các ...
# 36597                                                NaN
#
#                                             intruction_y  \
# 0      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 1      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 2      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 3      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# 4      Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595                                                NaN
# 36596                                                NaN
# 36597                                                NaN
#
#                                               question_y icd10  \
# 0      Một bệnh nhân đến khám với triệu chứng tiêu ch...   A00
# 1      Làm thế nào để nhận biết và chẩn đoán bệnh tả ...   A00
# 2      Những xét nghiệm cận lâm sàng nào cần được thự...   A00
# 3      Nguyên tắc điều trị bệnh tả là gì, đặc biệt tr...   A00
# 4      Các biện pháp phòng ngừa và kiểm soát dịch bện...   A00
# ...                                                  ...   ...
# 36593                                                NaN   NaN
# 36594                                                NaN   NaN
# 36595                                                NaN   NaN
# 36596                                                NaN   NaN
# 36597                                                NaN   NaN
#
#                                                symptom_y  \
# 0      Bệnh nhân có khởi phát đột ngột tiêu chảy nhiề...
# 1      Bệnh nhân có tiêu chảy liên tục (>5 lần/giờ), ...
# 2      Bệnh nhân có triệu chứng lâm sàng nghi ngờ tả ...
# 3      Bệnh nhân được chẩn đoán xác định hoặc nghi ng...
# 4      Không có triệu chứng lâm sàng cụ thể của bệnh ...
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595                                                NaN
# 36596                                                NaN
# 36597                                                NaN
#
#                                              diagnosis_y  \
# 0      Nghi ngờ lâm sàng Bệnh tả (ICD-10 A00 - Choler...
# 1      Bệnh tả có mất nước nặng (ICD-10 A00.0 - Chole...
# 2      Xác định chẩn đoán Bệnh tả (ICD-10 A00) bằng p...
# 3      Nguyên tắc điều trị Bệnh tả (ICD-10 A00) bao g...
# 4      Các biện pháp phòng ngừa và kiểm soát Bệnh tả ...
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595                                                NaN
# 36596                                                NaN
# 36597                                                NaN
#
#                                         document/title_y  \
# 0      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 1      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 2      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 3      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# 4      Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595                                                NaN
# 36596                                                NaN
# 36597                                                NaN
#
#                                   document/description_y  \
# 0      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 1      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 2      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 3      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# 4      Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595                                                NaN
# 36596                                                NaN
# 36597                                                NaN
#
#                                              cme/title_y  \
# 0      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 1      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 2      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 3      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# 4      Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595                                                NaN
# 36596                                                NaN
# 36597                                                NaN
#
#                                        cme/description_y
# 0      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 1      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 2      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 3      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# 4      Khóa học đào tạo y khoa liên tục (CME) dành ch...
# ...                                                  ...
# 36593                                                NaN
# 36594                                                NaN
# 36595                                                NaN
# 36596                                                NaN
# 36597                                                NaN
#
# [36598 rows x 24 columns]

# %%
# df = df[df.isna().any(axis=1)]
df_missing = df[df['icd10'].isna() & df['icd_10'].isna()]

# %%
df.to_excel("SVYKHOA_dataset_diagnosis_cleaned.xlsx", index=False)

# %%
df_missing
# Out:
#       STT CHƯƠNG MÃ CHƯƠNG                                     TÊN NHÓM CHÍNH  \
# 1244           I   A00-B99                              Bệnh nhiễm khuẩn khác
# 1245           I   A00-B99                              Bệnh nhiễm khuẩn khác
# 1246           I   A00-B99                              Bệnh nhiễm khuẩn khác
# 1247           I   A00-B99                              Bệnh nhiễm khuẩn khác
# 1248           I   A00-B99                              Bệnh nhiễm khuẩn khác
# ...          ...       ...                                                ...
# 36581        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36582        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36593        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36594        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# 36597        XXI   Z00-Z99  Những người có nguy cơ sức khỏe tiềm ẩn liên q...
#
#       MÃ BỆNH                                           TÊN BỆNH intruction_x  \
# 1244      A38                               Bệnh tinh hồng nhiệt          NaN
# 1245      A39                          Nhiễm trùng do não mô cầu          NaN
# 1246   A39.0†                 Viêm màng não do não mô cầu (G01*)          NaN
# 1247   A39.1†         Hội chứng Waterhouse-Friderichsen (E35.1*)          NaN
# 1248    A39.2              Nhiễm khuẩn huyết não mô cầu cấp tính          NaN
# ...       ...                                                ...          ...
# 36581     Z99  Tình trạng phụ thuộc vào các thiết bị và dụng ...          NaN
# 36582   Z99.0                                  Phụ thuộc máy hút          NaN
# 36593   Z99.3                               Phụ thuộc vào xe lăn          NaN
# 36594   Z99.4                          Lệ thuộc vào tim nhân tạo          NaN
# 36597   Z99.9   Phụ thuộc vào thiết bị và dụng cụ không xác định          NaN
#
#       icd_10 icd_10/title question_x symptom_x  ... cme/description_x  \
# 1244     NaN          NaN        NaN       NaN  ...               NaN
# 1245     NaN          NaN        NaN       NaN  ...               NaN
# 1246     NaN          NaN        NaN       NaN  ...               NaN
# 1247     NaN          NaN        NaN       NaN  ...               NaN
# 1248     NaN          NaN        NaN       NaN  ...               NaN
# ...      ...          ...        ...       ...  ...               ...
# 36581    NaN          NaN        NaN       NaN  ...               NaN
# 36582    NaN          NaN        NaN       NaN  ...               NaN
# 36593    NaN          NaN        NaN       NaN  ...               NaN
# 36594    NaN          NaN        NaN       NaN  ...               NaN
# 36597    NaN          NaN        NaN       NaN  ...               NaN
#
#       intruction_y question_y icd10 symptom_y diagnosis_y document/title_y  \
# 1244           NaN        NaN   NaN       NaN         NaN              NaN
# 1245           NaN        NaN   NaN       NaN         NaN              NaN
# 1246           NaN        NaN   NaN       NaN         NaN              NaN
# 1247           NaN        NaN   NaN       NaN         NaN              NaN
# 1248           NaN        NaN   NaN       NaN         NaN              NaN
# ...            ...        ...   ...       ...         ...              ...
# 36581          NaN        NaN   NaN       NaN         NaN              NaN
# 36582          NaN        NaN   NaN       NaN         NaN              NaN
# 36593          NaN        NaN   NaN       NaN         NaN              NaN
# 36594          NaN        NaN   NaN       NaN         NaN              NaN
# 36597          NaN        NaN   NaN       NaN         NaN              NaN
#
#       document/description_y cme/title_y cme/description_y
# 1244                     NaN         NaN               NaN
# 1245                     NaN         NaN               NaN
# 1246                     NaN         NaN               NaN
# 1247                     NaN         NaN               NaN
# 1248                     NaN         NaN               NaN
# ...                      ...         ...               ...
# 36581                    NaN         NaN               NaN
# 36582                    NaN         NaN               NaN
# 36593                    NaN         NaN               NaN
# 36594                    NaN         NaN               NaN
# 36597                    NaN         NaN               NaN
#
# [8518 rows x 24 columns]

# %%
import pandas as pd
import google.generativeai as genai
import time
import os
from tqdm import tqdm
import json
# Cấu hình API Key
genai.configure(api_key="AIzaSyBwVaHGxXZpSXgOz7GFcQKXZ72HeOwsKlc")  # <-- Nhớ điền API key ở đây

# Khởi tạo model
model = genai.GenerativeModel(model_name='models/gemini-2.5-flash')

# File input và output
input_file = "SVYKHOA_dataset_diagnosis_cleaned.xlsx"
output_file = "gen_SVYKHOA_dataset_diagnosis.xlsx"

# Đọc dữ liệu đầu vào
try:
    df_input = pd.read_excel(input_file)
    df_input = df_input[['TÊN NHÓM CHÍNH','MÃ BỆNH','TÊN BỆNH']].dropna().reset_index(drop=True)
    print(f"Đã đọc file Excel với {len(df_input)} dòng văn bản.")
except Exception as e:
    print(f"Lỗi khi đọc file Excel: {str(e)}")
    exit()

# Tạo DataFrame kết quả
result_columns = [
    "intruction", "question", "symptom", "diagnosis",
    "document/title",  "document/description",
    "cme/title", "cme/description"
]
if os.path.exists(output_file):
    df_result = pd.read_excel(output_file)
else:
    df_result = pd.DataFrame(columns=result_columns)

# Prompt Template mới
prompt_template = """
Bạn là một chuyên gia y tế chuyên về y khoa. Nhiệm vụ của bạn là tạo dữ liệu huấn luyện dành cho một **chatbot y khoa chuyên về y khoa** nhằm giúp chatbot phản hồi người dùng một cách chính xác, khoa học và đáng tin cậy theo chuẩn ICD-10 của Bộ Y tế Việt Nam.
Dựa vào các thông tin sau:
- TÊN NHÓM CHÍNH: {group_name}
- MÃ BỆNH: {disease_code}
- TÊN BỆNH: {disease_name}
Biết: 
- Tên nhóm chính là nhóm bệnh đại diện cho mã icd10 và loại bệnh đấy
- Mã bệnh là mã icd10 chính xác cho loại bệnh đấy
- Tên bệnh là tên bệnh chính xác cho loại bệnh đấy
Hãy sinh ra một **DANH SÁCH GỒM 5 ĐỐI TƯỢNG JSON** chứa đầy đủ TẤT CẢ các trường dưới đây. Tuyệt đối không được bỏ trống bất kỳ trường nào. Nếu đoạn văn không nêu rõ thông tin, bạn được phép **bổ sung hợp lý dựa trên kiến thức y khoa chính thống**, nhưng KHÔNG được bịa đặt hoặc sử dụng thông tin sai sự thật.
**Mục tiêu**: Dữ liệu được tạo ra sẽ được dùng để huấn luyện một **mô hình chatbot y tế**, vì vậy tất cả thông tin cần:
- Chính xác về mặt y học.
- Bám sát nội dung đoạn văn hoặc kiến thức y khoa phổ biến đã được xác thực (ví dụ: WHO, Bộ Y tế, giáo trình nha khoa).
- Có giá trị hướng dẫn, giải thích rõ ràng, có thể dùng để **tư vấn lâm sàng cho người dùng cuối**.
**Yêu cầu đặc biệt**:
- Nếu đoạn văn có đề cập đến các **chỉ số lâm sàng** như độ sâu túi lợi, chỉ số mảng bám, số răng tổn thương, mức độ đau... thì **phải đưa các con số và dữ liệu đó vào `symptom` và `diagnosis`** để tăng độ chính xác cho chatbot.
- `symptom` và `diagnosis` phải viết theo ngôn ngữ chuyên môn, **khoa học, cụ thể, không chung chung**, đủ để một bác sĩ hoặc chatbot sử dụng để diễn giải cho người bệnh.
Các trường cần điền:
- "intruction": Mô tả ngắn gọn về nhiệm vụ của chatbot, ví dụ: "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng dựa trên ICD-10."
- "question": Một câu hỏi y khoa phù hợp với **nội dung bài viết và câu trả lời**, tập trung vào chẩn đoán hoặc điều trị y khoa (giống như người dùng hay bác sỹ trẻ hỏi chatbot).
- "symptom": Các triệu chứng hoặc dấu hiệu lâm sàng được nêu trong bài, hoặc suy luận có cơ sở khoa học. **Bao gồm cả các chỉ số định lượng nếu có** như: túi nha chu 6mm, PI=2.2, v.v.
- "diagnosis": Chẩn đoán nha khoa chi tiết, có thể phân loại theo mức độ bệnh hoặc giai đoạn nếu phù hợp. **Phải có cơ sở y khoa vững chắc** và dùng thông số hỗ trợ chẩn đoán nếu có.
- "document/title": Tiêu đề tài liệu y khoa liên quan đến nội dung đoạn văn.
- "document/description": Mô tả ngắn gọn tài liệu tham khảo, nêu rõ mục đích hoặc giá trị ứng dụng.
- "cme/title": Tiêu đề khóa học đào tạo y khoa liên tục (CME) liên quan đến chủ đề trong đoạn văn.
- "cme/description": Mô tả ngắn về khóa học CME, giúp chatbot hiểu và phản hồi như một trợ lý học thuật chuyên ngành.
Lưu ý:- Chỉ xuất đầu ra dưới dạng đối tượng JSON hợp lệ. KHÔNG thêm bất kỳ mô tả, lời giải thích hoặc đoạn văn nào khác bên ngoài JSON.
      - Không được bổ trống bất kỳ trường nào trong đối tượng JSON.
"""



# Hàm sinh dữ liệu
def generate_with_retry(prompt, max_retries=3):
    for attempt in range(max_retries):
        try:
            response = model.generate_content(prompt)
            if response.text:
                return response
        except Exception as e:
            if attempt < max_retries - 1:
                wait_time = (attempt + 1) * 5
                print(f"Lỗi, thử lại sau {wait_time}s... (Lần {attempt + 1})")
                time.sleep(wait_time)
            else:
                print(f"Lỗi sau {max_retries} lần thử: {str(e)}")
                return None
    return None

# Hàm xử lý và lưu
def process_and_save(response, disease_code):
    try:
        cleaned = response.text.replace('```json', '').replace('```', '').strip()
        data_list = json.loads(cleaned)

        if not isinstance(data_list, list):
            raise ValueError("Kết quả không phải là danh sách JSON.")

        global df_result
        for data in data_list:
            new_row = {
                "intruction": data.get("intruction", ""),
                "question": data.get("question", ""),
                "icd10": disease_code,
                "symptom": data.get("symptom", ""),
                "diagnosis": data.get("diagnosis", ""),
                "document/title": data.get("document/title", ""),
                "document/description": data.get("document/description", ""),
                "cme/title": data.get("cme/title", ""),
                "cme/description": data.get("cme/description", "")
            }
            df_result.loc[len(df_result)] = new_row
        return True
    except Exception as e:
        print(f"\nLỗi xử lý response: {str(e)}")
        print(f"Response gốc: {response.text[:200]}...")
        return False

# Thiết lập số dòng xử lý
start_row = len(df_result)
end_row = len(df_input)
processed_count = 0
start_time = time.time()

# Vòng lặp xử lý
for index in tqdm(range(start_row, end_row)):
    row = df_input.iloc[index]
    retries = 0

    while retries < 3:
        try:
            group_name = row['TÊN NHÓM CHÍNH'].strip()
            disease_code = row['MÃ BỆNH'].strip()
            disease_name = row['TÊN BỆNH'].strip()
            prompt = prompt_template.format(
                group_name=group_name,
                disease_code=disease_code,
                disease_name=disease_name
            )
            response = generate_with_retry(prompt)

            if response and process_and_save(response, disease_code):
                processed_count += 1
                df_result.to_excel(output_file, index=False)
                time.sleep(2)
                break
            else:
                retries += 1
                print(f"Retry dòng {index} - Lần {retries}")
                time.sleep(3)

        except Exception as e:
            print(f"\nLỗi dòng {index}: {str(e)}")
            retries += 1
            time.sleep(3)

# Lưu cuốil
df_result.to_excel(output_file, index=False)
total_time = (time.time() - start_time) / 60
print(f"\nHoàn thành! Đã xử lý {processed_count} dòng.")
print(f"Thời gian chạy: {total_time:.2f} phút")
print(f"File kết quả: {output_file}")
# Out:
# Đã đọc file Excel với 10214 dòng văn bản.
#   0%|          | 8/1978 [06:16<25:46:02, 47.09s/it]
# Lỗi xử lý response: Invalid control character at: line 16 column 80 (char 2809)
# Response gốc: ```json
# [
#   {
#     "intruction": "Chatbot y khoa chuyên về y khoa, cung cấp thông tin và tư vấn lâm sàng về các tổn thương dập nát đa vùng dựa trên phân loại ICD-10 T04.7.",
#     "question": "Một bệnh n...
# Retry dòng 8244 - Lần 1
#   2%|▏         | 33/1978 [27:48<25:42:14, 47.58s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 16.239687929s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 16
# }
# ]
# Retry dòng 8269 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 57.921662971s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 57
# }
# ]
# Retry dòng 8269 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 39.63833738s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# Retry dòng 8269 - Lần 3
#   2%|▏         | 34/1978 [28:43<26:52:29, 49.77s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 21.353911361s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ]
# Retry dòng 8270 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 3.094890345s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
# Retry dòng 8270 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 44.782831968s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 44
# }
# ]
# Retry dòng 8270 - Lần 3
#   2%|▏         | 35/1978 [29:38<27:41:07, 51.30s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 26.474866593s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 26
# }
# ]
# Retry dòng 8271 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 8.202212891s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 8
# }
# ]
# Retry dòng 8271 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 49.93868626s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 49
# }
# ]
# Retry dòng 8271 - Lần 3
#   2%|▏         | 36/1978 [30:33<28:14:42, 52.36s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 31.632474238s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 31
# }
# ]
# Retry dòng 8272 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 13.350248238s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 13
# }
# ]
# Retry dòng 8272 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 55.094106648s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 55
# }
# ]
# Retry dòng 8272 - Lần 3
#   2%|▏         | 37/1978 [31:28<28:37:58, 53.11s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 36.834040741s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# Retry dòng 8273 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 18.57866032s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 18
# }
# ]
# Retry dòng 8273 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 321.910394ms. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# Retry dòng 8273 - Lần 3
#   2%|▏         | 38/1978 [32:23<28:53:16, 53.61s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 42.046064179s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# Retry dòng 8274 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 23.799840513s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 23
# }
# ]
# Retry dòng 8274 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 5.526879166s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 5
# }
# ]
# Retry dòng 8274 - Lần 3
#   2%|▏         | 39/1978 [33:17<29:03:51, 53.96s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 47.27153511s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Retry dòng 8275 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 29.023951448s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 29
# }
# ]
# Retry dòng 8275 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 10.776081371s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 10
# }
# ]
# Retry dòng 8275 - Lần 3
#   2%|▏         | 40/1978 [34:12<29:10:36, 54.20s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 52.459726748s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Retry dòng 8276 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 34.188117792s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 34
# }
# ]
# Retry dòng 8276 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 15.934423184s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 15
# }
# ]
# Retry dòng 8276 - Lần 3
#   2%|▏         | 41/1978 [35:07<29:15:59, 54.39s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 57.688543255s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 57
# }
# ]
# Retry dòng 8277 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 39.408192524s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# Retry dòng 8277 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 21.132535104s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ]
# Retry dòng 8277 - Lần 3
#   2%|▏         | 42/1978 [36:02<29:19:01, 54.52s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 2.86815219s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 2
# }
# ]
# Retry dòng 8278 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 44.607293572s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 44
# }
# ]
# Retry dòng 8278 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 26.355391081s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 26
# }
# ]
# Retry dòng 8278 - Lần 3
#   2%|▏         | 43/1978 [36:57<29:20:44, 54.60s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 8.093939328s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 8
# }
# ]
# Retry dòng 8279 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 49.841077908s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 49
# }
# ]
# Retry dòng 8279 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 31.585262016s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 31
# }
# ]
# Retry dòng 8279 - Lần 3
#   2%|▏         | 44/1978 [37:51<29:21:24, 54.65s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 13.228243864s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 13
# }
# ]
# Retry dòng 8280 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 54.945008455s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
# Retry dòng 8280 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 36.680396575s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# Retry dòng 8280 - Lần 3
#   2%|▏         | 45/1978 [38:46<29:22:59, 54.72s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 18.445990291s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 18
# }
# ]
# Retry dòng 8281 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 194.362205ms. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# Retry dòng 8281 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 41.941698378s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ]
# Retry dòng 8281 - Lần 3
#   2%|▏         | 46/1978 [39:41<29:22:16, 54.73s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 23.666521239s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 23
# }
# ]
# Retry dòng 8282 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 5.399194337s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 5
# }
# ]
# Retry dòng 8282 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 47.118999928s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
# Retry dòng 8282 - Lần 3
#   2%|▏         | 47/1978 [40:36<29:22:16, 54.76s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 28.846108646s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
# Retry dòng 8283 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 10.578399174s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 10
# }
# ]
# Retry dòng 8283 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 52.304693438s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# Retry dòng 8283 - Lần 3
#   2%|▏         | 48/1978 [41:31<29:21:54, 54.77s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 34.047698588s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 34
# }
# ]
# Retry dòng 8284 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 15.778274383s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 15
# }
# ]
# Retry dòng 8284 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 57.53589582s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 57
# }
# ]
# Retry dòng 8284 - Lần 3
#   2%|▏         | 49/1978 [42:25<29:20:56, 54.77s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 39.286985962s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# Retry dòng 8285 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 21.012690606s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 21
# }
# ]
# Retry dòng 8285 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 2.695437123s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 2
# }
# ]
# Retry dòng 8285 - Lần 3
#   3%|▎         | 50/1978 [43:20<29:20:47, 54.80s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 44.358036309s. [violations {
# ...
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
# Retry dòng 8341 - Lần 3
#   5%|▌         | 106/1978 [1:34:37<28:32:19, 54.88s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 27.806460374s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 27
# }
# ]
# Retry dòng 8342 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 9.259573438s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 9
# }
# ]
# Retry dòng 8342 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 49.524382635s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 49
# }
# ]
# Retry dòng 8342 - Lần 3
#   5%|▌         | 107/1978 [1:35:33<28:49:35, 55.47s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 30.451201719s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 30
# }
# ]
# Retry dòng 8343 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 12.203867494s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 12
# }
# ]
# Retry dòng 8343 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 53.955040968s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 53
# }
# ]
# Retry dòng 8343 - Lần 3
#   5%|▌         | 108/1978 [1:36:29<28:49:41, 55.50s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 35.714179224s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 35
# }
# ]
# Retry dòng 8344 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 17.441706703s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ]
# Retry dòng 8344 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 59.08700396s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 59
# }
# ]
# Retry dòng 8344 - Lần 3
#   6%|▌         | 109/1978 [1:37:24<28:42:54, 55.31s/it]
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 39.314393233s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# Retry dòng 8345 - Lần 1
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
# Lỗi sau 3 lần thử: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 17.010685472s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ]
# Retry dòng 8345 - Lần 2
# Lỗi, thử lại sau 5s... (Lần 1)
# Lỗi, thử lại sau 10s... (Lần 2)
#   6%|▌         | 109/1978 [1:38:21<28:06:32, 54.14s/it]
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[5], line 75, in generate_with_retry(prompt, max_retries)
#      74 try:
# ---> 75     response = model.generate_content(prompt)
#      76     if response.text:
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     330 else:
# --> 331     response = self._client.generate_content(
#     332         request,
#     333         **request_options,
#     334     )
#     335     return generation_types.GenerateContentResponse.from_response(response)
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146 try:
# --> 147     result = target()
#     148     if inspect.isawaitable(result):
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 250
# Please retry in 8.86347553s. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 250
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 8
# }
# ]
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 138
#     132 disease_name = row['TÊN BỆNH'].strip()
#     133 prompt = prompt_template.format(
#     134     group_name=group_name,
#     135     disease_code=disease_code,
#     136     disease_name=disease_name
#     137 )
# --> 138 response = generate_with_retry(prompt)
#     140 if response and process_and_save(response, disease_code):
#     141     processed_count += 1
#
# Cell In[5], line 82, in generate_with_retry(prompt, max_retries)
#      80     wait_time = (attempt + 1) * 5
#      81     print(f"Lỗi, thử lại sau {wait_time}s... (Lần {attempt + 1})")
# ---> 82     time.sleep(wait_time)
#      83 else:
#      84     print(f"Lỗi sau {max_retries} lần thử: {str(e)}")
#
# KeyboardInterrupt:
