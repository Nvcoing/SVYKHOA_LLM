# %%
from datasets import load_dataset
from transformers import MT5Tokenizer, MT5ForConditionalGeneration
from tqdm import tqdm
import pandas as pd
import torch
import os

# Kiểm tra GPU
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cuda" )
print(f"💻 Đang sử dụng thiết bị: {device}")

# Load model paraphrase và đưa lên GPU
CKPT = 'chieunq/vietnamese-sentence-paraphase'
tokenizer = MT5Tokenizer.from_pretrained(CKPT)
model = MT5ForConditionalGeneration.from_pretrained(CKPT).to(device)

# Hàm tạo paraphrase
def paraphrase(text, num_return_sequences=5):
    inputs = tokenizer(text, padding='longest', max_length=512, truncation=True, return_tensors='pt')
    inputs = {key: val.to(device) for key, val in inputs.items()}
    output = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_length=512,
        num_return_sequences=num_return_sequences,
        do_sample=True,
        top_p=0.95
    )
    return [tokenizer.decode(o, skip_special_tokens=True) for o in output]

# Load dataset
dataset = pd.read_parquet("../generate_dataset/SVYKHOA_dataset_diagnosis.parquet", engine="fastparquet")

# File Excel đầu ra
output_file = "SVYKHOA_dataset_diagnosis_5.xlsx"

# Tạo file Excel rỗng nếu chưa có
if not os.path.exists(output_file):
    df_empty = pd.DataFrame(columns=["STT CHƯƠNG", "MÃ CHƯƠNG", "TÊN NHÓM CHÍNH", "MÃ BỆNH", "TÊN BỆNH", "intruction", "question", "symptom", "diagnosis", "document/title", "document/description", "cme/title", "cme/description"])
    df_empty.to_excel(output_file, index=False)

# Đọc số dòng đã có để tiếp tục từ đó
existing_df = pd.read_excel(output_file)
# start_index = len(existing_df)
start_index = 25000
print(f"🚀 Bắt đầu từ dòng {start_index}")

# Số lượng mẫu muốn xử lý thêm
max_samples = 273500 - 250000  # Có thể chỉnh: 10, 100, 500...

# Duyệt dataset từ start_index
for i, row in dataset.iterrows():
    if i < start_index:
        continue
    if i >= start_index + max_samples:
        break
    print(row)

    question = row["question"]   # row là Series
    try:
        paraphrases = paraphrase(question, num_return_sequences=10)
    except Exception as e:
        print(f"Lỗi paraphrase tại mẫu {i}: {e}")
        paraphrases = [question]

    new_rows = []
    for pq in paraphrases:
        new_rows.append({
            "STT CHƯƠNG": row["STT CHƯƠNG"],
            "MÃ CHƯƠNG": row["MÃ CHƯƠNG"],
            "TÊN NHÓM CHÍNH": row["TÊN NHÓM CHÍNH"],
            "MÃ BỆNH": row["MÃ BỆNH"],
            "TÊN BỆNH": row["TÊN BỆNH"],
            "intruction": row["intruction"],
            "question": pq,
            "symptom": row["symptom"],
            "diagnosis": row["diagnosis"],
            "document/title": row["document/title"],
            "document/description": row["document/description"],
            "cme/title": row["cme/title"],
            "cme/description": row["cme/description"]
        })

    new_df = pd.DataFrame(new_rows)
    with pd.ExcelWriter(output_file, mode="a", engine="openpyxl", if_sheet_exists="overlay") as writer:
        sheet = writer.sheets["Sheet1"]
        start_row = sheet.max_row
        new_df.to_excel(writer, header=False, index=False, startrow=start_row)


print("✅ Đã lưu toàn bộ dữ liệu paraphrase vào file Excel.")
# Out:
# 💻 Đang sử dụng thiết bị: cuda
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'T5Tokenizer'.
# The class this function is called from is 'MT5Tokenizer'.
# You are using the default legacy behaviour of the <class 'transformers.models.mt5.tokenization_mt5.MT5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# 🚀 Bắt đầu từ dòng 25000
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Mối liên quan giữa tình trạng tăng đường huyết...
# symptom                 Bệnh nhân có nồng độ glucose trong máu lúc nhậ...
# diagnosis               Tình trạng tăng đường huyết, được xác định qua...
# document/title          Mối liên quan giữa tăng đường huyết và vết mổ ...
# document/description    Nghiên cứu tiến cứu nhằm xác định mối liên qua...
# cme/title               Quản lý đường huyết perioperative để tối ưu hó...
# cme/description         Khóa học tập trung vào các chiến lược sàng lọc...
# Name: 25000, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các yếu tố nguy cơ nhiễm khuẩn vết mổ sau phẫu...
# symptom                 Các yếu tố nguy cơ được xác định bao gồm tiền ...
# diagnosis               Mặc dù nghiên cứu không ghi nhận các trường hợ...
# document/title          Hệ thống tính điểm ASEPSIS để đánh giá vết mổ ...
# document/description    Tài liệu tham khảo mô tả chi tiết về hệ thống ...
# cme/title               Thực hành sử dụng thang điểm ASEPSIS và quản l...
# cme/description         Khóa học này tập trung vào việc hướng dẫn thực...
# Name: 25001, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thang điểm ASEPSIS được sử dụng như thế nào để...
# symptom                 Điểm ASEPSIS được sử dụng để đánh giá mức độ n...
# diagnosis               Thang điểm ASEPSIS là một công cụ đánh giá lâm...
# document/title          Ứng dụng thang điểm ASEPSIS trong Đánh giá và ...
# document/description    Tài liệu này cung cấp hướng dẫn chi tiết về cá...
# cme/title               Phòng ngừa và Chẩn đoán Nhiễm trùng Vết mổ Bằn...
# cme/description         Khóa học đào tạo CME chuyên sâu về các phương ...
# Name: 25002, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Mối liên hệ giữa đái tháo đường, đường huyết t...
# symptom                 ['Tiền sử đái tháo đường (ĐTĐ).', 'Nồng độ glu...
# diagnosis               Bệnh nhân đái tháo đường và/hoặc có nồng độ gl...
# document/title          Mối liên hệ giữa Đái tháo đường, Nồng độ Gluco...
# document/description    Tài liệu này phân tích mối liên hệ có ý nghĩa ...
# cme/title               Quản lý Đường huyết và Phòng ngừa Nhiễm trùng ...
# cme/description         Khóa học cung cấp kiến thức cập nhật về các ch...
# Name: 25003, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nhiễm trùng vết mổ sau phẫu thuật Fontan có tỷ...
# symptom                 Nhiễm trùng vết mổ là một trong những biến chứ...
# diagnosis               Chẩn đoán nhiễm trùng vết mổ hậu phẫu (T81.4) ...
# document/title          Phòng ngừa và điều trị nhiễm trùng vết mổ sau ...
# document/description    Tài liệu này cung cấp các hướng dẫn lâm sàng c...
# cme/title               Chiến lược kiểm soát nhiễm khuẩn bệnh viện tro...
# cme/description         Khóa học tập trung vào các biện pháp phòng ngừ...
# Name: 25004, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các biến chứng hậu phẫu thường gặp sau phẫu th...
# symptom                 Trong số 65 bệnh nhân, có 2 trường hợp (chiếm ...
# diagnosis               Chẩn đoán biến chứng hậu phẫu là Nhiễm trùng v...
# document/title          Tạp chí Y học Việt Nam số 03 - Tháng 9 - 2024:...
# document/description    Bài viết trình bày kết quả nghiên cứu về các b...
# cme/title               Quản lý và Phòng ngừa Nhiễm trùng Vết mổ trong...
# cme/description         Khóa học này cung cấp kiến thức chuyên sâu về ...
# Name: 25005, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các loại hình phẫu thuật cố định cột sống thắt...
# symptom                 Các cách thức mổ của đối tượng nghiên cứu (n=2...
# diagnosis               Phẫu thuật cố định cột sống thắt lưng cùng, gi...
# document/title          Đánh giá Các Kỹ thuật Phẫu thuật TLIF và Biến ...
# document/description    Nghiên cứu này chi tiết hóa các cách thức thực...
# cme/title               Phòng ngừa và Điều trị Nhiễm trùng Vết mổ tron...
# cme/description         Khóa học đào tạo y khoa liên tục này trang bị ...
# Name: 25006, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để phát hiện sớm nhiễm trùng vết m...
# symptom                 Tỷ lệ đối tượng nghiên cứu có biến chứng nhiễm...
# diagnosis               Nhiễm trùng sau thủ thuật (T81.4), đặc biệt là...
# document/title          Đặc điểm lâm sàng và kết quả phẫu thuật TLIF c...
# document/description    Tạp chí Y học Việt Nam cung cấp thông tin về t...
# cme/title               Phòng ngừa, chẩn đoán và điều trị nhiễm khuẩn ...
# cme/description         Khóa học CME này tập trung vào các chiến lược ...
# Name: 25007, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sau phẫu thuật cột sống TLIF, tôi cần lưu ý gì...
# symptom                 Ngày thứ 3 sau phẫu thuật, các chỉ số dấu hiệu...
# diagnosis               Phục hồi sau phẫu thuật TLIF thường tốt, với đ...
# document/title          Hướng dẫn theo dõi hậu phẫu và phòng ngừa biến...
# document/description    Tài liệu này cung cấp các khuyến nghị và hướng...
# cme/title               Quản lý chăm sóc bệnh nhân sau phẫu thuật cột ...
# cme/description         Khóa học CME này tập trung vào các phương pháp...
# Name: 25008, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nhiễm khuẩn bệnh viện là gì, tỷ lệ mắc bệnh hi...
# symptom                 Các dấu hiệu lâm sàng chung của nhiễm khuẩn bệ...
# diagnosis               Chẩn đoán chung là Nhiễm khuẩn bệnh viện (NKBV...
# document/title          THỰC TRẠNG NHIỄM KHUẨN BỆNH VIỆN TẠI CÁC KHOA ...
# document/description    Nghiên cứu mô tả cắt ngang có phân tích trên 3...
# cme/title               Kiểm soát nhiễm khuẩn bệnh viện: Từ lý thuyết ...
# cme/description         Khóa học đào tạo y khoa liên tục về các nguyên...
# Name: 25009, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những biến chứng sớm và muộn nào thường gặp sa...
# symptom                 Các biến chứng sớm bao gồm: nhiễm trùng vết mổ...
# diagnosis               Chẩn đoán các biến chứng hậu phẫu đòi hỏi sự t...
# document/title          Quản lý toàn diện biến chứng sau phẫu thuật ch...
# document/description    Tài liệu này trình bày các chiến lược nhận diệ...
# cme/title               Phục hồi chức năng và quản lý biến chứng dài h...
# cme/description         Khóa học trang bị kiến thức chuyên sâu về phục...
# Name: 25010, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những thương tật thứ cấp thường gặp ở bệnh nhâ...
# symptom                 Bệnh nhân cao tuổi (trên 60 tuổi, tuổi trung b...
# diagnosis               Các thương tật thứ cấp phổ biến sau phẫu thuật...
# document/title          ROLE OF REHABILITATION IN ELDERLY PATIENTS AFT...
# document/description    Bản tóm tắt tiếng Anh của nghiên cứu về vai tr...
# cme/title               Phòng ngừa và Điều trị Biến chứng hậu phẫu Ung...
# cme/description         CME này trang bị cho các chuyên gia y tế kiến ...
# Name: 25011, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sau phẫu thuật u tầng trước nền sọ bằng kỹ thu...
# symptom                 Bệnh nhân sau phẫu thuật u tầng trước nền sọ c...
# diagnosis               Mặc dù kỹ thuật vi phẫu thuật mở nắp sọ lỗ kho...
# document/title          KẾT QUẢ PHẪU THUẬT U TẦNG TRƯỚC NỀN SỌ BẰNG PH...
# document/description    Tài liệu này phân tích chi tiết các kết quả th...
# cme/title               Phòng ngừa và xử trí biến chứng trong phẫu thu...
# cme/description         Khóa học CME này tập trung vào các chiến lược ...
# Name: 25012, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Kháng sinh dự phòng có hiệu quả như thế nào tr...
# symptom                 Các dấu hiệu của nhiễm khuẩn vết mổ (nếu không...
# diagnosis               Nghiên cứu chỉ ra rằng sử dụng kháng sinh dự p...
# document/title          ĐÁNH GIÁ TÌNH HÌNH SỬ DỤNG KHÁNG SINH DỰ PHÒNG...
# document/description    Nghiên cứu tiến cứu trên 142 bệnh nhân phẫu th...
# cme/title               Cập nhật Hướng dẫn sử dụng Kháng sinh Dự phòng...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về các ...
# Name: 25013, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những loại phẫu thuật nào được chỉ định sử dụn...
# symptom                 Các dấu hiệu cảnh báo nguy cơ nhiễm khuẩn vết ...
# diagnosis               Kháng sinh dự phòng (KSDP) được chỉ định cho c...
# document/title          ĐÁNH GIÁ TÌNH HÌNH SỬ DỤNG KHÁNG SINH DỰ PHÒNG...
# document/description    Bài viết nghiên cứu các đặc điểm của bệnh nhân...
# cme/title               Phân loại vết mổ và Chỉ định Kháng sinh Dự phò...
# cme/description         Khóa học này đào tạo chuyên sâu về cách phân l...
# Name: 25014, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nhiễm khuẩn vết mổ sau phẫu thuật phổ biến ở m...
# symptom                 Các triệu chứng của nhiễm khuẩn vết mổ (NKVM) ...
# diagnosis               Nhiễm khuẩn vết mổ (NKVM) là một biến chứng ph...
# document/title          ĐÁNH GIÁ TÌNH HÌNH SỬ DỤNG KHÁNG SINH DỰ PHÒNG...
# document/description    Tạp chí Y học Việt Nam đăng tải nghiên cứu này...
# cme/title               Kiểm soát Nhiễm khuẩn Bệnh viện và Kháng sinh ...
# cme/description         Khóa học đào tạo y khoa liên tục này tập trung...
# Name: 25015, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Theo nghiên cứu, phác đồ kháng sinh dự phòng đ...
# symptom                 Nghiên cứu trên 142 bệnh nhân phẫu thuật sạch ...
# diagnosis               Phác đồ KSDP được nghiên cứu bao gồm Cephalosp...
# document/title              Tạp chí Y học Việt Nam số 01 - Tháng 7 - 2023
# document/description    Nghiên cứu tiến cứu có can thiệp lâm sàng về v...
# cme/title               Cập nhật Hướng dẫn Sử dụng Kháng sinh Dự phòng...
# cme/description         Khóa học tập trung vào các khuyến nghị mới nhấ...
# Name: 25016, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Xin bác sĩ cho biết những yếu tố nào làm tăng ...
# symptom                 Tuổi trung bình của bệnh nhân nghiên cứu là 44...
# diagnosis               Bệnh nhân có nguy cơ nhiễm khuẩn vết mổ (NKVM)...
# document/title          Nghiên cứu các yếu tố nguy cơ nhiễm khuẩn vết ...
# document/description    Tài liệu này tổng hợp kết quả nghiên cứu về cá...
# cme/title               Chiến lược phòng ngừa và kiểm soát nhiễm khuẩn...
# cme/description         Khóa học đào tạo liên tục nhằm trang bị kiến t...
# Name: 25017, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Kháng sinh dự phòng (KSDP) có vai trò như thế ...
# symptom                 Thời gian nằm điều trị trung bình sau phẫu thu...
# diagnosis               Kháng sinh dự phòng (KSDP) đóng vai trò quan t...
# document/title          Hướng dẫn sử dụng kháng sinh dự phòng của Bộ Y...
# document/description    Tài liệu này cung cấp các hướng dẫn chi tiết c...
# cme/title               Cập nhật và tối ưu hóa sử dụng kháng sinh dự p...
# cme/description         Khóa học CME này tập trung vào các phác đồ KSD...
# Name: 25018, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nhiễm khuẩn vết mổ do tụ cầu vàng kháng thuốc ...
# symptom                 Tỷ lệ nhiễm khuẩn vết mổ (NKVM) do trực khuẩn ...
# diagnosis               Chẩn đoán nhiễm khuẩn vết mổ (NKVM) do tụ cầu ...
# document/title          Biến đổi vi sinh vật gây nhiễm khuẩn vết mổ và...
# document/description    Tài liệu nghiên cứu này phân tích sự thay đổi ...
# cme/title               Kiểm soát nhiễm khuẩn và quản lý MRSA trong mô...
# cme/description         Khóa học đào tạo y khoa liên tục này cung cấp ...
# Name: 25019, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các biện pháp phòng ngừa nhiễm khuẩn vết mổ sa...
# symptom                 Người bệnh được phẫu thuật thuộc nhóm phẫu thu...
# diagnosis               Nhiễm khuẩn vết mổ (NKVM) là biến chứng thường...
# document/title          ĐÁNH GIÁ TÌNH HÌNH SỬ DỤNG KHÁNG SINH DỰ PHÒNG...
# document/description    Tạp chí Y học Việt Nam, Tập 528 - Tháng 7 - Số...
# cme/title               Cập nhật Phác đồ Phòng ngừa Nhiễm khuẩn Bệnh v...
# cme/description         Khóa học này tập trung vào các chiến lược phòn...
# Name: 25020, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các yếu tố nào của người bệnh có thể ảnh hưởng...
# symptom                 Nghiên cứu trên 142 bệnh nhân cho thấy độ tuổi...
# diagnosis               Các đặc điểm của người bệnh như tuổi (đặc biệt...
# document/title          Khuyến nghị về Đánh giá và Quản lý Bệnh nền ở ...
# document/description    Tài liệu này cung cấp các hướng dẫn lâm sàng t...
# cme/title               Quản lý Đa bệnh lý và Tối ưu hóa Chăm sóc trướ...
# cme/description         Khóa học này trang bị kiến thức và kỹ năng cho...
# Name: 25021, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những yếu tố nào làm tăng nguy cơ nhiễm khuẩn ...
# symptom                 Các yếu tố nguy cơ được ghi nhận bao gồm: tuổi...
# diagnosis               Bệnh nhân có nguy cơ cao phát triển nhiễm khuẩ...
# document/title          Hướng dẫn chẩn đoán và điều trị nhiễm khuẩn vế...
# document/description    Tài liệu này cung cấp các tiêu chí chẩn đoán, ...
# cme/title               Quản lý và phòng ngừa nhiễm khuẩn vết mổ: Từ l...
# cme/description         Khóa học này cung cấp kiến thức chuyên sâu về ...
# Name: 25022, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Kháng sinh dự phòng (KSDP) có vai trò và hiệu ...
# symptom                 Phân loại phẫu thuật: Sạch và sạch - nhiễm (29...
# diagnosis               Chỉ định kháng sinh dự phòng (KSDP) cho phẫu t...
# document/title          Hướng dẫn phòng ngừa nhiễm khuẩn vết mổ của Bộ...
# document/description    Tài liệu này cung cấp các hướng dẫn và quy trì...
# cme/title               Cập nhật Hướng dẫn sử dụng kháng sinh dự phòng...
# cme/description         Khóa học nhằm trang bị kiến thức chuyên sâu và...
# Name: 25023, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những yếu tố nào làm tăng nguy cơ nhiễm khuẩn ...
# symptom                 100% bệnh nhân trong nghiên cứu đều có can thi...
# diagnosis               Chẩn đoán nguy cơ cao nhiễm khuẩn bệnh viện (Y...
# document/title          Các yếu tố nguy cơ và chiến lược phòng ngừa nh...
# document/description    Bài báo này phân tích các yếu tố nguy cơ chính...
# cme/title               Phòng ngừa và kiểm soát nhiễm khuẩn liên quan ...
# cme/description         Khóa học cung cấp kiến thức toàn diện về các p...
# Name: 25024, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sau phẫu thuật tán sỏi nội soi qua da, bệnh nh...
# symptom                 Các biến chứng sau phẫu thuật tán sỏi nội soi ...
# diagnosis               Chẩn đoán các biến chứng sau phẫu thuật tán sỏ...
# document/title               Vietnam Medical Journal N02 - JANUARY - 2023
# document/description    Bài báo khoa học từ Tạp chí Y học Việt Nam số ...
# cme/title               Quản lý biến chứng và tiêu chuẩn đánh giá kết ...
# cme/description         Khóa học này tập trung vào nhận diện, phòng ng...
# Name: 25025, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tỷ lệ và phân loại các biến chứng chung sau ph...
# symptom                 Tổng tỷ lệ biến chứng chung sau phẫu thuật là ...
# diagnosis               Các biến chứng sau phẫu thuật sỏi thận được ph...
# document/title          Đánh giá vai trò của thang điểm S.T.O.N.E. tro...
# document/description    Nghiên cứu phân tích khả năng tiên đoán của th...
# cme/title               Tiếp cận chẩn đoán và quản lý biến chứng nhiễm...
# cme/description         Khóa học cung cấp kiến thức về chẩn đoán, phòn...
# Name: 25026, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những yếu tố nào làm tăng nguy cơ biến chứng n...
# symptom                 Triệu chứng cơ năng: Sốt cao đột ngột (ví dụ: ...
# diagnosis               Biến chứng nhiễm trùng sau phẫu thuật tán sỏi ...
# document/title          The influencing factors of infectious complica...
# document/description    Tổng quan hệ thống và phân tích gộp này đã tổn...
# cme/title               Quản lý và phòng ngừa nhiễm trùng trong phẫu t...
# cme/description         Khóa học này tập trung vào các chiến lược toàn...
# Name: 25027, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Vết mổ của tôi sau phẫu thuật 7 ngày có dấu hi...
# symptom                 Các dấu hiệu lâm sàng của nhiễm trùng vết mổ b...
# diagnosis               Dựa trên các triệu chứng sưng, đỏ, đau tăng và...
# document/title          Phương pháp đánh giá chất lượng các nghiên cứu...
# document/description    Bài viết này sử dụng công cụ Newcastle-Ottawa ...
# cme/title               Phòng ngừa và xử trí nhiễm trùng vết mổ sau ph...
# cme/description         Khóa học này cung cấp kiến thức về các yếu tố ...
# Name: 25028, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi bị nhiễm trùng vết mổ sau phẫu thuật, kết ...
# symptom                 Bệnh nhân có các dấu hiệu nhiễm trùng tại vị t...
# diagnosis               Chẩn đoán: Nhiễm trùng vị trí phẫu thuật (SSI)...
# document/title          Khuyến cáo về quản lý nhiễm trùng vết mổ và kh...
# document/description    Tài liệu hướng dẫn chẩn đoán, điều trị và phòn...
# cme/title               Chiến lược kiểm soát và điều trị nhiễm khuẩn b...
# cme/description         Khóa học CME này cung cấp kiến thức chuyên sâu...
# Name: 25029, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để xử lý nhiễm trùng vết mổ do E. ...
# symptom                 Bệnh nhân sau phẫu thuật hoặc thủ thuật có biể...
# diagnosis               Nhiễm trùng vết mổ hoặc vị trí dẫn lưu do Esch...
# document/title          Quản lý nhiễm khuẩn vết mổ: Phòng ngừa và điều...
# document/description    Tài liệu này cung cấp các hướng dẫn chi tiết v...
# cme/title               Cập nhật về kháng sinh nhóm 'last-line' trong ...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về các ...
# Name: 25030, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để phòng ngừa nhiễm trùng sau phẫu...
# symptom                 Sau phẫu thuật răng miệng, có thể xuất hiện cá...
# diagnosis               Nhiễm trùng khoang miệng sau phẫu thuật, thườn...
# document/title             vietnam medical journal n02 - SEPTEMBER - 2022
# document/description    Tạp chí y học Việt Nam, số 02, tháng 9 năm 202...
# cme/title               Phòng ngừa và xử trí nhiễm trùng sau phẫu thuậ...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về các ...
# Name: 25031, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để phòng ngừa nhiễm trùng sau phẫu...
# symptom                 Các triệu chứng của nhiễm trùng sau phẫu thuật...
# diagnosis               Nhiễm trùng vết mổ sau phẫu thuật răng miệng. ...
# document/title          Tạp chí Y học Việt Nam số 02 - THÁNG 9 - 2022:...
# document/description    Bài báo khoa học nghiên cứu về việc xây dựng c...
# cme/title               Kiểm soát nhiễm khuẩn trong phẫu thuật miệng v...
# cme/description         Khóa học đào tạo y khoa liên tục này cung cấp ...
# Name: 25032, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.4
# TÊN BỆNH                Nhiễm trùng sau thủ thuật, không xếp loại ở nơ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để xử trí các biến chứng như chậm ...
# symptom                 Chậm liền thương một phần vết mổ (ghi nhận ở 4...
# diagnosis               Biến chứng chậm liền thương vết mổ và nhiễm tr...
# document/title          The Posterior Arm Free Flap: Plastic and Recon...
# document/description    Nghiên cứu ban đầu của Masquelet AC và cộng sự...
# cme/title               Phẫu thuật Tái Tạo Phức Tạp và Quản lý Nhiễm T...
# cme/description         Khóa học nâng cao về kỹ thuật tái tạo phức tạp...
# Name: 25033, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.7
# TÊN BỆNH                Biến chứng huyết quản sau thủ thuật, không xếp...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Phác đồ xử trí đối với biến chứng ho ra máu lư...
# symptom                 Ho ra máu lượng nhiều sau sinh thiết xuyên thà...
# diagnosis               Biến chứng xuất huyết phổi nặng sau sinh thiết...
# document/title          Nghiên cứu về tỉ lệ và các yếu tố liên quan đế...
# document/description    Nghiên cứu mô tả tỉ lệ và các yếu tố liên quan...
# cme/title               Can thiệp mạch trong biến chứng sau thủ thuật ...
# cme/description         Chương trình đào tạo chuyên sâu về chẩn đoán v...
# Name: 25034, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.7
# TÊN BỆNH                Biến chứng huyết quản sau thủ thuật, không xếp...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sự khác biệt về lợi ích và rủi ro giữa tiếp cậ...
# symptom                 Tiếp cận qua động mạch đùi là tiêu chuẩn truyề...
# diagnosis               So sánh giữa tiếp cận động mạch quay và động m...
# document/title          KẾT QUẢ BĂNG ÉP VỊ TRÍ CHỌC ĐỘNG MẠCH TRONG PH...
# document/description    Bài báo cung cấp cái nhìn chi tiết về các lựa ...
# cme/title               Lựa Chọn Đường Vào Mạch Máu và Quản Lý Sau Thủ...
# cme/description         Khóa học này phân tích sâu về việc lựa chọn đư...
# Name: 25035, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.7
# TÊN BỆNH                Biến chứng huyết quản sau thủ thuật, không xếp...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những yếu tố nguy cơ nào có thể ảnh hưởng đến ...
# symptom                 Các yếu tố nguy cơ ảnh hưởng đến kết quả băng ...
# diagnosis               Đánh giá nguy cơ biến chứng mạch máu tại vị tr...
# document/title          KẾT QUẢ BĂNG ÉP VỊ TRÍ CHỌC ĐỘNG MẠCH TRONG PH...
# document/description    Nghiên cứu này đã xác định các yếu tố nguy cơ ...
# cme/title               Tối ưu hóa Chiến lược Can thiệp Tim mạch: Đánh...
# cme/description         Khóa học tập trung vào việc nhận diện, đánh gi...
# Name: 25036, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.7
# TÊN BỆNH                Biến chứng huyết quản sau thủ thuật, không xếp...
# intruction              Chatbot y khoa chuyên về tim mạch, cung cấp th...
# question                Các biến chứng mạch máu thường gặp tại vị trí ...
# symptom                 Các triệu chứng và dấu hiệu lâm sàng được ghi ...
# diagnosis               Chẩn đoán biến chứng mạch máu tại vị trí tiếp ...
# document/title          Tỷ lệ và đặc điểm biến chứng mạch máu tại vị t...
# document/description    Tài liệu này trình bày các kết quả nghiên cứu ...
# cme/title               Nhận diện và quản lý biến chứng mạch máu sau t...
# cme/description         Khóa học đào tạo y khoa liên tục này tập trung...
# Name: 25037, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.7
# TÊN BỆNH                Biến chứng huyết quản sau thủ thuật, không xếp...
# intruction              Chatbot y khoa chuyên về tim mạch, cung cấp th...
# question                Những yếu tố nào liên quan đến nguy cơ xảy ra ...
# symptom                 Nghiên cứu chỉ ra rằng giới tính có mối liên q...
# diagnosis               Các yếu tố nguy cơ liên quan đến biến chứng sa...
# document/title          Mối liên quan giữa đặc điểm đối tượng nghiên c...
# document/description    Bài nghiên cứu phân tích các yếu tố nhân khẩu ...
# cme/title               Đánh giá nguy cơ cá thể và tối ưu hóa chiến lư...
# cme/description         Khóa học này cung cấp kiến thức toàn diện về c...
# Name: 25038, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.7
# TÊN BỆNH                Biến chứng huyết quản sau thủ thuật, không xếp...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những biến chứng mạch máu nào thường gặp sau c...
# symptom                 Các triệu chứng có thể bao gồm tụ máu (chiếm 7...
# diagnosis               Chẩn đoán biến chứng mạch máu sau thủ thuật ca...
# document/title          Tạp chí Y học Việt Nam - Nghiên cứu về Biến ch...
# document/description    Báo cáo nghiên cứu đăng trên Tạp chí Y học Việ...
# cme/title               Cập nhật Chẩn đoán và Xử trí Biến chứng Mạch m...
# cme/description         Khóa học đào tạo y khoa liên tục tập trung vào...
# Name: 25039, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.7
# TÊN BỆNH                Biến chứng huyết quản sau thủ thuật, không xếp...
# intruction              Chatbot y khoa chuyên về can thiệp tim mạch, c...
# question                Giả phình mạch là gì và làm thế nào để chẩn đo...
# symptom                 Giả phình mạch tại vị trí chọc động mạch được ...
# diagnosis               Giả phình động mạch (pseudoaneurysm) là một bi...
# document/title          KẾT QUẢ BĂNG ÉP VỊ TRÍ CHỌC ĐỘNG MẠCH TRONG PH...
# document/description    Tài liệu này cung cấp dữ liệu về tỷ lệ giả phì...
# cme/title               Chẩn Đoán và Điều Trị Giả Phình Mạch Sau Can T...
# cme/description         Khóa học chuyên sâu này tập trung vào cơ chế b...
# Name: 25040, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.7
# TÊN BỆNH                Biến chứng huyết quản sau thủ thuật, không xếp...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Giả phình mạch và tắc mạch, những biến chứng m...
# symptom                 Các dấu hiệu và triệu chứng của giả phình mạch...
# diagnosis               Biến chứng giả phình mạch (1.7%) và tắc mạch (...
# document/title              Tạp chí Y học Việt Nam số 02 - THÁNG 1 - 2025
# document/description    Bài báo khoa học mô tả các đặc điểm lâm sàng, ...
# cme/title               Quản lý và điều trị giả phình mạch, tắc mạch s...
# cme/description         Khóa học tập trung vào các chiến lược quản lý ...
# Name: 25041, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.7
# TÊN BỆNH                Biến chứng huyết quản sau thủ thuật, không xếp...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các loại biến chứng mạch máu thường gặp tại vị...
# symptom                 Các biến chứng mạch máu tại vị trí băng ép đượ...
# diagnosis               Chẩn đoán biến chứng mạch máu tại vị trí băng ...
# document/title          Nghiên cứu tỷ lệ và yếu tố liên quan đến biến ...
# document/description    Bài báo khoa học từ Tạp chí Y học Việt Nam (Tậ...
# cme/title               Cập nhật chẩn đoán và quản lý biến chứng mạch ...
# cme/description         Khóa học đào tạo y khoa liên tục này tập trung...
# Name: 25042, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.7
# TÊN BỆNH                Biến chứng huyết quản sau thủ thuật, không xếp...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các đặc điểm của quy trình kỹ thuật can thiệp ...
# symptom                 Các biến chứng mạch máu (tụ máu 7,8%, chảy máu...
# diagnosis               Chẩn đoán các biến chứng mạch máu tại vị trí b...
# document/title          Ảnh hưởng của đặc điểm quy trình kỹ thuật đến ...
# document/description    Nghiên cứu này từ Tạp chí Y học Việt Nam (Tập ...
# cme/title               Tối ưu hóa kỹ thuật can thiệp để giảm thiểu bi...
# cme/description         Khóa học này tập trung vào việc áp dụng các kỹ...
# Name: 25043, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.7
# TÊN BỆNH                Biến chứng huyết quản sau thủ thuật, không xếp...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những biến chứng và tai biến nào có thể xảy ra...
# symptom                 Sau can thiệp điều trị vỡ túi phình động mạch ...
# diagnosis               Sau phẫu thuật can thiệp vỡ túi phình động mạc...
# document/title          Đánh giá kết quả điều trị và quản lý biến chứn...
# document/description    Bài báo này trình bày các chỉ tiêu đánh giá kế...
# cme/title               Quản lý biến chứng thần kinh sau phẫu thuật tú...
# cme/description         Khóa học tập trung vào chiến lược phòng ngừa, ...
# Name: 25044, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.7
# TÊN BỆNH                Biến chứng huyết quản sau thủ thuật, không xếp...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các yếu tố nào làm tăng nguy cơ biến chứng tắc...
# symptom                 - Chiều dài cuống mạch không tối ưu: Cuống mạc...
# diagnosis               Chẩn đoán nguy cơ tắc nghẽn mạch máu vạt da do...
# document/title                          VIETNAM MEDICAL JOURNAL, NO1/2023
# document/description    Phân tích các yếu tố kỹ thuật và giải phẫu ảnh...
# cme/title               Quản lý Biến chứng trong Phẫu thuật Tái tạo bằ...
# cme/description         Khóa học này trang bị kiến thức và kỹ năng nhậ...
# Name: 25045, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.7
# TÊN BỆNH                Biến chứng huyết quản sau thủ thuật, không xếp...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để giảm thiểu nguy cơ tắc mạch do ...
# symptom                 Nguy cơ tắc mạch do cuống mạch quá dài hoặc xo...
# diagnosis               Để giảm thiểu biến chứng tắc mạch do cuống mạc...
# document/title          Phòng ngừa biến chứng mạch máu trong phẫu thuậ...
# document/description    Tài liệu này phân tích các yếu tố giải phẫu ản...
# cme/title               Quản lý và phòng ngừa biến chứng trong phẫu th...
# cme/description         Khóa học này cung cấp kiến thức chuyên sâu về ...
# Name: 25046, dtype: object
# STT CHƯƠNG                                                            XIX
# MÃ CHƯƠNG                                                         S00-T98
# TÊN NHÓM CHÍNH          Biến chứng phẫu thuật và chăm sóc y tế không x...
# MÃ BỆNH                                                             T81.8
# TÊN BỆNH                Biến chứng khác của thủ thuật, không xếp loại ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các biến chứng thường gặp sau phẫu thuật tán s...
# symptom                 Tỷ lệ biến chứng chung sau soi đường mật trong...
# diagnosis               Chẩn đoán biến chứng sau phẫu thuật tán sỏi đư...
# ...
# cme/description         Khóa học này tập trung vào cách phân tích dữ l...
# Name: 27333, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z98.8
# TÊN BỆNH                            Các tình trạng hậu phẫu xác định khác
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những tiêu chuẩn nào cần được xem xét khi quyế...
# symptom                 Bệnh nhân đái tháo đường type 2 trong độ tuổi ...
# diagnosis               Việc cho phép bệnh nhân đái tháo đường type 2 ...
# document/title          Ảnh hưởng của việc uống dịch trong trước mổ lê...
# document/description    Tài liệu này không chỉ trình bày kết quả nghiê...
# cme/title               Đánh giá tiền phẫu toàn diện và lựa chọn bệnh ...
# cme/description         Khóa học cung cấp kiến thức và kỹ năng thực hà...
# Name: 27334, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z98.8
# TÊN BỆNH                            Các tình trạng hậu phẫu xác định khác
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những yếu tố nào ảnh hưởng đến kết quả tổng th...
# symptom                 Đánh giá chung của implant sau 6 tháng theo dõ...
# diagnosis               Kết quả tổng thể của cấy ghép implant sau 6 th...
# document/title          Đánh giá kết quả cấy ghép implant và các yếu t...
# document/description    Tài liệu này cung cấp một cái nhìn toàn diện v...
# cme/title               Tối ưu hóa thành công của cấy ghép implant: Từ...
# cme/description         Khóa học này bao gồm các chủ đề về lập kế hoạc...
# Name: 27335, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z98.8
# TÊN BỆNH                            Các tình trạng hậu phẫu xác định khác
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sau phẫu thuật tái tạo lưỡi bằng vạt cánh tay ...
# symptom                 Sau 6 tháng tái tạo lưỡi, các triệu chứng cần ...
# diagnosis               Sau 6 tháng tái tạo lưỡi bằng vạt cánh tay bên...
# document/title                                     Tạp chí Y học Việt Nam
# document/description    Tập san khoa học chuyên ngành y tế, cung cấp c...
# cme/title               Chăm sóc và Phục hồi Chức năng Sau Phẫu thuật ...
# cme/description         Khóa học này cung cấp kiến thức về quy trình c...
# Name: 27336, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z98.8
# TÊN BỆNH                            Các tình trạng hậu phẫu xác định khác
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Quy trình phẫu thuật và các phát hiện trong qu...
# symptom                 Chẩn đoán trước mổ là Ung thư thùy trên phổi p...
# diagnosis               Bệnh nhân được hội chẩn đa chuyên khoa và chỉ ...
# document/title          Kỹ thuật phẫu thuật nội soi cắt thùy phổi và n...
# document/description    Tài liệu chi tiết các bước chuẩn bị, tiến hành...
# cme/title               Quản lý ung thư phổi đa tổn thương: Tiếp cận p...
# cme/description         Khóa học này khám phá các chiến lược phẫu thuậ...
# Name: 27337, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z99.1
# TÊN BỆNH                                                Phụ thuộc máy thở
# intruction              Chatbot y khoa chuyên về Hồi sức cấp cứu và Hô...
# question                Ứng dụng siêu âm cơ hoành như thế nào để đánh ...
# symptom                 Bệnh nhân nặng đang trong quá trình cai máy th...
# diagnosis               Chẩn đoán rối loạn chức năng cơ hoành và đánh ...
# document/title          How we use ultrasound in the management of wea...
# document/description    Bài báo này cung cấp cái nhìn tổng quan về các...
# cme/title               Kỹ thuật và ứng dụng Siêu âm cơ hoành trong Hồ...
# cme/description         Khóa học thực hành chuyên sâu về kỹ thuật siêu...
# Name: 27338, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z99.1
# TÊN BỆNH                                                Phụ thuộc máy thở
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tính tin cậy và sự đồng nhất trong đánh giá mứ...
# symptom                 Nghiên cứu được thực hiện trên 60 người bệnh t...
# diagnosis               Thang điểm RASS (Richmond Agitation-Sedation S...
# document/title          KẾT QUẢ ÁP DỤNG THANG ĐIỂM RASS TRONG THEO DÕI...
# document/description    Tài liệu này cung cấp bằng chứng về tính nhất ...
# cme/title               Huấn luyện kỹ năng đánh giá và áp dụng thang đ...
# cme/description         Khóa học thực hành nhằm nâng cao kỹ năng cho đ...
# Name: 27339, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z99.2
# TÊN BỆNH                                     Phụ thuộc chạy thận nhân tạo
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để đánh giá hiệu quả điều trị thiế...
# symptom                 Bệnh nhân đang trong quá trình điều trị thiếu ...
# diagnosis               Đánh giá hiệu quả điều trị thiếu máu bằng eryt...
# document/title          Đánh giá hiệu quả điều trị thiếu máu bằng eryt...
# document/description    Nghiên cứu này là một phần của tổng thể tạp ch...
# cme/title               Hướng dẫn sử dụng Erythropoietin trong điều tr...
# cme/description         Khóa học này cung cấp các hướng dẫn lâm sàng c...
# Name: 27340, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z99.2
# TÊN BỆNH                                     Phụ thuộc chạy thận nhân tạo
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tiêu chuẩn lựa chọn và loại trừ bệnh nhân tron...
# symptom                 Đối tượng nghiên cứu là bệnh nhân suy thận mạn...
# diagnosis               Bệnh nhân được chẩn đoán suy thận mạn giai đoạ...
# document/title          Suy thận mạn lọc máu chu kỳ tại Bệnh viện Đa k...
# document/description    Phần mô tả phương pháp nghiên cứu, chi tiết cá...
# cme/title               Phác đồ sử dụng Erythropoietin trong điều trị ...
# cme/description         Khóa học đào tạo chuyên sâu về chỉ định, liều ...
# Name: 27341, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z99.2
# TÊN BỆNH                                     Phụ thuộc chạy thận nhân tạo
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nồng độ β2 microglobulin ở bệnh nhân thận nhân...
# symptom                 Ở bệnh nhân thận nhân tạo chu kỳ, nồng độ β2 m...
# diagnosis               Bệnh nhân phụ thuộc vào lọc thận chu kỳ thường...
# document/title          Khảo sát nồng độ β2 microglobulin ở bệnh nhân ...
# document/description    Nghiên cứu mô tả cắt ngang này khảo sát nồng đ...
# cme/title               Tối ưu hóa điều trị thận nhân tạo và quản lý b...
# cme/description         Khóa học tập trung vào các chiến lược tối ưu h...
# Name: 27342, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z99.2
# TÊN BỆNH                                     Phụ thuộc chạy thận nhân tạo
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nồng độ β2 microglobulin ở bệnh nhân thận nhân...
# symptom                 Nồng độ β2 microglobulin (β2-MG) huyết thanh t...
# diagnosis               Ở bệnh nhân thận nhân tạo chu kỳ, nồng độ β2 m...
# document/title          KHẢO SÁT NỒNG ĐỘ Β2 MICROGLOBULIN Ở BỆNH NHÂN ...
# document/description    Nghiên cứu mô tả cắt ngang này khảo sát nồng đ...
# cme/title               Đánh giá và quản lý β2 microglobulin trong bện...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về sinh...
# Name: 27343, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z99.2
# TÊN BỆNH                                     Phụ thuộc chạy thận nhân tạo
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi nào cần theo dõi các chỉ số cận lâm sàng l...
# symptom                 Bệnh nhân được chẩn đoán suy thận mạn giai đoạ...
# diagnosis               Đối với bệnh nhân suy thận mạn giai đoạn cuối ...
# document/title          Khuyến cáo K/DOQI 2003 về quản lý bệnh nhân bệ...
# document/description    Tài liệu này là một bộ hướng dẫn lâm sàng quan...
# cme/title               Tiếp cận thực hành các khuyến nghị K/DOQI tron...
# cme/description         Chương trình đào tạo này hướng dẫn các bác sĩ ...
# Name: 27344, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z99.2
# TÊN BỆNH                                     Phụ thuộc chạy thận nhân tạo
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các chỉ số siêu âm tim nào được sử dụng để đán...
# symptom                 Các chỉ số siêu âm tim quan trọng để đánh giá ...
# diagnosis               Đánh giá chức năng tâm thu và tâm trương thất ...
# document/title          Nghiên cứu về tỷ lệ E/e’ và thể tích nhĩ trái ...
# document/description    Nghiên cứu này cung cấp dữ liệu định lượng về ...
# cme/title               Siêu âm tim nâng cao: Kỹ thuật và diễn giải cá...
# cme/description         Khóa học trang bị kiến thức chuyên sâu về kỹ t...
# Name: 27345, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z99.2
# TÊN BỆNH                                     Phụ thuộc chạy thận nhân tạo
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Mối quan hệ giữa thể tích siêu lọc và sự thay ...
# symptom                 Nghiên cứu đánh giá mối tương quan giữa thể tí...
# diagnosis               Ở bệnh nhân lọc máu chu kỳ, thể tích siêu lọc ...
# document/title          Quy trình kỹ thuật Lọc máu chu kỳ và Quản lý t...
# document/description    Tài liệu này mô tả chi tiết các quy trình kỹ t...
# cme/title               Chiến lược Tối ưu hóa Siêu lọc và Giám sát Huy...
# cme/description         Khóa học này cung cấp kiến thức nâng cao về cá...
# Name: 27346, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z99.2
# TÊN BỆNH                                     Phụ thuộc chạy thận nhân tạo
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những yếu tố nào liên quan đến suy dinh dưỡng ...
# symptom                 Người bệnh lọc máu chu kỳ thường đối mặt với s...
# diagnosis               Chẩn đoán suy dinh dưỡng ở người bệnh phụ thuộ...
# document/title          TÌNH TRẠNG DINH DƯỠNG VÀ MỘT SỐ YẾU TỐ LIÊN QU...
# document/description    Nghiên cứu này trình bày kết quả về tỷ lệ suy ...
# cme/title               Chiến lược can thiệp dinh dưỡng dựa trên yếu t...
# cme/description         Khóa học này khám phá các yếu tố nguy cơ gây s...
# Name: 27347, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z99.8
# TÊN BỆNH                       Phụ thuộc vào các thiết bị và dụng cụ khác
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Kỹ thuật ECMO (Oxy hóa máu qua màng ngoài cơ t...
# symptom                 Các triệu chứng lâm sàng cho thấy bệnh nhân cầ...
# diagnosis               ECMO (Extracorporeal Membrane Oxygenation) là ...
# document/title          Kỹ thuật Oxy hóa máu qua màng ngoài cơ thể (EC...
# document/description    Tổng quan về nguyên lý hoạt động, phân loại (V...
# cme/title               ECMO cơ bản: Nguyên lý và thực hành lâm sàng t...
# cme/description         Khóa học này cung cấp kiến thức nền tảng về kỹ...
# Name: 27348, dtype: object
# STT CHƯƠNG                                                            XXI
# MÃ CHƯƠNG                                                         Z00-Z99
# TÊN NHÓM CHÍNH          Những người có nguy cơ sức khỏe tiềm ẩn liên q...
# MÃ BỆNH                                                             Z99.8
# TÊN BỆNH                       Phụ thuộc vào các thiết bị và dụng cụ khác
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những nhóm bệnh nhân nào có nguy cơ cao mắc nh...
# symptom                 Các bệnh nhân có nguy cơ cao mắc nhiễm khuẩn b...
# diagnosis               Các bệnh nhân tại khoa hồi sức tích cực được c...
# document/title          THỰC TRẠNG NHIỄM KHUẨN BỆNH VIỆN TẠI CÁC KHOA ...
# document/description    Nghiên cứu này làm rõ các yếu tố nguy cơ và bố...
# cme/title               An toàn người bệnh và phòng ngừa nhiễm khuẩn t...
# cme/description         Khóa học cung cấp kiến thức và kỹ năng về các ...
# Name: 27349, dtype: object
# ✅ Đã lưu toàn bộ dữ liệu paraphrase vào file Excel.
