# %%
from datasets import load_dataset
from transformers import MT5Tokenizer, MT5ForConditionalGeneration
from tqdm import tqdm
import pandas as pd
import torch
import os

# Kiểm tra GPU
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cuda" )
print(f"💻 Đang sử dụng thiết bị: {device}")

# Load model paraphrase và đưa lên GPU
CKPT = 'chieunq/vietnamese-sentence-paraphase'
tokenizer = MT5Tokenizer.from_pretrained(CKPT)
model = MT5ForConditionalGeneration.from_pretrained(CKPT).to(device)

# Hàm tạo paraphrase
def paraphrase(text, num_return_sequences=5):
    inputs = tokenizer(text, padding='longest', max_length=512, truncation=True, return_tensors='pt')
    inputs = {key: val.to(device) for key, val in inputs.items()}
    output = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_length=512,
        num_return_sequences=num_return_sequences,
        do_sample=True,
        top_p=0.95
    )
    return [tokenizer.decode(o, skip_special_tokens=True) for o in output]

# Load dataset
dataset = pd.read_parquet("../generate_dataset/SVYKHOA_dataset_medicaltalk.parquet", engine="fastparquet")

# File Excel đầu ra
output_file = "SVYKHOA_dataset_medicaltalk_6.xlsx"

# Tạo file Excel rỗng nếu chưa có
if not os.path.exists(output_file):
    df_empty = pd.DataFrame(columns=["intruction", "question", "answer"])
    df_empty.to_excel(output_file, index=False)

# Đọc số dòng đã có để tiếp tục từ đó
existing_df = pd.read_excel(output_file)
# start_index = len(existing_df)
start_index = 12115
print(f"🚀 Bắt đầu từ dòng {start_index}")

# Số lượng mẫu muốn xử lý thêm
max_samples = 202450 - 121150  # Có thể chỉnh: 10, 100, 500...

# Duyệt dataset từ start_index
for i, row in dataset.iterrows():
    if i < start_index:
        continue
    if i >= start_index + max_samples:
        break
    print(row)

    question = row["question"]   # row là Series
    try:
        paraphrases = paraphrase(question, num_return_sequences=10)
    except Exception as e:
        print(f"Lỗi paraphrase tại mẫu {i}: {e}")
        paraphrases = [question]

    new_rows = []
    for pq in paraphrases:
        new_rows.append({
            "intruction": row["intruction"],
            "question": pq,
            "answer": row["answer"]
        })

    new_df = pd.DataFrame(new_rows)
    with pd.ExcelWriter(output_file, mode="a", engine="openpyxl", if_sheet_exists="overlay") as writer:
        sheet = writer.sheets["Sheet1"]
        start_row = sheet.max_row
        new_df.to_excel(writer, header=False, index=False, startrow=start_row)


print("✅ Đã lưu toàn bộ dữ liệu paraphrase vào file Excel.")
# Out:
# 💻 Đang sử dụng thiết bị: cuda
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'T5Tokenizer'.
# The class this function is called from is 'MT5Tokenizer'.
# You are using the default legacy behaviour of the <class 'transformers.models.mt5.tokenization_mt5.MT5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# 🚀 Bắt đầu từ dòng 12115
# intruction    Chatbot y khoa chuyên về chấn thương chỉnh hìn...
# question      Những yếu tố nào được xác định là ảnh hưởng đế...
# answer        Nghiên cứu đã chỉ ra một số yếu tố quan trọng ...
# Name: 12115, dtype: object
# intruction    Chatbot y khoa chuyên về giải phẫu bệnh lý và ...
# question      Giải thích về nguyên nhân và cơ chế tổn thương...
# answer        Trong nghiên cứu này, nguyên nhân chủ yếu gây ...
# Name: 12116, dtype: object
# intruction    Chatbot y khoa hỗ trợ tổng hợp và phân loại kế...
# question      Mô tả các mức độ phục hồi cảm giác theo thang ...
# answer        Phục hồi cảm giác là một chỉ số quan trọng tro...
# Name: 12117, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y học và phâ...
# question      Tổng hợp kết quả phục hồi chức năng bàn tay (R...
# answer        Kết quả phục hồi chức năng bàn tay là một thướ...
# Name: 12118, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật thần kinh ...
# question      Xin cho biết những yếu tố chính nào ảnh hưởng ...
# answer        Kết quả phục hồi sau phẫu thuật khâu nối thần ...
# Name: 12119, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật thần kinh ...
# question      Vui lòng so sánh hai kỹ thuật khâu nối thần ki...
# answer        Trong phẫu thuật khâu nối thần kinh ngoại vi, ...
# Name: 12120, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật thần kinh ...
# question      Nghiên cứu của bạn đã đạt được kết quả phục hồ...
# answer        Nghiên cứu của chúng tôi trên 41 bệnh nhân đứt...
# Name: 12121, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật thần kinh ...
# question      Vui lòng tổng hợp các trường hợp bệnh nhân đặc...
# answer        Trong quá trình nghiên cứu, chúng tôi đã ghi n...
# Name: 12122, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật thần kinh ...
# question      Nghiên cứu của bạn đã so sánh kết quả phục hồi...
# answer        Để đánh giá hiệu quả của phương pháp phẫu thuậ...
# Name: 12123, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học, chẩn đoán v...
# question      Trật khớp cùng đòn (TKCĐ) là gì? Nguyên nhân v...
# answer        Trật khớp cùng đòn (TKCĐ) là một chấn thương t...
# Name: 12124, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật chỉnh hình...
# question      Trong điều trị trật khớp cùng đòn, phương pháp...
# answer        Phương pháp phẫu thuật điều trị trật khớp cùng...
# Name: 12125, dtype: object
# intruction    Chatbot y khoa chuyên về biến chứng sau phẫu t...
# question      Nghiên cứu về phẫu thuật điều trị trật khớp cù...
# answer        Nghiên cứu mô tả cắt ngang trên 45 bệnh nhân t...
# Name: 12126, dtype: object
# intruction    Chatbot y khoa chuyên về phân loại chấn thương...
# question      Hãy trình bày về phân loại trật khớp cùng đòn ...
# answer        Phân loại Rockwood là hệ thống phân loại trật ...
# Name: 12127, dtype: object
# intruction    Chatbot y khoa chuyên về phân tích kết quả lâm...
# question      Nghiên cứu tại Bệnh viện Trung ương Quân đội 1...
# answer        Nghiên cứu tại Bệnh viện Trung ương Quân đội 1...
# Name: 12128, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật tạo hình v...
# question      Những tác động tiêu cực nào của sẹo được đề cậ...
# answer        Theo nghiên cứu, tác động của sẹo sau phẫu thu...
# Name: 12129, dtype: object
# intruction    Chatbot y khoa hỗ trợ thông tin về các phương ...
# question      Xin hãy mô tả chi tiết về phương pháp phẫu thu...
# answer        Phương pháp phẫu thuật chuyển cơ thon vi phẫu ...
# Name: 12130, dtype: object
# intruction    Chatbot y khoa cung cấp tóm tắt nghiên cứu về ...
# question      Tóm tắt kết quả chính của nghiên cứu về phẫu t...
# answer        Nghiên cứu tiến cứu và hồi cứu trên 62 bệnh nh...
# Name: 12131, dtype: object
# intruction    Chatbot y khoa chuyên sâu về các tiêu chuẩn đá...
# question      Nghiên cứu về liệt mặt sử dụng thang điểm nào ...
# answer        Trong nghiên cứu về liệt mặt mạn tính, để định...
# Name: 12132, dtype: object
# intruction    Chatbot y khoa hỗ trợ phân tích dữ liệu nghiên...
# question      Trong nghiên cứu về gãy Galeazzi, kết quả phẫu...
# answer        Nghiên cứu về kết quả phẫu thuật điều trị gãy ...
# Name: 12133, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học chấn thương ...
# question      Xin vui lòng giải thích về gãy Galeazzi, đặc đ...
# answer        Gãy Galeazzi là một tổn thương phức tạp đặc tr...
# Name: 12134, dtype: object
# intruction    Chatbot y khoa chuyên về phương pháp nghiên cứ...
# question      Nghiên cứu về gãy Galeazzi tại Bệnh viện Việt ...
# answer        Nghiên cứu tại Bệnh viện Hữu Nghị Việt Đức về ...
# Name: 12135, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học và đặc đi...
# question      Dựa trên số liệu của Bệnh viện Việt Đức, những...
# answer        Nghiên cứu tại Bệnh viện Hữu Nghị Việt Đức đã ...
# Name: 12136, dtype: object
# intruction    Chatbot y khoa chuyên về đánh giá hiệu quả điề...
# question      Tổng quan về kết quả phẫu thuật gãy Galeazzi đ...
# answer        Phẫu thuật gãy Galeazzi được chứng minh là một...
# Name: 12137, dtype: object
# intruction    Chatbot y khoa chuyên về số liệu thống kê y tế...
# question      Xin vui lòng trình bày chi tiết về thời gian l...
# answer        Nghiên cứu tại Bệnh viện Hữu Nghị Việt Đức đã ...
# Name: 12138, dtype: object
# intruction                                                 None
# question      Tôi muốn biết về các đặc điểm dịch tễ học của ...
# answer        Theo nghiên cứu được cung cấp, các đặc điểm dị...
# Name: 12139, dtype: object
# intruction                                                 None
# question      Tôi muốn tìm hiểu chi tiết về các tiêu chí đán...
# answer        Theo thang điểm đánh giá kết quả của Mikic, ch...
# Name: 12140, dtype: object
# intruction                                                 None
# question      Xin cho tôi biết các yếu tố nào ảnh hưởng đến ...
# answer        Quá trình liền xương sau phẫu thuật gãy xương ...
# Name: 12141, dtype: object
# intruction                                                 None
# question      Tôi cần tổng hợp thông tin về kết quả chức năn...
# answer        Dựa trên dữ liệu nghiên cứu, chúng tôi có thể ...
# Name: 12142, dtype: object
# intruction                                                 None
# question      Xin vui lòng mô tả chi tiết về kết quả gần và ...
# answer        Kết quả điều trị sau phẫu thuật gãy xương Gale...
# Name: 12143, dtype: object
# intruction    Chatbot y khoa chuyên về chấn thương chỉnh hìn...
# question      Bác sĩ có thể cho tôi biết về định nghĩa gãy G...
# answer        Gãy Galeazzi là một loại gãy xương cẳng tay ph...
# Name: 12144, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu y học, phâ...
# question      Xin hãy so sánh kết quả điều trị phẫu thuật gã...
# answer        Các nghiên cứu về điều trị gãy Galeazzi đã chỉ...
# Name: 12145, dtype: object
# intruction    Chatbot y khoa chuyên về tiêu hóa và can thiệp...
# question      Kỹ thuật nội soi tán sỏi điện thuỷ lực qua đườ...
# answer        Kỹ thuật nội soi tán sỏi điện thuỷ lực qua đườ...
# Name: 12146, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y tế và kết ...
# question      Chatbot hãy tóm tắt các thông số thống kê chín...
# answer        Nghiên cứu hồi cứu tại Bệnh viện Đại học Y Hà ...
# Name: 12147, dtype: object
# intruction    Chatbot y khoa chuyên về tổng quan y học, cung...
# question      Từ các nghiên cứu đã cho, có thể rút ra những ...
# answer        Dựa trên các nghiên cứu được trình bày, có thể...
# Name: 12148, dtype: object
# intruction    Chatbot y khoa chuyên về chấn thương chỉnh hìn...
# question      Gãy Galeazzi là gì và tại sao phương pháp phẫu...
# answer        Gãy Galeazzi là một loại tổn thương đặc trưng ...
# Name: 12149, dtype: object
# intruction    Chatbot y khoa chuyên về phương pháp nghiên cứ...
# question      Xin tóm tắt phương pháp nghiên cứu, đối tượng ...
# answer        Nghiên cứu về gãy Galeazzi tại Bệnh viện Việt ...
# Name: 12150, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học bệnh lý c...
# question      Nghiên cứu đã chỉ ra những đặc điểm nhân khẩu ...
# answer        Nghiên cứu trên 62 bệnh nhân gãy Galeazzi tại ...
# Name: 12151, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật chấn thươn...
# question      Trình bày về kỹ thuật phẫu thuật và kết quả gầ...
# answer        Phẫu thuật điều trị gãy Galeazzi trong nghiên ...
# Name: 12152, dtype: object
# intruction    Chatbot y khoa chuyên về đánh giá hiệu quả điề...
# question      Nghiên cứu đã đánh giá kết quả xa như thế nào ...
# answer        Kết quả xa sau phẫu thuật gãy Galeazzi được đá...
# Name: 12153, dtype: object
# intruction    Chatbot y khoa chuyên về chấn thương chỉnh hìn...
# question      Tôi muốn tìm hiểu về đặc điểm dịch tễ học và n...
# answer        Dựa trên nghiên cứu được trích dẫn, gãy xương ...
# Name: 12154, dtype: object
# intruction    Chatbot y tế hỗ trợ phân tích hiệu quả điều tr...
# question      Nghiên cứu của quý vị cho thấy kết quả chức nă...
# answer        Sau phẫu thuật gãy xương Galeazzi (ICD-10: S52...
# Name: 12155, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật chỉnh hình...
# question      Sau phẫu thuật kết hợp xương quay do gãy Galea...
# answer        Sau phẫu thuật kết hợp xương quay trong trường...
# Name: 12156, dtype: object
# intruction    Chatbot chuyên gia y khoa trong lĩnh vực chấn ...
# question      Xin hãy trình bày về các tiêu chí đánh giá chứ...
# answer        Thang điểm Mikic là một công cụ đánh giá quan ...
# Name: 12157, dtype: object
# intruction    Chatbot chuyên về phân tích dữ liệu lâm sàng v...
# question      Dựa trên nghiên cứu, tỷ lệ giới tính và nguyên...
# answer        Nghiên cứu đã cung cấp cái nhìn rõ ràng về đặc...
# Name: 12158, dtype: object
# intruction    Chatbot y khoa chuyên về chấn thương chỉnh hìn...
# question      Gãy Galeazzi là gì và phương pháp điều trị nào...
# answer        Gãy Galeazzi, theo phân loại ICD-10 thường đượ...
# Name: 12159, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh và...
# question      Anh/chị có thể tóm tắt các đặc điểm về bệnh nh...
# answer        Nghiên cứu mô tả hồi cứu về nội soi tán sỏi đi...
# Name: 12160, dtype: object
# intruction    Chatbot y khoa chuyên về biến chứng phẫu thuật...
# question      Xin cho biết về các biến chứng thường gặp sau ...
# answer        Sau phẫu thuật gãy xương, đặc biệt là các trườ...
# Name: 12161, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng v...
# question      Để đánh giá hiệu quả của phẫu thuật trong điều...
# answer        Đánh giá hiệu quả của phẫu thuật gãy Galeazzi ...
# Name: 12162, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh lý sỏi mật và cá...
# question      Vui lòng cung cấp thông tin chi tiết về đặc đi...
# answer        Nghiên cứu về nội soi tán sỏi điện thủy lực qu...
# Name: 12163, dtype: object
# intruction    Chatbot y khoa chuyên về y học phục hồi, cung ...
# question      Tôi muốn tìm hiểu về tình trạng co cứng chi dư...
# answer        Đột quỵ não (ICD-10: I60-I69) là một nguyên nh...
# Name: 12164, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng, ...
# question      Bạn có thể mô tả chi tiết về đối tượng và phươ...
# answer        Nghiên cứu được thiết kế dưới dạng thử nghiệm ...
# Name: 12165, dtype: object
# intruction    Chatbot y khoa chuyên về điều trị thần kinh và...
# question      Kết quả và kết luận chính của nghiên cứu về ti...
# answer        Nghiên cứu đã cho thấy những kết quả rất khả q...
# Name: 12166, dtype: object
# intruction    Chatbot y khoa chuyên về thang đo lâm sàng và ...
# question      Để đánh giá chức năng vận động và co cứng chi ...
# answer        Trong y học phục hồi, đặc biệt là với các bệnh...
# Name: 12167, dtype: object
# intruction    Chatbot y khoa chuyên về phân tích kết quả ngh...
# question      Nghiên cứu đã chỉ ra những cải thiện cụ thể nà...
# answer        Nghiên cứu đã đánh giá kỹ lưỡng các thông số c...
# Name: 12168, dtype: object
# intruction    Chatbot y khoa chuyên về phục hồi chức năng th...
# question      Xin vui lòng giải thích các biện pháp đánh giá...
# answer        Nghiên cứu đã áp dụng một bộ các thang điểm và...
# Name: 12169, dtype: object
# intruction    Chatbot y khoa chuyên về dược lý học và điều t...
# question      Trong nghiên cứu về điều trị co cứng sau đột q...
# answer        Trong quá trình nghiên cứu nhằm đánh giá hiệu ...
# Name: 12170, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ và phục hồi c...
# question      Nghiên cứu này đã đưa ra những kết quả chính n...
# answer        Nghiên cứu đã cung cấp những thông tin quan tr...
# Name: 12171, dtype: object
# intruction    Chatbot y khoa chuyên về phương pháp nghiên cứ...
# question      Vui lòng mô tả các nguyên tắc đạo đức nghiên c...
# answer        Trong bất kỳ nghiên cứu y học nào, việc tuân t...
# Name: 12172, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y học và phâ...
# question      Vui lòng trình bày chi tiết sự thay đổi về trư...
# answer        Nghiên cứu đã đánh giá một cách định lượng sự ...
# Name: 12173, dtype: object
# intruction    Chatbot y khoa chuyên về phục hồi chức năng sa...
# question      Xin hãy tóm tắt những kết quả chính về hiệu qu...
# answer        Nghiên cứu đã chỉ ra rằng việc tiêm Botulinum ...
# Name: 12174, dtype: object
# intruction    Chatbot y khoa chuyên về thần kinh và phục hồi...
# question      Nghiên cứu đã sử dụng những thang điểm lượng g...
# answer        Trong nghiên cứu này, hiệu quả điều trị Botuli...
# Name: 12175, dtype: object
# intruction    Chatbot y khoa chuyên về dược học thần kinh và...
# question      Thông tin về đặc điểm đối tượng nghiên cứu tro...
# answer        Nghiên cứu đã mô tả chi tiết về đặc điểm đối t...
# Name: 12176, dtype: object
# intruction    Chatbot y khoa chuyên về phục hồi chức năng, c...
# question      Xin vui lòng tổng hợp các nhóm cơ chi dưới đã ...
# answer        Nghiên cứu đã tập trung đánh giá mức độ co cứn...
# Name: 12177, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y học và ngh...
# question      Nghiên cứu này đã ghi nhận các thông số thống ...
# answer        Nghiên cứu đã thu thập và phân tích nhiều thôn...
# Name: 12178, dtype: object
# intruction    Chatbot y khoa chuyên về ung bướu, cung cấp th...
# question      Xin chào chatbot, tôi đang tìm hiểu về Osimert...
# answer        Osimertinib là một thuốc ức chế Tyrosine Kinas...
# Name: 12179, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học ung thư, hỗ ...
# question      Dựa trên nghiên cứu tại Bệnh viện Ung Bướu Hà ...
# answer        Nghiên cứu tại Bệnh viện Ung Bướu Hà Nội đã cu...
# Name: 12180, dtype: object
# intruction    Chatbot y khoa chuyên về dược lý lâm sàng và q...
# question      Tôi là bác sĩ lâm sàng và đang quan tâm đến Os...
# answer        Trong quá trình điều trị bằng Osimertinib, như...
# Name: 12181, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng, ...
# question      Vui lòng tóm tắt các đặc điểm chính của nghiên...
# answer        Nghiên cứu về Osimertinib tại Bệnh viện Ung Bư...
# Name: 12182, dtype: object
# intruction    Chatbot y khoa chuyên về phân tích dữ liệu y t...
# question      Bạn có thể tổng hợp các chỉ số hiệu quả điều t...
# answer        Nghiên cứu tại Bệnh viện Ung Bướu Hà Nội đã cu...
# Name: 12183, dtype: object
# intruction    Chatbot y khoa chuyên về ung thư đường bài xuấ...
# question      Xin chào, tôi muốn tìm hiểu về phẫu thuật nội ...
# answer        Chào bạn, phẫu thuật nội soi cắt toàn bộ thận ...
# Name: 12184, dtype: object
# intruction    Chatbot y khoa chuyên về biến chứng phẫu thuật...
# question      Tôi quan tâm đến các biến chứng sớm sau phẫu t...
# answer        Để đánh giá tính an toàn của một phương pháp p...
# Name: 12185, dtype: object
# intruction    Chatbot y khoa chuyên về phục hồi chức năng th...
# question      Tôi đang nghiên cứu về các phương pháp phục hồ...
# answer        Việc phục hồi chức năng chi dưới cho người bện...
# Name: 12186, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật ung thư ti...
# question      Vui lòng tổng hợp các kết quả sớm sau phẫu thu...
# answer        Phẫu thuật nội soi cắt toàn bộ thận và niệu qu...
# Name: 12187, dtype: object
# intruction    Chatbot y khoa chuyên về đánh giá hiệu quả điề...
# question      Để hiểu rõ hơn về phẫu thuật cắt thận niệu quả...
# answer        Chắc chắn rồi. Việc so sánh kết quả giữa các n...
# Name: 12188, dtype: object
# intruction    Chatbot y khoa chuyên về thần kinh học, cung c...
# question      Một bệnh nhân bị đột quỵ não có co cứng chi dư...
# answer        Đột quỵ não (ICD-10: I63.x cho nhồi máu não, I...
# Name: 12189, dtype: object
# intruction    Chatbot y khoa chuyên về dược học và phục hồi ...
# question      Những lợi ích của tiêm Botulinum toxin nhóm A ...
# answer        So với các thuốc điều trị co cứng toàn thân, t...
# Name: 12190, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng, ...
# question      Để tham gia nghiên cứu về hiệu quả của tiêm Bo...
# answer        Để tham gia vào một nghiên cứu lâm sàng đánh g...
# Name: 12191, dtype: object
# intruction    Chatbot y khoa chuyên về đánh giá lâm sàng và ...
# question      Những công cụ đánh giá nào được sử dụng để the...
# answer        Trong phục hồi chức năng cho bệnh nhân đột quỵ...
# Name: 12192, dtype: object
# intruction    Chatbot y khoa chuyên về kết quả điều trị và t...
# question      Hãy trình bày các kết quả chính về sự cải thiệ...
# answer        Kết quả từ nghiên cứu lâm sàng về tiêm Botulin...
# Name: 12193, dtype: object
# intruction                                                 None
# question      Dựa trên dữ liệu nghiên cứu, vui lòng phân tíc...
# answer        Nghiên cứu đã khảo sát một nhóm đối tượng có c...
# Name: 12194, dtype: object
# intruction                                                 None
# question      Vui lòng liệt kê và mô tả ngắn gọn các thang đ...
# answer        Để lượng giá toàn diện khả năng vận động chi d...
# Name: 12195, dtype: object
# intruction                                                 None
# question      Vui lòng tóm tắt phân bố tổng liều tiêm Botuli...
# answer        Nghiên cứu này đã sử dụng Botulinum toxin nhóm...
# Name: 12196, dtype: object
# intruction                                                 None
# question      Vui lòng trình bày chi tiết về các nguyên tắc ...
# answer        Đạo đức nghiên cứu là một yếu tố then chốt đảm...
# Name: 12197, dtype: object
# intruction                                                 None
# question      Dữ liệu nghiên cứu cho thấy sự thay đổi trương...
# answer        Nghiên cứu đã đánh giá hiệu quả của Botulinum ...
# Name: 12198, dtype: object
# intruction    Chatbot y khoa chuyên về thần kinh học và phục...
# question      Xin vui lòng tóm tắt kết quả chính của nghiên ...
# answer        Nghiên cứu đã chỉ ra rằng việc tiêm Botulinum ...
# Name: 12199, dtype: object
# intruction    Chatbot y khoa chuyên về lượng giá chức năng v...
# question      Nghiên cứu này đã sử dụng những thang điểm lượ...
# answer        Nghiên cứu đã sử dụng nhiều thang điểm lượng g...
# Name: 12200, dtype: object
# intruction    Chatbot y khoa chuyên về dược lý và ứng dụng l...
# question      Mức độ cải thiện co cứng (theo thang điểm MAS)...
# answer        Theo kết quả nghiên cứu, có sự cải thiện rõ rệ...
# Name: 12201, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học và nhân k...
# question      Hãy phân tích đặc điểm nhân khẩu học và lâm sà...
# answer        Nghiên cứu đã phân tích kỹ lưỡng các đặc điểm ...
# Name: 12202, dtype: object
# intruction    Chatbot y khoa chuyên về đánh giá hiệu quả điề...
# question      Sau khi tiêm BoNT-A, các chỉ số về thăng bằng,...
# answer        Nghiên cứu đã ghi nhận những cải thiện đáng kể...
# Name: 12203, dtype: object
# intruction    Chatbot y khoa chuyên sâu về ung thư phổi, cun...
# question      Xin vui lòng giải thích về tầm quan trọng của ...
# answer        Ung thư phổi (UTP), được mã hóa trong ICD-10 l...
# Name: 12204, dtype: object
# intruction    Chatbot y khoa chuyên sâu về dược học và kết q...
# question      Dựa trên nghiên cứu tại Bệnh viện Ung Bướu Hà ...
# answer        Nghiên cứu tại Bệnh viện Ung Bướu Hà Nội đã ch...
# Name: 12205, dtype: object
# intruction    Chatbot y khoa cung cấp bản tóm tắt các phát h...
# question      Tóm tắt vai trò và hồ sơ an toàn của Osimertin...
# answer        Osimertinib, một thuốc kháng Tyrosine Kinase I...
# Name: 12206, dtype: object
# intruction    Chatbot y khoa chuyên về thiết kế nghiên cứu v...
# question      Nêu rõ thiết kế nghiên cứu và đặc điểm đối tượ...
# answer        Nghiên cứu về kết quả điều trị Osimertinib tại...
# Name: 12207, dtype: object
# intruction    Chatbot y khoa chuyên sâu về kết quả lâm sàng,...
# question      Vui lòng cung cấp các thông số định lượng về h...
# answer        Nghiên cứu về Osimertinib tại Bệnh viện Ung Bư...
# Name: 12208, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học ung thư và đ...
# question      Tôi muốn tìm hiểu chi tiết về ung thư lưỡi di ...
# answer        Ung thư lưỡi di động (mã ICD-10 C02.1), đặc bi...
# Name: 12209, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng v...
# question      Nghiên cứu về ung thư lưỡi tại Bệnh viện K đã ...
# answer        Nghiên cứu tại Bệnh viện K đã tập trung vào vi...
# Name: 12210, dtype: object
# intruction    Chatbot y khoa chuyên về dược học và phác đồ đ...
# question      Các phác đồ hóa chất tân bổ trợ nào đã được sử...
# answer        Trong nghiên cứu tại Bệnh viện K về điều trị u...
# Name: 12211, dtype: object
# intruction    Chatbot y khoa chuyên về phân loại bệnh tật và...
# question      Hãy tổng hợp các đặc điểm lâm sàng và cận lâm ...
# answer        Nghiên cứu tại Bệnh viện K đã khảo sát 50 bệnh...
# Name: 12212, dtype: object
# intruction    Chatbot y khoa chuyên về kết quả điều trị và t...
# question      Tôi muốn biết chi tiết về tỷ lệ sống thêm khôn...
# answer        Kết quả điều trị ung thư lưỡi giai đoạn cT3-4N...
# Name: 12213, dtype: object
# intruction    Chatbot y khoa chuyên sâu về ung thư lưỡi, hỗ ...
# question      Xin vui lòng mô tả chi tiết các đặc điểm chung...
# answer        Dựa trên nghiên cứu, nhóm bệnh nhân ung thư lư...
# Name: 12214, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng, ...
# question      Nghiên cứu về ung thư lưỡi này đã sử dụng thiế...
# answer        Nghiên cứu này được thiết kế và thực hiện với ...
# Name: 12215, dtype: object
# intruction    Chatbot y khoa chuyên về điều trị ung thư đầu ...
# question      Hãy tóm tắt các kết quả điều trị chính được tr...
# answer        Nghiên cứu đã cung cấp cái nhìn tổng quan về h...
# Name: 12216, dtype: object
# intruction    Chatbot y khoa chuyên về dược học và ung thư h...
# question      Trong nghiên cứu này, các phác đồ hóa trị tiền...
# answer        Nghiên cứu đã đánh giá hiệu quả của ba phác đồ...
# Name: 12217, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật ung thư và...
# question      Sau hóa trị tiền phẫu, những phương pháp phẫu ...
# answer        Sau khi hoàn thành hóa trị tiền phẫu, tất cả c...
# Name: 12218, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học ung thư, cun...
# question      Xin hãy giải thích về khái niệm thời gian sống...
# answer        Trong nghiên cứu ung thư, thời gian sống thêm ...
# Name: 12219, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng, ...
# question      Theo dữ liệu nghiên cứu, đâu là các yếu tố gia...
# answer        Dựa trên dữ liệu được cung cấp từ nghiên cứu, ...
# Name: 12220, dtype: object
# intruction    Chatbot y khoa chuyên về tiên lượng bệnh ung t...
# question      Bạn có thể tóm tắt các kết quả về tỷ lệ sống t...
# answer        Tổng kết các kết quả chính về tỷ lệ sống thêm ...
# Name: 12221, dtype: object
# intruction    Chatbot y khoa chuyên về phân tích thống kê y ...
# question      Làm ơn tổng hợp chi tiết tỷ lệ sống thêm không...
# answer        Việc theo dõi tỷ lệ sống thêm không bệnh (DFS)...
# Name: 12222, dtype: object
# intruction    Chatbot y khoa chuyên về y học ung thư, cung c...
# question      Vui lòng phân tích và trình bày sự khác biệt v...
# answer        Hệ thống phân loại TNM (Tumor, Node, Metastasi...
# Name: 12223, dtype: object
# intruction    Chatbot y khoa chuyên về ung thư lưỡi, cung cấ...
# question      Xin vui lòng tóm tắt các đặc điểm chính của nh...
# answer        Trong nghiên cứu này, nhóm bệnh nhân ung thư l...
# Name: 12224, dtype: object
# intruction    Chatbot y khoa chuyên về ung thư lưỡi, cung cấ...
# question      Các yếu tố tiên lượng nào ảnh hưởng đến thời g...
# answer        Theo nghiên cứu, một số yếu tố tiên lượng quan...
# Name: 12225, dtype: object
# intruction    Chatbot y khoa chuyên về ung thư lưỡi, cung cấ...
# question      Nghiên cứu này đã thực hiện các phương pháp ph...
# answer        Trong nghiên cứu này, phương pháp điều trị chí...
# Name: 12226, dtype: object
# intruction    Chatbot y khoa chuyên về ung thư lưỡi, cung cấ...
# question      Hãy tổng hợp các phương pháp phẫu thuật và kỹ ...
# answer        Trong nghiên cứu về ung thư lưỡi này, phương p...
# Name: 12227, dtype: object
# intruction    Chatbot y khoa chuyên về ung thư lưỡi, cung cấ...
# question      Hãy cung cấp một bảng so sánh chi tiết về tỷ l...
# answer        Kết quả nghiên cứu đã chỉ ra sự khác biệt rõ r...
# Name: 12228, dtype: object
# intruction    Chatbot y khoa chuyên về ung bướu, cung cấp th...
# question      Xin vui lòng giải thích về vai trò và lợi ích ...
# answer        Hóa trị tiền phẫu (neoadjuvant chemotherapy) đ...
# Name: 12229, dtype: object
# intruction    Chatbot y khoa chuyên về nội tiết và hô hấp, c...
# question      Những đặc điểm lâm sàng và cận lâm sàng chính ...
# answer        Hội chứng ngừng thở khi ngủ (HCNTKN) có tỷ lệ ...
# Name: 12230, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu y học, hỗ ...
# question      Trong bối cảnh nghiên cứu về ung thư đầu cổ, đ...
# answer        Các nghiên cứu về hiệu quả hóa trị tiền phẫu t...
# Name: 12231, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán và sàng lọc...
# question      Vui lòng trình bày chi tiết về các công cụ sàn...
# answer        Trong nghiên cứu về hội chứng ngừng thở khi ng...
# Name: 12232, dtype: object
# intruction    Chatbot y khoa chuyên về sinh lý bệnh và cận l...
# question      Các chỉ số cận lâm sàng đặc trưng của hội chứn...
# answer        Nghiên cứu về hội chứng ngừng thở khi ngủ (HCN...
# Name: 12233, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học ung thư, cun...
# question      Xin vui lòng mô tả tổng quan về bệnh ung thư l...
# answer        Ung thư lưỡi di động (mã ICD-10: C02.x, phổ bi...
# Name: 12234, dtype: object
# intruction    Chatbot y khoa chuyên về dược học và kết quả đ...
# question      Trong điều trị ung thư lưỡi giai đoạn tiến tri...
# answer        Trong nghiên cứu về điều trị ung thư lưỡi giai...
# Name: 12235, dtype: object
# intruction    Chatbot y khoa chuyên về tiên lượng và kết quả...
# question      Xin tóm tắt các kết quả chính về tỷ lệ sống th...
# answer        Nghiên cứu đánh giá kết quả điều trị ung thư l...
# Name: 12236, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng, ...
# question      Vui lòng tổng hợp thông tin chi tiết về đối tư...
# answer        Nghiên cứu được thực hiện tại Bệnh viện K nhằm...
# Name: 12237, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y học, phân ...
# question      Phân tích các yếu tố tiên lượng liên quan đến ...
# answer        Kết quả nghiên cứu đã chỉ ra rõ ràng rằng cả g...
# Name: 12238, dtype: object
# intruction    Chatbot y khoa chuyên về ung thư đầu cổ, cung ...
# question      Xin chào Chatbot, bạn có thể cho tôi biết tổng...
# answer        Dựa trên dữ liệu nghiên cứu đã được công bố tr...
# Name: 12239, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học bệnh lý v...
# question      Trong nghiên cứu này, những triệu chứng lâm sà...
# answer        Dựa trên kết quả nghiên cứu, các triệu chứng l...
# Name: 12240, dtype: object
# intruction    Chatbot y khoa chuyên về ung thư học lâm sàng,...
# question      Tôi muốn có một bản tóm tắt về các phác đồ hóa...
# answer        Trong nghiên cứu về ung thư lưỡi này, các bệnh...
# Name: 12241, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật ung thư và...
# question      Bạn có thể tổng hợp các phương pháp phẫu thuật...
# answer        Trong điều trị ung thư lưỡi (ICD-10 C02), sau ...
# Name: 12242, dtype: object
# intruction    Chatbot y khoa chuyên về dược học ung thư và p...
# question      Xin hãy cung cấp thông tin chi tiết về các phá...
# answer        Trong điều trị ung thư lưỡi giai đoạn tiến tri...
# Name: 12243, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu ung thư, c...
# question      Dựa trên dữ liệu nghiên cứu này, xin vui lòng ...
# answer        Trong nghiên cứu này, các chỉ số sống thêm qua...
# Name: 12244, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và tiên lượn...
# question      Mối liên hệ giữa giai đoạn khối u nguyên phát ...
# answer        Dựa trên Biểu đồ 3.2 từ nghiên cứu, có sự khác...
# Name: 12245, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán, phân loại ...
# question      Theo Biểu đồ 3.3, có sự khác biệt nào về tỷ lệ...
# answer        Dữ liệu từ Biểu đồ 3.3 cho thấy tình trạng di ...
# Name: 12246, dtype: object
# intruction    Chatbot y khoa chuyên về dữ liệu lâm sàng và n...
# question      Tổng hợp các yếu tố tiên lượng quan trọng được...
# answer        Trong các nghiên cứu về ung thư, việc xác định...
# Name: 12247, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y học và kết...
# question      Cung cấp chi tiết các tỷ lệ sống thêm không bệ...
# answer        Để đánh giá sâu hơn về tiên lượng của bệnh nhâ...
# Name: 12248, dtype: object
# intruction    Chatbot y khoa chuyên về ung thư đầu cổ, cung ...
# question      Vui lòng tóm tắt các đặc điểm bệnh nhân và phá...
# answer        Nghiên cứu về ung thư lưỡi này tập trung vào n...
# Name: 12249, dtype: object
# intruction    Chatbot y khoa chuyên về ung thư học, phân tíc...
# question      Các yếu tố nào có ảnh hưởng đáng kể đến thời g...
# answer        Theo nghiên cứu, một số yếu tố đóng vai trò qu...
# Name: 12250, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật ung thư và...
# question      Nghiên cứu đã đề cập đến những phương pháp phẫ...
# answer        Trong nghiên cứu này, tất cả bệnh nhân ung thư...
# Name: 12251, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và thống kê ...
# question      Hãy tổng hợp các phát hiện chính từ mục 'Bàn l...
# answer        Dưới đây là bảng tổng hợp các đặc điểm bệnh nh...
# Name: 12252, dtype: object
# intruction    Chatbot y khoa chuyên về dược lý lâm sàng và k...
# question      Dựa trên dữ liệu, hãy trình bày chi tiết về mố...
# answer        Mối liên hệ giữa đáp ứng với hóa chất tân bổ t...
# Name: 12253, dtype: object
# intruction    Chatbot y khoa chuyên về ung bướu, đặc biệt là...
# question      Vui lòng mô tả chi tiết về vai trò và hiệu quả...
# answer        Ung thư biểu mô tế bào vảy khoang miệng tiến t...
# Name: 12254, dtype: object
# intruction    Chatbot y khoa chuyên về các bệnh lý hô hấp và...
# question      Xin hãy tóm tắt các đặc điểm lâm sàng và cận l...
# answer        Hội chứng ngừng thở khi ngủ (HCNTKN) là một tì...
# Name: 12255, dtype: object
# intruction    Chatbot y khoa chuyên về tiên lượng bệnh và cá...
# question      Tiên lượng sống thêm của bệnh nhân ung thư biể...
# answer        Tiên lượng sống thêm của bệnh nhân ung thư biể...
# Name: 12256, dtype: object
# intruction    Chatbot y khoa chuyên về tổng hợp nghiên cứu v...
# question      Dựa vào nghiên cứu đã cung cấp, hãy tổng hợp c...
# answer        Nghiên cứu về đặc điểm lâm sàng và cận lâm sàn...
# Name: 12257, dtype: object
# intruction    Chatbot y khoa chuyên về phân tích dữ liệu lâm...
# question      Xin hãy cung cấp các thông số định lượng và ch...
# answer        Hội chứng ngừng thở khi ngủ (HCNTKN) có mối li...
# Name: 12258, dtype: object
# intruction                                                 None
# question      Theo nghiên cứu được công bố, mục tiêu và phươ...
# answer        Nghiên cứu được công bố trên Tạp chí Y học Việ...
# Name: 12259, dtype: object
# intruction                                                 None
# question      Các kết quả chính được ghi nhận trong nghiên c...
# answer        Nghiên cứu đã ghi nhận một số kết quả quan trọ...
# Name: 12260, dtype: object
# intruction                                                 None
# question      Nghiên cứu về phẫu thuật Longo điều trị bệnh t...
# answer        Kết luận từ nghiên cứu khẳng định phẫu thuật L...
# Name: 12261, dtype: object
# intruction                                                 None
# question      Ngoài phẫu thuật Longo, đoạn văn còn đề cập đế...
# answer        Theo đoạn văn, bên cạnh phẫu thuật Longo, có n...
# Name: 12262, dtype: object
# intruction                                                 None
# question      Hãy cung cấp một tổng hợp chi tiết về các thôn...
# answer        Nghiên cứu về phẫu thuật Longo tại Bệnh viện Đ...
# Name: 12263, dtype: object
# intruction                                                 None
# question      Xin chào chatbot, tôi đang nghiên cứu về các đ...
# answer        Dựa trên nghiên cứu được trích dẫn từ Tạp chí ...
# Name: 12264, dtype: object
# intruction                                                 None
# question      Tôi muốn tìm hiểu về các biến chứng thường gặp...
# answer        Các biến chứng sau phẫu thuật vùng hậu môn là ...
# Name: 12265, dtype: object
# intruction                                                 None
# question      Về vấn đề giảm đau sau phẫu thuật, dữ liệu ngh...
# answer        Dựa trên kết quả nghiên cứu, tình trạng đau sa...
# Name: 12266, dtype: object
# intruction                                                 None
# question      Bạn có thể cung cấp một bảng tổng hợp các thôn...
# answer        Dựa trên dữ liệu nghiên cứu về phẫu thuật vùng...
# Name: 12267, dtype: object
# intruction                                                 None
# question      Tôi cần tổng hợp các đặc điểm và biến chứng củ...
# answer        Để đánh giá toàn diện hiệu quả điều trị sau ph...
# Name: 12268, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và dịch tễ h...
# question      Bệnh trĩ phổ biến ở độ tuổi và giới tính nào t...
# answer        Bệnh trĩ (ICD-10: K64) là một tình trạng phổ b...
# Name: 12269, dtype: object
# intruction    Chatbot y khoa chuyên về triệu chứng học và ph...
# question      Các triệu chứng chính của bệnh trĩ là gì và bệ...
# answer        Bệnh trĩ (ICD-10: K64) được biểu hiện qua nhiề...
# Name: 12270, dtype: object
# intruction    Chatbot y khoa chuyên về kết quả điều trị và b...
# question      Phẫu thuật Longo điều trị trĩ có những kết quả...
# answer        Phẫu thuật Longo, một phương pháp điều trị trĩ...
# Name: 12271, dtype: object
# intruction    Chatbot y khoa chuyên về chỉ định và đặc điểm ...
# question      Khi nào thì bệnh nhân trĩ được chỉ định phẫu t...
# answer        Chỉ định phẫu thuật cho bệnh trĩ (ICD-10: K64)...
# Name: 12272, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu dịch tễ họ...
# question      Hãy tổng hợp các số liệu về tỷ lệ giới tính mắ...
# answer        Tỷ lệ mắc bệnh trĩ (ICD-10: K64) giữa nam và n...
# Name: 12273, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật tiêu hóa v...
# question      Xin vui lòng giải thích về tình trạng hẹp hậu ...
# answer        Hẹp hậu môn sau phẫu thuật cắt trĩ là một biến...
# Name: 12274, dtype: object
# intruction    Chatbot y khoa chuyên về ung thư học và xạ trị...
# question      Hãy tổng quan các điểm chính từ nghiên cứu về ...
# answer        Nghiên cứu tại Bệnh viện Ung Bướu Đà Nẵng đã đ...
# Name: 12275, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và phẫu thuậ...
# question      Hãy trình bày ý nghĩa của phân loại trĩ theo M...
# answer        Trong lĩnh vực chẩn đoán và điều trị bệnh trĩ,...
# Name: 12276, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật tiêu hóa v...
# question      Hẹp hậu môn sau phẫu thuật cắt trĩ thường gặp ...
# answer        Hẹp hậu môn sau phẫu thuật cắt trĩ là một biến...
# Name: 12277, dtype: object
# intruction    Chatbot y khoa chuyên về ung thư và xạ trị, ch...
# question      Xin hãy trình bày chi tiết về độc tính được gh...
# answer        Nghiên cứu về điều trị triệt để ung thư biểu m...
# Name: 12278, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật tiêu hóa, ...
# question      Bác sĩ có thể giải thích về các phương pháp ph...
# answer        Bệnh trĩ là một tình trạng phổ biến trong các ...
# Name: 12279, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học tiêu hóa, cu...
# question      Xin vui lòng cung cấp một tổng quan về bệnh tr...
# answer        Bệnh trĩ là một trong những bệnh lý hậu môn tr...
# Name: 12280, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng, ...
# question      Bạn có thể tóm tắt các kết quả chính từ nghiên...
# answer        Nghiên cứu mô tả tiến cứu về đánh giá kết quả ...
# Name: 12281, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y học và kết...
# question      Bác sĩ có thể cung cấp một bảng tổng hợp chi t...
# answer        Nghiên cứu về phẫu thuật Longo tại Bệnh viện Đ...
# Name: 12282, dtype: object
# intruction    Chatbot y khoa chuyên về phương pháp điều trị,...
# question      Dựa vào đoạn văn và kiến thức y khoa, bạn có t...
# answer        Bệnh trĩ là một tình trạng có nhiều lựa chọn đ...
# Name: 12283, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và phẫu thuậ...
# question      Bệnh trĩ nội độ 2 và 3 thường được điều trị bằ...
# answer        Tại Việt Nam, phẫu thuật Longo đã được áp dụng...
# Name: 12284, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng, ...
# question      Tóm tắt đối tượng và phương pháp nghiên cứu củ...
# answer        Nghiên cứu về phẫu thuật trĩ Longo tại bệnh vi...
# Name: 12285, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và dịch tễ h...
# question      Cung cấp thông tin chi tiết về đặc điểm chung ...
# answer        Nghiên cứu đã khảo sát tổng cộng 73 bệnh nhân ...
# Name: 12286, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh lý hậu môn trực ...
# question          Giải thích về phân loại bệnh trĩ theo Masuda.
# answer        Phân loại trĩ theo Masuda là một hệ thống chẩn...
# Name: 12287, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y học và kết...
# question      Trình bày kết quả phân loại bệnh nhân trĩ theo...
# answer        Kết quả phân loại bệnh nhân trĩ theo Masuda tr...
# Name: 12288, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật hậu môn tr...
# question      Xin vui lòng mô tả các phương pháp phẫu thuật ...
# answer        Trong nghiên cứu này, đa số các trường hợp phẫ...
# Name: 12289, dtype: object
# intruction    Chatbot y khoa chuyên về biến chứng và triệu c...
# question      Theo dữ liệu nghiên cứu, những triệu chứng hoặ...
# answer        Sau phẫu thuật, các bệnh nhân có thể gặp một s...
# Name: 12290, dtype: object
# intruction    Chatbot y khoa cung cấp thông tin về kết quả v...
# question      Sau 3 tháng phẫu thuật, các đặc điểm nào vẫn c...
# answer        Sau 3 tháng kể từ thời điểm phẫu thuật, một số...
# Name: 12291, dtype: object
# intruction    Chatbot y khoa chuyên về các kỹ thuật phẫu thu...
# question      Các thủ thuật bổ sung thường được thực hiện tr...
# answer        Trong quá trình phẫu thuật chính vùng hậu môn ...
# Name: 12292, dtype: object
# intruction    Chatbot y khoa chuyên về đánh giá và quản lý đ...
# question      Xin vui lòng trình bày chi tiết về mức độ đau ...
# answer        Quản lý đau và theo dõi sát sao các đặc điểm l...
# Name: 12293, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question      Xin chào chatbot, bạn có thể tóm tắt về bệnh t...
# answer        Chào bạn, bệnh trĩ (theo mã ICD-10 thuộc nhóm ...
# Name: 12294, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question      Vui lòng liệt kê các triệu chứng thường gặp củ...
# answer        Dựa trên các nghiên cứu được trích dẫn, bệnh t...
# Name: 12295, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question      Mô tả các đặc điểm về phẫu thuật Longo và các ...
# answer        Phẫu thuật Longo là một phương pháp điều trị b...
# Name: 12296, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question      Tôi muốn biết về tỷ lệ giới tính của bệnh trĩ ...
# answer        Dựa trên dữ liệu từ bài viết, tỷ lệ giới tính ...
# Name: 12297, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question      Sau phẫu thuật Longo điều trị trĩ, những biến ...
# answer        Sau phẫu thuật Longo, mặc dù là một kỹ thuật h...
# Name: 12298, dtype: object
# intruction                                                 None
# question      Xin hãy phân tích chi tiết về biến chứng hẹp h...
# answer        Hẹp hậu môn sau phẫu thuật trĩ là một biến chứ...
# Name: 12299, dtype: object
# intruction                                                 None
# question      Theo nghiên cứu được đề cập, đâu là những độc ...
# answer        Trong nghiên cứu về điều trị triệt để ung thư ...
# Name: 12300, dtype: object
# intruction                                                 None
# question      Hãy tóm tắt vai trò của phân loại trĩ theo Mas...
# answer        1.  **Phân loại trĩ theo Masuda:** Đây là một ...
# Name: 12301, dtype: object
# intruction                                                 None
# question      Xin hãy tổng hợp các đặc điểm của nhóm bệnh nh...
# answer        Nghiên cứu đã khảo sát 37 trường hợp bệnh nhân...
# Name: 12302, dtype: object
# intruction                                                 None
# question      Vui lòng trình bày chi tiết các kết quả về tỷ ...
# answer        Nghiên cứu về điều trị triệt để ung thư biểu m...
# Name: 12303, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và chẩn đoán...
# question      Bác sĩ có thể cho biết về đặc điểm lâm sàng và...
# answer        *   **Đặc điểm lâm sàng:**\n    *   U đặc giả ...
# Name: 12304, dtype: object
# intruction    Chatbot y khoa chuyên về các bệnh lý tiết niệu...
# question      Vai trò của MSCT trong đánh giá sỏi tiết niệu ...
# answer        1.  **Xác định đặc điểm hình ảnh sỏi:** MSCT (...
# Name: 12305, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật tiêu hóa v...
# question      Xin vui lòng mô tả chi tiết các phương pháp đi...
# answer        U đặc giả nhú đầu tụy (Solid Pseudopapillary T...
# Name: 12306, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học, cung cấp th...
# question      Bác sĩ có thể tổng hợp các đặc điểm chính của ...
# answer        U đặc giả nhú đầu tụy là một loại tổn thương h...
# Name: 12307, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng v...
# question      Tôi muốn biết các số liệu cụ thể về bệnh nhân ...
# answer        Nghiên cứu hồi cứu về u đặc giả nhú đầu tụy tạ...
# Name: 12308, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và phẫu thuậ...
# question      Xin hãy mô tả tổng quan về đặc điểm dịch tễ họ...
# answer        U đặc giả nhú tụy (Solid Pseudopapillary Tumor...
# Name: 12309, dtype: object
# intruction    Chatbot y khoa chuyên về các biến chứng sau ph...
# question      Sau phẫu thuật cắt khối tá tụy điều trị u đặc ...
# answer        Phẫu thuật cắt khối tá tụy là một phẫu thuật l...
# Name: 12310, dtype: object
# intruction    Chatbot y khoa chuyên về phương pháp điều trị,...
# question      Xin cho biết về phương pháp điều trị chính cho...
# answer        U đặc giả nhú tụy là một khối u có tiềm năng á...
# Name: 12311, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê phẫu thuật v...
# question      Dựa trên nghiên cứu, hãy tổng hợp các phương p...
# answer        Trong điều trị u đặc giả nhú tụy, phẫu thuật đ...
# Name: 12312, dtype: object
# intruction    Chatbot y khoa chuyên về phân tích biến chứng ...
# question      Nghiên cứu này có tìm thấy mối liên quan có ý ...
# answer        Để đánh giá mối liên quan giữa thời gian phẫu ...
# Name: 12313, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và chẩn đoán...
# question      Xin vui lòng mô tả tổng quan về các đặc điểm c...
# answer        U đặc giả nhú tụy (Solid Pseudopapillary Neopl...
# Name: 12314, dtype: object
# intruction    Chatbot y khoa chuyên về phương pháp điều trị ...
# question      Tổng hợp các phương pháp phẫu thuật được áp dụ...
# answer        Trong nghiên cứu này, phẫu thuật được xác định...
# Name: 12315, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học và đặc đi...
# question      Dựa vào nghiên cứu, hãy tóm tắt các đặc điểm v...
# answer        Nghiên cứu đã cung cấp những thông tin quan tr...
# Name: 12316, dtype: object
# intruction    Chatbot y khoa chuyên về phân tích biến chứng ...
# question      Vui lòng phân tích mối liên quan giữa thời gia...
# answer        Nghiên cứu đã tiến hành phân tích để xác định ...
# Name: 12317, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y tế và kết ...
# question      Vui lòng cung cấp chi tiết về các biến chứng s...
# answer        Nghiên cứu đã theo dõi và ghi nhận các biến ch...
# Name: 12318, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và phẫu thuậ...
# question      Xin hãy cung cấp thông tin chi tiết về các biế...
# answer        Phẫu thuật cắt khối tá tụy, mặc dù là một thủ ...
# Name: 12319, dtype: object
# intruction    Chatbot y khoa chuyên về ung thư và điều trị, ...
# question      Tôi muốn tìm hiểu tóm tắt về U đặc giả nhú đầu...
# answer        U đặc giả nhú đầu tụy (Solid Pseudopapillary T...
# Name: 12320, dtype: object
# intruction    Chatbot y khoa chuyên về nhi khoa và hô hấp, c...
# question      Kỹ thuật 'Tăng tốc thì thở ra' (AFE) có vai tr...
# answer        Kỹ thuật 'Tăng tốc thì thở ra' (Accelerated Ex...
# Name: 12321, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật tiêu hóa v...
# question      Xin hãy tổng hợp các yếu tố ảnh hưởng đến biến...
# answer        Phẫu thuật cắt khối tá tụy là một phẫu thuật p...
# Name: 12322, dtype: object
# intruction    Chatbot y khoa chuyên về điều trị hô hấp nhi k...
# question      Đánh giá chi tiết các thông số hô hấp cải thiệ...
# answer        Kỹ thuật 'Tăng tốc thì thở ra' (AFE) đã được n...
# Name: 12323, dtype: object
# intruction    Chatbot y khoa chuyên về vi sinh lâm sàng và c...
# question      Xin cho biết về ưu điểm của phương pháp phân t...
# answer        Phương pháp phân tử ngày càng trở nên phổ biến...
# Name: 12324, dtype: object
# intruction    Chatbot y khoa chuyên về ung thư học và phác đ...
# question      Phác đồ hóa trị FLOT được đề cập trong nghiên ...
# answer        Phác đồ hóa trị FLOT là một phác đồ kết hợp đư...
# Name: 12325, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng v...
# question      Kết quả ban đầu của nghiên cứu đánh giá phác đ...
# answer        Nghiên cứu 'Đánh giá đáp ứng trong điều trị un...
# Name: 12326, dtype: object
# intruction    Chatbot y khoa chuyên về kỹ thuật chẩn đoán vi...
# question      Hãy so sánh phương pháp nuôi cấy truyền thống ...
# answer        Trong y học lâm sàng, việc xác định chính xác ...
# Name: 12327, dtype: object
# intruction    Chatbot y khoa chuyên về dữ liệu lâm sàng, phâ...
# question      Vui lòng cung cấp chi tiết về phân bố giai đoạ...
# answer        Nghiên cứu tại Bệnh viện K đã cung cấp cái nhì...
# Name: 12328, dtype: object
# intruction    Chatbot y khoa chuyên về ung thư dạ dày, cung ...
# question      Phác đồ hóa trị FLOT được sử dụng như thế nào ...
# answer        Phác đồ hóa trị FLOT (Docetaxel, Oxaliplatin, ...
# Name: 12329, dtype: object
# intruction    Chatbot y khoa chuyên về phương pháp nghiên cứ...
# ...
# intruction    Chatbot y khoa chuyên về bệnh học nhi khoa, cu...
# question      Bác sĩ có thể cho biết về tình hình bệnh tiêu ...
# answer        Bệnh tiêu chảy cấp là một trong những thách th...
# Name: 14617, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu y học cộng...
# question      Xin hãy tóm tắt kết quả chính từ nghiên cứu về...
# answer        Nghiên cứu về kiến thức tiêu chảy cấp của các ...
# Name: 14618, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán và điều trị...
# question      Tiêu chảy cấp được phân loại theo ICD-10 như t...
# answer        Trong y khoa, tiêu chảy cấp là tình trạng đi n...
# Name: 14619, dtype: object
# intruction    Chatbot y khoa chuyên về sức khỏe cộng đồng và...
# question      Theo nghiên cứu tại Bệnh viện Vinmec Times Cit...
# answer        Nghiên cứu được thực hiện tại Bệnh viện Vinmec...
# Name: 14620, dtype: object
# intruction    Chatbot y khoa chuyên về phân tích thống kê y ...
# question      Xin vui lòng cung cấp một bảng tổng hợp chi ti...
# answer        Nghiên cứu thực hiện tại Bệnh viện Vinmec Time...
# Name: 14621, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và nghiên cứ...
# question      Xin chào chatbot, bạn có thể cho tôi biết về c...
# answer        Chào bạn, dựa trên nghiên cứu, các kết quả the...
# Name: 14622, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và nghiên cứ...
# question      Tôi muốn tìm hiểu về bệnh bụi phổi silic, đặc ...
# answer        Bệnh bụi phổi silic là một bệnh phổi nghề nghi...
# Name: 14623, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và nghiên cứ...
# question      Theo kết luận của nghiên cứu, những thách thức...
# answer        Kết luận của nghiên cứu đã nhấn mạnh rằng bệnh...
# Name: 14624, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và nghiên cứ...
# question      Bạn có thể tóm tắt các phát hiện trên phim X-q...
# answer        Dựa trên nghiên cứu tại Phú Yên năm 2020 về bệ...
# Name: 14625, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và nghiên cứ...
# question      Nghiên cứu đã báo cáo những thông số cụ thể nà...
# answer        Nghiên cứu đã cung cấp các thông số cụ thể về ...
# Name: 14626, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và dịch tễ h...
# question      Bác sĩ có thể giải thích chi tiết về bệnh bụi ...
# answer        Bệnh bụi phổi silic là một bệnh lý nghiêm trọn...
# Name: 14627, dtype: object
# intruction    Chatbot y khoa chuyên về các bệnh hô hấp và cá...
# question      Theo nghiên cứu được thực hiện tại tỉnh Phú Yê...
# answer        Nghiên cứu cắt ngang về bệnh bụi phổi silic tạ...
# Name: 14628, dtype: object
# intruction    Chatbot y khoa chuyên về phương pháp nghiên cứ...
# question      Xin hãy mô tả phương pháp nghiên cứu cụ thể đã...
# answer        Nghiên cứu về bệnh bụi phổi silic tại tỉnh Phú...
# Name: 14629, dtype: object
# intruction    Chatbot y khoa chuyên về sức khỏe nghề nghiệp ...
# question      Môi trường lao động có chứa bụi silic tự do gâ...
# answer        Môi trường lao động phát sinh bụi chứa dioxyd ...
# Name: 14630, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh và...
# question      Dựa trên kết quả nghiên cứu tại Phú Yên năm 20...
# answer        Nghiên cứu tại Phú Yên năm 2020 đã cung cấp nh...
# Name: 14631, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học hô hấp nghề ...
# question      Xin cho biết tổng quan về bệnh bụi phổi silic,...
# answer        Bệnh bụi phổi silic là một bệnh phổi kẽ mãn tí...
# Name: 14632, dtype: object
# intruction    Chatbot y khoa chuyên về các rối loạn hô hấp v...
# question      Các đặc điểm trên phim X-quang và triệu chứng ...
# answer        Theo kết quả nghiên cứu này, các đặc điểm trên...
# Name: 14633, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học bệnh nghề...
# question      Có sự khác biệt nào về tỷ lệ mắc bệnh bụi phổi...
# answer        Nghiên cứu này đã chỉ ra nhiều điểm khác biệt ...
# Name: 14634, dtype: object
# intruction    Chatbot y khoa chuyên về các bệnh phổi nghề ng...
# question      Xin trình bày về các loại rối loạn thông khí đ...
# answer        Rối loạn thông khí là tình trạng suy giảm chức...
# Name: 14635, dtype: object
# intruction    Chatbot y khoa chuyên về dữ liệu y tế và thống...
# question      Tổng hợp các yếu tố dịch tễ học chính liên qua...
# answer        Bệnh bụi phổi silic là một bệnh lý có sự phân ...
# Name: 14636, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học hô hấp, cung...
# question      Xin chào chatbot, tôi đang nghiên cứu về bệnh ...
# answer        Dựa trên nghiên cứu, bệnh bụi phổi silic (ICD-...
# Name: 14637, dtype: object
# intruction    Chatbot y khoa chuyên về di truyền học và hỗ t...
# question      Thông tin trong đoạn văn có đề cập đến một trư...
# answer        Hiện tượng Allele Drop Out (ADO), hay còn gọi ...
# Name: 14638, dtype: object
# intruction    Chatbot y khoa chuyên về y học lao động và bện...
# question      Dựa vào nghiên cứu được trích dẫn, hãy cho tôi...
# answer        Dựa trên kết quả nghiên cứu được trích dẫn, tì...
# Name: 14639, dtype: object
# intruction    Chatbot y khoa chuyên về triệu chứng học và bệ...
# question      Xin vui lòng tổng hợp các triệu chứng lâm sàng...
# answer        Bệnh bụi phổi silic (ICD-10: J62.1), một bệnh ...
# Name: 14640, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh và...
# question      Bạn có thể cung cấp một bảng tổng hợp các kết ...
# answer        Chẩn đoán bệnh bụi phổi silic (ICD-10: J62.1) ...
# Name: 14641, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và phẫu thuậ...
# question      Trình bày chi tiết về bệnh thoát vị tủy-màng t...
# answer        Thoát vị tủy-màng tủy (Myelomeningocele), mã I...
# Name: 14642, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh nghề nghiệp và y...
# question      Các triệu chứng lâm sàng và tổn thương X-quang...
# answer        Theo nghiên cứu về thực trạng mắc bệnh bụi phổ...
# Name: 14643, dtype: object
# intruction    Chatbot y khoa chuyên về các thách thức trong ...
# question      Tổng quan về hai bệnh lý được đề cập trong bài...
# answer        Bài viết trình bày về hai bệnh lý riêng biệt n...
# Name: 14644, dtype: object
# intruction    Chatbot y khoa chuyên về đánh giá hiệu quả điề...
# question      Vui lòng cung cấp một bảng tổng hợp các chỉ số...
# answer        Dưới đây là bảng tổng hợp các chỉ số theo dõi ...
# Name: 14645, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học bệnh nghề...
# question      Cung cấp thông tin chi tiết về tỷ lệ hiện mắc,...
# answer        Để hiểu rõ hơn về tình hình bệnh bụi phổi sili...
# Name: 14646, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học hô hấp, cung...
# question      Bệnh bụi phổi silic là gì và nguyên nhân gây b...
# answer        Bệnh bụi phổi silic (Silicosis) là một bệnh lý...
# Name: 14647, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu dịch tễ họ...
# question      Các đặc điểm lâm sàng và hình ảnh X-quang của ...
# answer        Dựa trên nghiên cứu tại Phú Yên năm 2020, bệnh...
# Name: 14648, dtype: object
# intruction    Chatbot y khoa chuyên về y tế công cộng và quả...
# question      Kết quả chính của nghiên cứu về bệnh bụi phổi ...
# answer        Nghiên cứu mô tả cắt ngang về bệnh bụi phổi si...
# Name: 14649, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán và điều trị...
# question      Để chẩn đoán bệnh bụi phổi silic, cần dựa vào ...
# answer        Để chẩn đoán bệnh bụi phổi silic một cách chín...
# Name: 14650, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y học và phâ...
# question      Vui lòng cung cấp số liệu chi tiết về tỷ lệ hi...
# answer        Nghiên cứu tại Phú Yên năm 2020 đã cung cấp cá...
# Name: 14651, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học hô hấp, cung...
# question      Bác sĩ có thể cho biết về tỷ lệ hiện mắc bệnh ...
# answer        Bệnh bụi phổi silic (Silicosis), được phân loạ...
# Name: 14652, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh và...
# question      Xin vui lòng tóm tắt các triệu chứng lâm sàng ...
# answer        Theo nghiên cứu, đa số người lao động tham gia...
# Name: 14653, dtype: object
# intruction    Chatbot y khoa chuyên về đạo đức nghiên cứu và...
# question      Nghiên cứu về bệnh bụi phổi silic (ICD-10: J62...
# answer        Nghiên cứu về bệnh bụi phổi silic này đã được ...
# Name: 14654, dtype: object
# intruction    Chatbot y khoa chuyên sâu về các bệnh lý nghề ...
# question      Dựa trên nghiên cứu, đâu là những yếu tố liên ...
# answer        Bệnh bụi phổi silic (Silicosis, ICD-10: J62.8)...
# Name: 14655, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học bệnh lý h...
# question      Tôi muốn biết chi tiết tỷ lệ hiện mắc bệnh bụi...
# answer        Dựa trên dữ liệu từ nghiên cứu về bệnh bụi phổ...
# Name: 14656, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học hô hấp, cung...
# question      Xin chào chatbot, tôi muốn tìm hiểu các triệu ...
# answer        Bệnh bụi phổi silic (ICD-10: J62.8) là một bện...
# Name: 14657, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh và...
# question      Chatbot có thể giải thích chi tiết hơn về các ...
# answer        Bệnh bụi phổi silic (ICD-10: J62.8) được chẩn ...
# Name: 14658, dtype: object
# intruction    Chatbot y khoa chuyên về di truyền học lâm sàn...
# question      Hiện tượng ADO trong PGT-M đối với bệnh β-Thal...
# answer        Hiện tượng Allele Drop Out (ADO) là một vấn đề...
# Name: 14659, dtype: object
# intruction    Chatbot y khoa chuyên về di truyền tiền làm tổ...
# question      Hãy trình bày tóm tắt về trường hợp nghiên cứu...
# answer        Trường hợp nghiên cứu được báo cáo nhằm làm rõ...
# Name: 14660, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học bệnh nghề...
# question      Chatbot có thể tổng hợp các số liệu về tỷ lệ h...
# answer        Bệnh bụi phổi silic (ICD-10: J62.8) là một bện...
# Name: 14661, dtype: object
# intruction    Chatbot y khoa chuyên về điều trị nội tiết, cu...
# question      Xin chào chatbot, tôi là một sinh viên y khoa ...
# answer        Chào bạn, dựa trên các nghiên cứu gần đây, có ...
# Name: 14662, dtype: object
# intruction    Chatbot y khoa chuyên về quản lý bệnh mạn tính...
# question      Để nâng cao chất lượng cuộc sống cho bệnh nhân...
# answer        Để giúp người bệnh đái tháo đường kiểm soát bệ...
# Name: 14663, dtype: object
# intruction    Chatbot y khoa chuyên về tiêu hóa, cung cấp th...
# question      Tôi đang tìm hiểu về thủ thuật nội soi mật tụy...
# answer        Thủ thuật nội soi mật tụy ngược dòng (ERCP) là...
# Name: 14664, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng, ...
# question      Trong nghiên cứu về nội soi mật tụy ngược dòng...
# answer        Trong nghiên cứu về nội soi mật tụy ngược dòng...
# Name: 14665, dtype: object
# intruction    Chatbot y khoa chuyên về giáo dục sức khỏe và ...
# question      Dựa trên các khảo sát gần đây, đâu là những đi...
# answer        Dựa trên các khảo sát gần đây về kiến thức và ...
# Name: 14666, dtype: object
# intruction    Chatbot y khoa chuyên về tiêu hóa và can thiệp...
# question      Theo nghiên cứu được đề cập, những đặc điểm nà...
# answer        Theo nghiên cứu, bệnh nhân cao tuổi (nhóm ≥ 60...
# Name: 14667, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật nội soi và...
# question      Nghiên cứu chỉ ra những ưu điểm nổi bật nào củ...
# answer        Nội soi mật tụy ngược dòng (NSMTND) được đánh ...
# Name: 14668, dtype: object
# intruction    Chatbot y khoa chuyên về lão khoa và can thiệp...
# question      Tóm tắt kết quả chính của nghiên cứu về tính a...
# answer        Nghiên cứu đã đánh giá tính an toàn và hiệu qu...
# Name: 14669, dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 76
#      69     new_rows.append({
#      70         "intruction": row["intruction"],
#      71         "question": pq,
#      72         "answer": row["answer"]
#      73     })
#      75 new_df = pd.DataFrame(new_rows)
# ---> 76 with pd.ExcelWriter(output_file, mode="a", engine="openpyxl", if_sheet_exists="overlay") as writer:
#      77     sheet = writer.sheets["Sheet1"]
#      78     start_row = sheet.max_row
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\pandas\io\excel\_base.py:1353, in ExcelWriter.__exit__(self, exc_type, exc_value, traceback)
#    1347 def __exit__(
#    1348     self,
#    1349     exc_type: type[BaseException] | None,
#    1350     exc_value: BaseException | None,
#    1351     traceback: TracebackType | None,
#    1352 ) -> None:
# -> 1353     self.close()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\pandas\io\excel\_base.py:1357, in ExcelWriter.close(self)
#    1355 def close(self) -> None:
#    1356     """synonym for save, to make it more file-like"""
# -> 1357     self._save()
#    1358     self._handles.close()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\pandas\io\excel\_openpyxl.py:110, in OpenpyxlWriter._save(self)
#     106 def _save(self) -> None:
#     107     """
#     108     Save workbook to disk.
#     109     """
# --> 110     self.book.save(self._handles.handle)
#     111     if "r+" in self._mode and not isinstance(self._handles.handle, mmap.mmap):
#     112         # truncate file to the written content
#     113         self._handles.handle.truncate()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\workbook\workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\writer\excel.py:294, in save_workbook(workbook, filename)
#     292 workbook.properties.modified = datetime.datetime.now(tz=datetime.timezone.utc).replace(tzinfo=None)
#     293 writer = ExcelWriter(workbook, archive)
# --> 294 writer.save()
#     295 return True
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\writer\excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\writer\excel.py:77, in ExcelWriter.write_data(self)
#      74     custom_override = CustomOverride()
#      75     self.manifest.append(custom_override)
# ---> 77 self._write_worksheets()
#      78 self._write_chartsheets()
#      79 self._write_images()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\writer\excel.py:215, in ExcelWriter._write_worksheets(self)
#     212 for idx, ws in enumerate(self.workbook.worksheets, 1):
#     214     ws._id = idx
# --> 215     self.write_worksheet(ws)
#     217     if ws._drawing:
#     218         self._write_drawing(ws._drawing)
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\writer\excel.py:200, in ExcelWriter.write_worksheet(self, ws)
#     198 else:
#     199     writer = WorksheetWriter(ws)
# --> 200     writer.write()
#     202 ws._rels = writer._rels
#     203 self._archive.write(writer.out, ws.path[1:])
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\worksheet\_writer.py:359, in openpyxl.worksheet._writer.WorksheetWriter.write()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\worksheet\_writer.py:123, in openpyxl.worksheet._writer.WorksheetWriter.write_rows()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\worksheet\_writer.py:125, in openpyxl.worksheet._writer.WorksheetWriter.write_rows()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\worksheet\_writer.py:135, in openpyxl.worksheet._writer.WorksheetWriter.write_row()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\worksheet\_writer.py:147, in openpyxl.worksheet._writer.WorksheetWriter.write_row()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\cell\_writer.py:118, in lxml_write_cell(xf, worksheet, cell, styled)
#     116     xf.write(el)
#     117 else:
# --> 118     with xf.element("is"):
#     119         if isinstance(value, str):
#     120             attrs = {}
#
# KeyboardInterrupt:
