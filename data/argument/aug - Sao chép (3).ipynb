# %%
from datasets import load_dataset
from transformers import MT5Tokenizer, MT5ForConditionalGeneration
from tqdm import tqdm
import pandas as pd
import torch
import os

# Kiểm tra GPU
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu" )
print(f"💻 Đang sử dụng thiết bị: {device}")

# Load model paraphrase và đưa lên GPU
CKPT = 'chieunq/vietnamese-sentence-paraphase'
tokenizer = MT5Tokenizer.from_pretrained(CKPT)
model = MT5ForConditionalGeneration.from_pretrained(CKPT).to(device)

# Hàm tạo paraphrase
def paraphrase(text, num_return_sequences=5):
    inputs = tokenizer(text, padding='longest', max_length=512, truncation=True, return_tensors='pt')
    inputs = {key: val.to(device) for key, val in inputs.items()}
    output = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_length=512,
        num_return_sequences=num_return_sequences,
        do_sample=True,
        top_p=0.95
    )
    return [tokenizer.decode(o, skip_special_tokens=True) for o in output]

# Load dataset
dataset = pd.read_parquet("../generate_dataset/SVYKHOA_dataset_guide.parquet", engine="fastparquet")

# File Excel đầu ra
output_file = "SVYKHOA_dataset_guide_5.xlsx"

# Tạo file Excel rỗng nếu chưa có
if not os.path.exists(output_file):
    df_empty = pd.DataFrame(columns=["intruction", "question", "answer","document/title","document/description","cme/title","cme/description"])
    df_empty.to_excel(output_file, index=False)

# Đọc số dòng đã có để tiếp tục từ đó
existing_df = pd.read_excel(output_file)
# start_index = len(existing_df)
start_index = 13000
print(f"🚀 Bắt đầu từ dòng {start_index}")

# Số lượng mẫu muốn xử lý thêm
max_samples = 139490 - 130000  # Có thể chỉnh: 10, 100, 500...

# Duyệt dataset từ start_index
for i, row in dataset.iterrows():
    if i < start_index:
        continue
    if i >= start_index + max_samples:
        break
    print(row)

    question = row["question"]   # row là Series
    try:
        paraphrases = paraphrase(question, num_return_sequences=15)
    except Exception as e:
        print(f"Lỗi paraphrase tại mẫu {i}: {e}")
        paraphrases = [question]

    new_rows = []
    for pq in paraphrases:
        new_rows.append({
            "intruction": row["intruction"],
            "question": pq,
            "answer": row["answer"],
            "document/title": row["document/title"],
            "document/description": row["document/description"],
            "cme/title": row["cme/title"],
            "cme/description": row["cme/description"],
        })

    new_df = pd.DataFrame(new_rows)
    with pd.ExcelWriter(output_file, mode="a", engine="openpyxl", if_sheet_exists="overlay") as writer:
        sheet = writer.sheets["Sheet1"]
        start_row = sheet.max_row
        new_df.to_excel(writer, header=False, index=False, startrow=start_row)


print("✅ Đã lưu toàn bộ dữ liệu paraphrase vào file Excel.")
# Out:
# 💻 Đang sử dụng thiết bị: cpu
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'T5Tokenizer'.
# The class this function is called from is 'MT5Tokenizer'.
# You are using the default legacy behaviour of the <class 'transformers.models.mt5.tokenization_mt5.MT5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# 🚀 Bắt đầu từ dòng 13000
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, độ lọc cầu thận ước tính (eGF...
# answer                  Chào bạn, đây là một câu hỏi rất quan trọng đố...
# document/title          Hướng dẫn Chẩn đoán và Điều trị Bệnh thận mạn ...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Cập nhật Đánh giá Chức năng Thận và Phân loại ...
# cme/description         Khóa học đào tạo y khoa liên tục này sẽ trang ...
# Name: 13000, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu so sánh công thức CKD-EPI 2021 và 2...
# answer                  Đây là một câu hỏi rất hay, cho thấy bạn đã nắ...
# document/title          Báo cáo khoa học: Ảnh hưởng của công thức CKD-...
# document/description    Tài liệu này trình bày các kết quả nghiên cứu ...
# cme/title               Phương pháp nghiên cứu dịch tễ học trong Y học...
# cme/description         Khóa học này tập trung vào các phương pháp ngh...
# Name: 13001, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu chỉ ra rằng công thức CKD-EPI 2021 ...
# answer                  Việc công thức CKD-EPI 2021 làm giảm số lượng ...
# document/title          Phác đồ chẩn đoán và điều trị bệnh thận mạn củ...
# document/description    Tài liệu này cung cấp phác đồ chẩn đoán và điề...
# cme/title               Quản lý toàn diện bệnh nhân Bệnh thận mạn: Từ ...
# cme/description         Khóa học CME này cung cấp một cái nhìn tổng qu...
# Name: 13002, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Chào bạn, tôi là một sinh viên y khoa năm cuối...
# answer                  Chào em, đây là một câu hỏi rất quan trọng mà ...
# document/title          Hướng dẫn chẩn đoán và điều trị bệnh thận mạn ...
# document/description    Tài liệu này là cẩm nang chính thức từ Bộ Y tế...
# cme/title               Cập nhật các Công thức Ước tính Độ lọc Cầu thậ...
# cme/description         Khóa học CME này được thiết kế để trang bị cho...
# Name: 13003, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi đang chuẩn bị cho kỳ thi lâm sàng nội khoa...
# answer                  Tuyệt vời, việc nắm vững định nghĩa và phân lo...
# document/title          KDIGO 2012 Clinical Practice Guideline for the...
# document/description    Tài liệu này là kim chỉ nam toàn cầu về bệnh t...
# cme/title               Bệnh thận mạn: Chẩn đoán, Phân loại và Điều tr...
# cme/description         Khóa học CME này sẽ tập trung vào việc làm rõ ...
# Name: 13004, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi là một bác sĩ trẻ đang muốn tìm hiểu sâu h...
# answer                  Rất hoan nghênh tinh thần học hỏi và nghiên cứ...
# document/title          Thống kê Y học: Nguyên lý và Ứng dụng trong Ng...
# document/description    Cuốn sách này là một tài liệu cơ bản nhưng toà...
# cme/title               Phương pháp Nghiên cứu và Phân tích Thống kê t...
# cme/description         Khóa học CME này được thiết kế đặc biệt cho cá...
# Name: 13005, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, với sự ra đời của công thức C...
# answer                  Chào em, sự thay đổi trong công thức tính eGFR...
# document/title          Hướng dẫn chẩn đoán và điều trị bệnh thận mạn ...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Cập nhật công thức tính eGFR và phân loại bệnh...
# cme/description         Khóa học CME này được thiết kế để cung cấp cho...
# Name: 13006, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với một bác sĩ trẻ, khi tiếp cận một bệnh nhân...
# answer                  Khi tiếp cận bệnh nhân và đánh giá chức năng t...
# document/title          Khuyến nghị của KDIGO 2024 về thực hành lâm sà...
# document/description    Đây là bộ hướng dẫn quốc tế mới nhất từ Kidney...
# cme/title               Quản lý bệnh thận mạn dựa trên bằng chứng: Từ ...
# cme/description         Khóa học CME này tập trung vào việc áp dụng cá...
# Name: 13007, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, tại sao việc đánh giá chức nă...
# answer                  Đánh giá chức năng lọc cầu thận (eGFR) là một ...
# document/title          KDIGO Clinical Practice Guidelines for the Eva...
# document/description    Bộ hướng dẫn quốc tế toàn diện này là tài liệu...
# cme/title               Thận học cơ bản và nâng cao: Từ sinh lý bệnh đ...
# cme/description         Khóa học CME này cung cấp một cái nhìn tổng qu...
# Name: 13008, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, với sự ra đời của công thức C...
# answer                  Chào bạn, đây là một câu hỏi rất hay và thiết ...
# document/title          Hướng dẫn thực hành lâm sàng về Bệnh thận mạn ...
# document/description    Tài liệu cung cấp các hướng dẫn chẩn đoán, phâ...
# cme/title               Cập nhật công thức eGFR và ứng dụng lâm sàng t...
# cme/description         Khóa học đào tạo y khoa liên tục tập trung vào...
# Name: 13009, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Em là một bác sĩ nội trú. Em muốn hỏi làm thế ...
# answer                  Chào bạn, đây là một câu hỏi rất thực tế và qu...
# document/title          Hướng dẫn thực hành lâm sàng KDIGO về đánh giá...
# document/description    Tài liệu tiêu chuẩn quốc tế cung cấp hướng dẫn...
# cme/title               Phân tích các trường hợp lâm sàng về bệnh thận...
# cme/description         Khóa học CME này sử dụng phương pháp học dựa t...
# Name: 13010, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với những thay đổi trong cách ước tính eGFR và...
# answer                  Chào bạn, câu hỏi của bạn chạm đến một khía cạ...
# document/title          Tạp chí Y học Việt Nam (Vietnamese Medical Jou...
# document/description    Đây là một trong những tạp chí y khoa hàng đầu...
# cme/title               Phương pháp nghiên cứu khoa học trong y học và...
# cme/description         Khóa học CME này trang bị cho bác sĩ và sinh v...
# Name: 13011, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, làm thế nào để đánh giá nguy ...
# answer                  Chào bạn, việc đánh giá nguy cơ tim mạch ở bện...
# document/title          NGUY CƠ TIM MẠCH THEO THANG ĐIỂM FRAMINGHAM TR...
# document/description    Tài liệu này cung cấp cái nhìn sâu sắc về mối ...
# cme/title               Quản lý Đa bệnh lý ở Bệnh nhân Vảy nến: Tiếp c...
# cme/description         Khóa học này tập trung vào việc nhận diện, đán...
# Name: 13012, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Xin chuyên gia hướng dẫn cách áp dụng các phươ...
# answer                  Chào bạn, việc ước tính độ lọc cầu thận (eGFR)...
# document/title          KDIGO 2012 clinical practice guideline for the...
# document/description    Hướng dẫn thực hành lâm sàng của KDIGO là tài ...
# cme/title               Cập nhật Chẩn đoán và Quản lý Bệnh thận Mạn th...
# cme/description         Khóa học này sẽ đi sâu vào những thay đổi mới ...
# Name: 13013, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, đóng vai trò ...
# question                Trong bối cảnh bệnh nhân vảy nến mảng có nguy ...
# answer                  Bạn thân mến, nhận thức về mối liên hệ chặt ch...
# document/title          A Unifying Approach for GFR Estimation: Recomm...
# document/description    Tài liệu này cung cấp các khuyến nghị quan trọ...
# cme/title               Phòng ngừa và Quản lý Bệnh Tim mạch ở Bệnh nhâ...
# cme/description         Khóa học này được thiết kế để cung cấp cho các...
# Name: 13014, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, khi điều trị viêm âm hộ - âm ...
# answer                  Chào các bác sĩ trẻ, khi tiếp cận điều trị viê...
# document/title          Hướng dẫn Quốc gia về các dịch vụ chăm sóc sức...
# document/description    Tài liệu của Bộ Y tế Việt Nam, cung cấp phác đ...
# cme/title               Cập nhật chẩn đoán và điều trị viêm âm đạo ở p...
# cme/description         Khóa học CME này cung cấp kiến thức chuyên sâu...
# Name: 13015, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, đóng vai trò ...
# question                Trong bối cảnh phòng chống HIV/AIDS, chúng em ...
# answer                  Các bạn thân mến, việc triển khai PrEP (Pre-Ex...
# document/title          Hướng dẫn Quốc gia về điều trị và chăm sóc HIV...
# document/description    Tài liệu chính thức của Bộ Y tế Việt Nam, cung...
# cme/title               PrEP trong dự phòng HIV: Từ lý thuyết đến thực...
# cme/description         Khóa học CME này tập trung vào cập nhật các kh...
# Name: 13016, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp kiến...
# question                Khi triển khai PrEP cho nhóm đối tượng nguy cơ...
# answer                  Chào các bác sĩ, việc quản lý hiệu quả các tác...
# document/title          Guidelines for the management of sexually tran...
# document/description    Hướng dẫn toàn cầu của Tổ chức Y tế Thế giới c...
# cme/title                Tư vấn và hỗ trợ tuân thủ điều trị PrEP hiệu quả
# cme/description         Khóa học CME này tập trung vào phát triển kỹ n...
# Name: 13017, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các bác sĩ trẻ và sinh viên y khoa cần lưu ý n...
# answer                  Kính chào các đồng nghiệp và sinh viên y khoa,...
# document/title          Hướng dẫn quốc gia về dự phòng trước phơi nhiễ...
# document/description    Tài liệu cung cấp kiến thức nền tảng và các kh...
# cme/title               Khóa học đào tạo liên tục: Quản lý và Tư vấn P...
# cme/description         Khóa học này tập trung vào các khía cạnh thực ...
# Name: 13018, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các lý do ngừng PrEP được nêu trong nghiên cứu...
# answer                  Thưa các đồng nghiệp và sinh viên y khoa,\n\nV...
# document/title          Hướng dẫn điều trị và chăm sóc HIV/AIDS của Bộ...
# document/description    Tài liệu toàn diện về phòng ngừa, chẩn đoán, đ...
# cme/title               Kỹ năng tư vấn và duy trì điều trị cho bệnh nh...
# cme/description         Khóa học này cung cấp các kỹ năng giao tiếp, t...
# Name: 13019, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa vào phần phương pháp nghiên cứu, các bác s...
# answer                  Chào các bác sĩ trẻ và sinh viên y khoa,\n\nPh...
# document/title          Cẩm nang hướng dẫn nghiên cứu khoa học trong y...
# document/description    Cuốn cẩm nang toàn diện về thiết kế nghiên cứu...
# cme/title               Đạo đức và Phương pháp Nghiên cứu Khoa học Y sinh
# cme/description         Khóa học cung cấp kiến thức nền tảng và nâng c...
# Name: 13020, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, dựa trên các nghiên cứu về Pr...
# answer                  Chào bạn, đây là một câu hỏi rất quan trọng tr...
# document/title          Hướng dẫn quốc gia về dự phòng trước phơi nhiễ...
# document/description    Tài liệu cung cấp các khuyến cáo chi tiết về c...
# cme/title               Quản lý PrEP: Từ lý thuyết đến thực hành lâm s...
# cme/description         Khóa học đào tạo y khoa liên tục này tập trung...
# Name: 13021, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, giải quyết cá...
# question                Thưa chuyên gia, khi bệnh nhân sử dụng PrEP, n...
# answer                  Chào bạn, việc tư vấn rõ ràng về tác dụng phụ ...
# document/title          Khuyến cáo của Tổ chức Y tế Thế giới (WHO) về ...
# document/description    Tài liệu toàn diện từ WHO về chỉ định, thực hà...
# cme/title               Kỹ năng tư vấn bệnh nhân và quản lý tác dụng p...
# cme/description         Khóa học này sẽ trang bị cho các bác sĩ và sin...
# Name: 13022, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, giúp sinh viê...
# question                Nghiên cứu chỉ ra tỷ lệ nhiễm HIV ở nhóm ED-Pr...
# answer                  Chào bạn, đây là một điểm rất thú vị và quan t...
# document/title            Hướng dẫn thực hành PrEP của CDC Hoa Kỳ và WHO.
# document/description    Tài liệu cập nhật về các phác đồ PrEP, bao gồm...
# cme/title               Phân tích và ứng dụng kết quả nghiên cứu lâm s...
# cme/description         Khóa học này sẽ giúp các bác sĩ và sinh viên y...
# Name: 13023, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, khi điều trị viêm âm hộ - âm ...
# answer                  Chào bạn, đây là một câu hỏi rất quan trọng tr...
# document/title          Hướng dẫn Quốc gia về các dịch vụ chăm sóc sức...
# document/description    Tài liệu từ Bộ Y tế Việt Nam cung cấp hướng dẫ...
# cme/title               Cập nhật chẩn đoán và điều trị viêm nhiễm phụ ...
# cme/description         Khóa học CME này tập trung vào các phác đồ chẩ...
# Name: 13024, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Chuyên gia có thể phân tích về hiệu quả của Pr...
# answer                  Chắc chắn rồi. Dự phòng trước phơi nhiễm HIV (...
# document/title          Hướng dẫn Quốc gia về các dịch vụ chăm sóc sức...
# document/description    Tài liệu của Bộ Y tế Việt Nam cung cấp các hướ...
# cme/title                    Quản lý và tư vấn PrEP trong phòng chống HIV
# cme/description         Khóa học CME này trang bị kiến thức chuyên sâu...
# Name: 13025, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các bác sĩ và sinh viên y khoa cần hiểu rõ nhữ...
# answer                  Chào bạn, việc phân tích sâu sắc các phác đồ v...
# document/title          CDC - Sexually Transmitted Infections Treatmen...
# document/description    Hướng dẫn của CDC là tài liệu tham khảo chuẩn ...
# cme/title               PrEP và các liệu pháp phòng chống HIV mới: Từ ...
# cme/description         Khóa học CME này cung cấp cái nhìn tổng quan v...
# Name: 13026, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa trên kết quả nghiên cứu về tỷ lệ duy trì P...
# answer                  Chào mừng các bạn bác sĩ trẻ và sinh viên y kh...
# document/title          Hướng dẫn quốc gia về dự phòng trước phơi nhiễ...
# document/description    Tài liệu chính thức của Bộ Y tế Việt Nam, cung...
# cme/title               Cập nhật Kiến thức và Kỹ năng Tư vấn PrEP tron...
# cme/description         Khóa học đào tạo y khoa liên tục cung cấp kiến...
# Name: 13027, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ sinh v...
# question                Khi đọc và diễn giải kết quả nghiên cứu như tr...
# answer                  Các bạn sinh viên và bác sĩ trẻ thân mến, việc...
# document/title          Thống kê Y học Ứng dụng trong Nghiên cứu Khoa ...
# document/description    Sách giáo trình chuyên sâu về các phương pháp ...
# cme/title               Thiết kế Nghiên cứu và Phân tích Số liệu Y học...
# cme/description         Khóa học thực hành chuyên sâu hướng dẫn sử dụn...
# Name: 13028, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp hướn...
# question                Nghiên cứu chỉ ra các lý do chính khiến đối tư...
# answer                  Các bạn bác sĩ trẻ và sinh viên y khoa cần nhậ...
# document/title          Tài liệu đào tạo Tư vấn viên PrEP và HIV cho C...
# document/description    Tài liệu hướng dẫn chuyên sâu của Bộ Y tế về k...
# cme/title               Kỹ năng Tư vấn và Quản lý Bệnh nhân PrEP: Từ L...
# cme/description         Khóa học cung cấp các công cụ và kỹ thuật hiệu...
# Name: 13029, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa bác sĩ, làm thế nào để chúng ta, những ng...
# answer                  Chào bạn, đây là một câu hỏi rất thực tế và qu...
# document/title          Hướng dẫn quốc gia về dự phòng trước phơi nhiễ...
# document/description    Tài liệu này cung cấp các khuyến nghị chi tiết...
# cme/title               Quản lý và Nâng cao Tuân thủ Điều trị PrEP tro...
# cme/description         Khóa học CME này tập trung vào việc trang bị c...
# Name: 13030, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu chỉ ra rằng tỷ lệ nhiễm HIV vẫn xảy...
# answer                  Chào bạn, đây là một thách thức thường gặp khi...
# document/title          PrEP: Hướng dẫn dành cho người dùng và cán bộ ...
# document/description    Tài liệu này của Tổ chức Y tế Thế giới cung cấ...
# cme/title               Tư vấn và Quản lý Tác dụng phụ của PrEP: Kỹ nă...
# cme/description         Khóa học CME này được thiết kế để nâng cao kỹ ...
# Name: 13031, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu này đã chỉ ra những hạn chế nhất đị...
# answer                  Đây là một câu hỏi rất hay, thể hiện tư duy ph...
# document/title          Thiết kế và Thực hiện Nghiên cứu Lâm sàng: Các...
# document/description    Cuốn sách cung cấp kiến thức nền tảng về phươn...
# cme/title               Phát triển và Đánh giá Chương trình Dự phòng H...
# cme/description         Khóa học này khám phá các phương pháp thiết kế...
# Name: 13032, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Xin chào chuyên gia, em là sinh viên y khoa. E...
# answer                  Chào bạn, đây là một câu hỏi rất quan trọng và...
# document/title          Nghiên cứu về cơ chế hình thành và phát triển ...
# document/description    Tài liệu này đi sâu vào các yếu tố phân tử và ...
# cme/title               Cập nhật Sinh lý bệnh học và Các phương pháp đ...
# cme/description         Khóa học này cung cấp cái nhìn toàn diện về cá...
# Name: 13033, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp hướn...
# question                Thưa chuyên gia, em là một bác sĩ nội trú đang...
# answer                  Chào bạn, đây là một lo ngại rất chính đáng và...
# document/title          Atlas Giải phẫu Mạch máu Thần kinh và Các Biến...
# document/description    Cuốn sách này là một tài liệu tham khảo thiết ...
# cme/title               Kỹ thuật Nút mạch Động mạch màng não giữa nâng...
# cme/description         Khóa học này bao gồm các buổi giảng lý thuyết ...
# Name: 13034, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ phân t...
# question                Kính gửi chuyên gia, trong quá trình theo dõi ...
# answer                  Chào bạn, việc phát hiện các tổn thương mạch m...
# document/title          Phân loại và Điều trị các Dị dạng Mạch máu Não...
# document/description    Cuốn sách này cung cấp thông tin chi tiết về p...
# cme/title               Quản lý các Biến chứng và Tổn thương mạch máu ...
# cme/description         Khóa học này được thiết kế để nâng cao khả năn...
# Name: 13035, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, xin giải thích cơ chế hình th...
# answer                  Chào bạn, một câu hỏi rất hay và thiết thực ch...
# document/title          Chụp Động Mạch Màng Não Giữa (DSA) trong Chẩn ...
# document/description    Tài liệu này cung cấp cái nhìn tổng quan về kỹ...
# cme/title               Khóa học Nút mạch Động mạch Màng não Giữa tron...
# cme/description         Khóa học CME này tập trung vào lý thuyết và th...
# Name: 13036, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Em muốn tìm hiểu sâu hơn về hệ thống miễn dịch...
# answer                  Chào bạn, câu hỏi của bạn rất cơ bản nhưng lại...
# document/title                  Miễn Dịch Học Cơ Bản và Ứng Dụng Lâm Sàng
# document/description    Sách giáo trình toàn diện về hệ thống miễn dịc...
# cme/title               Cập Nhật về Ảnh Hưởng của Lối Sống lên Hệ Miễn...
# cme/description         Khóa học CME này tập trung vào mối liên hệ giữ...
# Name: 13037, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Em là một bác sĩ trẻ đang tìm hiểu về các phươ...
# answer                  Chào bạn, rất mừng khi bạn có tinh thần cập nh...
# document/title          Tổng quan về Nút Động mạch Màng não Giữa trong...
# document/description    Bài tổng quan có hệ thống và phân tích gộp (me...
# cme/title               Đánh giá Bằng chứng Khoa học và Áp dụng Y học ...
# cme/description         Khóa học CME này được thiết kế để nâng cao kỹ ...
# Name: 13038, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, xin giải thích về bệnh máu tụ...
# answer                  Chào bạn, máu tụ dưới màng cứng mạn tính (cSDH...
# document/title          Hướng dẫn chẩn đoán và điều trị Máu tụ dưới mà...
# document/description    Tài liệu cung cấp các phác đồ chẩn đoán, tiêu ...
# cme/title               Kỹ thuật Chụp mạch số hóa xóa nền (DSA) trong ...
# cme/description         Khóa học đào tạo liên tục về nguyên lý, kỹ thu...
# Name: 13039, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hướng dẫn và ...
# question                Em muốn tìm hiểu kỹ hơn về quy trình can thiệp...
# answer                  Để thực hiện nút động mạch màng não giữa (MMA ...
# document/title          Atlas Giải phẫu học Động mạch Màng não giữa và...
# document/description    Tài liệu hình ảnh chi tiết các biến thể giải p...
# cme/title               An toàn trong Can thiệp Mạch não và Xử trí Biế...
# cme/description         Khóa học chuyên sâu về các phương pháp giảm th...
# Name: 13040, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ sinh v...
# question                Em là sinh viên y khoa và muốn tìm hiểu về các...
# answer                  Chào bạn, việc hiểu phương pháp nghiên cứu là ...
# document/title          Sổ tay Phương pháp Nghiên cứu Khoa học trong Y...
# document/description    Cuốn sách hướng dẫn chi tiết về thiết kế nghiê...
# cme/title                  Thống kê Y sinh và Phân tích Dữ liệu Lâm sàng.
# cme/description         Khóa học thực hành về ứng dụng các phương pháp...
# Name: 13041, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Xin thầy/cô có thể phân tích sâu hơn về cơ chế...
# answer                  Các em sinh viên và bác sĩ trẻ thân mến, việc ...
# document/title          Cập nhật Cơ chế Bệnh sinh và Điều trị Máu tụ d...
# document/description    Tài liệu này cung cấp cái nhìn tổng quan về nh...
# cme/title               Kỹ thuật và Hiệu quả Nút Động mạch màng não gi...
# cme/description         Khóa học CME này tập trung vào các bằng chứng ...
# Name: 13042, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong can thiệp nút động mạch màng não giữa, n...
# answer                  Khi tiến hành can thiệp nút động mạch màng não...
# document/title          Hướng dẫn chẩn đoán hình ảnh và can thiệp mạch...
# document/description    Tài liệu này cung cấp các hình ảnh chi tiết và...
# cme/title               Thực hành lâm sàng: Kỹ thuật Nút Động mạch màn...
# cme/description         Khóa học thực hành này tập trung vào các kỹ th...
# Name: 13043, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sau phẫu thuật máu tụ dưới màng cứng mạn tính,...
# answer                  Các em cần nhớ rằng, không phải tất cả các trư...
# document/title          Các trường hợp lâm sàng phức tạp trong Máu tụ ...
# document/description    Tài liệu này trình bày các trường hợp lâm sàng...
# cme/title               Chẩn đoán và Xử trí các Bất thường Mạch máu nã...
# cme/description         Khóa học này tập trung vào các kỹ thuật chẩn đ...
# Name: 13044, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, xin giải thích về vai trò của...
# answer                  Chào các bác sĩ trẻ và sinh viên y khoa, việc ...
# document/title          Cơ chế bệnh sinh và chiến lược can thiệp nút m...
# document/description    Tài liệu này cung cấp cái nhìn toàn diện về si...
# cme/title               Can thiệp Nội mạch trong Bệnh lý Mạch máu não:...
# cme/description         Khóa học CME này tập trung vào các kỹ thuật ca...
# Name: 13045, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một sinh viên y khoa, em muốn hiểu rõ hơn v...
# answer                  Để trở thành một bác sĩ giỏi, việc hiểu rõ về ...
# document/title          Miễn dịch học: Cơ sở và Ứng dụng Lâm sàng (ICD...
# document/description    Tài liệu này là một giáo trình miễn dịch học c...
# cme/title               Các Khía cạnh Thực hành của Miễn dịch học Lâm ...
# cme/description         Khóa học CME này được thiết kế để kết nối lý t...
# Name: 13046, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Em đã đọc tài liệu về tác hại của thuốc lá đối...
# answer                  Việc các bạn sinh viên và bác sĩ trẻ quan tâm ...
# document/title          Tác động của Thuốc lá đến Sức khỏe Toàn diện v...
# document/description    Tài liệu này cung cấp bằng chứng khoa học chi ...
# cme/title               Kỹ năng Tư vấn Cai thuốc lá Hiệu quả trong Thự...
# cme/description         Khóa học CME này tập trung vào việc trang bị c...
# Name: 13047, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Đối với các bác sĩ trẻ và sinh viên y khoa, xi...
# answer                  Khi tiếp cận phẫu thuật cắt bỏ bướu lành tính ...
# document/title          Hướng dẫn chẩn đoán và điều trị bướu tuyến nướ...
# document/description    Tài liệu này cung cấp các phác đồ chẩn đoán hì...
# cme/title               Kỹ thuật phẫu thuật tuyến mang tai và tái tạo ...
# cme/description         Khóa học đào tạo y khoa liên tục này tập trung...
# Name: 13048, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Để chẩn đoán chính xác sỏi ống mật chủ, các bá...
# answer                  Sỏi ống mật chủ (Choledocholithiasis) là một b...
# document/title          Hướng dẫn chẩn đoán và điều trị sỏi ống mật ch...
# document/description    Tài liệu này cung cấp hướng dẫn chuyên sâu về ...
# cme/title               Chẩn đoán hình ảnh nâng cao trong bệnh lý đườn...
# cme/description         Khóa học CME này tập trung vào việc đọc và phâ...
# Name: 13049, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sau phẫu thuật cắt bỏ bướu lành tính tuyến man...
# answer                  Việc đánh giá kết quả điều trị sau phẫu thuật ...
# document/title          Quản lý và theo dõi bệnh nhân sau phẫu thuật đ...
# document/description    Tài liệu này cung cấp hướng dẫn chi tiết về qu...
# cme/title               Chăm sóc hậu phẫu và quản lý biến chứng sau ph...
# cme/description         Khóa học đào tạo y khoa liên tục này trang bị ...
# Name: 13050, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, xin giải thích về các nguyên ...
# answer                  Chào các bác sĩ và sinh viên y khoa! Việc thực...
# document/title          Phẫu thuật tái tạo khuyết hổng vùng đầu mặt cổ...
# document/description    Tài liệu này tổng hợp các nghiên cứu chuyên sâ...
# cme/title               Kỹ thuật ghép mỡ trung bì tự thân trong phẫu t...
# cme/description         Khóa học CME này được thiết kế để cung cấp kiế...
# Name: 13051, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với vai trò là một bác sĩ phẫu thuật, làm thế ...
# answer                  Các bạn thân mến, đánh giá hiệu quả thẩm mỹ và...
# document/title          Hướng dẫn đánh giá kết quả thẩm mỹ và chất lượ...
# document/description    Tài liệu này cung cấp các công cụ và phương ph...
# cme/title               Quản lý kỳ vọng và tối ưu hóa kết quả thẩm mỹ ...
# cme/description         Khóa học tập trung vào cách giao tiếp hiệu quả...
# Name: 13052, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi lên kế hoạch phẫu thuật tái tạo khuyết hổn...
# answer                  Các bạn sinh viên và bác sĩ trẻ thân mến, việc...
# document/title          Atlas Phẫu thuật Tạo hình và Thẩm mỹ: Kỹ thuật...
# document/description    Cuốn sách này là một atlas toàn diện về các kỹ...
# cme/title               Hội thảo chuyên đề: Tối ưu hóa kết quả trong p...
# cme/description         Hội thảo kéo dài hai ngày, tập trung vào các c...
# Name: 13053, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Để đạt được kết quả thẩm mỹ tối ưu và phòng ng...
# answer                  Chào các bác sĩ và sinh viên y khoa! Việc đạt ...
# document/title          KẾT QUẢ ĐIỀU TRỊ MỘT THÌ KHUYẾT HỔNG SAU CẮT B...
# document/description    Bài báo này cung cấp cái nhìn sâu sắc về hiệu ...
# cme/title               Phẫu Thuật Tạo Hình và Tái Tạo Vùng Đầu Cổ: Kỹ...
# cme/description         Khóa học này tập trung vào các kỹ thuật phẫu t...
# Name: 13054, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ sinh v...
# question                Sau phẫu thuật cắt bướu tuyến mang tai sử dụng...
# answer                  Các bạn thân mến, quản lý biến chứng hậu phẫu ...
# document/title          KẾT QUẢ ĐIỀU TRỊ MỘT THÌ KHUYẾT HỔNG SAU CẮT B...
# document/description    Tài liệu này cung cấp các dữ liệu lâm sàng qua...
# cme/title               Quản Lý Toàn Diện Biến Chứng Hậu Phẫu trong Ph...
# cme/description         Khóa học chuyên sâu về nhận diện sớm, chẩn đoá...
# Name: 13055, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Đối với bệnh nhân nghi ngờ sỏi ống mật chủ, si...
# answer                  Kính gửi các bạn sinh viên và bác sĩ trẻ, việc...
# document/title          Magnetic resonance cholangiopancreatography: u...
# document/description    Tài liệu này đánh giá tính hữu dụng của MRCP t...
# cme/title               Chẩn Đoán Hình Ảnh Các Bệnh Lý Gan-Mật-Tụy: Từ...
# cme/description         Khóa học này sẽ trang bị kiến thức toàn diện v...
# Name: 13056, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, xin vui lòng giải thích về cá...
# answer                  Chào bạn, bướu lành tính tuyến mang tai là một...
# document/title                        Bài giảng Phẫu thuật Tuyến Nước Bọt
# document/description    Cung cấp kiến thức cơ bản và chuyên sâu về giả...
# cme/title               Phẫu thuật Tuyến Nước Bọt - Từ Giải phẫu đến K...
# cme/description         Khóa học CME tập trung vào cập nhật kiến thức ...
# Name: 13057, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ đào tạ...
# question                Em muốn tìm hiểu sâu hơn về kỹ thuật ghép trun...
# answer                  Ghép trung bì mỡ tự thân là một phương pháp tá...
# document/title                        Tạo hình và Tái tạo Vùng Đầu Mặt Cổ
# document/description    Cuốn sách cung cấp cái nhìn toàn diện về các n...
# cme/title               Kỹ thuật Ghép Mô Tự Thân trong Phẫu thuật Tái ...
# cme/description         Khóa học thực hành chuyên sâu giúp các bác sĩ ...
# Name: 13058, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ sinh v...
# question                Khi tham gia vào một nghiên cứu lâm sàng về cá...
# answer                  Tham gia nghiên cứu khoa học là một phần quan ...
# document/title              Sổ tay Phương pháp Nghiên cứu Khoa học Y sinh
# document/description    Cung cấp hướng dẫn chi tiết về các loại hình n...
# cme/title                Đạo đức và Phương pháp trong Nghiên cứu Lâm sàng
# cme/description         Khóa học chuyên sâu về thiết kế nghiên cứu lâm...
# Name: 13059, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, em đang là sinh viên y khoa n...
# answer                  Chào em, việc nắm vững chỉ định và quy trình k...
# document/title            Phẫu thuật nội soi mũi xoang cơ bản và nâng cao
# document/description    Tài liệu này cung cấp kiến thức toàn diện về c...
# cme/title               Khóa học thực hành Phẫu thuật nội soi mũi xoan...
# cme/description         Khóa học này tập trung vào các kỹ thuật phẫu t...
# Name: 13060, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Chào chuyên gia, sau khi phẫu thuật chỉnh hình...
# answer                  Việc chăm sóc hậu phẫu và theo dõi sát sao là ...
# document/title          Hướng dẫn chăm sóc hậu phẫu trong Phẫu thuật T...
# document/description    Cuốn sách này cung cấp các phác đồ và hướng dẫ...
# cme/title                Quản lý biến chứng trong phẫu thuật Tai Mũi Họng
# cme/description         Khóa học này đào tạo chuyên sâu về nhận diện, ...
# Name: 13061, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Chuyên gia cho em hỏi, khi bệnh nhân đến khám ...
# answer                  Việc chẩn đoán phân biệt chính xác nguyên nhân...
# document/title                            Bài giảng Bệnh học Tai Mũi Họng
# document/description    Tài liệu giáo trình kinh điển này giúp sinh vi...
# cme/title                Khám lâm sàng và chẩn đoán các bệnh lý mũi xoang
# cme/description         Khóa học này trang bị kỹ năng khám lâm sàng ch...
# Name: 13062, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi nào thì cân nhắc phẫu thuật chỉnh hình cuố...
# answer                  Chào các bác sĩ và sinh viên y khoa, việc cân ...
# document/title          Hướng dẫn Chẩn đoán và Điều trị Bệnh lý Cuốn M...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Cập nhật Phẫu thuật Cuốn Mũi Nội soi và Kỹ thu...
# cme/description         Khóa học tập trung vào các kỹ thuật phẫu thuật...
# Name: 13063, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ sinh v...
# question                Sau phẫu thuật chỉnh hình cuốn dưới, làm thế n...
# answer                  Để đánh giá hiệu quả điều trị sau phẫu thuật c...
# document/title          Thang điểm NOSE (Nasal Obstruction Symptom Eva...
# document/description    Tài liệu này cung cấp hướng dẫn chi tiết về cá...
# cme/title               Đánh giá Chất lượng Cuộc sống và Kết quả Điều ...
# cme/description         Khóa học này giới thiệu các công cụ và phương ...
# Name: 13064, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp kiến...
# question                Phẫu thuật chỉnh hình cuốn dưới có thể gặp phả...
# answer                  Các bác sĩ và sinh viên y khoa thân mến, mặc d...
# document/title          Quản lý Biến chứng trong Phẫu thuật Mũi Xoang ...
# document/description    Tài liệu chuyên sâu về các biến chứng thường g...
# cme/title               Chăm sóc Hậu phẫu và Phòng ngừa Biến chứng tro...
# cme/description         Khóa học cung cấp kiến thức thực hành về chăm ...
# Name: 13065, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Đối với bệnh nhân đái tháo đường típ 2 (ĐTĐT2)...
# answer                  Chào các bác sĩ trẻ và sinh viên y khoa! Việc ...
# document/title          Hướng dẫn chẩn đoán và điều trị Đái tháo đường...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Cập nhật kiến thức về các chỉ dấu sinh học mới...
# cme/description         Khóa học tập trung phân tích vai trò của các a...
# Name: 13066, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ phân t...
# question                Khi tiến hành một nghiên cứu định lượng biomar...
# answer                  Để đảm bảo tính khoa học và đáng tin cậy của b...
# document/title          Nguyên lý cơ bản trong nghiên cứu khoa học y s...
# document/description    Tài liệu này cung cấp kiến thức nền tảng về th...
# cme/title               Kỹ năng thiết kế và phân tích nghiên cứu lâm s...
# cme/description         Khóa học thực hành hướng dẫn từng bước quy trì...
# Name: 13067, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp kiến...
# question                Nghiên cứu về Nesfatin-1 chỉ ra mối liên quan ...
# answer                  Thật tuyệt vời khi các bạn đã nắm bắt được các...
# document/title          Hướng dẫn quản lý đa yếu tố nguy cơ tim mạch ở...
# document/description    Tài liệu chuyên sâu về chiến lược quản lý tích...
# cme/title               Quản lý toàn diện bệnh nhân ĐTĐT2: Từ chẩn đoá...
# cme/description         Khóa học cung cấp cái nhìn tổng quan và chi ti...
# Name: 13068, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi một bệnh nhân đến khám vì nghẹt mũi mạn tí...
# answer                  Chào bạn, với vai trò là một bác sĩ nội trú Ta...
# document/title          Hướng dẫn Chẩn đoán và Điều trị các bệnh Tai M...
# document/description    Tài liệu cung cấp các phác đồ và hướng dẫn chi...
# cme/title               Khóa học chuyên sâu: "Đánh giá chức năng mũi v...
# cme/description         Khóa học tập trung vào các phương pháp đánh gi...
# Name: 13069, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Đối với sinh viên y khoa đang học về phẫu thuậ...
# answer                  Chào các bạn sinh viên y khoa, nắm vững các kh...
# document/title          Sách giáo khoa "Phẫu thuật Tai Mũi Họng" của t...
# document/description    Cuốn sách cung cấp kiến thức nền tảng và chuyê...
# cme/title               Hội thảo khoa học: "Cập nhật các kỹ thuật phẫu...
# cme/description         Hội thảo nhằm cập nhật các kỹ thuật phẫu thuật...
# Name: 13070, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sau phẫu thuật chỉnh hình cuốn mũi dưới nội so...
# answer                  Chào các bạn đồng nghiệp và sinh viên y khoa, ...
# document/title          "Rhinitis Medicamentosa: Diagnosis and Treatme...
# document/description    Hướng dẫn thực hành lâm sàng cung cấp thông ti...
# cme/title               Khóa học online: "Quản lý toàn diện viêm mũi m...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về các ...
# Name: 13071, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, quá phát cuốn dưới mũi là tìn...
# answer                  Chào bạn, đây là một câu hỏi rất hay và thiết ...
# document/title          Hướng dẫn chẩn đoán và điều trị quá phát cuốn ...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Cập nhật các phương pháp điều trị quá phát cuố...
# cme/description         Khóa học này sẽ đi sâu vào các kỹ thuật phẫu t...
# Name: 13072, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ sinh v...
# question                Phương pháp phẫu thuật chỉnh hình cuốn dưới tạ...
# answer                  Các em sinh viên và bác sĩ trẻ thân mến, việc ...
# document/title          Kỹ thuật phẫu thuật nội soi chỉnh hình cuốn dư...
# document/description    Cuốn sách này cung cấp một hướng dẫn chi tiết ...
# cme/title               Workshop thực hành nâng cao phẫu thuật nội soi...
# cme/description         Khóa học thực hành chuyên sâu (hands-on worksh...
# Name: 13073, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, giúp đánh giá...
# question                Làm thế nào để đánh giá hiệu quả của phẫu thuậ...
# answer                  Kính gửi các đồng nghiệp trẻ và sinh viên y kh...
# document/title          Đánh giá kết quả lâu dài của phẫu thuật cuốn m...
# document/description    Tài liệu này tổng hợp các nghiên cứu lâm sàng ...
# cme/title               Quản lý và theo dõi bệnh nhân sau phẫu thuật c...
# cme/description         Khóa học này tập trung vào quy trình chăm sóc ...
# Name: 13074, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa vào nghiên cứu về can thiệp nâng cao chất ...
# answer                  Chào bạn, việc nâng cao chất lượng dịch vụ y t...
# document/title          Hướng dẫn thực hành quản lý chất lượng bệnh vi...
# document/description    Tài liệu cung cấp các nguyên tắc, tiêu chuẩn v...
# cme/title               Khóa học Đào tạo về Quản lý Chất lượng và An t...
# cme/description         Khóa học cung cấp kiến thức và kỹ năng thực hà...
# Name: 13075, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các tiêu chí chất lượng dịch vụ khám chữa bệnh...
# answer                  Các bác sĩ trẻ và sinh viên y khoa thân mến, t...
# document/title          Quyết định số 2151/QĐ-BYT về Kế hoạch triển kh...
# document/description    Văn bản pháp quy quan trọng của Bộ Y tế Việt N...
# cme/title               CME: Kỹ năng Giao tiếp và Chăm sóc Khách hàng ...
# cme/description         Khóa học tập trung vào việc trang bị cho nhân ...
# Name: 13076, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ trẻ hoặc sinh viên y khoa, bạn c...
# answer                  Việc đọc và hiểu các nghiên cứu khoa học, đặc ...
# document/title          Nguyên lý Nghiên cứu Khoa học trong Y học và S...
# document/description    Tài liệu học thuật cung cấp kiến thức nền tảng...
# cme/title               Khóa học Phương pháp Nghiên cứu Khoa học và Ph...
# cme/description         Khóa học chuyên sâu trang bị kiến thức về thiế...
# Name: 13077, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa vào kết quả cải thiện chất lượng dịch vụ k...
# answer                  Chào các bạn bác sĩ trẻ và sinh viên y khoa! V...
# document/title          Quyết định 2337/QĐ-BYT về Bộ tiêu chí chất lượ...
# document/description    Tài liệu này là căn cứ pháp lý và chuyên môn đ...
# cme/title               Khóa học "Quản lý chất lượng bệnh viện và an t...
# cme/description         Khóa học này cung cấp kiến thức toàn diện về c...
# Name: 13078, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong số các tiêu chí chất lượng, "Áp dụng và ...
# answer                  Các bạn sinh viên và bác sĩ trẻ thân mến, Tiêu...
# document/title          Hướng dẫn chẩn đoán và điều trị của Bộ Y tế (t...
# document/description    Các tài liệu này cung cấp các phác đồ, quy trì...
# cme/title                Khóa học "Dược lâm sàng và sử dụng thuốc hợp lý"
# cme/description         Khóa học tập trung vào các nguyên tắc dược lâm...
# Name: 13079, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trung tâm Y tế thành phố Dĩ An đã cải thiện đá...
# answer                  Xin chào các bạn bác sĩ và sinh viên y khoa,\n...
# document/title          Thông tư 58/2015/TT-BYT về Hướng dẫn công tác ...
# document/description    Văn bản pháp quy này cung cấp các hướng dẫn ch...
# cme/title               Khóa học "Kiểm soát nhiễm khuẩn và an toàn sin...
# cme/description         Khóa học đào tạo chuyên sâu về các nguyên tắc,...
# Name: 13080, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Theo những nghiên cứu về chất lượng dịch vụ kh...
# answer                  Chào em, vấn đề nhân lực y tế là cốt lõi để đả...
# document/title          Thông tư liên tịch số 08/2007/TTLT-BYT-BNV Hướ...
# document/description    Tài liệu quy định về định mức biên chế sự nghi...
# cme/title               Quản lý Nguồn Nhân lực Y tế và Phát triển Bền ...
# cme/description         Khóa học này cung cấp kiến thức và kỹ năng về ...
# Name: 13081, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong bối cảnh các tiêu chí chất lượng dịch vụ...
# answer                  Em thân mến, việc chủ động đánh giá và cải tiế...
# document/title          Bộ Tiêu chí Chất lượng Áp dụng cho Phòng khám ...
# document/description    Tài liệu này là cẩm nang chính thức giúp các c...
# cme/title               Quản lý Chất lượng và An toàn Người bệnh trong...
# cme/description         Khóa học này tập trung vào các nguyên tắc và c...
# Name: 13082, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Theo nghiên cứu, 'Tiêu chí 4 (Phòng khám bảo đ...
# answer                  Các em thân mến, Tiêu chí 4 và Tiêu chí 19 là ...
# document/title          Hướng dẫn Chẩn đoán và Điều trị một số Bệnh th...
# document/description    Tài liệu của Bộ Y tế Việt Nam cung cấp các phá...
# cme/title               Cấp Cứu Ban Đầu Toàn Diện và Chuyển Đổi Số tro...
# cme/description         Khóa học này trang bị kiến thức và kỹ năng thự...
# Name: 13083, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, làm thế nào để các bác sĩ trẻ...
# answer                  Các bạn bác sĩ trẻ và sinh viên y khoa thân mế...
# document/title          Quyết định 2151/QĐ-BYT ngày 04/6/2015 về việc ...
# document/description    Văn bản pháp quy của Bộ Y tế Việt Nam định hướ...
# cme/title               An Toàn Người Bệnh và Quản Lý Rủi Ro Trong Y T...
# cme/description         Khóa học này trang bị kiến thức và kỹ năng cần...
# Name: 13084, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Hồ sơ bệnh án và các quy trình kỹ thuật khám c...
# answer                  Thưa các bạn đồng nghiệp tương lai và hiện tại...
# document/title          Bộ Y tế (2018), Chỉ thị số 847/CT-BYT ngày 21/...
# document/description    Chỉ thị này cung cấp các giải pháp cụ thể từ B...
# cme/title               Quản Lý Hồ Sơ Bệnh Án Điện Tử và Thực Hành Dựa...
# cme/description         Khóa học này tập trung vào các quy định hiện h...
# Name: 13085, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các phòng khám đa khoa mới thành lập, đặc biệt...
# answer                  Chào các bạn, các phòng khám đa khoa mới, đặc ...
# document/title          Sở Y tế thành phố Hồ Chí Minh (2019), Tiêu chí...
# ...
# cme/description         Khóa học này trang bị cho học viên kỹ năng đán...
# Name: 13847, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Việc phân tích dữ liệu tỷ lệ tử vong theo nguy...
# answer                  Kính gửi các bạn sinh viên y khoa và các bác s...
# document/title          Phương pháp nghiên cứu Dịch tễ học trong Y học...
# document/description    Cuốn sách cung cấp kiến thức chuyên sâu về các...
# cme/title                 Dịch tễ học cơ bản và Thống kê y học cho Bác sĩ
# cme/description         Khóa học này cung cấp kiến thức và kỹ năng cần...
# Name: 13848, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ trẻ hoặc sinh viên y khoa, anh/c...
# answer                  Để giải quyết gánh nặng BKLN ngày càng tăng, đ...
# document/title          Hướng Dẫn Phương Pháp Nghiên Cứu Dịch Tễ Học M...
# document/description    Tài liệu này cung cấp các phương pháp luận và ...
# cme/title               Khóa Học Chuyên Sâu: Các Bệnh Không Lây Nhiễm ...
# cme/description         Khóa học CME này tập trung vào cập nhật kiến t...
# Name: 13849, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để phát triển các chương trình tru...
# answer                  Để phát triển các chương trình truyền thông hi...
# document/title          Tài Liệu Hướng Dẫn Truyền Thông Giáo Dục Sức K...
# document/description    Cuốn sách cung cấp kiến thức nền tảng và các c...
# cme/title               CME: Kỹ Năng Phát Triển và Thực Hiện Chương Tr...
# cme/description         Khóa học này được thiết kế để nâng cao năng lự...
# Name: 13850, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi tiến hành các nghiên cứu để tìm ra nguyên ...
# answer                  Khi tham gia hoặc khởi xướng các nghiên cứu nh...
# document/title            Sổ Tay Dịch Tễ Học Lâm Sàng và Nghiên Cứu Y Học
# document/description    Cuốn sách cung cấp kiến thức nền tảng và các k...
# cme/title               Khóa Học CME: Phương Pháp Nghiên Cứu Khoa Học ...
# cme/description         Khóa học này trang bị cho học viên kiến thức v...
# Name: 13851, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong bối cảnh lâm sàng, việc giám sát chất lư...
# answer                  Chào bạn, với vai trò là một bác sĩ hoặc sinh ...
# document/title          ÁP DỤNG HƯỚNG DẪN EP15A3 CỦA CLSI XÁC NH...
# document/description    Tài liệu này là một ví dụ thực tế về việc áp d...
# cme/title               Kiểm soát chất lượng nội bộ và ngoại kiểm tron...
# cme/description         Khóa học này trang bị kiến thức và kỹ năng thự...
# Name: 13852, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, tại sao việc xác nhận phương ...
# answer                  Chào bạn, câu hỏi của bạn rất quan trọng, nó c...
# document/title          ISO 15189: Yêu cầu về năng lực và chất lượng đ...
# document/description    Tiêu chuẩn quốc tế này quy định các yêu cầu cụ...
# cme/title               Quản lý Chất lượng Toàn diện trong Phòng Xét n...
# cme/description         Khóa học CME này cung cấp kiến thức và kỹ năng...
# Name: 13853, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Em xin hỏi về cách xác nhận độ chụm và độ đúng...
# answer                  Chào bạn, câu hỏi này rất hay vì nó đi sâu vào...
# document/title          CLSI EP15-A3: Hướng dẫn Xác nhận Hiệu năng Phâ...
# document/description    Tài liệu này là cẩm nang chuyên sâu từ Viện Ti...
# cme/title               Kiểm soát Chất lượng Nội bộ và Đánh giá Hiệu n...
# cme/description         Khóa học CME này cung cấp kiến thức thực hành ...
# Name: 13854, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu nhắc đến một số xét nghiệm hóa sinh...
# answer                  Đây là một câu hỏi rất thực tế và quan trọng đ...
# document/title          Sổ tay Xét nghiệm Hóa sinh Lâm sàng: Nguyên lý...
# document/description    Tài liệu này tổng hợp kiến thức về nguyên lý, ...
# cme/title               Cập nhật Chẩn đoán và Theo dõi Bệnh qua Xét ng...
# cme/description         Khóa học CME này đi sâu vào cập nhật các chỉ đ...
# Name: 13855, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, làm thế nào để một bác sĩ trẻ...
# answer                  Chào bạn, đây là một câu hỏi rất quan trọng tr...
# document/title          Hướng dẫn Quản lý Chất lượng Phòng Xét Nghiệm ...
# document/description    Tài liệu chính thống này cung cấp các nguyên t...
# cme/title               Kiểm Soát Chất Lượng Nội Bộ (IQC) và Ngoại Kiể...
# cme/description         Khóa học CME này được thiết kế để trang bị cho...
# Name: 13856, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với các kết quả về độ đúng cho thấy nhiều xét ...
# answer                  Đây là một điểm cực kỳ quan trọng và có thể ản...
# document/title          Tiêu chuẩn ISO 15189: 2012 - Yêu cầu về Năng l...
# document/description    Tài liệu này là kim chỉ nam quốc tế cho các ph...
# cme/title               Quản Lý Rủi Ro và Cải Tiến Chất Lượng Liên Tục...
# cme/description         Khóa học tập trung vào các phương pháp nhận di...
# Name: 13857, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với tư cách là một bác sĩ trẻ hoặc sinh viên y...
# answer                  Việc thấu hiểu quá trình xác nhận hiệu năng ph...
# document/title          Sổ tay Hướng dẫn Xét nghiệm Lâm sàng của Bộ Y ...
# document/description    Cẩm nang thiết yếu này cung cấp một cái nhìn t...
# cme/title               Ứng dụng Quản lý Chất lượng trong Thực hành Lâ...
# cme/description         Khóa học CME này được thiết kế để kết nối kiến...
# Name: 13858, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, khi phòng xét nghiệm thực hiệ...
# answer                  Chào các bạn đồng nghiệp và sinh viên y khoa,\...
# document/title          Hướng dẫn CLSI EP15-A3: Đánh giá độ đúng của p...
# document/description    Tài liệu này cung cấp hướng dẫn chi tiết từ Hi...
# cme/title               Kiểm soát Chất lượng và Xác nhận Phương pháp t...
# cme/description         Khóa học này đào tạo chuyên sâu về các nguyên ...
# Name: 13859, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ phân t...
# question                Đối với các xét nghiệm như AST và Creatinin, đ...
# answer                  Các bạn sinh viên và bác sĩ thân mến,\n\nĐây l...
# document/title          Tiêu chuẩn Hiệu năng Phân tích của CLIA và Ứng...
# document/description    Tài liệu này trình bày các tiêu chuẩn về hiệu ...
# cme/title               Giải thích và Ứng dụng Kết quả Xét nghiệm Hóa ...
# cme/description         Khóa học chuyên sâu này giúp bác sĩ lâm sàng v...
# Name: 13860, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, đóng vai trò ...
# question                Nghiên cứu về độ chụm và độ đúng trên hệ thống...
# answer                  Kính gửi các bạn đồng nghiệp và các bạn sinh v...
# document/title          Tiêu chuẩn ISO 15189: Yêu cầu về năng lực và c...
# document/description    Tiêu chuẩn quốc tế này quy định các yêu cầu cụ...
# cme/title               Hệ thống Quản lý Chất lượng Toàn diện trong Ph...
# cme/description         Khóa học này trang bị kiến thức và kỹ năng về ...
# Name: 13861, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ trẻ hoặc sinh viên y khoa, tôi c...
# answer                  Việc xác nhận độ chụm và độ đúng của các xét n...
# document/title          CLSI EP15-A3: Hướng dẫn xác nhận độ chụm và độ...
# document/description    Tài liệu hướng dẫn kỹ thuật chi tiết của Viện ...
# cme/title               Kiểm soát chất lượng phòng xét nghiệm và áp dụ...
# cme/description         Khóa học đào tạo y khoa liên tục (CME) chuyên ...
# Name: 13862, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một điều dưỡng viên hoặc bác sĩ trẻ, tôi mu...
# answer                  Chăm sóc dinh dưỡng đóng vai trò cốt yếu trong...
# document/title          Thông tư 08/2011/TT-BYT Hướng dẫn về công tác ...
# document/description    Văn bản pháp quy của Bộ Y tế Việt Nam ban hành...
# cme/title               Quản lý dinh dưỡng lâm sàng và tiết chế trong ...
# cme/description         Khóa học CME được thiết kế cho bác sĩ, điều dư...
# Name: 13863, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Để tư vấn hiệu quả cho bệnh nhân và quản lý cá...
# answer                  Đái tháo đường (ĐTĐ) là một bệnh rối loạn chuy...
# document/title          Kiến thức về bệnh đái tháo đường (Cục quản lý ...
# document/description    Tài liệu được xuất bản bởi Cục quản lý khám ch...
# cme/title               Cập nhật chẩn đoán, điều trị và quản lý biến c...
# cme/description         Khóa học CME toàn diện dành cho bác sĩ nội kho...
# Name: 13864, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ trẻ hoặc sinh viên y khoa làm vi...
# answer                  Chào em/anh/chị, việc xác nhận phương pháp xét...
# document/title          Hướng dẫn CLSI EP15-A3: Thực hành xác nhận hiệ...
# document/description    Tài liệu này cung cấp các quy trình thực hành ...
# cme/title               Khóa học Đảm bảo chất lượng trong xét nghiệm y...
# cme/description         Khóa học này cung cấp kiến thức toàn diện về c...
# Name: 13865, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi tiến hành xác nhận độ chụm và độ đúng cho ...
# answer                  Là một bác sĩ trẻ hoặc sinh viên y khoa, việc ...
# document/title              Sổ tay Kiểm soát chất lượng xét nghiệm y học.
# document/description    Tài liệu này cung cấp hướng dẫn chi tiết về cá...
# cme/title               Phân tích và khắc phục sự cố trong kiểm soát c...
# cme/description         Khóa học thực hành này tập trung vào việc nhận...
# Name: 13866, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong các nghiên cứu xác nhận phương pháp xét ...
# answer                  Chào em/anh/chị, trong bất kỳ nghiên cứu khoa ...
# document/title          Quy trình vận hành chuẩn (SOP) cho phòng xét n...
# document/description    Tài liệu này cung cấp các hướng dẫn chi tiết v...
# cme/title               Thực hành tốt phòng xét nghiệm (GLP) và đạo đứ...
# cme/description         Khóa học này trang bị kiến thức về các nguyên ...
# Name: 13867, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một sinh viên y khoa mới bắt đầu tìm hiểu v...
# answer                  Chào em, để đánh giá độ chụm của các xét nghiệ...
# document/title          Hướng dẫn thực hành Kiểm soát chất lượng nội b...
# document/description    Tài liệu này cung cấp kiến thức nền tảng và hư...
# cme/title               CME: Kiểm soát chất lượng xét nghiệm và đảm bả...
# cme/description         Khóa học này trang bị kiến thức chuyên sâu về ...
# Name: 13868, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi kết quả xác nhận độ đúng của nhiều xét ngh...
# answer                  Khi một xét nghiệm hóa sinh cho thấy độ đúng '...
# document/title          Tiêu chuẩn quốc gia TCVN ISO 15189:2012 - Phòn...
# document/description    Tài liệu này là tiêu chuẩn quốc tế về hệ thống...
# cme/title               CME: Diễn giải kết quả xét nghiệm hóa sinh bất...
# cme/description         Khóa học tập trung vào cách nhận diện, diễn gi...
# Name: 13869, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa trên những phân tích về độ chụm và độ đúng...
# answer                  Chào bạn, kết quả của nghiên cứu về độ chụm và...
# document/title          Sổ tay Kiểm soát Chất lượng Phòng xét nghiệm (...
# document/description    Sổ tay này là tài liệu chính thức từ Bộ Y tế V...
# cme/title               CME: Quản lý phòng xét nghiệm theo tiêu chuẩn ...
# cme/description         Khóa học chuyên sâu này đào tạo về các nguyên ...
# Name: 13870, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong bối cảnh thực hành lâm sàng hiện đại, tạ...
# answer                  Chào các bạn sinh viên y khoa và bác sĩ trẻ,\n...
# document/title          Hướng dẫn CLSI EP15-A3: Xác nhận hiệu năng cho...
# document/description    Tài liệu này cung cấp các nguyên tắc và quy tr...
# cme/title               Quản lý Chất lượng Toàn diện trong Phòng Xét n...
# cme/description         Khóa học này trang bị kiến thức chuyên sâu về ...
# Name: 13871, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ sinh v...
# question                Theo như bảng kết quả đánh giá độ chệch và sai...
# answer                  Các bạn thân mến,\n\nĐây là một điểm rất quan ...
# document/title          Tiêu chuẩn về Hiệu năng Phân tích của CLIA (Cl...
# document/description    Tài liệu này cung cấp các tiêu chuẩn bắt buộc ...
# cme/title               Hiểu và Ứng dụng Kiểm soát Chất lượng Ngoại ki...
# cme/description         Khóa học này tập trung vào các phương pháp đán...
# Name: 13872, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp kiến...
# question                Nghiên cứu chỉ ra rằng các xét nghiệm hóa sinh...
# answer                  Chào các bạn,\n\nViệc kết quả các xét nghiệm t...
# document/title          Sổ tay Quản lý Chất lượng Xét nghiệm của Bộ Y ...
# document/description    Tài liệu chính thức này cung cấp các hướng dẫn...
# cme/title               Phối hợp Lâm sàng - Cận lâm sàng trong chẩn đo...
# cme/description         Khóa học này tập trung vào việc tăng cường khả...
# Name: 13873, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, làm thế nào để đảm bảo độ chí...
# answer                  Các em sinh viên và bác sĩ trẻ thân mến, việc ...
# document/title          Quyết định 2429/QĐ-BYT ban hành Tiêu chí đánh ...
# document/description    Tài liệu hướng dẫn chính thức từ Bộ Y tế Việt ...
# cme/title               Cập nhật các quy trình Kiểm soát chất lượng tr...
# cme/description         Khóa học CME này tập trung vào các phương pháp...
# Name: 13874, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi đối diện với bệnh nhân có nhân tuyến giáp ...
# answer                  Các bạn đồng nghiệp tương lai, trong thực hành...
# document/title          Phẫu thuật tuyến giáp nội soi: Chỉ định, kỹ th...
# document/description    Một tài liệu chuyên khảo toàn diện về phẫu thu...
# cme/title               Chẩn đoán và quản lý nhân tuyến giáp theo khuy...
# cme/description         Khóa học CME cập nhật các hướng dẫn lâm sàng m...
# Name: 13875, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sau phẫu thuật cắt thùy tuyến giáp nội soi để ...
# answer                  Chào các bác sĩ tương lai và đồng nghiệp, quá ...
# document/title          Hướng dẫn thực hành lâm sàng về chăm sóc bệnh ...
# document/description    Sổ tay hướng dẫn chi tiết các bước chăm sóc bệ...
# cme/title               Điều trị và phục hồi chức năng toàn diện sau p...
# cme/description         Khóa học CME đa chuyên khoa này cung cấp kiến ...
# Name: 13876, dtype: object
# ✅ Đã lưu toàn bộ dữ liệu paraphrase vào file Excel.
