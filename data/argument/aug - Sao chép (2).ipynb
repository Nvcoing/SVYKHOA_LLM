# %%
from datasets import load_dataset
from transformers import MT5Tokenizer, MT5ForConditionalGeneration
from tqdm import tqdm
import pandas as pd
import torch
import os

# Kiểm tra GPU
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cpu" )
print(f"💻 Đang sử dụng thiết bị: {device}")

# Load model paraphrase và đưa lên GPU
CKPT = 'chieunq/vietnamese-sentence-paraphase'
tokenizer = MT5Tokenizer.from_pretrained(CKPT)
model = MT5ForConditionalGeneration.from_pretrained(CKPT).to(device)

# Hàm tạo paraphrase
def paraphrase(text, num_return_sequences=5):
    inputs = tokenizer(text, padding='longest', max_length=512, truncation=True, return_tensors='pt')
    inputs = {key: val.to(device) for key, val in inputs.items()}
    output = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_length=512,
        num_return_sequences=num_return_sequences,
        do_sample=True,
        top_p=0.95
    )
    return [tokenizer.decode(o, skip_special_tokens=True) for o in output]

# Load dataset
dataset = pd.read_parquet("../generate_dataset/SVYKHOA_dataset_guide.parquet", engine="fastparquet")

# File Excel đầu ra
output_file = "SVYKHOA_dataset_guide_4.xlsx"

# Tạo file Excel rỗng nếu chưa có
if not os.path.exists(output_file):
    df_empty = pd.DataFrame(columns=["intruction", "question", "answer","document/title","document/description","cme/title","cme/description"])
    df_empty.to_excel(output_file, index=False)

# Đọc số dòng đã có để tiếp tục từ đó
existing_df = pd.read_excel(output_file)
# start_index = len(existing_df)
start_index = 12000
print(f"🚀 Bắt đầu từ dòng {start_index}")

# Số lượng mẫu muốn xử lý thêm
max_samples = 139490 - 120000  # Có thể chỉnh: 10, 100, 500...

# Duyệt dataset từ start_index
for i, row in dataset.iterrows():
    if i < start_index:
        continue
    if i >= start_index + max_samples:
        break
    print(row)

    question = row["question"]   # row là Series
    try:
        paraphrases = paraphrase(question, num_return_sequences=15)
    except Exception as e:
        print(f"Lỗi paraphrase tại mẫu {i}: {e}")
        paraphrases = [question]

    new_rows = []
    for pq in paraphrases:
        new_rows.append({
            "intruction": row["intruction"],
            "question": pq,
            "answer": row["answer"],
            "document/title": row["document/title"],
            "document/description": row["document/description"],
            "cme/title": row["cme/title"],
            "cme/description": row["cme/description"],
        })

    new_df = pd.DataFrame(new_rows)
    with pd.ExcelWriter(output_file, mode="a", engine="openpyxl", if_sheet_exists="overlay") as writer:
        sheet = writer.sheets["Sheet1"]
        start_row = sheet.max_row
        new_df.to_excel(writer, header=False, index=False, startrow=start_row)


print("✅ Đã lưu toàn bộ dữ liệu paraphrase vào file Excel.")
# Out:
# 💻 Đang sử dụng thiết bị: cpu
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'T5Tokenizer'.
# The class this function is called from is 'MT5Tokenizer'.
# You are using the default legacy behaviour of the <class 'transformers.models.mt5.tokenization_mt5.MT5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# 🚀 Bắt đầu từ dòng 12000
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Chào chuyên gia, em đang nghiên cứu về vai trò...
# answer                  Chào bạn, việc tìm hiểu về vai trò của phẫu th...
# document/title          Phác đồ chẩn đoán và điều trị viêm mũi dị ứng ...
# document/description    Tài liệu cung cấp hướng dẫn chi tiết về chẩn đ...
# cme/title               Cập nhật các kỹ thuật phẫu thuật mũi xoang và ...
# cme/description         Khóa học này tập trung vào các tiến bộ trong p...
# Name: 12000, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ các bá...
# question                Là một bác sĩ trẻ, em rất quan tâm đến việc sử...
# answer                  Chào bạn, đây là một câu hỏi rất quan trọng, c...
# document/title          Thực hành Y học Dựa trên Bằng chứng: Hướng dẫn...
# document/description    Cuốn sách kinh điển này cung cấp một khuôn khổ...
# cme/title               Phương pháp nghiên cứu khoa học và thống kê y ...
# cme/description         Khóa học này trang bị cho bác sĩ và sinh viên ...
# Name: 12001, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, xin được giải thích về viêm m...
# answer                  Chào bạn, viêm mũi dị ứng (VMDU) là một tình t...
# document/title          Hướng dẫn chẩn đoán và điều trị Viêm mũi dị ứn...
# document/description    Tài liệu chính thức từ Bộ Y tế Việt Nam, cung ...
# cme/title               Cập nhật chẩn đoán và quản lý Viêm mũi dị ứng ...
# cme/description         Khóa học CME này tập trung vào các phương pháp...
# Name: 12002, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Chuyên gia có thể phân tích vai trò của dị hìn...
# answer                  Là các bác sĩ trẻ, các bạn cần hiểu rõ mối liê...
# document/title          Phẫu thuật Chỉnh hình Vách ngăn Mũi (Septoplas...
# document/description    Cuốn sách chuyên khảo toàn diện về giải phẫu v...
# cme/title               Phẫu thuật vách ngăn mũi nâng cao và vai trò t...
# cme/description         Khóa học chuyên sâu này trang bị cho học viên ...
# Name: 12003, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ hoặc sinh viên y khoa muốn tham ...
# answer                  Rất hoan nghênh tinh thần nghiên cứu khoa học ...
# document/title          Phương pháp nghiên cứu khoa học trong Y học Lâ...
# document/description    Sách hướng dẫn chi tiết về các loại hình nghiê...
# cme/title               Thiết kế và tiến hành Tổng quan luận điểm (Sco...
# cme/description         Khóa học thực hành chuyên sâu hướng dẫn các bư...
# Name: 12004, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với tỷ lệ chẩn đoán trước mổ viêm ruột thừa (V...
# answer                  Chào các bạn sinh viên và bác sĩ trẻ, đây là m...
# document/title          Hướng dẫn chẩn đoán và điều trị viêm túi thừa ...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Quản lý cấp cứu ổ bụng: Tiếp cận viêm túi thừa...
# cme/description         Khóa học này tập trung vào các tình huống cấp ...
# Name: 12005, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp hướn...
# question                Phân tích các phương pháp phẫu thuật được sử d...
# answer                  Các bạn đồng nghiệp và sinh viên thân mến, việ...
# document/title          Phác đồ phẫu thuật đại tràng và trực tràng tro...
# document/description    Tài liệu này là một cẩm nang hướng dẫn chi tiế...
# cme/title                  Kỹ thuật phẫu thuật nội soi đại tràng nâng cao
# cme/description         Khóa học tập trung vào việc nâng cao kỹ năng p...
# Name: 12006, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hướng dẫn sin...
# question                Dựa trên kết quả điều trị nội khoa được trình ...
# answer                  Chào các bạn, phần về điều trị nội khoa trong ...
# document/title          Thực hành lâm sàng về viêm túi thừa đại tràng:...
# document/description    Tài liệu này tổng hợp các kiến thức mới nhất v...
# cme/title               Cập nhật điều trị nội khoa các bệnh lý tiêu hó...
# cme/description         Khóa học này cung cấp thông tin cập nhật về ch...
# Name: 12007, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để chẩn đoán viêm túi thừa đại trà...
# answer                  Chào các bác sĩ trẻ và sinh viên y khoa!\n\nĐể...
# document/title          Hướng dẫn chẩn đoán và điều trị viêm túi thừa ...
# document/description    Tài liệu này cung cấp các hướng dẫn chi tiết v...
# cme/title               Cập nhật chẩn đoán hình ảnh và quản lý viêm tú...
# cme/description         Khóa học này tập trung vào các phương pháp chẩ...
# Name: 12008, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong trường hợp viêm túi thừa đại tràng có bi...
# answer                  Các em thân mến,\n\nKhi đối mặt với viêm túi t...
# document/title          Phẫu thuật trong viêm túi thừa đại tràng biến ...
# document/description    Cẩm nang này trình bày sâu về các kỹ thuật phẫ...
# cme/title               Quản lý cấp cứu viêm túi thừa đại tràng và nân...
# cme/description         Khóa học chuyên sâu này trang bị cho phẫu thuậ...
# Name: 12009, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Phẫu thuật nội soi cắt thực quản với nạo hạch ...
# answer                  Kính gửi các bác sĩ trẻ và sinh viên y khoa,\n...
# document/title          Đánh giá kết quả sớm của phẫu thuật nội soi cắ...
# document/description    Nghiên cứu này từ Bệnh viện Chợ Rẫy phân tích ...
# cme/title               Kỹ thuật tiên tiến trong phẫu thuật ung thư th...
# cme/description         Khóa học này cung cấp kiến thức chuyên sâu về ...
# Name: 12010, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi tiếp cận một bệnh nhân có đau bụng cấp tín...
# answer                  Chào bạn, đây là một tình huống lâm sàng rất t...
# document/title          Hướng dẫn chẩn đoán và điều trị bệnh túi thừa ...
# document/description    Tài liệu này cung cấp các tiêu chí chẩn đoán, ...
# cme/title               Cập nhật chẩn đoán và quản lý viêm túi thừa đạ...
# cme/description         Khóa học CME này tập trung vào các tiêu chuẩn ...
# Name: 12011, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với một bệnh nhân nghi ngờ viêm túi thừa đại t...
# answer                  Để có cái nhìn toàn diện và chính xác về tình ...
# document/title          Vai trò của CLVT trong chẩn đoán viêm túi thừa...
# document/description    Tài liệu này cung cấp chi tiết về các hình ảnh...
# cme/title               Kỹ năng đọc và diễn giải hình ảnh CLVT trong b...
# cme/description         Khóa học này được thiết kế để nâng cao năng lự...
# Name: 12012, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi nào nên chỉ định nội soi đại tràng ở bệnh ...
# answer                  Việc chỉ định nội soi đại tràng ở bệnh nhân có...
# document/title          Khuyến nghị về nội soi đại tràng trong quản lý...
# document/description    Tài liệu tổng hợp các khuyến nghị lâm sàng quố...
# cme/title               Tiếp cận chẩn đoán phân biệt bệnh lý đại tràng...
# cme/description         Khóa học này cung cấp kiến thức chuyên sâu về ...
# Name: 12013, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa trên kết quả nghiên cứu và kiến thức y kho...
# answer                  Để quản lý hiệu quả viêm túi thừa đại tràng kh...
# document/title          Hướng dẫn chẩn đoán và điều trị viêm túi thừa ...
# document/description    Tài liệu này cung cấp cái nhìn tổng quan chi t...
# cme/title               Cập nhật quản lý nội khoa viêm túi thừa đại tr...
# cme/description         Khóa học này sẽ đi sâu vào các phác đồ kháng s...
# Name: 12014, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi nào một bệnh nhân viêm túi thừa đại tràng ...
# answer                  Quyết định phẫu thuật trong điều trị viêm túi ...
# document/title          Hướng dẫn phẫu thuật viêm túi thừa đại tràng c...
# document/description    Tài liệu này trình bày chi tiết các kỹ thuật p...
# cme/title               Phẫu thuật nội soi và mổ mở trong điều trị viê...
# cme/description         Khóa học CME này tập trung vào các kỹ thuật ph...
# Name: 12015, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những biến chứng nào thường gặp trong điều trị...
# answer                  Việc nhận diện và quản lý các biến chứng của v...
# document/title          Quản lý biến chứng cấp tính và dài hạn sau phẫ...
# document/description    Tài liệu này cung cấp kiến thức chuyên sâu về ...
# cme/title               Tiếp cận đa chuyên khoa và xử trí biến chứng t...
# cme/description         Khóa học này trang bị cho học viên kiến thức v...
# Name: 12016, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với vai trò là một bác sĩ trẻ hoặc sinh viên y...
# answer                  Để tư vấn dinh dưỡng hiệu quả cho phụ nữ trong...
# document/title          Hướng dẫn quốc gia về Dinh dưỡng và Vận động h...
# document/description    Tài liệu này cung cấp các hướng dẫn chi tiết t...
# cme/title               Tập huấn chuyên sâu về Tư vấn Dinh dưỡng và Ch...
# cme/description         Khóa học CME này được thiết kế để trang bị cho...
# Name: 12017, dtype: object
# intruction              Chatbot y khoa chuyên sâu, hỗ trợ bác sĩ và si...
# question                Nghiên cứu chỉ ra tỷ lệ phụ nữ ăn 2 bữa/ngày v...
# answer                  Để cải thiện tình trạng phụ nữ ăn 2 bữa/ngày v...
# document/title          Sổ tay Dinh dưỡng cộng đồng dành cho cán bộ y ...
# document/description    Tài liệu thiết yếu này được biên soạn bởi Viện...
# cme/title               Quản lý và Phòng ngừa Suy dinh dưỡng và Thiếu ...
# cme/description         Khóa học CME này tập trung vào các chiến lược ...
# Name: 12018, dtype: object
# intruction              Chatbot y khoa hỗ trợ phát triển chuyên môn, c...
# question                Nghiên cứu còn chỉ ra tỷ lệ tập thể dục thấp (...
# answer                  Việc tư vấn tích hợp lối sống lành mạnh, bao g...
# document/title          Hướng dẫn chăm sóc sức khỏe toàn diện cho phụ ...
# document/description    Tài liệu này cung cấp một cái nhìn tổng quan s...
# cme/title               Lối sống lành mạnh và Phòng ngừa Bệnh không lâ...
# cme/description         Khóa học CME này tập trung vào vai trò quan tr...
# Name: 12019, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ trẻ hoặc sinh viên y khoa, làm t...
# answer                  Để nắm vững kiến thức về dinh dưỡng hợp lý cho...
# document/title          Hướng dẫn Quốc gia về Dinh dưỡng cho Phụ nữ ma...
# document/description    Tài liệu này do Bộ Y tế Việt Nam ban hành, cun...
# cme/title                        Dinh dưỡng Lâm sàng và Sức khỏe Sinh sản
# cme/description         Khóa học CME này tập trung vào cập nhật kiến t...
# Name: 12020, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với vai trò là bác sĩ, làm thế nào để chẩn đoá...
# answer                  Đối với bác sĩ và sinh viên y khoa, việc chẩn ...
# document/title          Bảng phân loại bệnh tật quốc tế ICD-10 (phiên ...
# document/description    Tài liệu này là cẩm nang chính thống do Bộ Y t...
# cme/title               Chẩn đoán và Điều trị Suy dinh dưỡng tại Cộng ...
# cme/description         Khóa học CME này cung cấp kiến thức và kỹ năng...
# Name: 12021, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ đang thực hành, tôi cần những ch...
# answer                  Để phòng chống thiếu dinh dưỡng ở phụ nữ độ tu...
# document/title          Khuyến nghị Dinh dưỡng cho Người Việt Nam (Việ...
# document/description    Tài liệu này do Viện Dinh dưỡng Quốc gia phối ...
# cme/title               Kỹ năng Tư vấn Dinh dưỡng và Giáo dục Sức khỏe...
# cme/description         Khóa học này tập trung phát triển kỹ năng giao...
# Name: 12022, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa trên số liệu nghiên cứu, làm thế nào để cá...
# answer                  Chào các bạn sinh viên y khoa và bác sĩ trẻ,\n...
# document/title          Hướng dẫn quốc gia về dinh dưỡng cho phụ nữ có...
# document/description    Tài liệu này do Bộ Y tế Việt Nam ban hành, cun...
# cme/title               Dinh dưỡng Lâm sàng trong Chăm sóc Sức khỏe Bà...
# cme/description         Khóa học này trang bị kiến thức chuyên sâu về ...
# Name: 12023, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Mặc dù 73,2% đối tượng nghiên cứu đã bổ sung s...
# answer                  Chào các bạn,\n\nThực tế này cho thấy việc thự...
# document/title          Khuyến nghị Dinh dưỡng cho Phụ nữ Mang thai củ...
# document/description    Tài liệu này cung cấp các hướng dẫn dựa trên b...
# cme/title                          Tư vấn Dinh dưỡng và Sức khỏe Sinh sản
# cme/description         Khóa học này tập trung vào phát triển kỹ năng ...
# Name: 12024, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Phân tích số liệu thực hành dinh dưỡng cho thấ...
# answer                  Các bạn sinh viên và bác sĩ thân mến,\n\nĐây l...
# document/title                  Khuyến nghị Dinh dưỡng cho người Việt Nam
# document/description    Tài liệu này của Viện Dinh dưỡng Quốc gia Việt...
# cme/title               Phương pháp Tiếp cận Cộng đồng trong Cải thiện...
# cme/description         Khóa học này trang bị cho học viên các kỹ năng...
# Name: 12025, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa trên kết quả nghiên cứu về tần suất ăn bữa...
# answer                  Để tư vấn dinh dưỡng hiệu quả cho phụ nữ độ tu...
# document/title          Hướng dẫn quốc gia về Dinh dưỡng cho phụ nữ có...
# document/description    Tài liệu của Bộ Y tế Việt Nam cung cấp các khu...
# cme/title               Chăm sóc Dinh dưỡng Toàn diện cho Phụ nữ trong...
# cme/description         Khóa học tập trung vào đánh giá tình trạng din...
# Name: 12026, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu tiết lộ 70,4% phụ nữ độ tuổi sinh s...
# answer                  Kết quả nghiên cứu này là một cảnh báo nghiêm ...
# document/title          Khuyến nghị của Tổ chức Y tế Thế giới (WHO) về...
# document/description    Tài liệu quốc tế cung cấp hướng dẫn dựa trên b...
# cme/title               Tư vấn Sức khỏe Toàn diện và Thay đổi Lối sống...
# cme/description         Khóa học chuyên sâu trang bị cho bác sĩ và sin...
# Name: 12027, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu nhấn mạnh những hạn chế về kiến thứ...
# answer                  Nghiên cứu đã chỉ rõ những lỗ hổng đáng kể tro...
# document/title          Dinh dưỡng và Sức khỏe Bà mẹ và Trẻ em: Hướng ...
# document/description    Sách chuyên khảo cung cấp kiến thức toàn diện ...
# cme/title               Nâng cao Năng lực Tư vấn Dinh dưỡng và Xây dựn...
# cme/description         Khóa học trang bị cho cán bộ y tế các kỹ năng ...
# Name: 12028, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi tiếp cận một bệnh nhân trẻ, đặc biệt là si...
# answer                  Chào các bác sĩ trẻ và sinh viên y khoa! Đối m...
# document/title          Hướng dẫn chẩn đoán và điều trị Rối loạn giấc ...
# document/description    Tài liệu cung cấp các tiêu chuẩn chẩn đoán chi...
# cme/title               Cập nhật chẩn đoán và quản lý mất ngủ không dù...
# cme/description         Khóa học này sẽ trang bị cho bác sĩ kiến thức ...
# Name: 12029, dtype: object
# intruction              Chatbot y khoa chuyên về dinh dưỡng công cộng ...
# question                Là một bác sĩ y học dự phòng hoặc sản phụ khoa...
# answer                  Các bác sĩ trẻ và sinh viên y khoa thân mến, v...
# document/title          Khuyến nghị Dinh dưỡng cho Phụ nữ trong Độ tuổ...
# document/description    Tài liệu tổng hợp các khuyến nghị dinh dưỡng c...
# cme/title               Kỹ năng tư vấn dinh dưỡng và xây dựng chương t...
# cme/description         Khóa học này tập trung vào các kỹ thuật tư vấn...
# Name: 12030, dtype: object
# intruction              Chatbot y khoa với vai trò trợ lý học thuật, g...
# question                Khi đọc một bài báo khoa học về thực trạng sức...
# answer                  Để trở thành một bác sĩ có tư duy phản biện và...
# document/title          Nguyên lý và Phương pháp Nghiên cứu Khoa học t...
# document/description    Sách giáo trình cung cấp kiến thức nền tảng về...
# cme/title               Y học thực chứng và Kỹ năng đánh giá tài liệu ...
# cme/description         Khóa học trang bị cho người học khả năng đánh ...
# Name: 12031, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thiếu năng lượng trường diễn (CED) ở phụ nữ độ...
# answer                  Các bác sĩ và sinh viên y khoa cần lưu ý các b...
# document/title          Hướng dẫn quốc gia về dinh dưỡng cho phụ nữ có...
# document/description    Tài liệu của Bộ Y tế Việt Nam cung cấp thông t...
# cme/title               Cập nhật kiến thức về Dinh dưỡng Lâm sàng và Y...
# cme/description         Khóa học này tập trung vào các phác đồ chẩn đo...
# Name: 12032, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ đào tạ...
# question                Nghiên cứu cho thấy cán bộ y tế và bạn bè/ngườ...
# answer                  Để tối ưu hóa hiệu quả truyền thông dinh dưỡng...
# document/title          Khung Chiến lược Truyền thông Thay đổi Hành vi...
# document/description    Tài liệu cung cấp các nguyên tắc và bước thực ...
# cme/title               Kỹ năng tư vấn và truyền thông giáo dục sức kh...
# cme/description         Khóa học này trang bị cho bác sĩ và sinh viên ...
# Name: 12033, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hướng dẫn phâ...
# question                Dựa trên các bảng kết quả nghiên cứu về thông ...
# answer                  Việc phân tích sâu các dữ liệu nghiên cứu như ...
# document/title          Phương pháp nghiên cứu định lượng trong Y học ...
# document/description    Sách giáo trình cung cấp kiến thức nền tảng về...
# cme/title               Phân tích dữ liệu dịch tễ học và lập kế hoạch ...
# cme/description         Khóa học này hướng dẫn các học viên cách sử dụ...
# Name: 12034, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để các bác sĩ trẻ và sinh viên y k...
# answer                  Chào bạn, đây là một câu hỏi rất quan trọng tr...
# document/title          Hướng dẫn Quốc gia về Dinh dưỡng và Hoạt động ...
# document/description    Tài liệu này cung cấp các khuyến nghị chi tiết...
# cme/title               Khóa học 'Tư vấn Dinh dưỡng và Lối sống lành m...
# cme/description         Khóa học CME này sẽ trang bị cho các học viên ...
# Name: 12035, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Việc bổ sung viên sắt/đa vi chất cho phụ nữ tr...
# answer                  Chào bạn, nhận thức về sự cần thiết của việc b...
# document/title          Quyết định số 2137/QĐ-BYT: Hướng dẫn thực hiện...
# document/description    Tài liệu này chứa các hướng dẫn chi tiết của B...
# cme/title               Hội thảo 'Quản lý Thai kỳ Nguy cơ Cao và Dinh ...
# cme/description         Hội thảo này tập trung vào các trường hợp thai...
# Name: 12036, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu cho thấy tỷ lệ đối tượng có kiến th...
# answer                  Chào bạn, đây là một thách thức lớn nhưng cũng...
# document/title          Chiến lược Quốc gia về Dinh dưỡng giai đoạn 20...
# document/description    Tài liệu chiến lược quan trọng này phác thảo c...
# cme/title               Khóa đào tạo 'Giáo dục Sức khỏe và Truyền thôn...
# cme/description         Khóa học này cung cấp các phương pháp luận và ...
# Name: 12037, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa trên kết quả nghiên cứu về kiến thức, thái...
# answer                  Chào bạn, đây là một câu hỏi rất quan trọng tr...
# document/title          Hướng dẫn Quốc gia về Dinh dưỡng và Tiết chế c...
# document/description    Tài liệu này cung cấp các nguyên tắc và khuyến...
# cme/title                  CME: Đánh giá và Can thiệp Dinh dưỡng Lâm sàng
# cme/description         Khóa học này trang bị kiến thức và kỹ năng chu...
# Name: 12038, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong bối cảnh tỷ lệ phụ nữ tuổi sinh đẻ ít vậ...
# answer                  Để cải thiện sức khỏe toàn diện cho phụ nữ tuổ...
# document/title          Khuyến nghị của WHO về bổ sung vi chất dinh dư...
# document/description    Tài liệu này từ Tổ chức Y tế Thế giới cung cấp...
# cme/title               CME: Chăm sóc Sức khỏe Sinh sản và Tư vấn Lối ...
# cme/description         Khóa học đào tạo y khoa liên tục này tập trung...
# Name: 12039, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, là trợ lý học...
# question                Để cải thiện thực hành dinh dưỡng hợp lý ở phụ...
# answer                  Để đóng góp hiệu quả vào việc cải thiện thực h...
# document/title          Tháp Dinh dưỡng cân đối và Hướng dẫn thực hành...
# document/description    Tài liệu này cung cấp các nguyên tắc xây dựng ...
# cme/title                     CME: Y học Dự phòng và Dinh dưỡng Cộng đồng
# cme/description         Khóa học này cung cấp cái nhìn tổng quan và ch...
# Name: 12040, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ trẻ hoặc sinh viên y khoa, em cầ...
# answer                  Chào em, việc tư vấn dinh dưỡng và lối sống ch...
# document/title          Khuyến nghị Dinh dưỡng cho Phụ nữ độ tuổi Sinh...
# document/description    Tài liệu cung cấp hướng dẫn chi tiết về nhu cầ...
# cme/title                    CME: Tư vấn Dinh dưỡng Lâm sàng và Cộng đồng
# cme/description         Khóa học trang bị kiến thức chuyên sâu về đánh...
# Name: 12041, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ sinh v...
# question                Là một bác sĩ trẻ, em cần lưu ý những điểm nào...
# answer                  Em thân mến, chất lượng chăm sóc điều dưỡng đó...
# document/title          Quy trình Chăm sóc Điều dưỡng Nhi khoa của Bộ ...
# document/description    Tài liệu này trình bày các quy trình chuẩn tro...
# cme/title               CME: Quản lý Chất lượng và An toàn Người bệnh ...
# cme/description         Khóa học tập trung vào các nguyên tắc quản lý ...
# Name: 12042, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, giúp bác sĩ v...
# question                Dựa trên kết quả khảo sát về sự hài lòng của t...
# answer                  Em thân mến, kết quả hài lòng trên 85% tại Bện...
# document/title                  Bộ tiêu chí chất lượng bệnh viện Việt Nam
# document/description    Tài liệu này bao gồm các tiêu chí đánh giá toà...
# cme/title                 CME: Kỹ năng Giao tiếp và Tư vấn cho Điều dưỡng
# cme/description         Khóa học này được thiết kế để nâng cao kỹ năng...
# Name: 12043, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Liên cầu nhóm B (GBS) có ý nghĩa như thế nào t...
# answer                  Chào bạn! Liên cầu nhóm B (GBS) là một vi khuẩ...
# document/title          Hướng dẫn Sàng lọc và Dự phòng Nhiễm Liên Cầu ...
# document/description    Tài liệu này cung cấp các khuyến nghị quốc tế ...
# cme/title               Cập nhật Phác đồ Quản lý Liên Cầu Nhóm B và Dự...
# cme/description         Khóa học CME này đi sâu vào các phác đồ sàng l...
# Name: 12044, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Xin hãy giải thích về đái tháo đường thai kỳ (...
# answer                  Để chẩn đoán và quản lý Đái tháo đường thai kỳ...
# document/title          Hướng dẫn Chẩn đoán và Xử trí Đái tháo đường T...
# document/description    Tài liệu chính thống này cung cấp phác đồ chi ...
# cme/title               Quản lý Toàn diện Đái tháo đường Thai kỳ và Dự...
# cme/description         Khóa học CME này tập trung vào các chiến lược ...
# Name: 12045, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Mối liên quan giữa đái tháo đường thai kỳ (ĐTĐ...
# answer                  Là một bác sĩ trẻ hoặc sinh viên y khoa, việc ...
# document/title            Cẩm nang Thiết kế và Thống kê Nghiên cứu Y học.
# document/description    Tài liệu này trình bày chi tiết về các loại hì...
# cme/title               Phương pháp Nghiên cứu Khoa học trong Y học Lâ...
# cme/description         Khóa học CME này cung cấp kiến thức nền tảng v...
# Name: 12046, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, tại sao việc sàng lọc đái thá...
# answer                  Chào bạn, đây là một câu hỏi rất quan trọng tr...
# document/title          Hướng dẫn quốc gia về các dịch vụ chăm sóc sức...
# document/description    Tài liệu cung cấp các khuyến nghị và quy trình...
# cme/title               Quản lý toàn diện đái tháo đường thai kỳ và ph...
# cme/description         Khóa học CME này sẽ cập nhật các phác đồ chẩn ...
# Name: 12047, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Em đang là sinh viên y khoa năm cuối và muốn t...
# answer                  Chào em, rất hoan nghênh tinh thần học hỏi của...
# document/title          Hướng dẫn chẩn đoán và điều trị đột quỵ thiếu ...
# document/description    Tài liệu cung cấp các phác đồ chuẩn về chẩn đo...
# cme/title               Cập nhật chẩn đoán và can thiệp đột quỵ vùng t...
# cme/description         Khóa học tập trung vào các kỹ thuật chẩn đoán ...
# Name: 12048, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với tư cách là một bác sĩ sản khoa trẻ, em rất...
# answer                  Chào bạn, đây là một mối quan tâm rất chính đá...
# document/title          Khuyến cáo của Hiệp hội Sản Phụ khoa Việt Nam ...
# document/description    Tài liệu chuyên sâu từ VSOG, cung cấp hướng dẫ...
# cme/title               Chuyên đề: "GBS và ĐTĐTK: Cập nhật chiến lược ...
# cme/description         Khóa học này đi sâu vào cơ sở sinh lý bệnh của...
# Name: 12049, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, dựa trên kết quả nghiên cứu t...
# answer                  Chào bạn, đây là một câu hỏi rất hay và thiết ...
# document/title          Hướng dẫn chẩn đoán và xử trí Đái tháo đường t...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Quản lý Đái tháo đường Thai kỳ và Nhiễm trùng ...
# cme/description         Khóa học CME này sẽ cập nhật kiến thức về chẩn...
# Name: 12050, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ bác sĩ...
# question                Dựa trên nghiên cứu được trích dẫn, bác sĩ trẻ...
# answer                  Các bạn sinh viên và bác sĩ trẻ thân mến, việc...
# document/title          Phác đồ chẩn đoán và điều trị bệnh sản phụ kho...
# document/description    Tài liệu này bao gồm các phác đồ chi tiết về c...
# cme/title               Cập nhật Kỹ thuật Xét nghiệm Chẩn đoán trong S...
# cme/description         Khóa học này tập trung vào các kỹ thuật xét ng...
# Name: 12051, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hướng dẫn các...
# question                Với phát hiện về mối liên quan giữa ĐTĐTK và G...
# answer                  Thưa các bạn đồng nghiệp tương lai, trong bối ...
# document/title          Tài liệu tư vấn sức khỏe sinh sản cho thai phụ...
# document/description    Tài liệu này cung cấp các hướng dẫn toàn diện ...
# cme/title               Kỹ năng Tư vấn và Giao tiếp Bệnh nhân trong Sả...
# cme/description         Khóa học này tập trung vào việc phát triển kỹ ...
# Name: 12052, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, nghiên cứu này chỉ ra mối liê...
# answer                  Chào bạn, đây là một câu hỏi rất quan trọng đố...
# document/title          Hướng dẫn Quốc gia về các dịch vụ chăm sóc sức...
# document/description    Tài liệu này cung cấp các khuyến nghị và quy t...
# cme/title               Quản lý Đái tháo đường thai kỳ và nhiễm trùng ...
# cme/description         Khóa học chuyên sâu này sẽ trang bị kiến thức ...
# Name: 12053, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu có đề cập đến việc trung vị đường h...
# answer                  Đây là một phát hiện tinh tế nhưng có giá trị ...
# document/title          Hiệp hội Đái tháo đường Hoa Kỳ (ADA) – Tiêu ch...
# document/description    Hướng dẫn toàn diện từ ADA cung cấp các tiêu c...
# cme/title               Cập nhật Phác đồ Chẩn đoán và Điều trị Đái thá...
# cme/description         Khóa học này tập trung vào các phác đồ chẩn đo...
# Name: 12054, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Ngoài mối liên quan giữa ĐTĐTK và GBS, bài ngh...
# answer                  Bạn đặt câu hỏi rất đúng trọng tâm. Mặc dù ngh...
# document/title                    Sổ tay Sản Phụ khoa Việt Nam (Bộ Y tế).
# document/description    Sổ tay này là tài liệu cần thiết cho các bác s...
# cme/title               Phòng ngừa và Quản lý Nhiễm trùng trong Thai k...
# cme/description         Khóa học này sẽ cung cấp cái nhìn tổng quan về...
# Name: 12055, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, mối liên quan giữa Đái tháo đ...
# answer                  Chào bạn, đây là một câu hỏi rất quan trọng tr...
# document/title          Hướng dẫn Chẩn đoán và Điều trị Đái tháo đường...
# document/description    Tài liệu chính thức từ Bộ Y tế Việt Nam cung c...
# cme/title               Cập nhật Kiến thức và Thực hành Quản lý Đái th...
# cme/description         Khóa học CME này tập trung vào các khuyến nghị...
# Name: 12056, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ sinh v...
# question                Tỷ lệ nhiễm Liên cầu nhóm B (GBS) ở thai phụ d...
# answer                  Bạn thân mến, tỷ lệ nhiễm Liên cầu nhóm B (GBS...
# document/title          Sàng lọc và Dự phòng Nhiễm Liên cầu nhóm B chu...
# document/description    Tài liệu này từ Hiệp hội Sản phụ khoa Hoa Kỳ (...
# cme/title               Tiến bộ trong Chẩn đoán Vi sinh và Quản lý Nhi...
# cme/description         Khóa học này sẽ cung cấp cái nhìn tổng quan về...
# Name: 12057, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, giúp sinh viê...
# question                Những yếu tố dịch tễ học và lối sống nào có th...
# answer                  Khi phân tích dữ liệu nghiên cứu về các bệnh l...
# document/title               Sách giáo khoa Dịch tễ học và Thống kê y học
# document/description    Cuốn sách cung cấp kiến thức nền tảng về thiết...
# cme/title               Phân tích thống kê và Phương pháp Nghiên cứu t...
# cme/description         Khóa học này trang bị kiến thức chuyên sâu về ...
# Name: 12058, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, khi tiếp cận một thai phụ, cá...
# answer                  Các bạn sinh viên và bác sĩ trẻ thân mến, việc...
# document/title          Hướng dẫn chẩn đoán và xử trí Đái tháo đường T...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Cập nhật các phương pháp sàng lọc và dự phòng ...
# cme/description         Khóa học đào tạo y khoa liên tục này tập trung...
# Name: 12059, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa trên dữ liệu nghiên cứu về mối liên hệ giữ...
# answer                  Các bạn bác sĩ trẻ cần hiểu rằng mối liên hệ g...
# document/title          Tạp chí Y học Việt Nam: Đái tháo đường thai kỳ...
# document/description    Bài báo khoa học này phân tích sâu về cơ chế b...
# cme/title               Quản lý Thai kỳ Nguy cơ cao: Đái tháo đường và...
# cme/description         Khóa học chuyên sâu này tập trung vào các trườ...
# Name: 12060, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi một bệnh nhân cao tuổi nhập viện với nghi ...
# answer                  Chào các bạn đồng nghiệp tương lai và các bác ...
# document/title          Phác đồ chẩn đoán và điều trị đột quỵ nhồi máu...
# document/description    Tài liệu hướng dẫn chi tiết về quy trình chẩn ...
# cme/title               Phân tích hình ảnh học nâng cao trong chẩn đoá...
# cme/description         Khóa học này trang bị kiến thức chuyên sâu về ...
# Name: 12061, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, xin giải thích về bệnh Tâm th...
# answer                  Chào bạn, việc nắm vững các bệnh lý tâm thần t...
# document/title          Phân loại bệnh quốc tế ICD-10, Chương V: Rối l...
# document/description    Tài liệu chính thống của Tổ chức Y tế Thế giới...
# cme/title               Kỹ thuật Kích thích Từ Xuyên Sọ (rTMS) trong c...
# cme/description         Khóa học CME này cung cấp kiến thức chuyên sâu...
# Name: 12062, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi tiến hành một nghiên cứu lâm sàng hoặc chẩ...
# answer                  Để chẩn đoán Tâm thần phân liệt thể paranoid (...
# document/title          Hướng dẫn chẩn đoán và điều trị Tâm thần phân ...
# document/description    Tài liệu này cung cấp các hướng dẫn chi tiết v...
# cme/title               Thiết kế và Thực hiện Nghiên cứu Lâm sàng tron...
# cme/description         Khóa học CME này tập trung vào các nguyên tắc ...
# Name: 12063, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, trong quá trình điều trị bằng...
# answer                  Việc theo dõi và quản lý tác dụng không mong m...
# document/title          Hướng dẫn thực hành Kích thích từ xuyên sọ (TM...
# document/description    Tài liệu này cung cấp các khuyến nghị dựa trên...
# cme/title               An toàn và Quản lý Tác dụng Phụ của các phương...
# cme/description         Khóa học CME này tập trung vào việc nhận diện,...
# Name: 12064, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, khi thực hiện liệu pháp kích ...
# answer                  Các em sinh viên y khoa thân mến, khi tham gia...
# document/title          Hướng dẫn thực hành lâm sàng liệu pháp kích th...
# document/description    Tài liệu này cung cấp một cái nhìn tổng quan s...
# cme/title               rTMS: Nhận diện và Xử trí tác dụng không mong ...
# cme/description         Khóa học này được thiết kế để trang bị cho các...
# Name: 12065, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong quá trình điều trị bằng rTMS, các tác dụ...
# answer                  Chào các em, việc hiểu rõ sự phân bố các TDKMM...
# document/title          Cẩm nang Y học giới tính và tuổi tác trong điề...
# document/description    Tài liệu này đi sâu vào cách các yếu tố sinh h...
# cme/title               rTMS: Chiến lược cá thể hóa điều trị và quản l...
# cme/description         Khóa học này tập trung vào việc phát triển năn...
# Name: 12066, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các tác dụng không mong muốn ít phổ biến hơn c...
# answer                  Các tác dụng không mong muốn (TDKMM) ít phổ bi...
# document/title          Phân loại bệnh quốc tế ICD-10: Hướng dẫn mã hó...
# document/description    Tài liệu này là cẩm nang chính thức về việc áp...
# cme/title               Nâng cao kỹ năng mã hóa ICD-10 và Quản lý TDKM...
# cme/description         Khóa học CME này cung cấp kiến thức chuyên sâu...
# Name: 12067, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những yếu tố nào có thể ảnh hưởng đến tỷ lệ xu...
# answer                  Để tối ưu hóa an toàn bệnh nhân trong điều trị...
# document/title          Hướng dẫn lâm sàng về kích thích từ trường xuy...
# document/description    Tài liệu này cung cấp các hướng dẫn chi tiết v...
# cme/title               An toàn và quản lý biến chứng trong liệu pháp ...
# cme/description         Khóa học CME này tập trung vào các biện pháp p...
# Name: 12068, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, với một trẻ sơ sinh được chẩn...
# answer                  Chào bạn, đây là một câu hỏi rất quan trọng tr...
# document/title          Hướng dẫn Chẩn đoán và Can thiệp sớm Nghe kém ...
# document/description    Tài liệu cung cấp các tiêu chuẩn chẩn đoán, qu...
# cme/title               Chẩn đoán và Quản lý Nghe kém bẩm sinh: Cập nh...
# cme/description         Khóa học CME này sẽ trang bị cho bác sĩ nhi kh...
# Name: 12069, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sau khi phẫu thuật cấy điện cực ốc tai cho trẻ...
# answer                  Chào bạn, việc đánh giá hiệu quả sau phẫu thuậ...
# document/title          Phục hồi chức năng thính giác và ngôn ngữ cho ...
# document/description    Tài liệu chi tiết các phương pháp đánh giá hiệ...
# cme/title               Đánh giá và Trị liệu Ngôn ngữ Thính giác chuyê...
# cme/description         Khóa học tập trung vào các kỹ thuật đánh giá t...
# Name: 12070, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Kích thích từ xuyên sọ lặp lại (rTMS) là gì và...
# answer                  Chào bạn, Kích thích từ xuyên sọ lặp lại (rTMS...
# document/title          Hướng dẫn thực hành lâm sàng về Kích thích từ ...
# document/description    Tài liệu này cung cấp các khuyến nghị dựa trên...
# cme/title               Kích thích từ xuyên sọ (TMS/rTMS): Nguyên lý, ...
# cme/description         Khóa học chuyên sâu về TMS/rTMS bao gồm cơ chế...
# Name: 12071, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi áp dụng Kích thích từ xuyên sọ (rTMS) cho ...
# answer                  Kính chào các đồng nghiệp và sinh viên y khoa,...
# document/title          Hướng dẫn chẩn đoán và điều trị Tâm thần phân ...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Khóa học chuyên đề: Kích thích từ xuyên sọ (rT...
# cme/description         Khóa học CME này tập trung vào các nguyên lý k...
# Name: 12072, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ đào tạ...
# question                Nghiên cứu chỉ ra rằng tác dụng không mong muố...
# answer                  Thân gửi các đồng nghiệp tương lai và hiện tại...
# document/title          Sổ tay hướng dẫn thực hành Kích thích từ xuyên...
# document/description    Tài liệu này cung cấp các giao thức thực hành ...
# cme/title               Hội thảo chuyên đề: Cá thể hóa điều trị rTMS t...
# cme/description         Hội thảo CME này đi sâu vào việc điều chỉnh ph...
# Name: 12073, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp kiến...
# question                Nghiên cứu chỉ ra rằng các tác dụng không mong...
# answer                  Các bạn sinh viên và bác sĩ trẻ thân mến, việc...
# document/title          Nguyên lý và Ứng dụng lâm sàng của Kích thích ...
# document/description    Cuốn sách này trình bày chi tiết về cơ chế hoạ...
# cme/title               Đào tạo chuyên sâu: Tối ưu hóa phác đồ rTMS và...
# cme/description         Khóa học CME này cung cấp các kiến thức nâng c...
# Name: 12074, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi tiếp cận bệnh nhân nghi ngờ mắc Tâm thần p...
# answer                  Để chẩn đoán và quản lý Tâm thần phân liệt thể...
# document/title          Hướng dẫn chẩn đoán và điều trị Rối loạn Tâm t...
# document/description    Tài liệu tham khảo chính thức về các tiêu chuẩ...
# cme/title               Cập nhật chẩn đoán và quản lý Tâm thần phân li...
# cme/description         Khóa học này tập trung vào việc củng cố kỹ năn...
# Name: 12075, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ đang xem xét áp dụng Kích thích ...
# answer                  Khi cân nhắc áp dụng Kích thích từ xuyên sọ lặ...
# document/title          Transcranial Magnetic Stimulation: A Clinical ...
# document/description    Cuốn sách cung cấp cái nhìn toàn diện về nguyê...
# cme/title               Kỹ thuật và An toàn trong Kích thích từ xuyên ...
# cme/description         Khóa học này trang bị kiến thức chuyên sâu về ...
# Name: 12076, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với vai trò là một bác sĩ trẻ hoặc sinh viên y...
# answer                  Để trở thành một nhà nghiên cứu lâm sàng giỏi,...
# document/title          Thiết kế và Phân tích Nghiên cứu Lâm sàng (Giá...
# document/description    Cuốn sách này cung cấp kiến thức nền tảng về c...
# cme/title               Phương pháp Nghiên cứu Khoa học và Y học Thực ...
# cme/description         Khóa học này sẽ hướng dẫn các bác sĩ trẻ cách ...
# Name: 12077, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, với một sinh viên y khoa sắp ...
# answer                  Chào bạn, đây là một câu hỏi rất thực tế và qu...
# document/title          Hướng dẫn Thực hành Lâm sàng về Kích thích từ ...
# document/description    Tài liệu này cung cấp các hướng dẫn chi tiết v...
# cme/title               rTMS Căn bản và Nâng cao: Ứng dụng Lâm sàng và...
# cme/description         Khóa học CME này được thiết kế để trang bị cho...
# Name: 12078, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa trên dữ liệu nghiên cứu về tác dụng phụ củ...
# answer                  Tuyệt vời, việc phân tích dữ liệu theo nhân kh...
# document/title          Phân tích Yếu tố Nguy cơ và Lợi ích của rTMS: ...
# document/description    Tài liệu này tổng hợp các nghiên cứu về yếu tố...
# cme/title               rTMS: Cá nhân hóa Liệu pháp dựa trên Đặc điểm ...
# cme/description         Khóa học CME này tập trung vào cách áp dụng dữ...
# Name: 12079, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Đối với các tác dụng phụ ít gặp nhưng cần đặc ...
# answer                  Câu hỏi này rất quan trọng, vì ngay cả những t...
# document/title          Quy trình An toàn và Thực hành Tốt nhất trong ...
# document/description    Cuốn sách hướng dẫn này cung cấp các giao thức...
# cme/title               Kiểm soát Chất lượng và An toàn trong Liệu phá...
# cme/description         Khóa học CME này tập trung vào việc xây dựng v...
# Name: 12080, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, nghiên cứu về tình hình sử dụ...
# answer                  Chào các bác sĩ trẻ và sinh viên y khoa! Nghiê...
# document/title          Hướng dẫn sử dụng bộ công cụ sàng lọc AUDIT (A...
# document/description    Tài liệu chính thức về bộ công cụ AUDIT, giúp ...
# cme/title               Sàng lọc và can thiệp ngắn gọn về rượu bia ở n...
# cme/description         Khóa học này cung cấp kiến thức chuyên sâu và ...
# Name: 12081, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                WHO và nhiều nghiên cứu đã chỉ ra mối liên hệ ...
# answer                  Các bác sĩ và sinh viên thân mến, việc hiểu rõ...
# document/title          Phân loại bệnh quốc tế ICD-10, Chương V: Rối l...
# document/description    Đây là tài liệu tham khảo chính thống từ Tổ ch...
# cme/title               Cập nhật chẩn đoán và điều trị bệnh lý gan mật...
# cme/description         Khóa học này tập trung vào các tiến bộ mới nhấ...
# Name: 12082, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu tại Nam Định đã đưa ra một cái nhìn...
# answer                  Kính gửi các bác sĩ và sinh viên y khoa quan t...
# document/title          Chiến lược quốc gia phòng, chống tác hại của r...
# document/description    Tài liệu này trình bày các mục tiêu, nhiệm vụ ...
# cme/title               Nghiên cứu dịch tễ học và phương pháp đánh giá...
# cme/description         Khóa học này trang bị cho các nhà nghiên cứu v...
# Name: 12083, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ lâm sàng, làm thế nào để tôi có ...
# answer                  Em/Bạn thân mến, việc sàng lọc sớm mức độ sử d...
# document/title          Hướng dẫn chẩn đoán và điều trị rối loạn sử dụ...
# document/description    Tài liệu này cung cấp các tiêu chí chẩn đoán c...
# cme/title               Khóa học: Đánh giá và Can thiệp sớm Rối loạn S...
# cme/description         Khóa học tập trung vào việc hướng dẫn sử dụng ...
# Name: 12084, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sinh viên y khoa cần lưu ý điều gì khi đọc và ...
# answer                  Chào em/bạn, việc đọc hiểu các nghiên cứu khoa...
# document/title           Sổ tay Phương pháp Nghiên cứu Dịch tễ học Cơ bản
# document/description    Cung cấp kiến thức nền tảng về các thiết kế ng...
# cme/title               Khóa học: Ứng dụng Thống kê Y sinh trong Nghiê...
# cme/description         Khóa học cung cấp kiến thức thực hành về các p...
# Name: 12085, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa trên nghiên cứu này và kiến thức y khoa, b...
# answer                  Em/Bạn thân mến, việc quản lý bệnh nhân cao tu...
# document/title          Hướng dẫn quốc gia về phòng, chống tác hại của...
# ...
# cme/description         Khóa học này trang bị cho học viên kỹ năng đán...
# Name: 13847, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Việc phân tích dữ liệu tỷ lệ tử vong theo nguy...
# answer                  Kính gửi các bạn sinh viên y khoa và các bác s...
# document/title          Phương pháp nghiên cứu Dịch tễ học trong Y học...
# document/description    Cuốn sách cung cấp kiến thức chuyên sâu về các...
# cme/title                 Dịch tễ học cơ bản và Thống kê y học cho Bác sĩ
# cme/description         Khóa học này cung cấp kiến thức và kỹ năng cần...
# Name: 13848, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ trẻ hoặc sinh viên y khoa, anh/c...
# answer                  Để giải quyết gánh nặng BKLN ngày càng tăng, đ...
# document/title          Hướng Dẫn Phương Pháp Nghiên Cứu Dịch Tễ Học M...
# document/description    Tài liệu này cung cấp các phương pháp luận và ...
# cme/title               Khóa Học Chuyên Sâu: Các Bệnh Không Lây Nhiễm ...
# cme/description         Khóa học CME này tập trung vào cập nhật kiến t...
# Name: 13849, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để phát triển các chương trình tru...
# answer                  Để phát triển các chương trình truyền thông hi...
# document/title          Tài Liệu Hướng Dẫn Truyền Thông Giáo Dục Sức K...
# document/description    Cuốn sách cung cấp kiến thức nền tảng và các c...
# cme/title               CME: Kỹ Năng Phát Triển và Thực Hiện Chương Tr...
# cme/description         Khóa học này được thiết kế để nâng cao năng lự...
# Name: 13850, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi tiến hành các nghiên cứu để tìm ra nguyên ...
# answer                  Khi tham gia hoặc khởi xướng các nghiên cứu nh...
# document/title            Sổ Tay Dịch Tễ Học Lâm Sàng và Nghiên Cứu Y Học
# document/description    Cuốn sách cung cấp kiến thức nền tảng và các k...
# cme/title               Khóa Học CME: Phương Pháp Nghiên Cứu Khoa Học ...
# cme/description         Khóa học này trang bị cho học viên kiến thức v...
# Name: 13851, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong bối cảnh lâm sàng, việc giám sát chất lư...
# answer                  Chào bạn, với vai trò là một bác sĩ hoặc sinh ...
# document/title          ÁP DỤNG HƯỚNG DẪN EP15A3 CỦA CLSI XÁC NH...
# document/description    Tài liệu này là một ví dụ thực tế về việc áp d...
# cme/title               Kiểm soát chất lượng nội bộ và ngoại kiểm tron...
# cme/description         Khóa học này trang bị kiến thức và kỹ năng thự...
# Name: 13852, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, tại sao việc xác nhận phương ...
# answer                  Chào bạn, câu hỏi của bạn rất quan trọng, nó c...
# document/title          ISO 15189: Yêu cầu về năng lực và chất lượng đ...
# document/description    Tiêu chuẩn quốc tế này quy định các yêu cầu cụ...
# cme/title               Quản lý Chất lượng Toàn diện trong Phòng Xét n...
# cme/description         Khóa học CME này cung cấp kiến thức và kỹ năng...
# Name: 13853, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Em xin hỏi về cách xác nhận độ chụm và độ đúng...
# answer                  Chào bạn, câu hỏi này rất hay vì nó đi sâu vào...
# document/title          CLSI EP15-A3: Hướng dẫn Xác nhận Hiệu năng Phâ...
# document/description    Tài liệu này là cẩm nang chuyên sâu từ Viện Ti...
# cme/title               Kiểm soát Chất lượng Nội bộ và Đánh giá Hiệu n...
# cme/description         Khóa học CME này cung cấp kiến thức thực hành ...
# Name: 13854, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu nhắc đến một số xét nghiệm hóa sinh...
# answer                  Đây là một câu hỏi rất thực tế và quan trọng đ...
# document/title          Sổ tay Xét nghiệm Hóa sinh Lâm sàng: Nguyên lý...
# document/description    Tài liệu này tổng hợp kiến thức về nguyên lý, ...
# cme/title               Cập nhật Chẩn đoán và Theo dõi Bệnh qua Xét ng...
# cme/description         Khóa học CME này đi sâu vào cập nhật các chỉ đ...
# Name: 13855, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, làm thế nào để một bác sĩ trẻ...
# answer                  Chào bạn, đây là một câu hỏi rất quan trọng tr...
# document/title          Hướng dẫn Quản lý Chất lượng Phòng Xét Nghiệm ...
# document/description    Tài liệu chính thống này cung cấp các nguyên t...
# cme/title               Kiểm Soát Chất Lượng Nội Bộ (IQC) và Ngoại Kiể...
# cme/description         Khóa học CME này được thiết kế để trang bị cho...
# Name: 13856, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với các kết quả về độ đúng cho thấy nhiều xét ...
# answer                  Đây là một điểm cực kỳ quan trọng và có thể ản...
# document/title          Tiêu chuẩn ISO 15189: 2012 - Yêu cầu về Năng l...
# document/description    Tài liệu này là kim chỉ nam quốc tế cho các ph...
# cme/title               Quản Lý Rủi Ro và Cải Tiến Chất Lượng Liên Tục...
# cme/description         Khóa học tập trung vào các phương pháp nhận di...
# Name: 13857, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với tư cách là một bác sĩ trẻ hoặc sinh viên y...
# answer                  Việc thấu hiểu quá trình xác nhận hiệu năng ph...
# document/title          Sổ tay Hướng dẫn Xét nghiệm Lâm sàng của Bộ Y ...
# document/description    Cẩm nang thiết yếu này cung cấp một cái nhìn t...
# cme/title               Ứng dụng Quản lý Chất lượng trong Thực hành Lâ...
# cme/description         Khóa học CME này được thiết kế để kết nối kiến...
# Name: 13858, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, khi phòng xét nghiệm thực hiệ...
# answer                  Chào các bạn đồng nghiệp và sinh viên y khoa,\...
# document/title          Hướng dẫn CLSI EP15-A3: Đánh giá độ đúng của p...
# document/description    Tài liệu này cung cấp hướng dẫn chi tiết từ Hi...
# cme/title               Kiểm soát Chất lượng và Xác nhận Phương pháp t...
# cme/description         Khóa học này đào tạo chuyên sâu về các nguyên ...
# Name: 13859, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ phân t...
# question                Đối với các xét nghiệm như AST và Creatinin, đ...
# answer                  Các bạn sinh viên và bác sĩ thân mến,\n\nĐây l...
# document/title          Tiêu chuẩn Hiệu năng Phân tích của CLIA và Ứng...
# document/description    Tài liệu này trình bày các tiêu chuẩn về hiệu ...
# cme/title               Giải thích và Ứng dụng Kết quả Xét nghiệm Hóa ...
# cme/description         Khóa học chuyên sâu này giúp bác sĩ lâm sàng v...
# Name: 13860, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, đóng vai trò ...
# question                Nghiên cứu về độ chụm và độ đúng trên hệ thống...
# answer                  Kính gửi các bạn đồng nghiệp và các bạn sinh v...
# document/title          Tiêu chuẩn ISO 15189: Yêu cầu về năng lực và c...
# document/description    Tiêu chuẩn quốc tế này quy định các yêu cầu cụ...
# cme/title               Hệ thống Quản lý Chất lượng Toàn diện trong Ph...
# cme/description         Khóa học này trang bị kiến thức và kỹ năng về ...
# Name: 13861, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ trẻ hoặc sinh viên y khoa, tôi c...
# answer                  Việc xác nhận độ chụm và độ đúng của các xét n...
# document/title          CLSI EP15-A3: Hướng dẫn xác nhận độ chụm và độ...
# document/description    Tài liệu hướng dẫn kỹ thuật chi tiết của Viện ...
# cme/title               Kiểm soát chất lượng phòng xét nghiệm và áp dụ...
# cme/description         Khóa học đào tạo y khoa liên tục (CME) chuyên ...
# Name: 13862, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một điều dưỡng viên hoặc bác sĩ trẻ, tôi mu...
# answer                  Chăm sóc dinh dưỡng đóng vai trò cốt yếu trong...
# document/title          Thông tư 08/2011/TT-BYT Hướng dẫn về công tác ...
# document/description    Văn bản pháp quy của Bộ Y tế Việt Nam ban hành...
# cme/title               Quản lý dinh dưỡng lâm sàng và tiết chế trong ...
# cme/description         Khóa học CME được thiết kế cho bác sĩ, điều dư...
# Name: 13863, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Để tư vấn hiệu quả cho bệnh nhân và quản lý cá...
# answer                  Đái tháo đường (ĐTĐ) là một bệnh rối loạn chuy...
# document/title          Kiến thức về bệnh đái tháo đường (Cục quản lý ...
# document/description    Tài liệu được xuất bản bởi Cục quản lý khám ch...
# cme/title               Cập nhật chẩn đoán, điều trị và quản lý biến c...
# cme/description         Khóa học CME toàn diện dành cho bác sĩ nội kho...
# Name: 13864, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ trẻ hoặc sinh viên y khoa làm vi...
# answer                  Chào em/anh/chị, việc xác nhận phương pháp xét...
# document/title          Hướng dẫn CLSI EP15-A3: Thực hành xác nhận hiệ...
# document/description    Tài liệu này cung cấp các quy trình thực hành ...
# cme/title               Khóa học Đảm bảo chất lượng trong xét nghiệm y...
# cme/description         Khóa học này cung cấp kiến thức toàn diện về c...
# Name: 13865, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi tiến hành xác nhận độ chụm và độ đúng cho ...
# answer                  Là một bác sĩ trẻ hoặc sinh viên y khoa, việc ...
# document/title              Sổ tay Kiểm soát chất lượng xét nghiệm y học.
# document/description    Tài liệu này cung cấp hướng dẫn chi tiết về cá...
# cme/title               Phân tích và khắc phục sự cố trong kiểm soát c...
# cme/description         Khóa học thực hành này tập trung vào việc nhận...
# Name: 13866, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong các nghiên cứu xác nhận phương pháp xét ...
# answer                  Chào em/anh/chị, trong bất kỳ nghiên cứu khoa ...
# document/title          Quy trình vận hành chuẩn (SOP) cho phòng xét n...
# document/description    Tài liệu này cung cấp các hướng dẫn chi tiết v...
# cme/title               Thực hành tốt phòng xét nghiệm (GLP) và đạo đứ...
# cme/description         Khóa học này trang bị kiến thức về các nguyên ...
# Name: 13867, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một sinh viên y khoa mới bắt đầu tìm hiểu v...
# answer                  Chào em, để đánh giá độ chụm của các xét nghiệ...
# document/title          Hướng dẫn thực hành Kiểm soát chất lượng nội b...
# document/description    Tài liệu này cung cấp kiến thức nền tảng và hư...
# cme/title               CME: Kiểm soát chất lượng xét nghiệm và đảm bả...
# cme/description         Khóa học này trang bị kiến thức chuyên sâu về ...
# Name: 13868, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi kết quả xác nhận độ đúng của nhiều xét ngh...
# answer                  Khi một xét nghiệm hóa sinh cho thấy độ đúng '...
# document/title          Tiêu chuẩn quốc gia TCVN ISO 15189:2012 - Phòn...
# document/description    Tài liệu này là tiêu chuẩn quốc tế về hệ thống...
# cme/title               CME: Diễn giải kết quả xét nghiệm hóa sinh bất...
# cme/description         Khóa học tập trung vào cách nhận diện, diễn gi...
# Name: 13869, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa trên những phân tích về độ chụm và độ đúng...
# answer                  Chào bạn, kết quả của nghiên cứu về độ chụm và...
# document/title          Sổ tay Kiểm soát Chất lượng Phòng xét nghiệm (...
# document/description    Sổ tay này là tài liệu chính thức từ Bộ Y tế V...
# cme/title               CME: Quản lý phòng xét nghiệm theo tiêu chuẩn ...
# cme/description         Khóa học chuyên sâu này đào tạo về các nguyên ...
# Name: 13870, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong bối cảnh thực hành lâm sàng hiện đại, tạ...
# answer                  Chào các bạn sinh viên y khoa và bác sĩ trẻ,\n...
# document/title          Hướng dẫn CLSI EP15-A3: Xác nhận hiệu năng cho...
# document/description    Tài liệu này cung cấp các nguyên tắc và quy tr...
# cme/title               Quản lý Chất lượng Toàn diện trong Phòng Xét n...
# cme/description         Khóa học này trang bị kiến thức chuyên sâu về ...
# Name: 13871, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ sinh v...
# question                Theo như bảng kết quả đánh giá độ chệch và sai...
# answer                  Các bạn thân mến,\n\nĐây là một điểm rất quan ...
# document/title          Tiêu chuẩn về Hiệu năng Phân tích của CLIA (Cl...
# document/description    Tài liệu này cung cấp các tiêu chuẩn bắt buộc ...
# cme/title               Hiểu và Ứng dụng Kiểm soát Chất lượng Ngoại ki...
# cme/description         Khóa học này tập trung vào các phương pháp đán...
# Name: 13872, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp kiến...
# question                Nghiên cứu chỉ ra rằng các xét nghiệm hóa sinh...
# answer                  Chào các bạn,\n\nViệc kết quả các xét nghiệm t...
# document/title          Sổ tay Quản lý Chất lượng Xét nghiệm của Bộ Y ...
# document/description    Tài liệu chính thức này cung cấp các hướng dẫn...
# cme/title               Phối hợp Lâm sàng - Cận lâm sàng trong chẩn đo...
# cme/description         Khóa học này tập trung vào việc tăng cường khả...
# Name: 13873, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, làm thế nào để đảm bảo độ chí...
# answer                  Các em sinh viên và bác sĩ trẻ thân mến, việc ...
# document/title          Quyết định 2429/QĐ-BYT ban hành Tiêu chí đánh ...
# document/description    Tài liệu hướng dẫn chính thức từ Bộ Y tế Việt ...
# cme/title               Cập nhật các quy trình Kiểm soát chất lượng tr...
# cme/description         Khóa học CME này tập trung vào các phương pháp...
# Name: 13874, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi đối diện với bệnh nhân có nhân tuyến giáp ...
# answer                  Các bạn đồng nghiệp tương lai, trong thực hành...
# document/title          Phẫu thuật tuyến giáp nội soi: Chỉ định, kỹ th...
# document/description    Một tài liệu chuyên khảo toàn diện về phẫu thu...
# cme/title               Chẩn đoán và quản lý nhân tuyến giáp theo khuy...
# cme/description         Khóa học CME cập nhật các hướng dẫn lâm sàng m...
# Name: 13875, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sau phẫu thuật cắt thùy tuyến giáp nội soi để ...
# answer                  Chào các bác sĩ tương lai và đồng nghiệp, quá ...
# document/title          Hướng dẫn thực hành lâm sàng về chăm sóc bệnh ...
# document/description    Sổ tay hướng dẫn chi tiết các bước chăm sóc bệ...
# cme/title               Điều trị và phục hồi chức năng toàn diện sau p...
# cme/description         Khóa học CME đa chuyên khoa này cung cấp kiến ...
# Name: 13876, dtype: object
# ✅ Đã lưu toàn bộ dữ liệu paraphrase vào file Excel.
