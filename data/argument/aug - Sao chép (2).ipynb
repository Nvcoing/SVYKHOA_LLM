# %%
from datasets import load_dataset
from transformers import MT5Tokenizer, MT5ForConditionalGeneration
from tqdm import tqdm
import pandas as pd
import torch
import os

# Kiểm tra GPU
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cuda" )
print(f"💻 Đang sử dụng thiết bị: {device}")

# Load model paraphrase và đưa lên GPU
CKPT = 'chieunq/vietnamese-sentence-paraphase'
tokenizer = MT5Tokenizer.from_pretrained(CKPT)
model = MT5ForConditionalGeneration.from_pretrained(CKPT).to(device)

# Hàm tạo paraphrase
def paraphrase(text, num_return_sequences=5):
    inputs = tokenizer(text, padding='longest', max_length=512, truncation=True, return_tensors='pt')
    inputs = {key: val.to(device) for key, val in inputs.items()}
    output = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_length=512,
        num_return_sequences=num_return_sequences,
        do_sample=True,
        top_p=0.95
    )
    return [tokenizer.decode(o, skip_special_tokens=True) for o in output]

# Load dataset
dataset = pd.read_parquet("../generate_dataset/SVYKHOA_dataset_medicaltalk.parquet", engine="fastparquet")

# File Excel đầu ra
output_file = "SVYKHOA_dataset_diagnosis_4.xlsx"

# Tạo file Excel rỗng nếu chưa có
if not os.path.exists(output_file):
    df_empty = pd.DataFrame(columns=["STT CHƯƠNG", "MÃ CHƯƠNG", "TÊN NHÓM CHÍNH", "MÃ BỆNH", "TÊN BỆNH", "intruction", "question", "symptom", "diagnosis", "document/title", "document/description", "cme/title", "cme/description"])
    df_empty.to_excel(output_file, index=False)

# Đọc số dòng đã có để tiếp tục từ đó
existing_df = pd.read_excel(output_file)
# start_index = len(existing_df)
start_index = 15000
print(f"🚀 Bắt đầu từ dòng {start_index}")

# Số lượng mẫu muốn xử lý thêm
max_samples = 273500  # Có thể chỉnh: 10, 100, 500...

# Duyệt dataset từ start_index
for i, row in dataset.iterrows():
    if i < start_index:
        continue
    if i >= start_index + max_samples:
        break
    print(row)

    question = row["question"]   # row là Series
    try:
        paraphrases = paraphrase(question, num_return_sequences=10)
    except Exception as e:
        print(f"Lỗi paraphrase tại mẫu {i}: {e}")
        paraphrases = [question]

    new_rows = []
    for pq in paraphrases:
        new_rows.append({
            "STT CHƯƠNG": row["STT CHƯƠNG"],
            "MÃ CHƯƠNG": row["MÃ CHƯƠNG"],
            "TÊN NHÓM CHÍNH": row["TÊN NHÓM CHÍNH"],
            "MÃ BỆNH": row["MÃ BỆNH"],
            "TÊN BỆNH": row["TÊN BỆNH"],
            "intruction": row["intruction"],
            "question": pq,
            "symptom": row["symptom"],
            "diagnosis": row["diagnosis"],
            "document/title": row["document/title"],
            "document/description": row["document/description"],
            "cme/title": row["cme/title"],
            "cme/description": row["cme/description"]
        })

    new_df = pd.DataFrame(new_rows)
    with pd.ExcelWriter(output_file, mode="a", engine="openpyxl", if_sheet_exists="overlay") as writer:
        sheet = writer.sheets["Sheet1"]
        start_row = sheet.max_row
        new_df.to_excel(writer, header=False, index=False, startrow=start_row)


print("✅ Đã lưu toàn bộ dữ liệu paraphrase vào file Excel.")
# Out:
# 💻 Đang sử dụng thiết bị: cuda
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'T5Tokenizer'.
# The class this function is called from is 'MT5Tokenizer'.
# You are using the default legacy behaviour of the <class 'transformers.models.mt5.tokenization_mt5.MT5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# 🚀 Bắt đầu từ dòng 15000
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                               K52
# TÊN BỆNH                Viêm dạ dày-ruột và viêm đại tràng khác không ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sau khi xạ trị vùng bụng, tôi xuất hiện các tr...
# symptom                 Bệnh nhân nữ, 55 tuổi, tiền sử xạ trị vùng chậ...
# diagnosis               Chẩn đoán: Viêm đại tràng do xạ trị (K52.0 - R...
# document/title          Hướng dẫn quản lý biến chứng tiêu hóa muộn sau...
# document/description    Tài liệu này cung cấp các nguyên tắc chẩn đoán...
# cme/title               Chẩn đoán và xử trí biến chứng tiêu hóa sau đi...
# cme/description         Khóa học chuyên sâu về các biến chứng tiêu hóa...
# Name: 15000, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                               K52
# TÊN BỆNH                Viêm dạ dày-ruột và viêm đại tràng khác không ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi có triệu chứng buồn nôn, nôn mửa tái phát ...
# symptom                 Bệnh nhân nữ, 28 tuổi, xuất hiện các đợt buồn ...
# diagnosis               Chẩn đoán: Viêm dạ dày-ruột tăng bạch cầu ái t...
# document/title          Sổ tay lâm sàng về bệnh lý viêm dạ dày-ruột tă...
# document/description    Tài liệu này cung cấp một cái nhìn toàn diện v...
# cme/title               Tiếp cận chẩn đoán và điều trị bệnh viêm ruột ...
# cme/description         Khóa học này cung cấp kiến thức sâu rộng về vi...
# Name: 15001, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.0
# TÊN BỆNH                        Viêm dạ dày - ruột và đại tràng do tia xạ
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Xin vui lòng cho biết các triệu chứng điển hìn...
# symptom                 Các triệu chứng của viêm dạ dày - ruột và đại ...
# diagnosis               Chẩn đoán viêm dạ dày - ruột và đại tràng do t...
# document/title          Hướng dẫn chẩn đoán và điều trị viêm ruột do t...
# document/description    Tài liệu cung cấp thông tin chi tiết về các ti...
# cme/title               Quản lý toàn diện viêm dạ dày - ruột và đại tr...
# cme/description         Khóa học CME này tập trung vào việc cập nhật k...
# Name: 15002, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.0
# TÊN BỆNH                        Viêm dạ dày - ruột và đại tràng do tia xạ
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Để chẩn đoán chính xác bệnh viêm dạ dày - ruột...
# symptom                 Bệnh nhân thường có tiền sử rõ ràng về việc đã...
# diagnosis               Chẩn đoán xác định K52.0 đòi hỏi sự phối hợp c...
# document/title          Hướng dẫn thực hành lâm sàng về chẩn đoán và q...
# document/description    Tài liệu này cung cấp các khuyến nghị dựa trên...
# cme/title               Các phương pháp chẩn đoán hình ảnh tiên tiến t...
# cme/description         Khóa học này tập trung vào việc sử dụng và diễ...
# Name: 15003, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.0
# TÊN BỆNH                        Viêm dạ dày - ruột và đại tràng do tia xạ
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các phương pháp điều trị hiện tại cho bệnh viê...
# symptom                 Bệnh nhân thường trình bày với các triệu chứng...
# diagnosis               Chẩn đoán K52.0 đã được xác nhận thông qua tiề...
# document/title          Phác đồ điều trị viêm ruột do tia xạ của Bộ Y ...
# document/description    Tài liệu chính thức của Bộ Y tế Việt Nam cung ...
# cme/title               Cập nhật các phương pháp điều trị viêm ruột do...
# cme/description         Khóa học này cung cấp cái nhìn tổng quan về cá...
# Name: 15004, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.0
# TÊN BỆNH                        Viêm dạ dày - ruột và đại tràng do tia xạ
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Viêm dạ dày - ruột và đại tràng do tia xạ (K52...
# symptom                 Bệnh nhân với K52.0 mạn tính có thể xuất hiện ...
# diagnosis               Chẩn đoán biến chứng của K52.0 dựa trên sự nặn...
# document/title          Quản lý biến chứng của viêm ruột do tia xạ: Ti...
# document/description    Tài liệu này đề cập đến các biến chứng thường ...
# cme/title               Chiến lược phòng ngừa và điều trị biến chứng m...
# cme/description         Khóa học này cung cấp kiến thức chuyên sâu về ...
# Name: 15005, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.0
# TÊN BỆNH                        Viêm dạ dày - ruột và đại tràng do tia xạ
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Cơ chế bệnh sinh của viêm dạ dày - ruột và đại...
# symptom                 Bệnh nhân có thể không có triệu chứng ban đầu ...
# diagnosis               Chẩn đoán K52.0 dựa trên việc xác định tiền sử...
# document/title          Cơ chế bệnh sinh và chiến lược phòng ngừa viêm...
# document/description    Tài liệu này cung cấp hiểu biết sâu sắc về các...
# cme/title               Tối ưu hóa kỹ thuật xạ trị để giảm thiểu tác d...
# cme/description         Khóa học này tập trung vào các kỹ thuật xạ trị...
# Name: 15006, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.1
# TÊN BỆNH                     Viêm dạ dày - ruột và đại tràng do nhiễm độc
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các tác dụng phụ phổ biến nhất khi điều trị ti...
# symptom                 Các triệu chứng tiêu hóa: tiêu chảy (tỷ lệ 28,...
# diagnosis               Tình trạng viêm dạ dày ruột và viêm đại tràng ...
# document/title          Các Biến cố Bất lợi của Thuốc trong Điều trị T...
# document/description    Tài liệu này tổng hợp các biến cố bất lợi của ...
# cme/title               Quản lý Tác dụng Phụ của Thuốc trong Điều trị ...
# cme/description         Khóa học này cung cấp kiến thức chuyên sâu về ...
# Name: 15007, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.2
# TÊN BỆNH                Viêm dạ dày - ruột và đại tràng do dị ứng và t...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi bị đau bụng, tiêu chảy sau khi ăn một số l...
# symptom                 Đau quặn bụng vùng thượng vị hoặc quanh rốn, x...
# diagnosis               Dựa trên các triệu chứng mô tả, có thể nghi ng...
# document/title          Hướng dẫn chẩn đoán và điều trị Viêm dạ dày - ...
# document/description    Tài liệu này cung cấp các tiêu chí chẩn đoán, ...
# cme/title               Cập nhật về chẩn đoán và quản lý Viêm dạ dày -...
# cme/description         Khóa học này tập trung vào các phương pháp chẩ...
# Name: 15008, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.2
# TÊN BỆNH                Viêm dạ dày - ruột và đại tràng do dị ứng và t...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Để chẩn đoán xác định Viêm dạ dày - ruột và đạ...
# symptom                 Bệnh nhân thường có tiền sử các triệu chứng ti...
# diagnosis               Chẩn đoán xác định Viêm dạ dày - ruột và đại t...
# document/title          Phác đồ chẩn đoán và điều trị Viêm dạ dày - ru...
# document/description    Tài liệu này chi tiết hóa các bước chẩn đoán, ...
# cme/title               Kỹ thuật sinh thiết và giải phẫu bệnh trong ch...
# cme/description         Khóa học chuyên sâu về các kỹ thuật sinh thiết...
# Name: 15009, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.2
# TÊN BỆNH                Viêm dạ dày - ruột và đại tràng do dị ứng và t...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi được chẩn đoán K52.2. Chế độ ăn uống và cá...
# symptom                 Bệnh nhân đã được chẩn đoán xác định Viêm dạ d...
# diagnosis               Điều trị Viêm dạ dày - ruột và đại tràng do dị...
# document/title          Hướng dẫn xây dựng chế độ ăn kiêng trong điều ...
# document/description    Tài liệu này cung cấp chi tiết về cách xác địn...
# cme/title               Quản lý dinh dưỡng và dược lý trong Viêm dạ dà...
# cme/description         Khóa học này cung cấp kiến thức toàn diện về c...
# Name: 15010, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.2
# TÊN BỆNH                Viêm dạ dày - ruột và đại tràng do dị ứng và t...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Cơ chế gây bệnh của Viêm dạ dày - ruột và đại ...
# symptom                 Mặc dù không phải triệu chứng lâm sàng trực ti...
# diagnosis               Viêm dạ dày - ruột và đại tràng do dị ứng và t...
# document/title          Cơ chế bệnh sinh của Viêm dạ dày - ruột và đại...
# document/description    Tài liệu này đi sâu vào cơ chế miễn dịch và vi...
# cme/title               Bệnh lý học và miễn dịch học của Viêm đường ti...
# cme/description         Khóa học này khám phá các khía cạnh bệnh lý họ...
# Name: 15011, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.2
# TÊN BỆNH                Viêm dạ dày - ruột và đại tràng do dị ứng và t...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những biến chứng có thể xảy ra và cách quản lý...
# symptom                 Bệnh nhân K52.2 có thể có tiền sử các đợt bùng...
# diagnosis               Các biến chứng tiềm ẩn của Viêm dạ dày - ruột ...
# document/title          Quản lý dài hạn và phòng ngừa biến chứng của V...
# document/description    Tài liệu này hướng dẫn các chiến lược quản lý ...
# cme/title               Tiếp cận đa chuyên khoa trong quản lý Viêm dạ ...
# cme/description         Khóa học này nhấn mạnh vai trò của tiếp cận đa...
# Name: 15012, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.3
# TÊN BỆNH                                    Viêm đại tràng không xác định
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi bị đau bụng đi ngoài nhiều lần, không rõ n...
# symptom                 Bệnh nhân có triệu chứng đau bụng âm ỉ hoặc qu...
# diagnosis               Dựa trên triệu chứng lâm sàng, cần xem xét chẩ...
# document/title          Hướng dẫn chẩn đoán và điều trị bệnh viêm ruột...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Cập nhật chẩn đoán và quản lý viêm đại tràng k...
# cme/description         Khóa học này tập trung vào các phương pháp tiế...
# Name: 15013, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.3
# TÊN BỆNH                                    Viêm đại tràng không xác định
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nếu các triệu chứng viêm đại tràng kéo dài mà ...
# symptom                 Bệnh nhân trải qua các đợt tiêu chảy tái đi tá...
# diagnosis               Khi các triệu chứng viêm đại tràng kéo dài và ...
# document/title          Thực hành lâm sàng tiêu hóa: Chẩn đoán và điều...
# document/description    Cuốn sách cung cấp kiến thức sâu rộng về chẩn ...
# cme/title               Vai trò của nội soi và sinh thiết trong chẩn đ...
# cme/description         Khóa học này sẽ hướng dẫn các bác sĩ về kỹ thu...
# Name: 15014, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.3
# TÊN BỆNH                                    Viêm đại tràng không xác định
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Viêm đại tràng không xác định (K52.3) có thể t...
# symptom                 Triệu chứng viêm đại tràng kéo dài với các đợt...
# diagnosis               Viêm đại tràng không xác định (K52.3) là một c...
# document/title          Hướng dẫn điều trị bệnh viêm ruột của Hiệp hội...
# document/description    Tài liệu quốc tế cung cấp các khuyến nghị dựa ...
# cme/title               Quản lý dược lý và dinh dưỡng trong viêm đại t...
# cme/description         Khóa học này đào tạo về các lựa chọn thuốc điề...
# Name: 15015, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.3
# TÊN BỆNH                                    Viêm đại tràng không xác định
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những biến chứng tiềm ẩn nào có thể xảy ra ở b...
# symptom                 Các triệu chứng nặng đột ngột như đau bụng dữ ...
# diagnosis               Mặc dù là 'không xác định', viêm đại tràng K52...
# document/title          Quản lý biến chứng trong các bệnh viêm ruột mã...
# document/description    Tài liệu này cung cấp hướng dẫn chi tiết về cá...
# cme/title               Phát hiện sớm và xử trí các biến chứng của viê...
# cme/description         Khóa học nhằm trang bị kiến thức cho bác sĩ về...
# Name: 15016, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.3
# TÊN BỆNH                                    Viêm đại tràng không xác định
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Ngoài điều trị bằng thuốc, bệnh nhân viêm đại ...
# symptom                 Bệnh nhân thường than phiền về các triệu chứng...
# diagnosis               Đối với viêm đại tràng không xác định (K52.3),...
# document/title          Dinh dưỡng và quản lý lối sống cho bệnh nhân v...
# document/description    Tài liệu này cung cấp các hướng dẫn chi tiết v...
# cme/title               Tư vấn dinh dưỡng và tâm lý cho bệnh nhân bệnh...
# cme/description         Khóa học này trang bị cho các chuyên gia y tế ...
# Name: 15017, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.8
# TÊN BỆNH                Viêm dạ dày - ruột và đại tràng đặc hiệu khác ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi có các triệu chứng đau bụng và tiêu chảy k...
# symptom                 Đau bụng âm ỉ hoặc quặn từng cơn vùng quanh rố...
# diagnosis               Chẩn đoán ban đầu dựa trên lâm sàng và loại tr...
# document/title          Hướng dẫn chẩn đoán và điều trị Viêm dạ dày-ru...
# document/description    Tài liệu chuyên khảo cung cấp tiêu chuẩn chẩn ...
# cme/title               CME: Tiếp cận toàn diện các bệnh lý viêm ruột ...
# cme/description         Khóa học này sẽ cập nhật kiến thức về các nguy...
# Name: 15018, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.8
# TÊN BỆNH                Viêm dạ dày - ruột và đại tràng đặc hiệu khác ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để phân biệt Viêm dạ dày-ruột và đ...
# symptom                 Bệnh nhân thường trình bày với đau bụng mạn tí...
# diagnosis               Chẩn đoán phân biệt dựa trên kết quả nội soi đ...
# document/title          Chẩn đoán phân biệt giữa Viêm ruột không nhiễm...
# document/description    Tài liệu này tập trung vào các tiêu chí lâm sà...
# cme/title               CME: Cập nhật tiêu chuẩn vàng trong chẩn đoán ...
# cme/description         Khóa học đào tạo chuyên sâu về các công cụ chẩ...
# Name: 15019, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.8
# TÊN BỆNH                Viêm dạ dày - ruột và đại tràng đặc hiệu khác ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các nguyên nhân phổ biến nào gây ra Viêm dạ dà...
# symptom                 Triệu chứng có thể bao gồm đau bụng quặn khu t...
# diagnosis               Các nguyên nhân thường gặp của K52.8 bao gồm: ...
# document/title          Quản lý Viêm dạ dày-ruột và đại tràng không do...
# document/description    Tổng quan các nguyên nhân phổ biến và hiếm gặp...
# cme/title               CME: Tiếp cận điều trị theo nguyên nhân trong ...
# cme/description         Khóa học tập trung vào việc xác định các yếu t...
# Name: 15020, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.8
# TÊN BỆNH                Viêm dạ dày - ruột và đại tràng đặc hiệu khác ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi đang được chẩn đoán Viêm dạ dày-ruột và đạ...
# symptom                 Các triệu chứng hiện tại bao gồm tiêu chảy kéo...
# diagnosis               Chế độ ăn uống cho bệnh nhân K52.8 cần được cá...
# document/title          Chế độ dinh dưỡng và quản lý chế độ ăn cho bện...
# document/description    Tài liệu hướng dẫn chi tiết về các nguyên tắc ...
# cme/title               CME: Tư vấn dinh dưỡng lâm sàng cho bệnh nhân ...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu cho bác...
# Name: 15021, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.8
# TÊN BỆNH                Viêm dạ dày - ruột và đại tràng đặc hiệu khác ...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi vừa được chẩn đoán mắc Viêm dạ dày-ruột và...
# symptom                 Các triệu chứng bao gồm tiêu chảy phân nước (t...
# diagnosis               Điều trị K52.8 chủ yếu là điều trị triệu chứng...
# document/title          Phác đồ điều trị và quản lý tái khám cho Viêm ...
# document/description    Tài liệu này cung cấp hướng dẫn chi tiết về cá...
# cme/title               CME: Chiến lược điều trị và theo dõi bệnh nhân...
# cme/description         Khóa học này sẽ thảo luận về các chiến lược đi...
# Name: 15022, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.9
# TÊN BỆNH                Viêm dạ dày - ruột và đại tràng không nhiễm tr...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những nguyên nhân hiếm gặp và thách thức trong...
# symptom                 Tiêu chảy kéo dài ở trẻ sơ sinh và nhũ nhi (th...
# diagnosis               Tiêu chảy kéo dài ở trẻ sơ sinh và nhũ nhi là ...
# document/title          Tiêu chảy kéo dài ở trẻ sơ sinh và nhũ nhi: Kh...
# document/description    Tài liệu này thảo luận về các nguyên nhân hiếm...
# cme/title               Tiếp cận toàn diện tiêu chảy kéo dài ở nhi kho...
# cme/description         Khóa học CME này dành cho bác sĩ nhi khoa, tiê...
# Name: 15023, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH            Viêm ruột non và đại tràng không do nhiễm trùng
# MÃ BỆNH                                                             K52.9
# TÊN BỆNH                Viêm dạ dày - ruột và đại tràng không nhiễm tr...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Công dụng và cơ chế hoạt động của Octreotide t...
# symptom                 Tiêu chảy kéo dài (ví dụ >3-4 lần đi cầu/ngày ...
# diagnosis               Chỉ định sử dụng Octreotide cần được cân nhắc ...
# document/title          Octreotide trong điều trị tiêu chảy kéo dài ở ...
# document/description    Tài liệu này xem xét vai trò của Octreotide, m...
# cme/title               Ứng dụng Octreotide trong các bệnh lý tiêu hóa...
# cme/description         Khóa học này cung cấp kiến thức về cơ chế tác ...
# Name: 15024, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                               K55
# TÊN BỆNH                                       Rối loạn mạch máu của ruột
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi bị đau bụng đột ngột dữ dội, không tương x...
# symptom                 Đau bụng dữ dội, khởi phát đột ngột, thường kh...
# diagnosis               Chẩn đoán thiếu máu cục bộ ruột cấp tính (K55....
# document/title          Hướng dẫn chẩn đoán và điều trị thiếu máu cục ...
# document/description    Tài liệu chuyên sâu từ Bộ Y tế về các tiêu chu...
# cme/title               Cập nhật chẩn đoán và quản lý thiếu máu mạc tr...
# cme/description         Khóa học đào tạo y khoa liên tục về các tiến b...
# Name: 15025, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                               K55
# TÊN BỆNH                                       Rối loạn mạch máu của ruột
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi thường bị đau bụng sau khi ăn và sụt cân k...
# symptom                 Đau bụng tái diễn, có tính chất co thắt, thườn...
# diagnosis               Chẩn đoán rối loạn mạch máu ruột mãn tính (K55...
# document/title          Chẩn đoán và xử trí thiếu máu cục bộ mạc treo ...
# document/description    Hướng dẫn lâm sàng chi tiết về các bước chẩn đ...
# cme/title               Bệnh lý mạch máu ruột: Từ chẩn đoán hình ảnh đ...
# cme/description         Khóa học tập trung vào việc nhận diện sớm các ...
# Name: 15026, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                               K55
# TÊN BỆNH                                       Rối loạn mạch máu của ruột
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi bị xuất huyết tiêu hóa dưới tái phát, khôn...
# symptom                 Xuất huyết tiêu hóa dưới tái phát hoặc mãn tín...
# diagnosis               Chẩn đoán angiodysplasia đại tràng (K55.2) chủ...
# document/title          Chẩn đoán và điều trị angiodysplasia đường tiê...
# document/description    Tài liệu tổng quan về các phương pháp chẩn đoá...
# cme/title               Tiếp cận chẩn đoán và điều trị xuất huyết tiêu...
# cme/description         Khóa học tập trung vào các công cụ chẩn đoán t...
# Name: 15027, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                               K55
# TÊN BỆNH                                       Rối loạn mạch máu của ruột
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Rối loạn mạch máu của ruột (K55) bao gồm những...
# symptom                 Triệu chứng của rối loạn mạch máu ruột rất đa ...
# diagnosis               Rối loạn mạch máu của ruột (K55) bao gồm: Thiế...
# document/title            Tổng quan về bệnh lý mạch máu ruột (ICD-10 K55)
# document/description    Bài viết cung cấp cái nhìn tổng thể về các phâ...
# cme/title               Các yếu tố nguy cơ và chiến lược phòng ngừa bệ...
# cme/description         Khóa học chuyên sâu về nhận diện và quản lý cá...
# Name: 15028, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                               K55
# TÊN BỆNH                                       Rối loạn mạch máu của ruột
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi được chẩn đoán mắc bệnh rối loạn mạch máu ...
# symptom                 Các triệu chứng như đau bụng (VAS score >7/10)...
# diagnosis               Quyết định điều trị dựa trên chẩn đoán chính x...
# document/title          Phác đồ điều trị bệnh lý mạch máu ruột theo IC...
# document/description    Tài liệu hướng dẫn chi tiết về các lựa chọn đi...
# cme/title               Quản lý toàn diện bệnh nhân rối loạn mạch máu ...
# cme/description         Khóa học đào tạo chuyên sâu về cách tiếp cận đ...
# Name: 15029, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.0
# TÊN BỆNH                                  Rối loạn mạch máu ruột cấp tính
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Triệu chứng phổ biến của rối loạn mạch máu ruộ...
# symptom                 Đau bụng cấp tính, dữ dội, đột ngột, thường kh...
# diagnosis               Rối loạn mạch máu ruột cấp tính (K55.0) nghi n...
# document/title          Hướng dẫn chẩn đoán và xử trí Rối loạn mạch má...
# document/description    Tài liệu tham khảo chuyên sâu về sinh lý bệnh,...
# cme/title               Cập nhật chẩn đoán và xử trí Rối loạn mạch máu...
# cme/description         Khóa học đào tạo y khoa liên tục dành cho bác ...
# Name: 15030, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.0
# TÊN BỆNH                                  Rối loạn mạch máu ruột cấp tính
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong trường hợp rối loạn mạch máu ruột cấp tí...
# symptom                 Khởi phát đột ngột đau bụng dữ dội ở vùng quan...
# diagnosis               Rối loạn mạch máu ruột cấp tính (K55.0) do thu...
# document/title          Hướng dẫn chẩn đoán và xử trí Rối loạn mạch má...
# document/description    Tài liệu tham khảo chuyên sâu về sinh lý bệnh,...
# cme/title               Cập nhật chẩn đoán và xử trí Rối loạn mạch máu...
# cme/description         Khóa học đào tạo y khoa liên tục dành cho bác ...
# Name: 15031, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.0
# TÊN BỆNH                                  Rối loạn mạch máu ruột cấp tính
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi bị đau bụng âm ỉ kéo dài nhiều ngày, sau đ...
# symptom                 Đau bụng khởi phát âm ỉ, bán cấp, kéo dài vài ...
# diagnosis               Rối loạn mạch máu ruột cấp tính (K55.0) do huy...
# document/title          Hướng dẫn chẩn đoán và xử trí Rối loạn mạch má...
# document/description    Tài liệu tham khảo chuyên sâu về sinh lý bệnh,...
# cme/title               Cập nhật chẩn đoán và xử trí Rối loạn mạch máu...
# cme/description         Khóa học đào tạo y khoa liên tục dành cho bác ...
# Name: 15032, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.0
# TÊN BỆNH                                  Rối loạn mạch máu ruột cấp tính
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Rối loạn mạch máu ruột cấp tính không do tắc n...
# symptom                 Đau bụng không điển hình, có thể âm ỉ hoặc dữ ...
# diagnosis               Rối loạn mạch máu ruột cấp tính (K55.0) không ...
# document/title          Hướng dẫn chẩn đoán và xử trí Rối loạn mạch má...
# document/description    Tài liệu tham khảo chuyên sâu về sinh lý bệnh,...
# cme/title               Cập nhật chẩn đoán và xử trí Rối loạn mạch máu...
# cme/description         Khóa học đào tạo y khoa liên tục dành cho bác ...
# Name: 15033, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.0
# TÊN BỆNH                                  Rối loạn mạch máu ruột cấp tính
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những biến chứng nguy hiểm nào có thể xảy ra d...
# symptom                 Đau bụng dữ dội không thuyên giảm (VAS >9/10),...
# diagnosis               Rối loạn mạch máu ruột cấp tính (K55.0) có biế...
# document/title          Hướng dẫn chẩn đoán và xử trí Rối loạn mạch má...
# document/description    Tài liệu tham khảo chuyên sâu về sinh lý bệnh,...
# cme/title               Cập nhật chẩn đoán và xử trí Rối loạn mạch máu...
# cme/description         Khóa học đào tạo y khoa liên tục dành cho bác ...
# Name: 15034, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.1
# TÊN BỆNH                                       Rối loạn mạch máu ruột mạn
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các triệu chứng điển hình của rối loạn mạch má...
# symptom                 Đau bụng sau ăn tái phát, thường bắt đầu 15-60...
# diagnosis               Nghi ngờ Rối loạn mạch máu ruột mạn (K55.1) dự...
# document/title          Hướng dẫn chẩn đoán và điều trị bệnh thiếu máu...
# document/description    Tài liệu chuyên sâu về sinh lý bệnh, tiêu chuẩ...
# cme/title               Cập nhật chẩn đoán và can thiệp nội mạch trong...
# cme/description         Khóa học tập trung vào các kỹ thuật chẩn đoán ...
# Name: 15035, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.1
# TÊN BỆNH                                       Rối loạn mạch máu ruột mạn
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những yếu tố nguy cơ nào liên quan đến sự phát...
# symptom                 Bệnh nhân có tiền sử mắc các bệnh xơ vữa động ...
# diagnosis               Rối loạn mạch máu ruột mạn (K55.1) thường liên...
# document/title          Xơ vữa động mạch và các bệnh lý mạch máu nội tạng
# document/description    Tổng quan về cơ chế bệnh sinh của xơ vữa động ...
# cme/title               Quản lý toàn diện các yếu tố nguy cơ tim mạch ...
# cme/description         Khóa học dành cho bác sĩ nội khoa, tập trung v...
# Name: 15036, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.1
# TÊN BỆNH                                       Rối loạn mạch máu ruột mạn
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Phương pháp chẩn đoán hình ảnh nào là tiêu chu...
# symptom                 Đau bụng sau ăn dữ dội, đau dai dẳng, không th...
# diagnosis               Chụp mạch máu xóa nền (DSA) hoặc Chụp cắt lớp ...
# document/title          Vai trò của Chụp cắt lớp vi tính mạch máu (CTA...
# document/description    Nghiên cứu đánh giá độ nhạy và độ đặc hiệu của...
# cme/title               Kỹ thuật và diễn giải hình ảnh mạch máu trong ...
# cme/description         Khóa học chuyên sâu dành cho bác sĩ chẩn đoán ...
# Name: 15037, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.1
# TÊN BỆNH                                       Rối loạn mạch máu ruột mạn
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các lựa chọn điều trị chính cho rối loạn mạch ...
# symptom                 Bệnh nhân có triệu chứng đau bụng sau ăn nặng,...
# diagnosis               Điều trị Rối loạn mạch máu ruột mạn (K55.1) ch...
# document/title          Khuyến nghị điều trị thiếu máu cục bộ mạc treo...
# document/description    Tóm tắt các khuyến nghị điều trị dựa trên bằng...
# cme/title               Tiến bộ trong tái tưới máu động mạch mạc treo:...
# cme/description         Khóa học cung cấp cái nhìn tổng quan về các ph...
# Name: 15038, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.1
# TÊN BỆNH                                       Rối loạn mạch máu ruột mạn
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để phân biệt rối loạn mạch máu ruộ...
# symptom                 Đau bụng không liên quan đến chu kỳ kinh nguyệ...
# diagnosis               Phân biệt Rối loạn mạch máu ruột mạn (K55.1) v...
# document/title          Chẩn đoán phân biệt đau bụng mạn tính: Tiếp cậ...
# document/description    Tài liệu hướng dẫn cách tiếp cận chẩn đoán phâ...
# cme/title               Tiếp cận chẩn đoán đau bụng mạn tính không rõ ...
# cme/description         Khóa học trang bị cho bác sĩ đa khoa và chuyên...
# Name: 15039, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.2
# TÊN BỆNH                                      Loạn sản mạch máu đại tràng
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Loạn sản mạch máu đại tràng (K55.2) là gì và c...
# symptom                 Các triệu chứng thường không đặc hiệu và liên ...
# diagnosis               Chẩn đoán xác định loạn sản mạch máu đại tràng...
# document/title          Hướng dẫn chẩn đoán và điều trị Loạn sản mạch ...
# document/description    Tài liệu y khoa toàn diện cung cấp phác đồ chu...
# cme/title               Cập nhật phương pháp chẩn đoán và điều trị Loạ...
# cme/description         Khóa học đào tạo y khoa liên tục trình bày nhữ...
# Name: 15040, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.2
# TÊN BỆNH                                      Loạn sản mạch máu đại tràng
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các phương pháp chẩn đoán hình ảnh và xét nghi...
# symptom                 Bệnh nhân thường đến khám vì triệu chứng chảy ...
# diagnosis               Để chẩn đoán loạn sản mạch máu đại tràng (K55....
# document/title          Nội soi tiêu hóa: Kỹ thuật chẩn đoán các tổn t...
# document/description    Tài liệu hướng dẫn chi tiết về kỹ thuật nội so...
# cme/title               Kỹ thuật nội soi đại tràng nâng cao trong phát...
# cme/description         Khóa học chuyên sâu dành cho bác sĩ nội soi, t...
# Name: 15041, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.2
# TÊN BỆNH                                      Loạn sản mạch máu đại tràng
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các phương pháp điều trị hiệu quả cho bệnh nhâ...
# symptom                 Bệnh nhân thường có biểu hiện chảy máu đường t...
# diagnosis               Sau khi chẩn đoán xác định loạn sản mạch máu đ...
# document/title          Phác đồ điều trị xuất huyết tiêu hóa dưới do l...
# document/description    Tổng hợp các bằng chứng lâm sàng và khuyến ngh...
# cme/title               Tiến bộ trong nội soi can thiệp cầm máu các tổ...
# cme/description         Khóa học này tập trung vào các kỹ thuật can th...
# Name: 15042, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.2
# TÊN BỆNH                                      Loạn sản mạch máu đại tràng
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nguyên nhân và yếu tố nguy cơ phát triển loạn ...
# symptom                 Các bệnh nhân thường là người lớn tuổi, trên 6...
# diagnosis               Loạn sản mạch máu đại tràng (K55.2) được cho l...
# document/title          Dịch tễ học và các yếu tố nguy cơ của loạn sản...
# document/description    Nghiên cứu khoa học phân tích các yếu tố dịch ...
# cme/title               Quản lý bệnh nhân cao tuổi mắc xuất huyết tiêu...
# cme/description         Khóa học tập trung vào việc quản lý bệnh nhân ...
# Name: 15043, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.2
# TÊN BỆNH                                      Loạn sản mạch máu đại tràng
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi nào cần xem xét phẫu thuật trong điều trị ...
# symptom                 Bệnh nhân có thể có các đợt chảy máu đường tiê...
# diagnosis               Phẫu thuật cắt bỏ đoạn đại tràng chứa tổn thươ...
# document/title          Chỉ định phẫu thuật trong xuất huyết tiêu hóa ...
# document/description    Tài liệu chuyên khảo về các tiêu chí lâm sàng ...
# cme/title               Quản lý ca khó: Phẫu thuật trong điều trị chảy...
# cme/description         Khóa học dành cho các bác sĩ phẫu thuật và tiê...
# Name: 15044, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.8
# TÊN BỆNH                                  Rối loạn mạch máu khác của ruột
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các triệu chứng và phương pháp chẩn đoán điển ...
# symptom                 Bệnh nhân có tiền sử xuất huyết tiêu hóa dưới ...
# diagnosis               Nghi ngờ dị sản mạch máu (angiodysplasia) của ...
# document/title          Hướng dẫn chẩn đoán và điều trị xuất huyết tiê...
# document/description    Tài liệu này cung cấp các khuyến nghị lâm sàng...
# cme/title               Cập nhật các phương pháp chẩn đoán và điều trị...
# cme/description         Khóa học này tập trung vào các kỹ thuật nội so...
# Name: 15045, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.8
# TÊN BỆNH                                  Rối loạn mạch máu khác của ruột
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Một bệnh nhân đến khám với đau bụng sau ăn và ...
# symptom                 Đau bụng quặn thắt nghiêm trọng sau khi ăn (đa...
# diagnosis               Nghi ngờ thiếu máu cục bộ mạc treo mạn tính (K...
# document/title          Khuyến nghị chẩn đoán và quản lý bệnh thiếu má...
# document/description    Tài liệu này cung cấp hướng dẫn toàn diện về c...
# cme/title               Tiếp cận đa chuyên khoa trong chẩn đoán và điề...
# cme/description         Khóa học đào tạo y khoa liên tục này nhằm nâng...
# Name: 15046, dtype: object
# STT CHƯƠNG                                                             XI
# MÃ CHƯƠNG                                                         K00-K93
# TÊN NHÓM CHÍNH                                       Bệnh đường ruột khác
# MÃ BỆNH                                                             K55.8
# TÊN BỆNH                                  Rối loạn mạch máu khác của ruột
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trường hợp xuất huyết tiêu hóa ẩn do dị dạng m...
# symptom                 Xuất huyết tiêu hóa ẩn tái phát, biểu hiện dướ...
# diagnosis               Xuất huyết tiêu hóa ẩn do nghi ngờ dị dạng mạc...
# ...
# cme/title               Quản lý và Điều trị Sỏi đường tiết niệu & Bệnh...
# cme/description         Khóa học tập trung vào các phương pháp chẩn đo...
# Name: 18400, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                                              Sỏi tiết niệu
# MÃ BỆNH                                                             N20.0
# TÊN BỆNH                                                         Sỏi thận
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sỏi thận được chẩn đoán như thế nào và có nhữn...
# symptom                 Bệnh nhân có triệu chứng 'Thấp nhiệt hạ tiêu' ...
# diagnosis               Chẩn đoán Sỏi thận trái đa viên kích thước lớn...
# document/title          Phác đồ chẩn đoán và điều trị sỏi tiết niệu củ...
# document/description    Tài liệu này hướng dẫn chi tiết về các phương ...
# cme/title               Cập nhật kỹ thuật tán sỏi và phẫu thuật nội so...
# cme/description         Khóa học tập trung vào các tiến bộ trong kỹ th...
# Name: 18401, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                                              Sỏi tiết niệu
# MÃ BỆNH                                                             N20.0
# TÊN BỆNH                                                         Sỏi thận
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nội soi mềm niệu quản thận ngược dòng (RIRS) c...
# symptom                 Bệnh nhân mắc sỏi đài thận. Trong nghiên cứu s...
# diagnosis               Nội soi mềm niệu quản thận ngược dòng (RIRS) l...
# document/title          Hiệu quả điều trị sỏi đài thận bằng nội soi mề...
# document/description    Nghiên cứu đánh giá hiệu quả của phương pháp n...
# cme/title               Cập nhật kỹ thuật nội soi mềm niệu quản thận n...
# cme/description         Khóa học chuyên sâu về chỉ định, quy trình thự...
# Name: 18402, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                                              Sỏi tiết niệu
# MÃ BỆNH                                                             N20.0
# TÊN BỆNH                                                         Sỏi thận
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sau nội soi mềm niệu quản thận ngược dòng để đ...
# symptom                 Các biến chứng sau nội soi mềm niệu quản thận ...
# diagnosis               Bệnh nhân sau thủ thuật nội soi mềm niệu quản ...
# document/title          Nghiên cứu về Hiệu quả và Biến chứng của Nội s...
# document/description    Tài liệu này tổng hợp các kết quả và tỷ lệ biế...
# cme/title               Quản lý Biến chứng trong Nội soi mềm niệu quản...
# cme/description         Khóa học tập trung vào nhận diện sớm, đánh giá...
# Name: 18403, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                                              Sỏi tiết niệu
# MÃ BỆNH                                                             N20.0
# TÊN BỆNH                                                         Sỏi thận
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những nguy cơ và lưu ý đặc biệt khi thực hiện ...
# symptom                 Theo nghiên cứu của Yanke và cs (2007), bệnh n...
# diagnosis               Bệnh nhân sỏi thận có tiền sử nhiễm khuẩn đườn...
# document/title          Ảnh hưởng của Tiền sử Nhiễm khuẩn đường tiết n...
# document/description    Nghiên cứu so sánh kết quả và biến chứng của n...
# cme/title               Tiếp cận Bệnh nhân sỏi thận có tiền sử Nhiễm k...
# cme/description         Khóa học cung cấp kiến thức và chiến lược quản...
# Name: 18404, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                                              Sỏi tiết niệu
# MÃ BỆNH                                                             N20.0
# TÊN BỆNH                                                         Sỏi thận
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Cần lưu ý gì về đánh giá tim mạch khi chẩn đoá...
# symptom                 Bệnh nhân nữ 83 tuổi nhập viện vì đau vùng thắ...
# diagnosis               Chẩn đoán chính là sỏi thận (ICD-10 N20.0) và ...
# document/title          Bất sản động mạch mũ trái và động mạch vành ph...
# document/description    Bài báo khoa học đăng trên Tạp chí Y học Việt ...
# cme/title               Đánh giá nguy cơ tim mạch tiền phẫu ở bệnh nhâ...
# cme/description         Khóa học này cung cấp hướng dẫn về cách tiếp c...
# Name: 18405, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                                              Sỏi tiết niệu
# MÃ BỆNH                                                             N20.1
# TÊN BỆNH                                                    Sỏi niệu quản
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sỏi niệu quản là bệnh gì và mức độ phổ biến củ...
# symptom                 Sỏi niệu quản thường gây tắc nghẽn đường tiết ...
# diagnosis               Sỏi tiết niệu là bệnh lý hay gặp, với tỉ lệ mắ...
# document/title          Thực trạng nội soi ngược dòng tán sỏi niệu quả...
# document/description    Nghiên cứu mô tả thực trạng và các đặc điểm dị...
# cme/title               Chẩn đoán và Quản lý Bệnh Sỏi Tiết Niệu: Cập n...
# cme/description         Khóa học cung cấp kiến thức toàn diện về chẩn ...
# Name: 18406, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                                              Sỏi tiết niệu
# MÃ BỆNH                                                             N20.1
# TÊN BỆNH                                                    Sỏi niệu quản
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nội soi ngược dòng tán sỏi niệu quản 1/3 trên ...
# symptom                 Đối tượng bệnh nhân sỏi niệu quản 1/3 trên thư...
# diagnosis               Nội soi ngược dòng tán sỏi niệu quản 1/3 trên ...
# document/title          Thực trạng nội soi ngược dòng tán sỏi niệu quả...
# document/description    Báo cáo kết quả nghiên cứu cắt ngang mô tả chi...
# cme/title               Kỹ thuật Nội soi Ngược dòng Tán sỏi Niệu quản:...
# cme/description         Khóa học chuyên sâu về các bước thực hiện kỹ t...
# Name: 18407, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                                              Sỏi tiết niệu
# MÃ BỆNH                                                             N20.1
# TÊN BỆNH                                                    Sỏi niệu quản
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những ưu điểm của nội soi ngược dòng tán sỏi n...
# symptom                 Các phương pháp điều trị sỏi tiết niệu truyền ...
# diagnosis               Nội soi ngược dòng tán sỏi niệu quản 1/3 trên ...
# document/title          Thực trạng nội soi ngược dòng tán sỏi niệu quả...
# document/description    Bài báo khoa học này đánh giá hiệu quả và độ a...
# cme/title               Đổi mới trong Can thiệp Sỏi Tiết Niệu: Các Kỹ ...
# cme/description         Khóa học tập trung vào các phương pháp điều tr...
# Name: 18408, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                                              Sỏi tiết niệu
# MÃ BỆNH                                                             N20.1
# TÊN BỆNH                                                    Sỏi niệu quản
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Xin chào, tôi muốn tìm hiểu về bệnh sỏi niệu q...
# symptom                 Sỏi niệu quản là bệnh lý hay gặp trong tiết ni...
# diagnosis               Bệnh lý sỏi niệu quản 1/3 trên (Ureteral calcu...
# document/title          THỰC TRẠNG NỘI SOI NGƯỢC DÒNG TÁN SỎI NIỆU QUẢ...
# document/description    Nghiên cứu mô tả thực trạng và hiệu quả của ph...
# cme/title               Cập nhật Chẩn đoán và Điều trị Sỏi Niệu Quản: ...
# cme/description         Khóa học này tập trung vào các phương pháp chẩ...
# Name: 18409, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                                              Sỏi tiết niệu
# MÃ BỆNH                                                             N20.1
# TÊN BỆNH                                                    Sỏi niệu quản
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi muốn biết thêm chi tiết về quy trình nội s...
# symptom                 Các trường hợp sỏi niệu quản 1/3 trên thường c...
# diagnosis               Sỏi niệu quản 1/3 trên đã được chẩn đoán, có c...
# document/title          THỰC TRẠNG NỘI SOI NGƯỢC DÒNG TÁN SỎI NIỆU QUẢ...
# document/description    Bài viết này cung cấp cái nhìn chi tiết về quy...
# cme/title               Kỹ thuật Nội soi Ngược dòng Tán sỏi Niệu quản:...
# cme/description         Khóa học thực hành chuyên sâu về kỹ thuật nội ...
# Name: 18410, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                                              Sỏi tiết niệu
# MÃ BỆNH                                                             N20.1
# TÊN BỆNH                                                    Sỏi niệu quản
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sự phát triển của khoa học kỹ thuật đã thay đổ...
# symptom                 Sỏi tiết niệu là bệnh lý phổ biến, với sỏi niệ...
# diagnosis               Bệnh nhân được chẩn đoán sỏi niệu quản 1/3 trê...
# document/title          THỰC TRẠNG NỘI SOI NGƯỢC DÒNG TÁN SỎI NIỆU QUẢ...
# document/description    Bài báo này không chỉ trình bày thực trạng điề...
# cme/title               Tiến bộ Công nghệ trong Điều trị Sỏi Tiết Niệu...
# cme/description         Khóa học khám phá những đổi mới công nghệ tron...
# Name: 18411, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                                              Sỏi tiết niệu
# MÃ BỆNH                                                             N20.9
# TÊN BỆNH                                    Sỏi tiết niệu, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thực trạng kiến thức và thực hành của người bệ...
# symptom                 Các chỉ số lâm sàng liên quan đến kiến thức và...
# diagnosis               Chẩn đoán về tình trạng quản lý bệnh cho thấy:...
# document/title          Thực trạng kiến thức và thực hành về phòng tái...
# document/description    Nghiên cứu mô tả cắt ngang trên 60 người bệnh ...
# cme/title               Tư vấn và giáo dục sức khỏe toàn diện cho bệnh...
# cme/description         Khóa học dành cho nhân viên y tế nhằm nâng cao...
# Name: 18412, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                                              Sỏi tiết niệu
# MÃ BỆNH                                                             N20.9
# TÊN BỆNH                                    Sỏi tiết niệu, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thực trạng kiến thức và thực hành của bệnh nhâ...
# symptom                 Các chỉ số lâm sàng và dấu hiệu hành vi liên q...
# diagnosis               Bệnh nhân sỏi tiết niệu tại Bệnh viện Đa khoa ...
# document/title          Thực trạng kiến thức và thực hành về phòng tái...
# document/description    Nghiên cứu mô tả cắt ngang được tiến hành trên...
# cme/title               Tư vấn và giáo dục sức khỏe cho bệnh nhân sỏi ...
# cme/description         Khóa học đào tạo liên tục (CME) dành cho cán b...
# Name: 18413, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                    Các rối loạn khác của thận và niệu quản
# MÃ BỆNH                                                             N25.0
# TÊN BỆNH                                         Loạn dưỡng xương do thận
# intruction              Chatbot y khoa chuyên về nội khoa, cung cấp th...
# question                Phương pháp nào được sử dụng để đánh giá mật đ...
# symptom                 Đánh giá mật độ xương (MĐX) bằng phương pháp D...
# diagnosis               Chẩn đoán tình trạng mật độ xương (bình thường...
# document/title          Mô tả mật độ xương và một số yếu tố liên quan ...
# document/description    Nghiên cứu này đánh giá mật độ xương bằng phươ...
# cme/title               Kỹ thuật DEXA và diễn giải kết quả trong chẩn ...
# cme/description         Khóa học cung cấp kiến thức về nguyên lý, quy ...
# Name: 18414, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                    Các rối loạn khác của thận và niệu quản
# MÃ BỆNH                                                             N25.0
# TÊN BỆNH                                         Loạn dưỡng xương do thận
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những dấu hiệu cận lâm sàng nào cho thấy rối l...
# symptom                 Các dấu hiệu cận lâm sàng của rối loạn chuyển ...
# diagnosis               Bệnh nhân lọc máu chu kỳ thường mắc loạn dưỡng...
# document/title          Vai trò của β2-Microglobulin và các chỉ số sin...
# document/description    Nghiên cứu này tập trung vào việc phân tích mố...
# cme/title               Tiếp cận chẩn đoán và điều trị cường cận giáp ...
# cme/description         Khóa học này cung cấp kiến thức toàn diện về s...
# Name: 18415, dtype: object
# STT CHƯƠNG                                                            XIV
# MÃ CHƯƠNG                                                         N00-N99
# TÊN NHÓM CHÍNH                    Các rối loạn khác của thận và niệu quản
# MÃ BỆNH                                                             N25.0
# TÊN BỆNH                                         Loạn dưỡng xương do thận
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Bệnh nhân suy thận mạn lọc máu chu kỳ thường g...
# symptom                 Tỷ lệ bệnh nhân có PTH trên 300 pg/ml chiếm 58...
# diagnosis               Chẩn đoán rối loạn chuyển hóa xương và khoáng ...
# document/title          Rối Loạn Chuyển Hóa Xương và Khoáng Chất ở Bện...
# document/description    Nghiên cứu đánh giá các chỉ số cận lâm sàng qu...
# cme/title               Cập Nhật Hướng Dẫn Điều Trị Rối Loạn Chuyển Hó...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về chẩn...
# Name: 18416, dtype: object
