# %%
from datasets import load_dataset
from transformers import MT5Tokenizer, MT5ForConditionalGeneration
from tqdm import tqdm
import pandas as pd
import torch
import os

# Kiểm tra GPU
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cuda" )
print(f"💻 Đang sử dụng thiết bị: {device}")

# Load model paraphrase và đưa lên GPU
CKPT = 'chieunq/vietnamese-sentence-paraphase'
tokenizer = MT5Tokenizer.from_pretrained(CKPT)
model = MT5ForConditionalGeneration.from_pretrained(CKPT).to(device)

# Hàm tạo paraphrase
def paraphrase(text, num_return_sequences=5):
    inputs = tokenizer(text, padding='longest', max_length=512, truncation=True, return_tensors='pt')
    inputs = {key: val.to(device) for key, val in inputs.items()}
    output = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_length=512,
        num_return_sequences=num_return_sequences,
        do_sample=True,
        top_p=0.95
    )
    return [tokenizer.decode(o, skip_special_tokens=True) for o in output]

# Load dataset
dataset = pd.read_parquet("../generate_dataset/SVYKHOA_dataset_medicaltalk.parquet", engine="fastparquet")

# File Excel đầu ra
output_file = "SVYKHOA_dataset_medicaltalk.xlsx"

# Tạo file Excel rỗng nếu chưa có
if not os.path.exists(output_file):
    df_empty = pd.DataFrame(columns=["STT CHƯƠNG", "MÃ CHƯƠNG", "TÊN NHÓM CHÍNH", "MÃ BỆNH", "TÊN BỆNH", "intruction", "question", "symptom", "diagnosis", "document/title", "document/description", "cme/title", "cme/description"])
    df_empty.to_excel(output_file, index=False)

# Đọc số dòng đã có để tiếp tục từ đó
existing_df = pd.read_excel(output_file)
# start_index = len(existing_df)
start_index = 3817
print(f"🚀 Bắt đầu từ dòng {start_index}")

# Số lượng mẫu muốn xử lý thêm
max_samples = 273500-38170  # Có thể chỉnh: 10, 100, 500...

# Duyệt dataset từ start_index
for i, row in dataset.iterrows():
    if i < start_index:
        continue
    if i >= start_index + max_samples:
        break
    print(row)

    question = row["question"]   # row là Series
    try:
        paraphrases = paraphrase(question, num_return_sequences=10)
    except Exception as e:
        print(f"Lỗi paraphrase tại mẫu {i}: {e}")
        paraphrases = [question]

    new_rows = []
    for pq in paraphrases:
        new_rows.append({
            "STT CHƯƠNG": row["STT CHƯƠNG"],
            "MÃ CHƯƠNG": row["MÃ CHƯƠNG"],
            "TÊN NHÓM CHÍNH": row["TÊN NHÓM CHÍNH"],
            "MÃ BỆNH": row["MÃ BỆNH"],
            "TÊN BỆNH": row["TÊN BỆNH"],
            "intruction": row["intruction"],
            "question": pq,
            "symptom": row["symptom"],
            "diagnosis": row["diagnosis"],
            "document/title": row["document/title"],
            "document/description": row["document/description"],
            "cme/title": row["cme/title"],
            "cme/description": row["cme/description"]
        })

    new_df = pd.DataFrame(new_rows)
    with pd.ExcelWriter(output_file, mode="a", engine="openpyxl", if_sheet_exists="overlay") as writer:
        sheet = writer.sheets["Sheet1"]
        start_row = sheet.max_row
        new_df.to_excel(writer, header=False, index=False, startrow=start_row)


print("✅ Đã lưu toàn bộ dữ liệu paraphrase vào file Excel.")
# Out:
# 💻 Đang sử dụng thiết bị: cuda
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'T5Tokenizer'.
# The class this function is called from is 'MT5Tokenizer'.
# 🚀 Bắt đầu từ dòng 3817
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                So sánh hiệu quả của CHT tuyến vú quy trình rú...
# symptom                 Tổn thương tuyến vú quan sát trên CHT, được ph...
# diagnosis               Độ tương hợp giữa hai phương pháp chụp CHT tuy...
# document/title          So sánh độ tương hợp của CHT tuyến vú quy trìn...
# document/description    Nghiên cứu đánh giá mức độ tương đồng trong ph...
# cme/title               Ứng dụng CHT tuyến vú quy trình rút gọn trong ...
# cme/description         Khóa học tập trung vào các ưu điểm, hạn chế và...
# Name: 3817, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Độ nhạy và độ đặc hiệu của CHT tuyến vú quy tr...
# symptom                 Tổng số 92 tổn thương tuyến vú được đánh giá, ...
# diagnosis               Sử dụng phân loại BI-RADS 4 làm ngưỡng chẩn đo...
# document/title          Giá trị chẩn đoán của CHT tuyến vú quy trình r...
# document/description    Nghiên cứu đánh giá độ nhạy, độ đặc hiệu của C...
# cme/title               Đánh giá hiệu quả chẩn đoán của các phương phá...
# cme/description         Khóa học cung cấp cái nhìn tổng quan và chuyên...
# Name: 3818, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                CHT tuyến vú rút gọn đánh giá tính chất xâm lấ...
# symptom                 Dấu hiệu hình ảnh nghi ngờ tính chất xâm lấn h...
# diagnosis               CHT tuyến vú rút gọn thể hiện vai trò quan trọ...
# document/title          Giá trị của Chụp Cộng hưởng từ tuyến vú trong ...
# document/description    Bài viết phân tích khả năng của CHT tuyến vú, ...
# cme/title               Chẩn đoán hình ảnh ung thư vú đa ổ và xâm lấn ...
# cme/description         Khóa học tập trung vào các đặc điểm hình ảnh C...
# Name: 3819, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Cộng hưởng từ vú quy trình rút gọn (AMRI) có g...
# symptom                 Bệnh nhân có các tổn thương nghi ngờ ung thư t...
# diagnosis               Cộng hưởng từ tuyến vú với quy trình rút gọn (...
# document/title          KẾT QUẢ CHỤP CỘNG HƯỞNG TỪ THEO QUY TRÌNH RÚT ...
# document/description    Nghiên cứu được tiến hành tại Bệnh viện K từ t...
# cme/title               Cập nhật vai trò của Cộng hưởng từ vú quy trìn...
# cme/description         Khóa học tập trung vào các kỹ thuật và quy trì...
# Name: 3820, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Quy trình AMRI để chẩn đoán ung thư vú được th...
# symptom                 Bệnh nhân có tổn thương nghi ngờ ung thư tuyến...
# diagnosis               Quy trình cộng hưởng từ tuyến vú rút gọn (AMRI...
# document/title          KẾT QUẢ CHỤP CỘNG HƯỞNG TỪ THEO QUY TRÌNH RÚT ...
# document/description    Nghiên cứu đánh giá hiệu quả của AMRI trong ch...
# cme/title               Kỹ thuật và ứng dụng lâm sàng của cộng hưởng t...
# cme/description         Khóa học chuyên sâu cung cấp kiến thức về các ...
# Name: 3821, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để phân loại tổn thương tuyến vú t...
# symptom                 Bệnh nhân cần được phân loại chính xác các tổn...
# diagnosis               Khả năng phân loại tổn thương tuyến vú theo BI...
# document/title          KẾT QUẢ CHỤP CỘNG HƯỞNG TỪ THEO QUY TRÌNH RÚT ...
# document/description    Nghiên cứu này đánh giá độ tin cậy của AMRI tr...
# cme/title               Phân tích và diễn giải kết quả cộng hưởng từ t...
# cme/description         Khóa học chuyên sâu về cách phân tích, diễn gi...
# Name: 3822, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Xin cho biết về các phương pháp chẩn đoán ung ...
# symptom                 Tổn thương nghi ngờ ung thư tuyến vú trên lâm ...
# diagnosis               Các phương pháp chẩn đoán hình ảnh phổ biến để...
# document/title          Nghiên cứu so sánh hiệu quả chẩn đoán của Cộng...
# document/description    Tài liệu khoa học từ Tạp chí Y học Việt Nam, s...
# cme/title               Cập nhật các phương pháp chẩn đoán hình ảnh un...
# cme/description         Khóa học đào tạo y khoa liên tục về vai trò, ư...
# Name: 3823, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Cộng hưởng từ tuyến vú (Breast MRI) có ưu điểm...
# symptom                 Nghi ngờ ung thư tuyến vú; Phụ nữ có nguy cơ m...
# diagnosis               Cộng hưởng từ (CHT) tuyến vú là phương pháp ch...
# document/title          Đánh giá vai trò của Cộng hưởng từ tuyến vú và...
# document/description    Tài liệu tập trung vào phân tích hiệu quả của ...
# cme/title               Kỹ thuật và Ứng dụng Cộng hưởng từ tuyến vú qu...
# cme/description         Khóa học chuyên sâu về nguyên lý kỹ thuật, quy...
# Name: 3824, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Hệ thống phân loại BI-RADS là gì và nó được áp...
# symptom                 Tổn thương nghi ngờ ung thư tuyến vú trên lâm ...
# diagnosis               Hệ thống phân loại BI-RADS (Breast Imaging-Rep...
# document/title          Phân loại tổn thương vú theo BI-RADS 2013 trên...
# document/description    Nghiên cứu mô tả cắt ngang được thực hiện tại ...
# cme/title               Áp dụng hệ thống phân loại BI-RADS 2013 trong ...
# cme/description         Khóa học chuyên sâu hướng dẫn chi tiết cách đọ...
# Name: 3825, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về ung bướu, cung cấp th...
# question                Xin cho biết về độ tương hợp giữa quy trình ch...
# symptom                 Các tổn thương tuyến vú được đánh giá độc lập ...
# diagnosis               Độ tương hợp trong phân loại tổn thương tuyến ...
# document/title          So sánh khả năng phân loại tổn thương tuyến vú...
# document/description    Nghiên cứu đánh giá độ tương hợp và sự khác bi...
# cme/title               Cập nhật BI-RADS 2013 và ứng dụng MRI tuyến vú...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về hệ t...
# Name: 3826, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về ung bướu, cung cấp th...
# question                Giá trị của phân loại BI-RADS 4 trở lên trên c...
# symptom                 Các tổn thương tuyến vú được phân loại BI-RADS...
# diagnosis               Sử dụng phân loại BI-RADS 4 làm ngưỡng chẩn đo...
# document/title          Đánh giá độ nhạy và độ đặc hiệu của BI-RADS 4 ...
# document/description    Tài liệu này phân tích hiệu quả chẩn đoán của ...
# cme/title               Tối ưu hóa chẩn đoán ung thư vú bằng MRI: Hiểu...
# cme/description         Khóa học cung cấp cái nhìn sâu sắc về các chỉ ...
# Name: 3827, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về ung bướu, cung cấp th...
# question                Khả năng chẩn đoán tính chất đa ổ của ung thư ...
# symptom                 Trong số 51 trường hợp ung thư tuyến vú (UTV) ...
# diagnosis               CHT với quy trình rút gọn cho thấy khả năng ch...
# document/title          So sánh hiệu quả chẩn đoán ung thư vú đa ổ bằn...
# document/description    Tài liệu này tập trung vào khả năng của cộng h...
# cme/title               Chẩn đoán và quản lý ung thư vú đa ổ: Vai trò ...
# cme/description         Khóa học này khám phá các thách thức và phương...
# Name: 3828, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Cộng hưởng từ tuyến vú rút gọn có vai trò gì t...
# symptom                 Tổn thương vú đã được chẩn đoán hoặc nghi ngờ ...
# diagnosis               CHT tuyến vú, kể cả quy trình rút gọn, thể hiệ...
# document/title          Abbreviated Breast MRI for Estimating Extent o...
# document/description    Nghiên cứu của Lee-Felker S. và cộng sự năm 20...
# cme/title               Đánh giá mức độ lan rộng và tính chất đa ổ của...
# cme/description         Khóa học tập trung vào việc ứng dụng CHT trong...
# Name: 3829, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Cung nách có ý nghĩa lâm sàng như thế nào tron...
# symptom                 Bệnh nhân ung thư vú trước khi phẫu thuật có t...
# diagnosis               Cung nách là một biến thể giải phẫu quan trọng...
# document/title          Cung nách và mối tương quan với tình trạng phâ...
# document/description    Nghiên cứu mô tả tần suất và hình thái của cun...
# cme/title               Giải phẫu phẫu thuật vùng nách và chiến lược n...
# cme/description         Khóa học chuyên sâu về giải phẫu vùng nách, cá...
# Name: 3830, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tần suất và hình thái thường gặp của cung nách...
# symptom                 Bệnh nhân ung thư vú (UTV) chuẩn bị hoặc đã tr...
# diagnosis               Phát hiện cung nách là một biến thể giải phẫu ...
# document/title          Cung nách và mối tương quan với tình trạng phâ...
# document/description    Nghiên cứu mô tả cắt ngang về tần suất (11.9%)...
# cme/title               Giải phẫu phẫu thuật vùng nách trong ung thư v...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về giải...
# Name: 3831, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Cung nách ảnh hưởng như thế nào đến việc vét h...
# symptom                 Bệnh nhân ung thư vú (UTV) undergoing phẫu thu...
# diagnosis               Đánh giá nguy cơ che lấp hạch nách và yêu cầu ...
# document/title          Cung nách và mối tương quan với tình trạng phâ...
# document/description    Bài báo phân tích mối tương quan giữa cung nác...
# cme/title               Kỹ thuật vét hạch nách tối ưu khi có cung nách...
# cme/description         Khóa học tập trung vào các kỹ thuật phẫu thuật...
# Name: 3832, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thực trạng nhu cầu hỗ trợ chăm sóc của người b...
# symptom                 Người bệnh ung thư vú có độ tuổi trung bình là...
# diagnosis               Nghiên cứu mô tả về đặc điểm lâm sàng và điều ...
# document/title          Thực trạng nhu cầu hỗ trợ chăm sóc người bệnh ...
# document/description    Nghiên cứu mô tả cắt ngang này khảo sát các đặ...
# cme/title               Chăm sóc toàn diện cho người bệnh ung thư vú: ...
# cme/description         Khóa học cung cấp kiến thức cập nhật về quản l...
# Name: 3833, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các đặc điểm lâm sàng, phác đồ điều trị phổ bi...
# symptom                 Người bệnh ung thư vú thường biểu hiện khối u ...
# diagnosis               Chẩn đoán ung thư vú dựa trên các biểu hiện lâ...
# document/title          Thực trạng nhu cầu hỗ trợ chăm sóc người bệnh ...
# document/description    Nghiên cứu mô tả đặc điểm lâm sàng và điều trị...
# cme/title               Quản lý chăm sóc toàn diện và hỗ trợ tâm lý ch...
# cme/description         Khóa học đào tạo liên tục nhằm nâng cao năng l...
# Name: 3834, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Xin chào chatbot, bạn có thể giải thích về các...
# symptom                 Các đặc điểm phân tử của khối u vú, bao gồm sự...
# diagnosis               Chẩn đoán ung thư vú dựa trên các phân nhóm ph...
# document/title          Molecular Subtypes of Breast Cancer and Tamoxi...
# document/description    Tập hợp các nghiên cứu về các phân nhóm phân t...
# cme/title               Cập nhật Phân loại Phân tử Ung thư Vú và Chiến...
# cme/description         Khóa học này sẽ đi sâu vào các phân loại phân ...
# Name: 3835, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa, cung cấp thông tin và tư vấn l...
# question                Các phân loại phân tử của ung thư vú là gì và ...
# symptom                 Mặc dù tài liệu không nêu cụ thể triệu chứng l...
# diagnosis               Chẩn đoán ung thư vú được xác định thông qua s...
# document/title          Phân loại phân tử và đặc điểm lâm sàng của ung...
# document/description    Nghiên cứu tổng quan về các phân loại phân tử ...
# cme/title               Cập nhật chẩn đoán và điều trị ung thư vú theo...
# cme/description         Khóa học cung cấp kiến thức mới nhất về cách p...
# Name: 3836, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về ung bướu, cung cấp th...
# question                Xin hỏi về đặc điểm mô hóa miễn dịch và phân b...
# symptom                 Dựa trên kết quả nghiên cứu: Tỷ lệ dương tính ...
# diagnosis               Ung thư biểu mô tuyến vú thể xâm nhập (UTBMTTX...
# document/title          Nghiên cứu đặc điểm miễn dịch hóa mô và phân l...
# document/description    Bài báo khoa học trình bày kết quả nghiên cứu ...
# cme/title               Phân loại phân tử ung thư vú và ý nghĩa trong ...
# cme/description         Khóa học này tập trung vào các phương pháp phâ...
# Name: 3837, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về ung bướu, cung cấp th...
# question                Các nghiên cứu khác trên thế giới đã ghi nhận ...
# symptom                 Các kết quả nghiên cứu so sánh về tỷ lệ phân b...
# diagnosis               Phân bố các dưới tuýp phân tử của ung thư biểu...
# document/title          Tổng quan các nghiên cứu về tỷ lệ phân bố dưới...
# document/description    Tài liệu này tổng hợp dữ liệu từ nhiều nghiên ...
# cme/title               Tiến bộ trong phân loại ung thư vú và quản lý ...
# cme/description         Khóa học cung cấp cái nhìn tổng thể về tiến bộ...
# Name: 3838, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Mối liên quan giữa chất lượng giấc ngủ và bệnh...
# symptom                 Bệnh nhân ung thư vú có thể trải qua các rối l...
# diagnosis               Rối loạn giấc ngủ ở bệnh nhân ung thư vú (Slee...
# document/title          Chất lượng giấc ngủ và các yếu tố liên quan ở ...
# document/description    Nghiên cứu đánh giá chất lượng giấc ngủ và các...
# cme/title                   Quản lý rối loạn giấc ngủ ở bệnh nhân ung thư
# cme/description         Khóa học tập trung vào chẩn đoán, đánh giá và ...
# Name: 3839, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về ung thư vú, cung cấp ...
# question                Phác đồ hóa trị bổ trợ Docetaxel – Carboplatin...
# symptom                 Bệnh nhân ung thư vú (C50.9) giai đoạn I-II-II...
# diagnosis               Chẩn đoán ung thư vú (C50.9) giai đoạn I-II-II...
# document/title          Kết quả hóa trị bổ trợ phác đồ Docetaxel – Car...
# document/description    Nghiên cứu mô tả cắt ngang hồi cứu kết hợp tiế...
# cme/title               Quản lý và điều trị ung thư vú HER2 dương tính...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về chẩn...
# Name: 3840, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về ung bướu, cung cấp th...
# question                Phác đồ hóa trị bổ trợ Docetaxel – Carboplatin...
# symptom                 Bệnh nhân được chẩn đoán ung thư vú có HER2/ne...
# diagnosis               Phác đồ hóa trị bổ trợ Docetaxel – Carboplatin...
# document/title          KẾT QUẢ HÓA TRỊ BỔ TRỢ PHÁC ĐỒ DOCETAXEL – CAR...
# document/description    Nghiên cứu mô tả cắt ngang hồi cứu kết hợp tiế...
# cme/title               Quản lý và điều trị ung thư vú HER2/neu dương ...
# cme/description         Khóa học này tập trung vào các chiến lược chẩn...
# Name: 3841, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về ung bướu, cung cấp th...
# question                Những tác dụng phụ nào thường gặp và mức độ ng...
# symptom                 Bệnh nhân ung thư vú có HER2/neu dương tính (C...
# diagnosis               Các tác dụng phụ huyết học là phổ biến trong p...
# document/title          KẾT QUẢ HÓA TRỊ BỔ TRỢ PHÁC ĐỒ DOCETAXEL – CAR...
# document/description    Bài báo nghiên cứu này cung cấp thông tin chi ...
# cme/title               Quản lý và phòng ngừa tác dụng phụ của hóa trị...
# cme/description         Khóa học này tập trung vào chiến lược toàn diệ...
# Name: 3842, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Phác đồ hóa trị bổ trợ Docetaxel-Carboplatin-T...
# symptom                 Bệnh nhân đã được chẩn đoán ung thư vú có tình...
# diagnosis               Ung thư vú xâm lấn có thụ thể Her2/neu dương t...
# document/title          Adjuvant Trastuzumab in HER2-Positive Breast C...
# document/description    Nghiên cứu lâm sàng được trích dẫn của Slamon ...
# cme/title               Cập nhật các phác đồ điều trị bổ trợ cho ung t...
# cme/description         Khóa học đào tạo y khoa liên tục này cung cấp ...
# Name: 3843, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Phác đồ hóa trị bổ trợ Docetaxel – Carboplatin...
# symptom                 Bệnh nhân ung thư vú đã được chẩn đoán, có kết...
# diagnosis               Ung thư vú HER2/neu dương tính (ICD-10: C50.9)...
# document/title          Hóa trị bổ trợ phác đồ Docetaxel – Carboplatin...
# document/description    Nghiên cứu đánh giá hiệu quả và độ an toàn của...
# cme/title               Cập nhật Phác đồ điều trị bổ trợ ung thư vú HE...
# cme/description         Khóa học tập trung vào các phác đồ hóa trị bổ ...
# Name: 3844, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Cơ chế hoạt động của Trastuzumab trong điều tr...
# symptom                 Bệnh nhân ung thư vú có thụ thể HER2/neu dương...
# diagnosis               Ung thư vú HER2/neu dương tính (ICD-10: C50.9)...
# document/title          Cơ chế hoạt động và biến chứng của Trastuzumab...
# document/description    Tài liệu này tổng hợp thông tin về cơ chế tác ...
# cme/title               Quản lý độc tính tim mạch trong điều trị ung t...
# cme/description         Khóa học đào tạo liên tục về nhận diện, đánh g...
# Name: 3845, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Một phụ nữ 55 tuổi sờ thấy khối u ở vú trái, k...
# symptom                 Khối u cứng chắc ở 1/4 trên ngoài vú trái, ran...
# diagnosis               Chẩn đoán ban đầu nghi ngờ: U ác tính vú (Mali...
# document/title          Hướng dẫn chẩn đoán, điều trị và dự phòng Ung ...
# document/description    Tập hợp các khuyến nghị lâm sàng về tầm soát, ...
# cme/title               Quản lý đa phương thức Ung thư vú: Từ chẩn đoá...
# cme/description         Khóa học này cung cấp kiến thức toàn diện về t...
# Name: 3846, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Việc chi phí thuốc phóng xạ tăng tại Bệnh viện...
# symptom                 Xuất hiện khối u cứng, không di động, không đa...
# diagnosis               U ác của vú (C50.9), được chẩn đoán xác định q...
# document/title          Phân tích xu hướng sử dụng thuốc Bảo hiểm Y tế...
# document/description    Nghiên cứu đã ghi nhận sự tăng chi phí thuốc p...
# cme/title               Vai trò của y học hạt nhân trong chẩn đoán và ...
# cme/description         Khóa học tập trung vào các ứng dụng của thuốc ...
# Name: 3847, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để phòng ngừa và phát hiện sớm ung...
# symptom                 Các dấu hiệu cần chú ý cho phát hiện sớm ung t...
# diagnosis               Dựa trên kết quả nghiên cứu, phụ nữ 18-60 tuổi...
# document/title          NGHIÊN CỨU KIẾN THỨC, THỰC HÀNH VỀ PHÒNG VÀ PH...
# document/description    Nghiên cứu mô tả cắt ngang trên 286 phụ nữ tại...
# cme/title               Nâng cao kiến thức và thực hành về tầm soát, p...
# cme/description         Khóa học tập trung vào các phương pháp giáo dụ...
# Name: 3848, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Người dùng cần biết về các yếu tố nguy cơ của ...
# symptom                 Theo nghiên cứu, chỉ 19,6% phụ nữ có kiến thức...
# diagnosis               Mức độ nhận thức về các yếu tố nguy cơ ung thư...
# document/title               Vietnam Medical Journal n01 - JANUARY - 2021
# document/description    Nghiên cứu về kiến thức và thực hành phát hiện...
# cme/title               Nâng cao nhận thức cộng đồng về các yếu tố ngu...
# cme/description         Khóa học cung cấp kiến thức cập nhật về các yế...
# Name: 3849, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để phát hiện sớm ung thư vú hiệu q...
# symptom                 Các bất thường ở vú (khối u, thay đổi cấu trúc...
# diagnosis               Phát hiện sớm ung thư vú (UTV) thông qua chụp ...
# document/title          Nghiên cứu kiến thức, thực hành phòng và phát ...
# document/description    Tài liệu này tổng hợp kết quả nghiên cứu về th...
# cme/title               Cập nhật các phương pháp sàng lọc và chẩn đoán...
# cme/description         Khóa học dành cho cán bộ y tế, cung cấp kiến t...
# Name: 3850, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những đặc điểm lâm sàng và cận lâm sàng nổi bậ...
# symptom                 Đối tượng nghiên cứu là phụ nữ ≤40 tuổi (tuổi ...
# diagnosis               Ung thư vú ở phụ nữ trẻ thường được chẩn đoán ...
# document/title          ĐÁNH GIÁ KẾT QUẢ ĐIỀU TRỊ UNG THƯ VÚ Ở PHỤ NỮ ...
# document/description    Nghiên cứu mô tả và phân tích các đặc điểm lâm...
# cme/title               Chẩn đoán và phân loại phân tử ung thư vú ở bệ...
# cme/description         Khóa học cập nhật kiến thức về các phương pháp...
# Name: 3851, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các phương pháp điều trị ung thư vú ở phụ nữ t...
# symptom                 Bệnh nhân được chẩn đoán ung thư vú, độ tuổi t...
# diagnosis               Điều trị ung thư vú ở phụ nữ trẻ là đa mô thức...
# document/title          ĐÁNH GIÁ KẾT QUẢ ĐIỀU TRỊ UNG THƯ VÚ Ở PHỤ NỮ ...
# document/description    Bài báo cung cấp thông tin về các phương pháp ...
# cme/title               Cập nhật phác đồ điều trị ung thư vú đa mô thứ...
# cme/description         Khóa học tập trung vào các phác đồ điều trị hi...
# Name: 3852, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tiên lượng và các chỉ số sống thêm của ung thư...
# symptom                 Sau quá trình điều trị đa mô thức (phẫu thuật,...
# diagnosis               Kết quả điều trị ung thư vú ở phụ nữ trẻ tại B...
# document/title          ĐÁNH GIÁ KẾT QUẢ ĐIỀU TRỊ UNG THƯ VÚ Ở PHỤ NỮ ...
# document/description    Bài báo trình bày chi tiết các chỉ số tiên lượ...
# cme/title               Các yếu tố tiên lượng và quản lý tái phát tron...
# cme/description         Khóa học đi sâu vào các yếu tố ảnh hưởng đến t...
# Name: 3853, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Ung thư vú ở phụ nữ trẻ có những đặc điểm lâm ...
# symptom                 Các đặc điểm lâm sàng và cận lâm sàng được ghi...
# diagnosis               Chẩn đoán ung thư vú ở phụ nữ trẻ (≤40 tuổi) t...
# document/title          ĐÁNH GIÁ KẾT QUẢ ĐIỀU TRỊ UNG THƯ VÚ Ở PHỤ NỮ ...
# document/description    Nghiên cứu mô tả phân tích trên 84 bệnh nhân u...
# cme/title               Cập nhật chẩn đoán và quản lý ung thư vú ở phụ...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về các ...
# Name: 3854, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các phương pháp điều trị ung thư vú ở phụ nữ t...
# symptom                 Bệnh nhân ung thư vú trẻ tuổi (≤40 tuổi), tuổi...
# diagnosis               Ung thư vú ở phụ nữ trẻ (≤40 tuổi) được điều t...
# document/title          ĐÁNH GIÁ KẾT QUẢ ĐIỀU TRỊ UNG THƯ VÚ Ở PHỤ NỮ ...
# document/description    Bài báo nghiên cứu về các phương pháp điều trị...
# cme/title               Tiếp cận đa ngành trong điều trị ung thư vú: P...
# cme/description         Khóa học này khám phá các nguyên tắc và thực h...
# Name: 3855, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tiên lượng và tỷ lệ tái phát ung thư vú ở phụ ...
# symptom                 Các đặc điểm liên quan đến tiên lượng của ung ...
# diagnosis               Tiên lượng của ung thư vú ở phụ nữ trẻ (≤40 tu...
# document/title          ĐÁNH GIÁ KẾT QUẢ ĐIỀU TRỊ UNG THƯ VÚ Ở PHỤ NỮ ...
# document/description    Nghiên cứu tập trung vào các kết quả sống còn ...
# cme/title               Quản lý theo dõi và xử trí tái phát trong ung ...
# cme/description         Khóa học đào tạo chuyên sâu về các chiến lược ...
# Name: 3856, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Bác sĩ cho tôi hỏi, điều trị ung thư vú có thể...
# symptom                 Tiền sử ung thư vú, đã điều trị bằng hóa trị l...
# diagnosis               Bệnh bạch cầu cấp dòng tủy (AML) là một biến c...
# document/title          Biến chứng bạch cầu cấp dòng tủy sau hóa trị l...
# document/description    Nghiên cứu về tỷ lệ mắc và các yếu tố nguy cơ ...
# cme/title               Quản lý biến chứng huyết học trong điều trị un...
# cme/description         Khóa học nhằm trang bị kiến thức về nhận diện ...
# Name: 3857, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các phương pháp điều trị ung thư vú là gì và n...
# symptom                 Các triệu chứng của ung thư vú có thể bao gồm ...
# diagnosis               **Ung thư vú:** Đây là một loại ung thư thể đặ...
# document/title          Hóa trị liệu ung thư vú và nguy cơ phát triển ...
# document/description    Tài liệu này đánh giá các phương pháp điều trị...
# cme/title               Quản lý tác dụng phụ và biến chứng huyết học c...
# cme/description         Khóa học này cung cấp kiến thức và kỹ năng cần...
# Name: 3858, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nhân tố phiên mã NF-κB p65 là gì và nó liên qu...
# symptom                 Dấu hiệu lâm sàng của ung thư vú: Sờ thấy khối...
# diagnosis               Chẩn đoán ung thư vú (ví dụ: carcinoma ống xâm...
# document/title          Vai trò của nhân tố phiên mã NF-κB p65 trong u...
# document/description    Tài liệu này tổng quan về chức năng sinh học c...
# cme/title               Cập nhật kiến thức về con đường tín hiệu NF-κB...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về cấu ...
# Name: 3859, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Yếu tố phiên mã NF-κB p65 có vai trò gì trong ...
# symptom                 Đoạn văn không cung cấp các triệu chứng lâm sà...
# diagnosis               Đoạn văn mô tả việc tạo ra protein NF-κB p65 t...
# document/title          Biểu hiện và tinh sạch protein NF-κB p65 tái t...
# document/description    Nghiên cứu tập trung vào việc sản xuất lượng l...
# cme/title               Cập nhật vai trò của NF-κB trong sinh bệnh học...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về cơ c...
# Name: 3860, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Mối liên hệ giữa NF-κB p65 và ung thư vú là gì...
# symptom                 Các triệu chứng lâm sàng điển hình của ung thư...
# diagnosis               Chẩn đoán xác định ung thư vú được thực hiện t...
# document/title          Vai trò của NF-κB trong ung thư vú và các chiế...
# document/description    Tài liệu này tổng quan về các nghiên cứu đã ch...
# cme/title               Quản lý và Điều trị Ung thư Vú: Từ chẩn đoán đ...
# cme/description         Khóa học CME này bao gồm các chủ đề từ chẩn đo...
# Name: 3861, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Hiệu quả của phác đồ hóa trị dựa trên platin đ...
# symptom                 Các chỉ số hiệu quả điều trị của phác đồ hóa t...
# diagnosis               Đánh giá hiệu quả điều trị Ung thư vú bộ ba âm...
# document/title          Bàn luận về hiệu quả điều trị Ung thư vú bộ ba...
# document/description    Phân tích và so sánh các kết quả về tỷ lệ đáp ...
# cme/title               Cập nhật Phác đồ Hóa trị liệu Ung thư vú Bộ ba...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về các ...
# Name: 3862, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các độc tính thường gặp của phác đồ hóa trị li...
# symptom                 Các độc tính thường gặp của phác đồ hóa trị li...
# diagnosis               Độc tính của phác đồ hóa trị liệu dựa trên pla...
# document/title          Đánh giá Độc tính của Phác đồ Hóa chất dựa trê...
# document/description    Nghiên cứu đánh giá các tác dụng phụ và độc tí...
# cme/title                 Quản lý Độc tính trong Hóa trị liệu Ung thư Vú.
# cme/description         Khóa học tập trung vào nhận diện, đánh giá và ...
# Name: 3863, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Xin hỏi về hiệu quả điều trị của phác đồ hóa t...
# symptom                 Bệnh nhân được chẩn đoán ung thư vú bộ ba âm t...
# diagnosis               Chẩn đoán xác định: Ung thư vú bộ ba âm tính (...
# document/title          Hiệu quả của hóa trị dựa trên platin trong điề...
# document/description    Nghiên cứu về tỉ lệ đáp ứng và thời gian sống ...
# cme/title               Cập nhật phác đồ điều trị ung thư vú bộ ba âm ...
# cme/description         Khóa học đào tạo y khoa liên tục về các chiến ...
# Name: 3864, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# ...
# cme/title               Liệu pháp miễn dịch trong điều trị ung thư: Từ...
# cme/description         Khóa học cung cấp kiến thức toàn diện về cơ ch...
# Name: 3865, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với trường hợp ung thư vú tái phát di căn da đ...
# symptom                 Bệnh nhân được chẩn đoán ung thư vú tái phát d...
# diagnosis               Bệnh nhân được điều trị hóa chất phối hợp liệu...
# document/title          Hướng dẫn điều trị ung thư vú di căn ba âm tín...
# document/description    Tài liệu cung cấp các khuyến nghị về phác đồ đ...
# cme/title               Quản lý ung thư vú di căn ba âm tính: Chiến lư...
# cme/description         Khóa học tập trung vào các chiến lược điều trị...
# Name: 3866, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để phân biệt di căn da từ ung thư ...
# symptom                 Các tổn thương da đầu có thể biểu hiện dưới dạ...
# diagnosis               Để chẩn đoán phân biệt di căn da từ ung thư vú...
# document/title          Vai trò của hóa mô miễn dịch trong chẩn đoán p...
# document/description    Nghiên cứu này tổng hợp các dấu ấn hóa mô miễn...
# cme/title               Cập nhật ứng dụng hóa mô miễn dịch trong chẩn ...
# cme/description         Khóa học dành cho các bác sĩ giải phẫu bệnh và...
# Name: 3867, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Đặc điểm lâm sàng, cận lâm sàng và phương pháp...
# symptom                 Một trường hợp điển hình là bệnh nhân nữ 49 tu...
# diagnosis               Ung thư vú (ICD-10: C50.9) đã di căn xa, đặc b...
# document/title          Báo cáo ca lâm sàng: Ung thư vú di căn da đầu ...
# document/description    Tài liệu này trình bày một ca bệnh hiếm gặp về...
# cme/title               Cập nhật chẩn đoán và quản lý ung thư vú di că...
# cme/description         Khóa học CME chuyên sâu về các tiến bộ trong c...
# Name: 3868, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để chẩn đoán chính xác ung thư vú ...
# symptom                 Bệnh nhân nữ, 49 tuổi, có tiền sử tăng huyết á...
# diagnosis               Chẩn đoán ung thư vú tái phát di căn da đầu, h...
# document/title          Đặc điểm lâm sàng, chẩn đoán và điều trị ung t...
# document/description    Tài liệu này cung cấp một báo cáo ca lâm sàng ...
# cme/title               Tiếp cận chẩn đoán đa phương thức trong ung th...
# cme/description         Khóa học này tập trung vào các phương pháp chẩ...
# Name: 3869, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Phác đồ điều trị ung thư vú di căn da đầu và c...
# symptom                 Bệnh nhân nữ, 49 tuổi, có tiền sử ung thư vú p...
# diagnosis               Chẩn đoán ung thư vú tái phát di căn đa vị trí...
# document/title          Hiệu quả và thách thức trong điều trị ung thư ...
# document/description    Tài liệu này phân tích hiệu quả của các phác đ...
# cme/title               Quản lý điều trị ung thư vú di căn kháng thuốc...
# cme/description         Khóa học này cung cấp kiến thức cập nhật về cá...
# Name: 3870, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Ung thư vú di căn da đầu có tiên lượng như thế...
# symptom                 Bệnh nhân nữ, 49 tuổi, có tiền sử ung thư vú p...
# diagnosis               Chẩn đoán ung thư vú tái phát di căn đa vị trí...
# document/title          Tiên lượng và các yếu tố ảnh hưởng trong ung t...
# document/description    Bài viết thảo luận về tiên lượng của ung thư v...
# cme/title               Đánh giá tiên lượng và lập kế hoạch chăm sóc g...
# cme/description         Khóa học này cung cấp kiến thức chuyên sâu về ...
# Name: 3871, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Ung thư vú thể dị sản có những đặc điểm lâm sà...
# symptom                 Các dấu hiệu và đặc điểm lâm sàng, cận lâm sàn...
# diagnosis               Ung thư vú thể dị sản thường được chẩn đoán kh...
# document/title          ĐẶC ĐIỂM LÂM SÀNG VÀ CẬN LÂM SÀNG CỦA BỆNH NHÂ...
# document/description    Nghiên cứu mô tả hồi cứu kết hợp tiến cứu trên...
# cme/title               Cập nhật chẩn đoán và quản lý ung thư vú thể d...
# cme/description         Khóa học đào tạo y khoa liên tục này cung cấp ...
# Name: 3872, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Đặc điểm lâm sàng và cận lâm sàng của ung thư ...
# symptom                 Bệnh nhân thường có khối u vú kích thước lớn (...
# diagnosis               Ung thư vú thể dị sản (Metaplastic Breast Canc...
# document/title          ĐẶC ĐIỂM LÂM SÀNG VÀ CẬN LÂM SÀNG CỦA BỆNH NHÂ...
# document/description    Nghiên cứu mô tả hồi cứu kết hợp tiến cứu trên...
# cme/title               Cập nhật chẩn đoán và quản lý ung thư vú thể d...
# cme/description         Khóa học này cung cấp kiến thức chuyên sâu về ...
# Name: 3873, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Phân loại hóa mô miễn dịch có ý nghĩa như thế ...
# symptom                 Bệnh nhân ung thư vú thể dị sản thường được ph...
# diagnosis               Phân loại hóa mô miễn dịch là yếu tố quan trọn...
# document/title          ĐẶC ĐIỂM LÂM SÀNG VÀ CẬN LÂM SÀNG CỦA BỆNH NHÂ...
# document/description    Nghiên cứu này tập trung vào phân tích các đặc...
# cme/title               Tiếp cận điều trị ung thư vú bộ ba âm tính thể...
# cme/description         Khóa học này đi sâu vào các phác đồ điều trị đ...
# Name: 3874, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C50.9
# TÊN BỆNH                                       U ác của vú không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những khó khăn trong chẩn đoán hình ảnh ung th...
# symptom                 Bệnh nhân có khối u vú kích thước lớn (trung b...
# diagnosis               Chẩn đoán ung thư vú thể dị sản qua hình ảnh g...
# document/title          ĐẶC ĐIỂM LÂM SÀNG VÀ CẬN LÂM SÀNG CỦA BỆNH NHÂ...
# document/description    Bài nghiên cứu này chỉ ra những hạn chế và khó...
# cme/title               Chẩn đoán hình ảnh tiên tiến và vai trò của si...
# cme/description         Khóa học cung cấp kiến thức về cách nhận diện ...
# Name: 3875, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                               C53
# TÊN BỆNH                                              U ác của cổ tử cung
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Ung thư cổ tử cung là gì, các type HPV nguy cơ...
# symptom                 Giai đoạn đầu thường không có triệu chứng rõ r...
# diagnosis               Ung thư cổ tử cung là một khối u ác tính phát ...
# document/title          Tỉ Lệ Nhiễm HPV Nguy Cơ Cao Và Mối Liên Quan V...
# document/description    Nghiên cứu mô tả cắt ngang nhằm đánh giá tỉ lệ...
# cme/title               Cập nhật chẩn đoán và quản lý nhiễm HPV, sàng ...
# cme/description         Khóa học CME trang bị kiến thức mới nhất về dị...
# Name: 3876, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                               C53
# TÊN BỆNH                                              U ác của cổ tử cung
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Phác đồ điều trị ung thư cổ tử cung nào được n...
# symptom                 Bệnh nhân có chẩn đoán xác định ung thư cổ tử ...
# diagnosis               Chẩn đoán xác định ung thư cổ tử cung. Phương ...
# document/title          Đánh giá hiệu quả điều trị ung thư cổ tử cung ...
# document/description    Bài báo nghiên cứu can thiệp lâm sàng không nh...
# cme/title               Cập nhật Phác đồ Xạ trị Điều biến Liều (VMAT) ...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về kỹ t...
# Name: 3877, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                               C53
# TÊN BỆNH                                              U ác của cổ tử cung
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Chi tiết về liều lượng và kỹ thuật xạ trị ngoà...
# symptom                 Bệnh nhân đã có chẩn đoán xác định ung thư cổ ...
# diagnosis               Dựa trên chẩn đoán ung thư cổ tử cung và kết q...
# document/title          Tạp chí Y học Việt Nam - Tập 523, Số 1, Tháng ...
# document/description    Đây là một số của Tạp chí Y học Việt Nam, xuất...
# cme/title               Thực hành Lập kế hoạch Xạ trị Áp sát 3D và Xạ ...
# cme/description         Khóa học chuyên sâu về quy trình mô phỏng, lập...
# Name: 3878, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                               C53
# TÊN BỆNH                                              U ác của cổ tử cung
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tiêu chuẩn đánh giá kết quả và tác dụng phụ củ...
# symptom                 Sau khi kết thúc điều trị xạ trị kết hợp hóa c...
# diagnosis               Kết quả điều trị được đánh giá tại thời điểm 3...
# document/title          Nghiên cứu Đáp ứng và Tác dụng Phụ của Xạ trị-...
# document/description    Bài viết phân tích kết quả điều trị về tỷ lệ đ...
# cme/title               Phương pháp Đánh giá Đáp ứng và Quản lý Tác dụ...
# cme/description         Khóa học tập trung vào các tiêu chuẩn đánh giá...
# Name: 3879, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                               C53
# TÊN BỆNH                                              U ác của cổ tử cung
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi muốn tìm hiểu về chẩn đoán và phác đồ điều...
# symptom                 Các dấu hiệu lâm sàng và cận lâm sàng bao gồm ...
# diagnosis               Chẩn đoán xác định ung thư cổ tử cung dựa trên...
# document/title              Tạp chí Y học Việt Nam, Tập 523 - Số 1 - 2023
# document/description    Nghiên cứu can thiệp lâm sàng không nhóm chứng...
# cme/title               Cập nhật Phác đồ điều trị Ung thư Cổ tử cung: ...
# cme/description         Khóa học CME cung cấp kiến thức chuyên sâu về ...
# Name: 3880, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                               C53
# TÊN BỆNH                                              U ác của cổ tử cung
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi muốn biết về hiệu quả điều trị và các chỉ ...
# symptom                 Các chỉ số điều trị bao gồm liều xạ tại PTV45 ...
# diagnosis               Bệnh nhân ung thư cổ tử cung được điều trị bằn...
# document/title              Tạp chí Y học Việt Nam, Tập 523 - Số 1 - 2023
# document/description    Báo cáo kết quả nghiên cứu lâm sàng về hiệu qu...
# cme/title               Đánh giá Hiệu quả và Đáp ứng Điều trị Ung thư ...
# cme/description         Khóa học tập trung vào các tiêu chuẩn đánh giá...
# Name: 3881, dtype: object
