# %%
from datasets import load_dataset
from transformers import MT5Tokenizer, MT5ForConditionalGeneration
from tqdm import tqdm
import pandas as pd
import torch
import os

# Kiểm tra GPU
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cuda" )
print(f"💻 Đang sử dụng thiết bị: {device}")

# Load model paraphrase và đưa lên GPU
CKPT = 'chieunq/vietnamese-sentence-paraphase'
tokenizer = MT5Tokenizer.from_pretrained(CKPT)
model = MT5ForConditionalGeneration.from_pretrained(CKPT).to(device)

# Hàm tạo paraphrase
def paraphrase(text, num_return_sequences=5):
    inputs = tokenizer(text, padding='longest', max_length=512, truncation=True, return_tensors='pt')
    inputs = {key: val.to(device) for key, val in inputs.items()}
    output = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_length=512,
        num_return_sequences=num_return_sequences,
        do_sample=True,
        top_p=0.95
    )
    return [tokenizer.decode(o, skip_special_tokens=True) for o in output]

# Load dataset
dataset = pd.read_parquet("../generate_dataset/SVYKHOA_dataset_guide.parquet", engine="fastparquet")

# File Excel đầu ra
output_file = "SVYKHOA_dataset_guide_0.xlsx"

# Tạo file Excel rỗng nếu chưa có
if not os.path.exists(output_file):
    df_empty = pd.DataFrame(columns=["intruction", "question", "answer","document/title","document/description","cme/title","cme/description"])
    df_empty.to_excel(output_file, index=False)

# Đọc số dòng đã có để tiếp tục từ đó
existing_df = pd.read_excel(output_file)
# start_index = len(existing_df)
start_index = 0
print(f"🚀 Bắt đầu từ dòng {start_index}")

# Số lượng mẫu muốn xử lý thêm
max_samples = 139490  # Có thể chỉnh: 10, 100, 500...

# Duyệt dataset từ start_index
for i, row in dataset.iterrows():
    if i < start_index:
        continue
    if i >= start_index + max_samples:
        break
    print(row)

    question = row["question"]   # row là Series
    try:
        paraphrases = paraphrase(question, num_return_sequences=15)
    except Exception as e:
        print(f"Lỗi paraphrase tại mẫu {i}: {e}")
        paraphrases = [question]

    new_rows = []
    for pq in paraphrases:
        new_rows.append({
            "intruction": row["intruction"],
            "question": pq,
            "answer": row["answer"],
            "document/title": row["document/title"],
            "document/description": row["document/description"],
            "cme/title": row["cme/title"],
            "cme/description": row["cme/description"],
        })

    new_df = pd.DataFrame(new_rows)
    with pd.ExcelWriter(output_file, mode="a", engine="openpyxl", if_sheet_exists="overlay") as writer:
        sheet = writer.sheets["Sheet1"]
        start_row = sheet.max_row
        new_df.to_excel(writer, header=False, index=False, startrow=start_row)


print("✅ Đã lưu toàn bộ dữ liệu paraphrase vào file Excel.")
# Out:
# 💻 Đang sử dụng thiết bị: cuda
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'T5Tokenizer'.
# The class this function is called from is 'MT5Tokenizer'.
# You are using the default legacy behaviour of the <class 'transformers.models.mt5.tokenization_mt5.MT5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# 🚀 Bắt đầu từ dòng 0
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa bác sĩ, làm thế nào để chẩn đoán chính xá...
# answer                  Chào bạn, một sinh viên y khoa! Việc chẩn đoán...
# document/title          Hướng dẫn chẩn đoán và điều trị tiểu không tự ...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Cập nhật chẩn đoán và điều trị phẫu thuật TOT ...
# cme/description         Khóa học này bao gồm các kỹ thuật chẩn đoán nâ...
# Name: 0, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp kiến...
# question                Ngoài các triệu chứng lâm sàng, tiểu không tự ...
# answer                  Chào bạn, một bác sĩ trẻ có tâm! Câu hỏi của b...
# document/title          Tâm lý bệnh nhân và tư vấn trong thực hành sản...
# document/description    Cuốn sách này cung cấp các nguyên tắc và kỹ th...
# cme/title               Kỹ năng giao tiếp và tư vấn trong y học và chă...
# cme/description         Khóa học này tập trung vào việc phát triển kỹ ...
# Name: 1, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ sinh v...
# question                Một sinh viên y khoa muốn tìm hiểu sâu hơn: 'X...
# answer                  Chào bạn, đây là một câu hỏi rất hay và cho th...
# document/title          Giáo trình Sản phụ khoa - Phần Tiết niệu học p...
# document/description    Cuốn giáo trình này cung cấp kiến thức nền tản...
# cme/title               Tiếp cận đa chuyên ngành trong quản lý rối loạ...
# cme/description         Khóa học CME này thảo luận về các phương pháp ...
# Name: 2, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa trên nghiên cứu về phẫu thuật TOT cho són ...
# answer                  Để lựa chọn bệnh nhân són tiểu gắng sức (Stres...
# document/title          Hướng dẫn chẩn đoán và điều trị Són tiểu gắng ...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Cập nhật chẩn đoán và quản lý són tiểu gắng sứ...
# cme/description         Khóa học đào tạo y khoa liên tục này tập trung...
# Name: 3, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi tiến hành một nghiên cứu lâm sàng như nghi...
# answer                  Các bác sĩ trẻ khi tham gia nghiên cứu lâm sàn...
# document/title          Nguyên lý và Phương pháp nghiên cứu khoa học t...
# document/description    Cuốn sách cung cấp kiến thức nền tảng về các l...
# cme/title               Thống kê Y học cơ bản và ứng dụng STATA trong ...
# cme/description         Khóa học thực hành này hướng dẫn chi tiết cách...
# Name: 4, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong mọi nghiên cứu lâm sàng, đặc biệt là phẫ...
# answer                  Đạo đức trong nghiên cứu lâm sàng là nền tảng ...
# document/title          Hướng dẫn thực hành lâm sàng tốt (GCP) của Bộ ...
# document/description    Tài liệu này là cẩm nang pháp quy chi tiết, cu...
# cme/title               Đạo đức trong nghiên cứu y sinh và bảo vệ đối ...
# cme/description         Khóa học này cung cấp kiến thức toàn diện về c...
# Name: 5, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, làm thế nào để hiểu rõ hơn về...
# answer                  Chào bạn, việc nắm vững các yếu tố nhân khẩu h...
# document/title          Són tiểu ở người cao tuổi: Thực trạng và Hướng...
# document/description    Tài liệu này cung cấp cái nhìn tổng quan về dị...
# cme/title               Quản lý són tiểu ở phụ nữ: Từ chẩn đoán đến ca...
# cme/description         Khóa học tập trung vào cập nhật các kiến thức ...
# Name: 6, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các yếu tố liên quan đến tiền sử sản khoa như ...
# answer                  Khai thác tiền sử sản khoa là một phần không t...
# document/title          Phục hồi chức năng sàn chậu sau sinh và phòng ...
# document/description    Tài liệu này trình bày chi tiết về các bài tập...
# cme/title               Đánh giá và điều trị rối loạn chức năng sàn ch...
# cme/description         Khóa học cung cấp kiến thức toàn diện về chẩn ...
# Name: 7, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dữ liệu nghiên cứu này cho thấy sự khác biệt s...
# answer                  Việc so sánh kết quả nghiên cứu với các tài li...
# document/title          Thực hành Y học dựa trên bằng chứng: Hướng dẫn...
# document/description    Cuốn sách này cung cấp các nguyên tắc và phươn...
# cme/title               Kỹ năng đọc và đánh giá bài báo khoa học trong...
# cme/description         Khóa học trang bị cho người học khả năng phân ...
# Name: 8, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, khi tiếp cận một bệnh nhân nữ...
# answer                  Em thân mến, việc khai thác tiền sử sản khoa l...
# document/title          Hướng dẫn chẩn đoán và điều trị tiểu không tự ...
# document/description    Tài liệu chuyên sâu cung cấp các tiêu chuẩn ch...
# cme/title               Khóa học chuyên đề: Đánh giá và Quản lý Rối lo...
# cme/description         Khóa học đào tạo y khoa liên tục trang bị kiến...
# Name: 9, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Đoạn văn có đề cập đến nhiều loại triệu chứng ...
# answer                  Chào em, việc phân biệt các thể lâm sàng của r...
# document/title          Sổ tay ICD-10 - Chương XIV: Bệnh của hệ tiết n...
# document/description    Tài liệu tham khảo chính thống của Bộ Y tế, cu...
# cme/title               Khóa học chuyên sâu về Niệu động học và Chẩn đ...
# cme/description         Khóa học đào tạo thực hành về kỹ thuật đo niệu...
# Name: 10, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dữ liệu cho thấy tỷ lệ bệnh nhân nhập viện vì ...
# answer                  Chào em, đây là một câu hỏi rất thực tế và qua...
# document/title          Phác đồ điều trị rối loạn chức năng sàn chậu v...
# document/description    Tài liệu này cung cấp các phác đồ điều trị chi...
# cme/title               Hội thảo quốc tế về Phẫu thuật Sàn chậu và Tiể...
# cme/description         Khóa học cập nhật các kỹ thuật phẫu thuật tiên...
# Name: 11, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa trên dữ liệu nghiên cứu, làm thế nào để ch...
# answer                  Chào em, dựa vào dữ liệu nghiên cứu cho thấy t...
# document/title          Hướng dẫn chẩn đoán và điều trị Sa tạng chậu (...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Khóa học CME: "Cập nhật chẩn đoán và quản lý s...
# cme/description         Khóa học này sẽ đi sâu vào các kỹ thuật thăm k...
# Name: 12, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu chỉ ra tỷ lệ cao các vấn đề về tiểu...
# answer                  Chào em, dữ liệu nghiên cứu rất rõ ràng khi ch...
# document/title          Phác đồ chẩn đoán và điều trị rối loạn chức nă...
# document/description    Tài liệu này tổng hợp các hướng dẫn chuyên sâu...
# cme/title               Khóa học CME: "Quản lý toàn diện tiểu không tự...
# cme/description         Khóa học này tập trung vào việc đánh giá đa ch...
# Name: 13, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Đối với các bệnh nhân có sa tạng chậu và tiểu ...
# answer                  Chào em, dữ liệu nghiên cứu cho thấy mức độ ti...
# document/title          Hướng dẫn quốc gia về chăm sóc sức khỏe sinh s...
# document/description    Tài liệu này cung cấp các hướng dẫn toàn diện ...
# cme/title               Khóa học CME: "Phục hồi chức năng sàn chậu và ...
# cme/description         Khóa học này cung cấp kiến thức chuyên sâu về ...
# Name: 14, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, khi tiếp cận một bệnh nhân nữ...
# answer                  Chào bạn, khi tiếp cận bệnh nhân nữ có triệu c...
# document/title          Hướng dẫn chẩn đoán và điều trị són tiểu khi g...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Chẩn đoán và Quản lý Són tiểu ở Phụ nữ: Từ Lý ...
# cme/description         Khóa học CME này tập trung vào việc nâng cao k...
# Name: 15, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi quyết định chỉ định phẫu thuật TOT cho bện...
# answer                  Các bạn thân mến, việc đánh giá các yếu tố sản...
# document/title          Tổng quan về Yếu tố nguy cơ và Dự phòng Són ti...
# document/description    Tài liệu này cung cấp một cái nhìn sâu sắc về ...
# cme/title               Quản lý Bệnh lý Sàn chậu và Són tiểu liên quan...
# cme/description         Khóa học này được thiết kế cho các bác sĩ sản ...
# Name: 16, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Chuyên gia có thể giải thích về phẫu thuật TOT...
# answer                  Chào các bạn, phẫu thuật TOT (Transobturator T...
# document/title          Phẫu thuật đặt băng nâng niệu đạo (TOT/TVT) tr...
# document/description    Tài liệu chuyên sâu này cung cấp hướng dẫn chi...
# cme/title               Phẫu thuật Tạo hình Sàn chậu và Kỹ thuật Đặt B...
# cme/description         Khóa học CME thực hành (hands-on) này được thi...
# Name: 17, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để đánh giá tiềm năng biệt hóa của...
# answer                  Chào các em và các đồng nghiệp trẻ, việc đánh ...
# document/title          Hướng dẫn thực hành lâm sàng về ứng dụng tế bà...
# document/description    Tài liệu này cung cấp một cái nhìn tổng quan t...
# cme/title               Khóa học chuyên sâu: Tế bào gốc trung mô và cô...
# cme/description         Khóa học này cung cấp kiến thức nền tảng và cậ...
# Name: 18, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hướng dẫn các...
# question                Những kỹ thuật nào là cần thiết để kiểm tra sự...
# answer                  Để kiểm tra một cách đáng tin cậy sự biệt hóa ...
# document/title          Cẩm nang kỹ thuật nuôi cấy và biệt hóa tế bào ...
# document/description    Cuốn cẩm nang toàn diện này chi tiết hóa các b...
# cme/title               Hội thảo kỹ thuật: Phân tích tế bào bằng Flow ...
# cme/description         Hội thảo thực hành này tập trung vào việc nắm ...
# Name: 19, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp kiến...
# question                Với những kết quả nghiên cứu về Hue Biostimula...
# answer                  Kính chào các đồng nghiệp và sinh viên y khoa!...
# document/title          Báo cáo đồng thuận quốc tế về liệu pháp tế bào...
# document/description    Tài liệu này tổng hợp các bằng chứng lâm sàng ...
# cme/title               Khóa học trực tuyến: Công nghệ mới trong điều ...
# cme/description         Khóa học cập nhật các tiến bộ khoa học và công...
# Name: 20, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, tại sao tổn thương cơ tim do ...
# answer                  Chào bạn, đây là một câu hỏi rất quan trọng mà...
# document/title          Harrison's Principles of Internal Medicine - C...
# document/description    Sách giáo khoa kinh điển cung cấp kiến thức to...
# cme/title               Cập nhật Chẩn đoán và Điều trị Suy tim theo ES...
# cme/description         Khóa học CME tập trung vào các hướng dẫn lâm s...
# Name: 21, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ sinh v...
# question                Các loại tế bào gốc trung mô (MSCs) nào đang đ...
# answer                  Chào bạn, việc lựa chọn nguồn tế bào gốc và ph...
# document/title          Stem Cells: An Overview of the Current Status ...
# document/description    Một bài tổng quan cập nhật về các loại tế bào ...
# cme/title               Kỹ thuật Nuôi cấy Tế bào Gốc và Ứng dụng trong...
# cme/description         Khóa học thực hành và lý thuyết chuyên sâu về ...
# Name: 22, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, giúp bác sĩ v...
# question                Nghiên cứu về kích thích điện lên UC-MSCs để b...
# answer                  Chào bạn, nghiên cứu về kích thích điện lên tế...
# document/title          Protocol for Isolation and Culture of Umbilica...
# document/description    Một tài liệu hướng dẫn chi tiết về các bước th...
# cme/title               Workshop về Kỹ thuật Điện sinh lý và Ứng dụng ...
# cme/description         Khóa học chuyên sâu trang bị kiến thức và kỹ n...
# Name: 23, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hướng dẫn sin...
# question                Khi thực hiện xét nghiệm đánh giá khả năng sốn...
# answer                  Để đảm bảo tính chính xác và khoa học trong xé...
# document/title          Hướng dẫn Thực hành Tốt trong Nuôi cấy Tế bào ...
# document/description    Tài liệu cung cấp các nguyên tắc và quy trình ...
# cme/title               Khóa học GLP (Good Laboratory Practice) Chuyên...
# cme/description         Khóa học đào tạo chuyên sâu về các nguyên tắc ...
# Name: 24, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hướng dẫn phâ...
# question                Làm thế nào để phân tích hiệu quả sự thay đổi ...
# answer                  Để phân tích hiệu quả sự thay đổi hình thái tế...
# document/title          Sổ tay Hướng dẫn Phân tích Hình ảnh Y sinh với...
# document/description    Tài liệu chi tiết hướng dẫn sử dụng phần mềm I...
# cme/title               Phân tích Dữ liệu Hình ảnh Sinh học Nâng cao v...
# cme/description         Khóa học chuyên sâu về các kỹ thuật phân tích ...
# Name: 25, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp kiến...
# question                Để tối ưu hóa quá trình biệt hóa tế bào gốc tr...
# answer                  Để tối ưu hóa quá trình biệt hóa UC-MSCs thành...
# document/title          Kỹ thuật Mô và Y học Tái tạo: Nguyên lý và Ứng...
# document/description    Sách giáo trình tổng quan về các nguyên lý cơ ...
# cme/title               Phát triển và Ứng dụng Tế bào Gốc trong Y học ...
# cme/description         Khóa học đào tạo chuyên sâu về các loại tế bào...
# Name: 26, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong nghiên cứu tế bào gốc như UC-MSCs, việc ...
# answer                  RT-PCR (Reverse Transcription Polymerase Chain...
# document/title          Kỹ Thuật PCR và RT-PCR Trong Chẩn Đoán và Nghi...
# document/description    Tài liệu chuyên sâu về nguyên lý, quy trình th...
# cme/title               Ứng Dụng Kỹ Thuật Sinh Học Phân Tử Trong Y Học...
# cme/description         Khóa học CME này cung cấp cái nhìn tổng quan v...
# Name: 27, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Kỹ thuật hóa mô miễn dịch (Immunohistochemistr...
# answer                  Kỹ thuật hóa mô miễn dịch (IHC) là một công cụ...
# document/title            Hóa Mô Miễn Dịch Trong Chẩn Đoán Giải Phẫu Bệnh
# document/description    Sách giáo trình toàn diện về nguyên lý, kỹ thu...
# cme/title               Cập Nhật Kỹ Thuật Hóa Mô Miễn Dịch Nâng Cao Tr...
# cme/description         Khóa học này sẽ cập nhật những tiến bộ mới nhấ...
# Name: 28, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong nghiên cứu y khoa, đặc biệt khi đánh giá...
# answer                  Phân tích thống kê là xương sống của bất kỳ ng...
# document/title                          Thống Kê Y Học Cơ Bản và Nâng Cao
# document/description    Cuốn sách cung cấp kiến thức toàn diện về các ...
# cme/title               Phân Tích Thống Kê Dữ Liệu Lâm Sàng Với Phần M...
# cme/description         Khóa học thực hành này tập trung vào việc sử d...
# Name: 29, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hướng dẫn các...
# question                Thưa chuyên gia, làm thế nào để xác định các đ...
# answer                  Chào bạn, việc xác định đặc tính của tế bào gố...
# document/title          Hướng dẫn thực hành phân tích tế bào bằng Flow...
# document/description    Tài liệu này cung cấp kiến thức nền tảng và hư...
# cme/title               Khóa học CME: Kỹ thuật Flow Cytometry nâng cao...
# cme/description         Khóa học đào tạo liên tục dành cho bác sĩ, nhà...
# Name: 30, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp kiến...
# question                Xin chuyên gia tư vấn về các kỹ thuật nuôi cấy...
# answer                  Các bạn sinh viên và bác sĩ thân mến, nuôi cấy...
# document/title          Sổ tay Kỹ thuật Nuôi cấy Tế bào Gốc Người theo...
# document/description    Tài liệu này cung cấp các giao thức chuẩn và m...
# cme/title               Khóa học CME: Thực hành Nuôi cấy Tế bào Gốc và...
# cme/description         Khóa học đào tạo liên tục này được thiết kế để...
# Name: 31, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ các bá...
# question                Xin chuyên gia giải thích ý nghĩa của việc đán...
# answer                  Chào các bạn, việc đánh giá khả năng biệt hóa ...
# document/title          Giáo trình Sinh học Tế bào Gốc và Cơ chế Biệt ...
# document/description    Tài liệu học thuật chuyên sâu này trình bày cá...
# cme/title               Khóa học CME: Các Kỹ thuật Nâng cao trong Đánh...
# cme/description         Khóa học này tập trung vào các kỹ thuật tiên t...
# Name: 32, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Đối với một nghiên cứu về biệt hóa tế bào gốc,...
# answer                  Chào các bạn bác sĩ trẻ và sinh viên y khoa,\n...
# document/title          Kỹ Thuật Kính Hiển Vi và Phân Tích Hình Ảnh Tr...
# document/description    Cuốn sách này cung cấp kiến thức nền tảng về c...
# cme/title               Phân Tích Hình Ảnh Tế Bào Nâng Cao Với Image J...
# cme/description         Khóa học thực hành chuyên sâu giúp các bác sĩ ...
# Name: 33, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, đóng vai trò ...
# question                Nghiên cứu này đề xuất phương pháp kích thích ...
# answer                  Chào các bạn,\n\nNghiên cứu về kích thích điện...
# document/title          Kỹ Thuật Điện Sinh Lý Tế Bào và Mô: Nguyên Lý ...
# document/description    Cuốn sách này cung cấp một cái nhìn toàn diện ...
# cme/title               Thiết Kế và Tối Ưu Hóa Giao Thức Kích Thích Tế...
# cme/description         Khóa học này tập trung vào các nguyên tắc thiế...
# Name: 34, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp hướn...
# question                Sau khi quan sát sự thay đổi hình thái, làm th...
# answer                  Chào các bạn đồng nghiệp,\n\nViệc xác nhận sự ...
# document/title          Phân Tích Dấu Ấn Sinh Học Tế Bào Gốc và Ứng Dụ...
# document/description    Tài liệu này đi sâu vào các loại dấu ấn sinh h...
# cme/title               Liệu Pháp Tế Bào Gốc Trong Y Học Tim Mạch: Từ ...
# cme/description         Khóa học này cung cấp một cái nhìn tổng thể về...
# Name: 35, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu về tác động của kích thích điện lên...
# answer                  Kính chào các đồng nghiệp và sinh viên y khoa,...
# document/title          Tế bào gốc trung mô từ dây rốn trong y học tái...
# document/description    Tài liệu này cung cấp cái nhìn toàn diện về đặ...
# cme/title               Khóa học Chuyên sâu về Ứng dụng Tế bào gốc tro...
# cme/description         Khóa học này sẽ đi sâu vào các nguyên lý cơ bả...
# Name: 36, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ bác sĩ...
# question                Nghiên cứu chỉ ra rằng tỷ lệ UC-MSCs với góc θ...
# answer                  Chào các bạn, việc phân tích dữ liệu định hướn...
# document/title          Cơ học tế bào và Sinh học phát triển: Ảnh hưởn...
# document/description    Cuốn sách giáo trình này cung cấp kiến thức nề...
# cme/title               Khóa học Phương pháp Nghiên cứu Khoa học và Ph...
# cme/description         Khóa học thực hành này tập trung vào các kỹ th...
# Name: 37, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp kiến...
# question                Với sự phát triển nhanh chóng của các kỹ thuật...
# answer                  Các bạn thân mến, lĩnh vực y học tái tạo và li...
# document/title          Hướng dẫn Đạo đức và Quy định trong Nghiên cứu...
# document/description    Tài liệu này tổng hợp các hướng dẫn và quy địn...
# cme/title               Hội thảo Quốc tế về Tiến bộ mới nhất trong Y h...
# cme/description         Tham gia hội thảo thường niên này để cập nhật ...
# Name: 38, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ trẻ hoặc sinh viên y khoa, làm t...
# answer                  Chào bạn, việc phân tích mức độ biểu hiện gen ...
# document/title          Sổ Tay Kỹ Thuật Sinh Học Phân Tử Cơ Bản và Nân...
# document/description    Tài liệu này cung cấp hướng dẫn chi tiết từ ng...
# cme/title               Khóa Học Chuyên Sâu về Real-time PCR và Phân T...
# cme/description         Khóa học đào tạo y khoa liên tục này tập trung...
# Name: 39, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu chỉ ra rằng Desmin là một dấu ấn sớ...
# answer                  Các bạn thân mến, việc xác định các dấu ấn đặc...
# document/title          Atlas Hình Ảnh Miễn Dịch Hóa Học Các Dấu Ấn Tế...
# document/description    Cung cấp bộ sưu tập hình ảnh và diễn giải kết ...
# cme/title               Phân Tích Dấu Ấn Tế Bào Bằng Kỹ Thuật Miễn Dịc...
# cme/description         Khóa học này hướng dẫn các bác sĩ và sinh viên...
# Name: 40, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu đã chứng minh rằng kích thích điện ...
# answer                  Chào các bạn, kết quả của nghiên cứu này mở ra...
# document/title          Hướng Dẫn Nghiên Cứu và Ứng Dụng Tế Bào Gốc Tr...
# document/description    Tài liệu này cung cấp cái nhìn tổng quan về cá...
# cme/title               Từ Nghiên Cứu Khoa Học Cơ Bản Đến Ứng Dụng Lâm...
# cme/description         Khóa học này được thiết kế cho các nhà khoa họ...
# Name: 41, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ trẻ hoặc sinh viên y khoa, em nê...
# answer                  Chào em. Việc lựa chọn nguồn tế bào gốc trung ...
# document/title          Hướng dẫn thực hành lâm sàng về liệu pháp tế b...
# document/description    Tài liệu này cung cấp các nguyên tắc và khuyến...
# cme/title               Liệu pháp Tế bào Gốc trong Bệnh Tim Mạch: Từ C...
# cme/description         Khóa học này tập trung vào các kiến thức nền t...
# Name: 42, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong bối cảnh liệu pháp tế bào đang phát triể...
# answer                  Chào em. Việc tiền biệt hóa tế bào gốc trung m...
# document/title          Kỹ thuật Kích thích Điện trong Kỹ thuật Mô Tim...
# document/description    Tài liệu này trình bày chi tiết các nguyên tắc...
# cme/title               Công nghệ Biệt hóa Tế bào Gốc cho Kỹ thuật Tái...
# cme/description         Khóa học chuyên sâu này đào tạo về các phương ...
# Name: 43, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi đánh giá hiệu quả của quá trình biệt hóa t...
# answer                  Chào em. Việc xác định và theo dõi các dấu ấn ...
# document/title          Phân tích Dấu ấn Sinh học trong Y học Tái tạo ...
# document/description    Cuốn sách này cung cấp một cái nhìn toàn diện ...
# cme/title               Đánh giá Biệt hóa Tế bào Gốc bằng Dấu ấn Sinh ...
# cme/description         Khóa học này sẽ trang bị cho học viên những ki...
# Name: 44, dtype: object
# intruction              Chatbot y khoa chuyên sâu, hỗ trợ đào tạo và t...
# question                Thưa chuyên gia, trong bối cảnh các nghiên cứu...
# answer                  Kính chào các bác sĩ trẻ và sinh viên y khoa, ...
# document/title          Hướng dẫn Đánh giá Tiềm năng Biệt hóa của Tế b...
# document/description    Tài liệu này cung cấp cái nhìn tổng quan có hệ...
# cme/title               Liệu pháp Tế bào Gốc trong Bệnh Tim mạch: Từ C...
# cme/description         Khóa học CME này sẽ đi sâu vào cơ chế sinh học...
# Name: 45, dtype: object
# intruction              Chatbot y khoa cung cấp kiến thức chuyên sâu v...
# question                Khi thiết kế nghiên cứu hoặc áp dụng các kỹ th...
# answer                  Để tiến hành một nghiên cứu hay ứng dụng kỹ th...
# document/title          Kỹ thuật Kích thích Điện trong Kỹ thuật Mô Tim...
# document/description    Cuốn sách này mô tả chi tiết các nguyên lý vật...
# cme/title               Cập nhật Các Kỹ thuật Phân tích và Hình ảnh Tế...
# cme/description         Khóa học tập trung vào các kỹ thuật hiện đại n...
# Name: 46, dtype: object
# intruction              Chatbot y khoa định hướng tư duy phản biện và ...
# question                Các nghiên cứu trong đoạn văn cho thấy không p...
# answer                  Chào các bạn, khả năng phân biệt giữa một nghi...
# document/title          Phương pháp Luận trong Nghiên cứu Tế bào Gốc v...
# document/description    Tài liệu này nhấn mạnh tầm quan trọng của thiế...
# cme/title               Tư duy Phản biện và Đánh giá Nghiên cứu Khoa h...
# cme/description         Khóa học này trang bị cho học viên kỹ năng phâ...
# Name: 47, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi đánh giá kết quả sau phẫu thuật chấn thươn...
# answer                  Chào các bác sĩ trẻ và sinh viên y khoa!\n\nVi...
# document/title          Hướng dẫn Chẩn đoán và Điều trị Chấn thương Kh...
# document/description    Tài liệu này cung cấp phác đồ chẩn đoán, nguyê...
# cme/title               Quản lý Chấn thương Khuỷu tay Trẻ em: Từ Chẩn ...
# cme/description         Khóa học CME này tập trung vào các kỹ thuật ch...
# Name: 48, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong việc đánh giá X-quang sau phẫu thuật khu...
# answer                  Chào các bạn bác sĩ và sinh viên y khoa,\n\nSa...
# document/title          Sách giáo khoa Chẩn đoán hình ảnh Cơ xương khớ...
# document/description    Tài liệu này cung cấp kiến thức nền tảng và ch...
# cme/title               Thực hành Đọc X-quang Chấn thương Nhi khoa: Ch...
# cme/description         Khóa học CME này bao gồm các buổi thực hành đọ...
# Name: 49, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Đối với một bệnh nhân nhi 7 tuổi sau phẫu thuậ...
# answer                  Chào các bạn bác sĩ và sinh viên y khoa,\n\nQu...
# document/title          Phục hồi chức năng chấn thương chỉnh hình: Sác...
# document/description    Tài liệu này cung cấp các nguyên tắc và phác đ...
# cme/title               Quản lý Toàn diện và Phục hồi Chức năng Chấn t...
# cme/description         Khóa học CME này tập trung vào các chiến lược ...
# Name: 50, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để sinh viên y khoa và bác sĩ trẻ ...
# answer                  Kính chào các bác sĩ trẻ và sinh viên y khoa! ...
# document/title          Hướng dẫn chẩn đoán và điều trị trật khớp chỏm...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Cập nhật kiến thức về chấn thương khớp khuỷu v...
# cme/description         Khóa học này tập trung vào các loại chấn thươn...
# Name: 51, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Đối với trật khớp chỏm xương quay đơn thuần sa...
# answer                  Các bạn đồng nghiệp thân mến, khi đối mặt với ...
# document/title          Phẫu thuật tái tạo dây chằng vòng trong trật k...
# document/description    Tài liệu này trình bày chi tiết các kỹ thuật p...
# cme/title               Quản lý toàn diện chấn thương khớp khuỷu phức ...
# cme/description         Khóa học chuyên sâu này sẽ trang bị kiến thức ...
# Name: 52, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Vì trật khớp chỏm xương quay đơn thuần sau chấ...
# answer                  Chào các bạn đồng nghiệp, nhận thức về 'dễ bỏ ...
# document/title          Hướng dẫn quốc gia về chẩn đoán và điều trị cá...
# document/description    Tài liệu do Bộ Y tế ban hành, cung cấp các hướ...
# cme/title               Thực hành y học bằng chứng trong chẩn đoán và ...
# cme/description         Khóa học này sẽ hướng dẫn các bác sĩ cách tiếp...
# Name: 53, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ trẻ hoặc sinh viên y khoa, tôi c...
# answer                  Chào bạn, gãy Monteggia ở trẻ em là một chấn t...
# document/title          Pathology of the annular ligament in paediatri...
# document/description    Bài viết này phân tích sâu về bệnh lý dây chằn...
# cme/title               Cập nhật Chẩn đoán và Điều trị Gãy Monteggia ở...
# cme/description         Khóa học CME này cung cấp cái nhìn toàn diện v...
# Name: 54, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Đối với một trường hợp trật khớp chỏm xương qu...
# answer                  Khi đối mặt với trật khớp chỏm xương quay đơn ...
# document/title             Isolated" traumatic radial -head dislocation .
# document/description    Nghiên cứu kinh điển này cung cấp cái nhìn sâu...
# cme/title               Tiếp cận Chẩn đoán và Điều trị Chấn thương Khủ...
# cme/description         Khóa học CME này tập trung vào các trường hợp ...
# Name: 55, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi thực hiện tái tạo dây chằng bên trụ ngoài ...
# answer                  Kỹ thuật tái tạo dây chằng bên trụ ngoài (Late...
# document/title          The docking technique for lateral ulnar collat...
# document/description    Bài viết này mô tả chi tiết kỹ thuật docking t...
# cme/title               Phẫu thuật Tái tạo Dây chằng Khuỷu tay: Các kỹ...
# cme/description         Khóa học CME chuyên sâu này trang bị cho bác s...
# Name: 56, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các em sinh viên y khoa và bác sĩ trẻ cần hiểu...
# answer                  Các em sinh viên y khoa và bác sĩ trẻ thân mến...
# document/title          Cơ sở phân tử của liệu pháp virus oncolytic tr...
# document/description    Tài liệu này cung cấp cái nhìn sâu sắc về các ...
# cme/title               Liệu pháp gen và virus trong điều trị ung thư:...
# cme/description         Khóa học này bao gồm các buổi giảng về lý thuy...
# Name: 57, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi nghiên cứu hiệu quả của virus vắc-xin sởi ...
# answer                  Chào các bác sĩ trẻ và sinh viên y khoa, trong...
# document/title          Atlas hình thái học tế bào ung thư dưới kính h...
# document/description    Tài liệu tham khảo chuyên sâu với các hình ảnh...
# cme/title               Phương pháp và kỹ thuật trong nghiên cứu ung t...
# cme/description         Khóa học này đào tạo về các phương pháp nghiên...
# Name: 58, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với dữ liệu an toàn đã được thiết lập của viru...
# answer                  Các em sinh viên y khoa và bác sĩ trẻ thân mến...
# document/title          Các chiến lược phối hợp trong liệu pháp miễn d...
# document/description    Tài liệu này tổng hợp các cách tiếp cận để kết...
# cme/title               Thiết kế và thực hiện thử nghiệm lâm sàng tron...
# cme/description         Khóa học này cung cấp kiến thức toàn diện về q...
# Name: 59, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sinh viên y khoa nên hiểu rõ cơ chế hoạt động ...
# answer                  Chào bạn, để hiểu và ứng dụng cơ chế hoạt động...
# document/title          Cơ chế hoạt động của virus oncolytic trong điề...
# document/description    Tài liệu này cung cấp cái nhìn tổng quan về cá...
# cme/title               Ứng dụng virus oncolytic trong điều trị ung th...
# cme/description         Khóa học này sẽ đi sâu vào các nghiên cứu tiền...
# Name: 60, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi thực hiện nghiên cứu in vitro trên dòng tế...
# answer                  Chào bạn, việc thực hiện nghiên cứu in vitro t...
# document/title          Kỹ thuật nuôi cấy tế bào ung thư HT-29 và ứng ...
# document/description    Tài liệu này cung cấp hướng dẫn chi tiết về cá...
# cme/title               Kỹ năng thực hành nuôi cấy tế bào và mô hình i...
# cme/description         Khóa học thực hành chuyên sâu về kỹ thuật nuôi...
# Name: 61, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong nghiên cứu ung thư, việc sử dụng mô hình...
# answer                  Chào bạn, việc sử dụng mô hình động vật (in vi...
# document/title          Mô hình động vật trong nghiên cứu ung thư: Từ ...
# document/description    Tài liệu này cung cấp cái nhìn toàn diện về cá...
# cme/title               Đạo đức và Thực hành tốt trong Nghiên cứu Động...
# cme/description         Khóa học này tập trung vào các nguyên tắc đạo ...
# Name: 62, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Kính thưa chuyên gia, xin vui lòng giải thích ...
# answer                  Chào bạn, một câu hỏi rất quan trọng đối với c...
# document/title          Tương tác Virus-Vật chủ và Cơ chế Ly giải Tế b...
# document/description    Tài liệu này cung cấp một cái nhìn toàn diện v...
# cme/title               Chuyên đề: Sinh học phân tử virus và ứng dụng ...
# cme/description         Khóa học đào tạo chuyên sâu về cấu trúc, chu t...
# Name: 63, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi đang thực hiện các thí nghiệm với virus sở...
# answer                  Chào bạn, việc quan sát và đánh giá chính xác ...
# document/title          Phương pháp thực hành trong nghiên cứu hiệu ứn...
# document/description    Tài liệu này cung cấp các giao thức thí nghiệm...
# cme/title               Khoa học hình thái tế bào và ứng dụng trong ng...
# cme/description         Khóa học tập trung vào kỹ thuật hiển vi tiên t...
# Name: 64, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa trên những kết quả hứa hẹn từ các nghiên c...
# answer                  Chào bạn, việc chuyển đổi một phát hiện *in vi...
# document/title          Hướng dẫn quốc gia về nghiên cứu và phát triển...
# document/description    Tài liệu này cung cấp khung pháp lý và khoa họ...
# cme/title               Cập nhật các nguyên tắc thử nghiệm lâm sàng tr...
# cme/description         Khóa học này tập trung vào các nguyên tắc đạo ...
# Name: 65, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một sinh viên y khoa hoặc bác sĩ trẻ, làm t...
# answer                  Để nhận biết apoptosis dưới kính hiển vi, các ...
# document/title             Atlas Giải phẫu Bệnh học Đại cương và Hệ thống
# document/description    Tài liệu cung cấp hình ảnh minh họa chi tiết v...
# cme/title               Khóa học Kỹ thuật Mô học và Chẩn đoán Bệnh học...
# cme/description         Khóa học CME này tập trung vào các kỹ thuật ch...
# Name: 66, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một bác sĩ trẻ hoặc nhà nghiên cứu tương la...
# answer                  Các em thân mến, việc nắm vững apoptosis không...
# document/title                    Cơ sở Sinh học Phân tử của Bệnh Ung thư
# document/description    Sách chuyên khảo này đi sâu vào các con đường ...
# cme/title               Cập nhật về Cơ chế Chết theo Chương trình của ...
# cme/description         Khóa học CME này cung cấp kiến thức chuyên sâu...
# Name: 67, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Theo kết quả nghiên cứu được đề cập, làm thế n...
# answer                  Nghiên cứu chỉ ra rằng virus sởi (MeV) và quai...
# document/title          Liệu pháp Virus trong Điều trị Ung thư: Từ Cơ ...
# document/description    Cuốn sách cung cấp cái nhìn toàn diện về tiềm ...
# cme/title               Khóa học Chuyên sâu về Oncolytic Virotherapy v...
# cme/description         Khóa học CME này dành cho các bác sĩ và nhà ng...
# Name: 68, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, em đang tìm hiểu về các phươn...
# answer                  Chào em, câu hỏi của em rất quan trọng và phản...
# document/title          Hướng dẫn chẩn đoán và điều trị Ung thư phổi (...
# document/description    Tài liệu này cung cấp các khuyến nghị lâm sàng...
# cme/title               Cập nhật kỹ thuật Nội soi phế quản huỳnh quang...
# cme/description         Khóa học CME này sẽ tập trung vào nguyên lý vậ...
# Name: 69, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu đã chỉ ra độ nhạy và độ đặc hiệu củ...
# answer                  Chào em, việc hiểu và áp dụng độ nhạy (Sensiti...
# document/title          Y học thực chứng và sinh thống kê ứng dụng tro...
# document/description    Cuốn sách này cung cấp kiến thức nền tảng và n...
# cme/title               Phân tích và diễn giải các chỉ số chẩn đoán tr...
# cme/description         Khóa học này được thiết kế để trang bị cho các...
# Name: 70, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu tại Bệnh viện Phổi Trung ương đã sử...
# answer                  Chào em, việc kết hợp nhiều phương pháp chẩn đ...
# document/title          Phác đồ chẩn đoán và điều trị Ung thư phổi (WH...
# document/description    Tài liệu này tổng hợp các phác đồ chẩn đoán và...
# cme/title               Chiến lược chẩn đoán sớm và tầm soát Ung thư p...
# cme/description         Khóa học này sẽ trang bị cho các bác sĩ và cán...
# Name: 71, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Là một sinh viên y khoa sắp tốt nghiệp, tôi rấ...
# answer                  Chào bạn, đây là một câu hỏi rất hay và thiết ...
# document/title          Hướng dẫn chẩn đoán và điều trị Ung thư phổi B...
# document/description    Tài liệu chính thức này cung cấp phác đồ chuẩn...
# cme/title               Khóa học Kỹ thuật Nội soi Phế quản Huỳnh quang...
# cme/description         Khóa học thực hành chuyên sâu này giúp bác sĩ ...
# Name: 72, dtype: object
# intruction              Chatbot y khoa chuyên sâu, hỗ trợ bác sĩ và si...
# question                Là một bác sĩ nội trú chuyên ngành hô hấp, tôi...
# answer                  Chào bạn, việc phối hợp hiệu quả giữa WLB và F...
# document/title               Atlas Nội soi Phế quản Chẩn đoán và Điều trị
# document/description    Cuốn atlas này là một nguồn tài liệu hình ảnh ...
# cme/title               Hội thảo Sinh thiết Phế quản Dưới Hướng dẫn Đa...
# cme/description         Hội thảo chuyên sâu tập trung vào các kỹ thuật...
# Name: 73, dtype: object
# intruction              Chatbot y khoa đóng vai trò là trợ lý học thuậ...
# question                Với tư cách là một bác sĩ trẻ mới ra trường, t...
# answer                  Chào bạn, việc nắm vững quy trình chẩn đoán un...
# document/title          Sách giáo khoa Bệnh học Hô hấp (Respiratory Di...
# document/description    Cuốn sách giáo khoa kinh điển cung cấp kiến th...
# cme/title               Chuỗi hội thảo Cập nhật Chẩn đoán và Điều trị ...
# cme/description         Chuỗi hội thảo CME này liên tục cập nhật các p...
# Name: 74, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong bối cảnh chẩn đoán ung thư phổi, bác sĩ ...
# answer                  Kính chào các đồng nghiệp trẻ và các em sinh v...
# document/title             Sổ tay Nội soi phế quản chẩn đoán và can thiệp
# document/description    Tài liệu chuyên sâu hướng dẫn chi tiết về các ...
# cme/title               Nâng cao kỹ năng chẩn đoán sớm ung thư phổi bằ...
# cme/description         Khóa học đào tạo y khoa liên tục (CME) cung cấ...
# Name: 75, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi đọc một nghiên cứu về hiệu quả chẩn đoán u...
# answer                  Các em sinh viên và đồng nghiệp thân mến,\n\nV...
# document/title                   Giáo trình Thống kê Y học và Dịch tễ học
# document/description    Cuốn sách cung cấp kiến thức cơ bản và nâng ca...
# cme/title               Phân tích và diễn giải kết quả xét nghiệm chẩn...
# cme/description         Khóa học CME tập trung vào kỹ năng phân tích c...
# Name: 76, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Sau khi nội soi phế quản huỳnh quang phát hiện...
# answer                  Chào các bạn đồng nghiệp và các em sinh viên,\...
# document/title          Phân loại bệnh tật quốc tế ICD-10 (Bộ Y tế Việ...
# document/description    Tài liệu chính thức về hệ thống phân loại bệnh...
# cme/title               Quản lý và cập nhật mã hóa bệnh tật theo ICD-1...
# cme/description         Khóa học đào tạo liên tục hướng dẫn chi tiết c...
# Name: 77, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, tại sao vạt da xuyên nhánh độ...
# answer                  Chào bạn, một phẫu thuật viên trẻ cần hiểu rõ ...
# document/title          Giải phẫu phẫu thuật các vạt tự do và vạt cuốn...
# document/description    Tài liệu này cung cấp kiến thức nền tảng và ch...
# cme/title                    Khóa học phẫu thuật vi phẫu tái tạo nâng cao
# cme/description         Khóa học này tập trung vào các kỹ thuật vi phẫ...
# Name: 78, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Xin chuyên gia hướng dẫn về các thông số giải ...
# answer                  Tuyệt vời! Việc nắm vững các thông số giải phẫ...
# document/title                Atlas Giải Phẫu Vi Phẫu và Các Kỹ Thuật Vạt
# document/description    Tài liệu này là một atlas toàn diện, cung cấp ...
# cme/title               Workshop Thực hành trên Cadaver: Kỹ thuật Lấy ...
# cme/description         Khóa học thực hành chuyên sâu này cho phép học...
# Name: 79, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Để nâng cao kỹ năng tái tạo, một phẫu thuật vi...
# answer                  Chắc chắn rồi! Để trở thành một phẫu thuật viê...
# document/title          Phẫu Thuật Tái Tạo: Nguyên Lý, Giải Phẫu & Kỹ ...
# document/description    Đây là một cuốn sách giáo khoa toàn diện về ph...
# cme/title               Hội Thảo Quốc Tế về Phẫu Thuật Vi Phẫu và Tái Tạo
# cme/description         Hội thảo thường niên này quy tụ các chuyên gia...
# Name: 80, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, khi chuẩn bị thực hiện vạt da...
# answer                  Để thành công với vạt MSAPF, đặc biệt khi thực...
# document/title          Giải phẫu Người Tập I: Hệ Cơ - Xương - Khớp, H...
# document/description    Tài liệu cơ bản và chuyên sâu về giải phẫu học...
# cme/title               Khóa học Chuyên sâu về Vạt Vi phẫu trong Tái t...
# cme/description         Khóa học cung cấp kiến thức lý thuyết và thực ...
# Name: 81, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ phân t...
# question                Là một bác sĩ trẻ đang muốn tham gia nghiên cứ...
# answer                  Nghiên cứu trên xác (cadaveric dissection stud...
# document/title          Cẩm nang Phương pháp Nghiên cứu Khoa học trong...
# document/description    Cuốn sách hướng dẫn chi tiết về các loại hình ...
# cme/title               Workshop: Kỹ thuật Bóc tách Giải phẫu trên Xác...
# cme/description         Khóa học thực hành chuyên sâu về các kỹ thuật ...
# Name: 82, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Chuyên gia có thể phân tích sâu hơn về ứng dụn...
# answer                  Vạt da tưới máu bởi nhánh xuyên động mạch bắp ...
# document/title                  Atlas Phẫu thuật Tạo hình Vùng Đầu Mặt Cổ
# document/description    Tập hợp các kỹ thuật phẫu thuật tạo hình và tá...
# cme/title               Chuyên đề: Quản lý và Tái tạo Khuyết hổng Phức...
# cme/description         Khóa học tập trung vào các trường hợp lâm sàng...
# Name: 83, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các bác sĩ phẫu thuật tạo hình và sinh viên y ...
# answer                  Chào bạn, việc nắm vững giải phẫu động mạch bắ...
# document/title          Giải phẫu Lâm sàng và Phẫu thuật Tạo hình Chi ...
# document/description    Cuốn sách này cung cấp kiến thức giải phẫu lâm...
# cme/title               Khóa học CME: Các Nguyên tắc Cơ bản và Nâng ca...
# cme/description         Khóa học này bao gồm các nguyên tắc cơ bản của...
# Name: 84, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ sinh v...
# question                Khi đối mặt với sự khác biệt về giải phẫu động...
# answer                  Thật tuyệt vời khi bạn quan tâm đến việc đối c...
# document/title          Sách giáo khoa Giải phẫu người: Hệ thống mạch ...
# document/description    Cuốn sách này cung cấp kiến thức nền tảng và c...
# cme/title               Khóa học CME: Biến thể giải phẫu mạch máu và ý...
# cme/description         Khóa học này tập trung vào các biến thể giải p...
# Name: 85, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ sinh v...
# question                Dữ liệu định lượng về số lượng (mean ± SD) và ...
# answer                  Hiểu và áp dụng các dữ liệu định lượng (quanti...
# document/title          Tập san Y học Việt Nam: Nghiên cứu định lượng ...
# document/description    Bài báo này trình bày chi tiết kết quả nghiên ...
# cme/title               Khóa học CME: Ứng dụng Thống kê Y học trong Ph...
# cme/description         Khóa học này hướng dẫn các bác sĩ cách đọc, hi...
# Name: 86, dtype: object
# ...
# answer                  Các bác sĩ trẻ và sinh viên thân mến, mặc dù v...
# document/title          Chương trình tiêm chủng mở rộng và các hướng d...
# document/description    Tài liệu này cung cấp thông tin chi tiết về lị...
# cme/title                Phòng ngừa và quản lý biến chứng hô hấp ở trẻ em
# cme/description         Khóa học này cung cấp kiến thức chuyên sâu về ...
# Name: 3024, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Khi bắt đầu điều trị viêm phổi do phế cầu ở tr...
# answer                  Kính gửi các bác sĩ trẻ và sinh viên y khoa, v...
# document/title          Hướng dẫn chẩn đoán và điều trị viêm phổi cộng...
# document/description    Tài liệu cung cấp các phác đồ điều trị chuẩn c...
# cme/title               Cập nhật chiến lược quản lý kháng sinh và điều...
# cme/description         Khóa học CME này sẽ giúp các bác sĩ nâng cao k...
# Name: 3025, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Theo nghiên cứu, đặc điểm dịch tễ học về tuổi ...
# answer                  Chào các bạn sinh viên và bác sĩ trẻ, việc hiể...
# document/title          Vắc xin phế cầu khuẩn: Hướng dẫn tiêm chủng và...
# document/description    Tài liệu này cung cấp thông tin chi tiết về vắ...
# cme/title               Dịch tễ học các bệnh nhiễm trùng hô hấp ở trẻ ...
# cme/description         Khóa học CME này tập trung vào các yếu tố dịch...
# Name: 3026, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa vào nghiên cứu, thời gian nằm viện của bện...
# answer                  Các bác sĩ trẻ và sinh viên y khoa thân mến, v...
# document/title          Phác đồ điều trị các biến chứng của viêm phổi ...
# document/description    Tài liệu này cung cấp hướng dẫn chi tiết về ch...
# cme/title               Quản lý cấp tính và dự phòng biến chứng trong ...
# cme/description         Khóa học CME này sẽ trang bị cho các bác sĩ ki...
# Name: 3027, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Xin thầy/cô cho biết về kỹ thuật gây tê caudal...
# answer                  Chào bạn, việc nắm vững các kỹ thuật gây tê vù...
# document/title          Sổ tay Gây tê Vùng Dưới Hướng dẫn Siêu âm: Kỹ ...
# document/description    Cuốn sổ tay này cung cấp kiến thức toàn diện v...
# cme/title               Khóa học Chuyên sâu về Gây tê Caudal và Các Kỹ...
# cme/description         Khóa học này được thiết kế để cung cấp cho các...
# Name: 3028, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hỗ trợ sinh v...
# question                Nguyên tắc giảm đau đa phương thức trong quản ...
# answer                  Các bạn sinh viên và bác sĩ trẻ thân mến, quản...
# document/title          Hướng dẫn Quốc gia về Quản lý Đau Cấp tính và ...
# document/description    Tài liệu này cung cấp các phác đồ và khuyến ng...
# cme/title               Chương trình CME: Tối ưu hóa Giảm đau sau mổ v...
# cme/description         Khóa học này tập trung vào việc cập nhật các c...
# Name: 3029, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, giúp bác sĩ v...
# question                Ropivacaine có những đặc điểm gì nổi bật khi đ...
# answer                  Chào bạn, với vai trò là một bác sĩ gây mê, vi...
# document/title          Dược lý học Thuốc tê và Kỹ thuật Gây tê Vùng N...
# document/description    Cuốn sách này cung cấp kiến thức chi tiết về c...
# cme/title               Hội thảo Chuyên đề: Cập nhật Dược lý thuốc tê ...
# cme/description         Hội thảo cung cấp các bài giảng chuyên sâu về ...
# Name: 3030, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hướng dẫn các...
# question                Dựa vào nghiên cứu được đề cập, đồng nghiệp có...
# answer                  Đồng nghiệp thân mến, từ nghiên cứu tại Bệnh v...
# document/title          Hướng dẫn chẩn đoán và điều trị bệnh viêm đườn...
# document/description    Tài liệu cung cấp phác đồ chuẩn quốc gia về ch...
# cme/title                 Cập nhật điều trị viêm phổi do phế cầu ở trẻ em
# cme/description         Khóa học cung cấp kiến thức cập nhật nhất về d...
# Name: 3031, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hướng dẫn các...
# question                Để đảm bảo an toàn cho người bệnh và nhân viên...
# answer                  Chào các bạn đồng nghiệp, tiêm an toàn là một ...
# document/title          Quyết định số 3671/QĐ-BYT năm 2012 của Bộ Y tế...
# document/description    Tài liệu pháp lý và chuyên môn quan trọng, cun...
# cme/title               Kỹ năng thực hành tiêm an toàn và phòng ngừa l...
# cme/description         Khóa học tập trung vào việc củng cố kiến thức ...
# Name: 3032, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp kiến...
# question                Làm thế nào để giải thích và nhấn mạnh tầm qua...
# answer                  Các bác sĩ trẻ thân mến, viêm phổi do phế cầu ...
# document/title          Khuyến nghị của WHO về vắc xin phế cầu liên hợ...
# document/description    Tài liệu toàn diện của Tổ chức Y tế Thế giới c...
# cme/title               Dịch tễ học và phòng ngừa các bệnh nhiễm trùng...
# cme/description         Khóa học trang bị kiến thức chuyên sâu về dịch...
# Name: 3033, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, bệnh viêm phổi do phế cầu ở t...
# answer                  Chào bạn, viêm phổi do phế cầu (*Streptococcus...
# document/title          Hướng dẫn chẩn đoán và điều trị viêm phổi ở tr...
# document/description    Tài liệu này cung cấp các phác đồ chuẩn hóa về...
# cme/title               Quản lý kháng sinh trong điều trị nhiễm khuẩn ...
# cme/description         Khóa học CME này tập trung vào các nguyên tắc ...
# Name: 3034, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Để chẩn đoán xác định viêm phổi do phế cầu ở t...
# answer                  Sinh viên y khoa và các bác sĩ trẻ cần nắm vữn...
# document/title          Nguyên lý cơ bản của kỹ thuật xét nghiệm vi si...
# document/description    Tài liệu này cung cấp kiến thức nền tảng về cá...
# cme/title               Cập nhật chẩn đoán hình ảnh trong bệnh lý hô h...
# cme/description         Khóa học này sẽ hướng dẫn các bác sĩ và sinh v...
# Name: 3035, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa vào nghiên cứu đã nêu, những đặc điểm dịch...
# answer                  Để tối ưu hóa việc điều trị viêm phổi do phế c...
# document/title          Sổ tay hướng dẫn điều trị kháng sinh của Bệnh ...
# document/description    Tài liệu này cung cấp các phác đồ điều trị khá...
# cme/title               Phác đồ điều trị viêm phổi nhi khoa và cập nhậ...
# cme/description         Khóa học CME này cung cấp cái nhìn tổng quan v...
# Name: 3036, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, khi tiếp cận bệnh nhân viêm p...
# answer                  Chào bạn, đây là một câu hỏi rất quan trọng tr...
# document/title          Hướng dẫn chẩn đoán và điều trị Viêm phổi cộng...
# document/description    Tài liệu cung cấp phác đồ điều trị chuẩn cho v...
# cme/title               Quản lý và sử dụng kháng sinh hợp lý trong điề...
# cme/description         Khóa học này tập trung vào các nguyên tắc lựa ...
# Name: 3037, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Dựa trên các nghiên cứu về viêm phổi do phế cầ...
# answer                  Bạn đã đặt ra một câu hỏi rất hay, việc hiểu r...
# document/title          Sổ tay Nhi khoa lâm sàng: Chẩn đoán và Điều tr...
# document/description    Tài liệu này cung cấp kiến thức chuyên sâu về ...
# cme/title                    Tiếp cận và quản lý viêm phổi nặng ở trẻ em.
# cme/description         Khóa học này sẽ trang bị cho người học những k...
# Name: 3038, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nghiên cứu chỉ ra rằng Cephalosporin vẫn được ...
# answer                  Đây là một điểm rất đáng lưu ý trong thực hành...
# document/title          Kháng sinh đồ và nguyên tắc sử dụng kháng sinh...
# document/description    Tài liệu chuyên sâu về cách đọc, diễn giải khá...
# cme/title               Hội thảo quốc tế về kháng kháng sinh và chiến ...
# cme/description         Khóa học này cung cấp cái nhìn tổng quan về tì...
# Name: 3039, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, hướng dẫn sin...
# question                Làm thế nào để bác sĩ trẻ và sinh viên y khoa ...
# answer                  Chào các em và đồng nghiệp, việc tích hợp khán...
# document/title          Khuyến cáo về sử dụng kháng sinh trong điều tr...
# document/description    Tài liệu này cung cấp các khuyến cáo chi tiết ...
# cme/title               Phác đồ Điều trị Kháng sinh và Thực hành Quản ...
# cme/description         Khóa học này sẽ hướng dẫn các bác sĩ cách xây ...
# Name: 3040, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với vai trò là một bác sĩ nhi khoa tại Bệnh vi...
# answer                  Là một bác sĩ nhi khoa, việc điều trị viêm phổ...
# document/title          Phác đồ chẩn đoán và điều trị viêm phổi ở trẻ ...
# document/description    Tài liệu hướng dẫn chi tiết từ Bộ Y tế về chẩn...
# cme/title               Quản lý kháng sinh trong điều trị viêm phổi cộ...
# cme/description         Khóa học CME này tập trung vào các nguyên tắc ...
# Name: 3041, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Với vai trò là bác sĩ gây mê hồi sức, làm thế ...
# answer                  Gây tê caudal dưới hướng dẫn siêu âm là một kỹ...
# document/title          Hướng dẫn thực hành gây tê vùng dưới hướng dẫn...
# document/description    Tài liệu tổng hợp các nguyên tắc, kỹ thuật và ...
# cme/title               Kỹ thuật gây tê vùng nâng cao và quản lý đau c...
# cme/description         Khóa học CME chuyên sâu này cung cấp kiến thức...
# Name: 3042, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Trong bối cảnh giảm đau đa phương thức sau mổ,...
# answer                  Đau sau mổ (mã ICD-10 G89.18) là một thách thứ...
# document/title                  Sách giáo trình Gây mê Hồi sức - Giảm đau
# document/description    Tài liệu cơ bản và toàn diện cung cấp kiến thứ...
# cme/title               Cập nhật các phương pháp và thuốc trong quản l...
# cme/description         Khóa học CME này tập trung vào các tiến bộ mới...
# Name: 3043, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thưa chuyên gia, dựa trên dữ liệu nghiên cứu, ...
# answer                  Chào bạn, đây là một câu hỏi rất thực tế và qu...
# document/title          Hướng dẫn chẩn đoán và điều trị bệnh phổi tắc ...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Quản lý đa yếu tố nguy cơ tim mạch và chương t...
# cme/description         Khóa học này tập trung vào việc trang bị cho b...
# Name: 3044, dtype: object
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Chuyên gia có thể giải thích rõ hơn về các thể...
# answer                  Bạn đã đặt ra một câu hỏi rất quan trọng về cá...
# document/title          Y học cổ truyền: Lý luận cơ bản và chẩn đoán bệnh
# document/description    Cuốn sách là giáo trình nền tảng về lý luận YH...
# cme/title               Chẩn đoán và ứng dụng thể chất Y học cổ truyền...
# cme/description         Khóa học này cung cấp kiến thức và kỹ năng thự...
# Name: 3045, dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 80
#      69     new_rows.append({
#      70         "intruction": row["intruction"],
#      71         "question": pq,
#    (...)
#      76         "cme/description": row["cme/description"],
#      77     })
#      79 new_df = pd.DataFrame(new_rows)
# ---> 80 with pd.ExcelWriter(output_file, mode="a", engine="openpyxl", if_sheet_exists="overlay") as writer:
#      81     sheet = writer.sheets["Sheet1"]
#      82     start_row = sheet.max_row
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\pandas\io\excel\_base.py:1353, in ExcelWriter.__exit__(self, exc_type, exc_value, traceback)
#    1347 def __exit__(
#    1348     self,
#    1349     exc_type: type[BaseException] | None,
#    1350     exc_value: BaseException | None,
#    1351     traceback: TracebackType | None,
#    1352 ) -> None:
# -> 1353     self.close()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\pandas\io\excel\_base.py:1357, in ExcelWriter.close(self)
#    1355 def close(self) -> None:
#    1356     """synonym for save, to make it more file-like"""
# -> 1357     self._save()
#    1358     self._handles.close()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\pandas\io\excel\_openpyxl.py:110, in OpenpyxlWriter._save(self)
#     106 def _save(self) -> None:
#     107     """
#     108     Save workbook to disk.
#     109     """
# --> 110     self.book.save(self._handles.handle)
#     111     if "r+" in self._mode and not isinstance(self._handles.handle, mmap.mmap):
#     112         # truncate file to the written content
#     113         self._handles.handle.truncate()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\workbook\workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\writer\excel.py:294, in save_workbook(workbook, filename)
#     292 workbook.properties.modified = datetime.datetime.now(tz=datetime.timezone.utc).replace(tzinfo=None)
#     293 writer = ExcelWriter(workbook, archive)
# --> 294 writer.save()
#     295 return True
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\writer\excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\writer\excel.py:77, in ExcelWriter.write_data(self)
#      74     custom_override = CustomOverride()
#      75     self.manifest.append(custom_override)
# ---> 77 self._write_worksheets()
#      78 self._write_chartsheets()
#      79 self._write_images()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\writer\excel.py:215, in ExcelWriter._write_worksheets(self)
#     212 for idx, ws in enumerate(self.workbook.worksheets, 1):
#     214     ws._id = idx
# --> 215     self.write_worksheet(ws)
#     217     if ws._drawing:
#     218         self._write_drawing(ws._drawing)
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\writer\excel.py:203, in ExcelWriter.write_worksheet(self, ws)
#     200     writer.write()
#     202 ws._rels = writer._rels
# --> 203 self._archive.write(writer.out, ws.path[1:])
#     204 self.manifest.append(ws)
#     205 writer.cleanup()
#
# File c:\Users\PC\.conda\envs\AI\Lib\zipfile\__init__.py:1908, in ZipFile.write(self, filename, arcname, compress_type, compresslevel)
#    1905     zinfo.compress_level = self.compresslevel
#    1907 with open(filename, "rb") as src, self.open(zinfo, 'w') as dest:
# -> 1908     shutil.copyfileobj(src, dest, 1024*8)
#
# File c:\Users\PC\.conda\envs\AI\Lib\shutil.py:204, in copyfileobj(fsrc, fdst, length)
#     202 fdst_write = fdst.write
#     203 while buf := fsrc_read(length):
# --> 204     fdst_write(buf)
#
# File c:\Users\PC\.conda\envs\AI\Lib\zipfile\__init__.py:1252, in _ZipWriteFile.write(self, data)
#    1250     data = self._compressor.compress(data)
#    1251     self._compress_size += len(data)
# -> 1252 self._fileobj.write(data)
#    1253 return nbytes
#
# KeyboardInterrupt:
