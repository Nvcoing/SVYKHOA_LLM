# %%
from datasets import load_dataset
from transformers import MT5Tokenizer, MT5ForConditionalGeneration
from tqdm import tqdm
import pandas as pd
import torch
import os

# Kiểm tra GPU
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cuda" )
print(f"💻 Đang sử dụng thiết bị: {device}")

# Load model paraphrase và đưa lên GPU
CKPT = 'chieunq/vietnamese-sentence-paraphase'
tokenizer = MT5Tokenizer.from_pretrained(CKPT)
model = MT5ForConditionalGeneration.from_pretrained(CKPT).to(device)

# Hàm tạo paraphrase
def paraphrase(text, num_return_sequences=5):
    inputs = tokenizer(text, padding='longest', max_length=512, truncation=True, return_tensors='pt')
    inputs = {key: val.to(device) for key, val in inputs.items()}
    output = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_length=512,
        num_return_sequences=num_return_sequences,
        do_sample=True,
        top_p=0.95
    )
    return [tokenizer.decode(o, skip_special_tokens=True) for o in output]

# Load dataset
dataset = pd.read_parquet("../generate_dataset/SVYKHOA_dataset_medicaltalk.parquet", engine="fastparquet")

# File Excel đầu ra
output_file = "SVYKHOA_dataset_medicaltalk_4.xlsx"

# Tạo file Excel rỗng nếu chưa có
if not os.path.exists(output_file):
    df_empty = pd.DataFrame(columns=["intruction", "question", "answer"])
    df_empty.to_excel(output_file, index=False)

# Đọc số dòng đã có để tiếp tục từ đó
existing_df = pd.read_excel(output_file)
# start_index = len(existing_df)
start_index = 2187
print(f"🚀 Bắt đầu từ dòng {start_index}")

# Số lượng mẫu muốn xử lý thêm
max_samples = 202450 - 21870  # Có thể chỉnh: 10, 100, 500...

# Duyệt dataset từ start_index
for i, row in dataset.iterrows():
    if i < start_index:
        continue
    if i >= start_index + max_samples:
        break
    print(row)

    question = row["question"]   # row là Series
    try:
        paraphrases = paraphrase(question, num_return_sequences=10)
    except Exception as e:
        print(f"Lỗi paraphrase tại mẫu {i}: {e}")
        paraphrases = [question]

    new_rows = []
    for pq in paraphrases:
        new_rows.append({
            "intruction": row["intruction"],
            "question": pq,
            "answer": row["answer"]
        })

    new_df = pd.DataFrame(new_rows)
    with pd.ExcelWriter(output_file, mode="a", engine="openpyxl", if_sheet_exists="overlay") as writer:
        sheet = writer.sheets["Sheet1"]
        start_row = sheet.max_row
        new_df.to_excel(writer, header=False, index=False, startrow=start_row)


print("✅ Đã lưu toàn bộ dữ liệu paraphrase vào file Excel.")
# Out:
# 💻 Đang sử dụng thiết bị: cuda
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'T5Tokenizer'.
# The class this function is called from is 'MT5Tokenizer'.
# You are using the default legacy behaviour of the <class 'transformers.models.mt5.tokenization_mt5.MT5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# 🚀 Bắt đầu từ dòng 2187
# intruction    Chatbot y khoa chuyên về giải phẫu học và bệnh...
# question      Dị vật thực quản ở trẻ em thường mắc kẹt ở vị ...
# answer        Dị vật thực quản ở trẻ em phần lớn thường mắc ...
# Name: 2187, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh và...
# question      Làm thế nào để phân biệt dị vật đồng xu và pin...
# answer        Việc phân biệt dị vật đồng xu và pin nút áo tr...
# Name: 2188, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y học và hiệ...
# question      Phim X-quang và nội soi thực quản có hiệu quả ...
# answer        Để đánh giá hiệu quả của các phương pháp chẩn ...
# Name: 2189, dtype: object
# intruction                                                 None
# question      Thưa bác sĩ, dị vật thực quản ở trẻ em có nhữn...
# answer        Dị vật thực quản ở trẻ em có nhiều đặc điểm kh...
# Name: 2190, dtype: object
# intruction                                                 None
# question      Để chẩn đoán dị vật thực quản ở trẻ em, chúng ...
# answer        Để chẩn đoán sớm và chính xác dị vật thực quản...
# Name: 2191, dtype: object
# intruction                                                 None
# question      Xin hãy tóm tắt những điểm chính về tầm quan t...
# answer        Việc phát hiện sớm và xử trí kịp thời dị vật t...
# Name: 2192, dtype: object
# intruction                                                 None
# question      Dựa trên các nghiên cứu gần đây, những loại dị...
# answer        Dị vật thực quản là một tình trạng cấp cứu thư...
# Name: 2193, dtype: object
# intruction                                                 None
# question      Có thể tổng hợp số liệu thống kê về tần suất m...
# answer        Dựa trên các thông tin được cung cấp từ nghiên...
# Name: 2194, dtype: object
# intruction                                                 None
# question      Xin vui lòng mô tả tầm quan trọng của việc chẩ...
# answer        Dị vật thực quản là một tình trạng cấp cứu khẩ...
# Name: 2195, dtype: object
# intruction                                                 None
# question      Theo nghiên cứu đã được công bố, các đặc điểm ...
# answer        Dựa trên nghiên cứu khảo sát tại Bệnh viện Nhi...
# Name: 2196, dtype: object
# intruction                                                 None
# question      Những cảnh báo và khuyến nghị quan trọng nào c...
# answer        Từ nghiên cứu về dị vật thực quản ở trẻ em, có...
# Name: 2197, dtype: object
# intruction                                                 None
# question      Xin tổng hợp các đặc điểm về nhân khẩu học và ...
# answer        Nghiên cứu đã tổng hợp các đặc điểm về nhân kh...
# Name: 2198, dtype: object
# intruction                                                 None
# question      Vui lòng cung cấp chi tiết các phát hiện cận l...
# answer        Để chẩn đoán và đánh giá tình trạng dị vật thự...
# Name: 2199, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học tiêu hóa, cu...
# question      Dị vật thực quản là một vấn đề y tế đáng quan ...
# answer        Dị vật thực quản (Foreign body in esophagus), ...
# Name: 2200, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng v...
# question      Nghiên cứu về dị vật thực quản tại Bệnh viện N...
# answer        Nghiên cứu về dị vật thực quản ở trẻ em tại Bệ...
# Name: 2201, dtype: object
# intruction    Chatbot y khoa chuyên về triệu chứng học, chẩn...
# question      Theo kết quả nghiên cứu, các triệu chứng lâm s...
# answer        Nghiên cứu tại Bệnh viện Nhi đồng 1 đã chỉ ra ...
# Name: 2202, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học lâm sàng ...
# question      Vui lòng trình bày chi tiết về đặc điểm nhân k...
# answer        Nghiên cứu tại Bệnh viện Nhi đồng 1 đã thu thậ...
# Name: 2203, dtype: object
# intruction    Chatbot y khoa chuyên về biến chứng và tổn thư...
# question      Các biến chứng và tổn thương thực quản được gh...
# answer        Dù nghiên cứu tại Bệnh viện Nhi đồng 1 ghi nhậ...
# Name: 2204, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học nhi khoa, cu...
# question      Trình bày chi tiết về đối tượng và phương pháp...
# answer        Nghiên cứu này tập trung vào tình trạng dị vật...
# Name: 2205, dtype: object
# intruction    Chatbot y khoa chuyên về cận lâm sàng và chẩn ...
# question      Theo đoạn văn, những đặc điểm nào về cận lâm s...
# answer        Trong nghiên cứu về dị vật thực quản (ICD-10: ...
# Name: 2206, dtype: object
# intruction    Chatbot y khoa chuyên về y đức và quản lý nghi...
# question      Các vấn đề y đức đã được xem xét như thế nào t...
# answer        Trong nghiên cứu về dị vật thực quản ở trẻ em,...
# Name: 2207, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học và đặc đi...
# question      Xin hãy tóm tắt các tiêu chuẩn chọn mẫu của ng...
# answer        Nghiên cứu về dị vật thực quản (Foreign Body i...
# Name: 2208, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học tiêu hóa, cu...
# question      Mô tả tổng quan về các trường hợp bệnh nhân nu...
# answer        Nghiên cứu trên 50 bệnh nhân nuốt dị vật đã ch...
# Name: 2209, dtype: object
# intruction    Chatbot y khoa chuyên về cấp cứu nội soi tiêu ...
# question      Liệt kê các triệu chứng thường gặp ở bệnh nhân...
# answer        Dựa trên nghiên cứu về 50 trường hợp nuốt dị v...
# Name: 2210, dtype: object
# intruction    Chatbot y khoa chuyên về dược học và điều trị ...
# question      Phân tích thời gian điều trị nội trú trung bìn...
# answer        Thời gian điều trị nội trú cho bệnh nhân nuốt ...
# Name: 2211, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học lâm sàng,...
# question      Trình bày tổng hợp về thời gian từ lúc nuốt dị...
# answer        Thời gian từ lúc nuốt dị vật đến khi bệnh nhân...
# Name: 2212, dtype: object
# intruction    Chatbot y khoa chuyên về quản lý bệnh viện và ...
# question      Phân tích thời gian từ lúc khám đến lúc nội so...
# answer        Thời gian từ lúc khám đến lúc nội soi và thời ...
# Name: 2213, dtype: object
# intruction    Chatbot y khoa chuyên về tiêu hóa, cung cấp th...
# question      Xin hãy mô tả chi tiết các đặc điểm cận lâm sà...
# answer        Dựa trên kết quả nghiên cứu, các đặc điểm cận ...
# Name: 2214, dtype: object
# intruction    Chatbot y khoa chuyên về cấp cứu, tư vấn xử tr...
# question      Với một trường hợp nghi ngờ dị vật đường tiêu ...
# answer        Khi nghi ngờ có dị vật đường tiêu hóa trên, vi...
# Name: 2215, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và sinh lý b...
# question      Những điểm chính về vị trí và loại dị vật thườ...
# answer        Phân tích các trường hợp dị vật thực quản cho ...
# Name: 2216, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh, c...
# question      Anh/chị có thể tổng hợp các đặc điểm X-quang t...
# answer        Trong quá trình chẩn đoán dị vật thực quản, X-...
# Name: 2217, dtype: object
# intruction    Chatbot y khoa chuyên về xét nghiệm huyết học ...
# question      Làm thế nào để phân tích kết quả công thức bạc...
# answer        Công thức bạch cầu (CBC) là một xét nghiệm cận...
# Name: 2218, dtype: object
# intruction                                                 None
# question      Dựa trên nghiên cứu tại Bệnh viện Nhi đồng 1, ...
# answer        Nghiên cứu về 50 trường hợp dị vật thực quản ở...
# Name: 2219, dtype: object
# intruction                                                 None
# question      Anh/chị hãy mô tả đặc điểm về độ tuổi của các ...
# answer        Nghiên cứu 50 trường hợp dị vật thực quản tại ...
# Name: 2220, dtype: object
# intruction                                                 None
# question      Xin vui lòng cung cấp thông tin về tình trạng ...
# answer        Nghiên cứu đã đánh giá tình trạng tổn thương t...
# Name: 2221, dtype: object
# intruction                                                 None
# question      Sự khác biệt về độ tuổi mắc dị vật thực quản g...
# answer        Sự khác biệt về độ tuổi trung bình và nhóm tuổ...
# Name: 2222, dtype: object
# intruction                                                 None
# question      Anh/chị hãy tổng hợp các loại dị vật thực quản...
# answer        Nghiên cứu đã cung cấp dữ liệu chi tiết về các...
# Name: 2223, dtype: object
# intruction    Chatbot y khoa chuyên về tiêu hóa, cung cấp th...
# question      Xin cho biết vai trò và hạn chế của phương phá...
# answer        X-quang đóng vai trò quan trọng trong việc gợi...
# Name: 2224, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh, h...
# question      Làm thế nào để phân biệt hình ảnh dị vật đồng ...
# answer        Để phân biệt dị vật đồng xu và pin nút áo trên...
# Name: 2225, dtype: object
# intruction    Chatbot y khoa chuyên về cấp cứu nhi khoa, hướ...
# question      Các đặc điểm nội soi thực quản thường gặp khi ...
# answer        Nội soi thực quản là phương pháp chẩn đoán xác...
# Name: 2226, dtype: object
# intruction    Chatbot y khoa chuyên về phẫu thuật tiêu hóa, ...
# question      Hãy tổng hợp các phương pháp chẩn đoán và đặc ...
# answer        Chẩn đoán dị vật thực quản đòi hỏi sự kết hợp ...
# Name: 2227, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu y học, phâ...
# question      Dựa trên các nghiên cứu được trích dẫn, hãy tr...
# answer        Các nghiên cứu về dị vật thực quản đã chỉ ra c...
# Name: 2228, dtype: object
# intruction                                                 None
# question      Dị vật thực quản ở trẻ em thường có những đặc ...
# answer        Dị vật thực quản ở trẻ em là một tình trạng cấ...
# Name: 2229, dtype: object
# intruction                                                 None
# question      Những loại dị vật thực quản nào thường gặp nhấ...
# answer        Ở trẻ em, các loại dị vật thực quản thường gặp...
# Name: 2230, dtype: object
# intruction                                                 None
# question      Làm thế nào để phân biệt dị vật đồng xu và pin...
# answer        Trên phim X-quang, việc phân biệt giữa dị vật ...
# Name: 2231, dtype: object
# intruction                                                 None
# question      Tổng hợp các loại dị vật thực quản thường gặp ...
# answer        Dị vật thực quản là một vấn đề y tế phổ biến ở...
# Name: 2232, dtype: object
# intruction                                                 None
# question      Theo các nghiên cứu gần đây, tỷ lệ phần trăm c...
# answer        Nghiên cứu về dị vật thực quản ở trẻ em đã chỉ...
# Name: 2233, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học nhi khoa, cu...
# question      Xin vui lòng tóm tắt các khía cạnh chính về dị...
# answer        Dị vật đường ăn ở trẻ em là một vấn đề cấp cứu...
# Name: 2234, dtype: object
# intruction    Chatbot y khoa chuyên về tiêu hóa nhi, hỗ trợ ...
# question      Các phương pháp quản lý dị vật thực quản ở trẻ...
# answer        Quản lý dị vật thực quản ở trẻ em đòi hỏi sự đ...
# Name: 2235, dtype: object
# intruction    Chatbot y khoa chuyên về cấp cứu nhi, hướng dẫ...
# question      Thời gian từ khi nuốt dị vật đến khi điều trị ...
# answer        Thời gian từ khi nuốt dị vật đến khi điều trị ...
# Name: 2236, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu y học, tổn...
# question      Bạn có thể tổng hợp các nghiên cứu về dị vật đ...
# answer        Dựa trên các tài liệu tham khảo được cung cấp,...
# Name: 2237, dtype: object
# intruction    Chatbot y khoa chuyên về thông tin dược học và...
# question      Trong quản lý dị vật đường ăn ở trẻ em, những ...
# answer        Dị vật đường ăn ở trẻ em rất đa dạng, từ các v...
# Name: 2238, dtype: object
# intruction                                                 None
# question      Xin chào, tôi đang nghiên cứu về tình trạng ti...
# answer        Tiểu không kiểm soát (TNKKS), theo phân loại I...
# Name: 2239, dtype: object
# intruction                                                 None
# question      Dựa trên nghiên cứu tại Bệnh viện Hùng Vương, ...
# answer        Dựa trên nghiên cứu tại Bệnh viện Hùng Vương T...
# Name: 2240, dtype: object
# intruction                                                 None
# question      Nghiên cứu về tiểu không kiểm soát ở thai phụ ...
# answer        Nghiên cứu về tình trạng tiểu không kiểm soát ...
# Name: 2241, dtype: object
# intruction                                                 None
# question      Từ kết quả nghiên cứu về tiểu không kiểm soát ...
# answer        Tình trạng tiểu không kiểm soát ở thai phụ tro...
# Name: 2242, dtype: object
# intruction                                                 None
# question      Bạn có thể tổng hợp các kết quả chính về tình ...
# answer        Nghiên cứu được thực hiện tại Bệnh viện Hùng V...
# Name: 2243, dtype: object
# intruction    Chatbot y khoa chuyên về sản phụ khoa, cung cấ...
# question      Xin cho biết chi tiết về các loại và mức độ nặ...
# answer        Dựa trên bảng câu hỏi ICIQ-UI-SF được sử dụng ...
# Name: 2244, dtype: object
# intruction    Chatbot hỗ trợ nghiên cứu y học, phân tích phư...
# question      Nghiên cứu về tiểu không kiểm soát ở thai phụ ...
# answer        Nghiên cứu về tiểu không kiểm soát ở thai phụ ...
# Name: 2245, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học hệ tiết niệu...
# question      Trong nghiên cứu về tiểu không kiểm soát ở tha...
# answer        Trong nghiên cứu về tiểu không kiểm soát ở tha...
# Name: 2246, dtype: object
# intruction    Chatbot hỗ trợ lâm sàng về chẩn đoán và phân l...
# question      Vui lòng tổng hợp cách phân loại các loại tiểu...
# answer        Dựa trên bảng câu hỏi ICIQ-UI-SF được sử dụng ...
# Name: 2247, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y học và dịc...
# question      Hãy cung cấp thông tin chi tiết về đặc điểm dâ...
# answer        Nghiên cứu đã phỏng vấn tổng cộng 376 thai phụ...
# Name: 2248, dtype: object
# intruction    Chatbot y khoa chuyên về sản phụ khoa và nội t...
# question      Xin vui lòng mô tả tổng quan về tình trạng tiể...
# answer        Tiểu không kiểm soát (Urinary Incontinence - U...
# Name: 2249, dtype: object
# intruction    Chatbot y khoa chuyên về sản phụ khoa và nội t...
# question      Theo nghiên cứu được đề cập, các dạng tiểu khô...
# answer        Dựa trên nghiên cứu đã thực hiện, các dạng tiể...
# Name: 2250, dtype: object
# intruction    Chatbot y khoa chuyên về sản phụ khoa và nội t...
# question      Có sự khác biệt đáng kể nào về tỷ lệ tiểu khôn...
# answer        Vâng, có sự khác biệt đáng kể về tỷ lệ tiểu kh...
# Name: 2251, dtype: object
# intruction    Chatbot y khoa chuyên về sản phụ khoa và nội t...
# question      Hãy tổng hợp dữ liệu về mức độ nặng của tình t...
# answer        Mức độ nặng của tình trạng tiểu không kiểm soá...
# Name: 2252, dtype: object
# intruction    Chatbot y khoa chuyên về sản phụ khoa và nội t...
# question      Vui lòng phân loại các dạng tiểu không kiểm so...
# answer        Tiểu không kiểm soát ở thai phụ có thể được ph...
# Name: 2253, dtype: object
# intruction    Chatbot y khoa chuyên về sản phụ khoa, cung cấ...
# question      Xin vui lòng giải thích các loại tiểu không ki...
# answer        Dựa trên phân loại của Hiệp hội tiểu không kiể...
# Name: 2254, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và quản lý t...
# question      Các biện pháp quản lý không xâm lấn nào được k...
# answer        Để quản lý tiểu không kiểm soát (TNKC) ở thai ...
# Name: 2255, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu và dịch tễ...
# question      Nghiên cứu về tác động của tiểu không kiểm soá...
# answer        Nghiên cứu đã đánh giá tác động của tiểu không...
# Name: 2256, dtype: object
# intruction    Chatbot y khoa chuyên về phương pháp nghiên cứ...
# question      Công cụ đánh giá tiểu không kiểm soát nào được...
# answer        Trong nghiên cứu này, công cụ chính được sử dụ...
# Name: 2257, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học và bệnh l...
# question      Phân loại và mức độ nặng của tiểu không kiểm s...
# answer        Nghiên cứu đã phân loại tiểu không kiểm soát (...
# Name: 2258, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question      Bệnh tiểu không kiểm soát ở thai phụ, đặc biệt...
# answer        Tiểu không kiểm soát (Urinary Incontinence - U...
# Name: 2259, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question      Những phát hiện chính và khuyến nghị từ nghiên...
# answer        Nghiên cứu về tiểu không kiểm soát (Urinary In...
# Name: 2260, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question      Nghiên cứu về tiểu không kiểm soát ở thai phụ ...
# answer        Nghiên cứu về tiểu không kiểm soát ở thai phụ ...
# Name: 2261, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question      Bạn có thể tổng hợp các đặc điểm chính của tiể...
# answer        Dựa trên nghiên cứu tại Bệnh viện Hùng Vương, ...
# Name: 2262, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question      Các chỉ số hiệu suất chẩn đoán và độ tin cậy c...
# answer        Nghiên cứu đã đánh giá hiệu suất của bảng câu ...
# Name: 2263, dtype: object
# intruction    Chatbot y khoa chuyên về sản phụ khoa và tiết ...
# question      Xin chào, tôi muốn tìm hiểu về tình trạng tiểu...
# answer        Tình trạng tiểu không tự chủ (Urinary Incontin...
# Name: 2264, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng v...
# question      Có những phương pháp nghiên cứu nào được đề cậ...
# answer        Các tài liệu nghiên cứu gần đây về tiểu không ...
# Name: 2265, dtype: object
# intruction    Chatbot y khoa chuyên về phục hồi chức năng sà...
# question      Liệu pháp cơ sàn chậu có hiệu quả trong điều t...
# answer        Liệu pháp cơ sàn chậu, đặc biệt là liệu pháp n...
# Name: 2266, dtype: object
# intruction    Chatbot y khoa chuyên về tổng hợp tài liệu y h...
# question      Bạn có thể tóm tắt các nghiên cứu chính về tiể...
# answer        Các tài liệu nghiên cứu về tiểu không tự chủ t...
# Name: 2267, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y tế và dịch...
# question      Có thông tin thống kê nào về tỷ lệ hiện mắc củ...
# answer        Tỷ lệ hiện mắc của tiểu không tự chủ (Urinary ...
# Name: 2268, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question      Tiểu không kiểm soát ở thai phụ, đặc biệt tron...
# answer        Tiểu không kiểm soát (Urinary Incontinence – U...
# Name: 2269, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu khoa học, ...
# question      Hãy tóm tắt phương pháp nghiên cứu và các kết ...
# answer        Nghiên cứu về tình trạng tiểu không kiểm soát ...
# Name: 2270, dtype: object
# intruction    Chatbot y khoa chuyên về các vấn đề sản phụ kh...
# question      Hãy cho biết một bản tóm tắt về tình trạng tiể...
# answer        Tình trạng tiểu không kiểm soát (Urinary Incon...
# Name: 2271, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và phân loại...
# question      Có những loại tiểu không kiểm soát nào thường ...
# answer        Tiểu không kiểm soát (UI) là một tình trạng đa...
# Name: 2272, dtype: object
# intruction    Chatbot y khoa chuyên phân tích dữ liệu nghiên...
# question      Trình bày cụ thể các số liệu và thông số chính...
# answer        Nghiên cứu được tiến hành tại Bệnh viện Hùng V...
# Name: 2273, dtype: object
# intruction    Chatbot y khoa chuyên về sản phụ khoa, cung cấ...
# question      Xin chào chatbot, xin vui lòng cho tôi biết về...
# answer        Tiểu không kiểm soát là một vấn đề sức khỏe có...
# Name: 2274, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học, hỗ trợ p...
# question      Tôi muốn biết về tỉ lệ tiểu không kiểm soát tr...
# answer        Dựa trên các báo cáo dịch tễ học quốc tế, tỉ l...
# Name: 2275, dtype: object
# intruction    Chatbot y khoa chuyên về y học lâm sàng, cung ...
# question      Trong ba tháng cuối thai kỳ, nguyên nhân nào l...
# answer        Trong ba tháng cuối thai kỳ, nguy cơ tiểu khôn...
# Name: 2276, dtype: object
# intruction    Chatbot y khoa chuyên về phương pháp nghiên cứ...
# question      Nghiên cứu được đề cập trong tài liệu có mục t...
# answer        Nghiên cứu được thực hiện với mục tiêu rõ ràng...
# Name: 2277, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng, ...
# question      Xin hãy tổng hợp các yếu tố loại trừ khỏi nghi...
# answer        Trong nghiên cứu về tiểu không kiểm soát ở tha...
# Name: 2278, dtype: object
# intruction    Chatbot y khoa chuyên về y học sản phụ khoa, c...
# question      Mô tả tổng quan về nghiên cứu về tiểu không ki...
# answer        Nghiên cứu đã phỏng vấn 376 thai phụ đang tron...
# Name: 2279, dtype: object
# intruction    Chatbot y khoa chuyên về phân tích nhân khẩu h...
# question      Vui lòng liệt kê các đặc điểm nhân khẩu học ch...
# answer        Các đặc điểm nhân khẩu học chính của nhóm thai...
# Name: 2280, dtype: object
# intruction    Chatbot y khoa chuyên về triệu chứng học và ph...
# question      Tóm tắt các đặc điểm chính về tần suất và lượn...
# answer        Trong số các thai phụ bị tiểu không kiểm soát,...
# Name: 2281, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán lâm sàng và...
# question      Vui lòng mô tả chi tiết các hoàn cảnh điển hìn...
# answer        Tiểu không kiểm soát ở thai phụ có thể biểu hi...
# Name: 2282, dtype: object
# intruction    Chatbot y khoa chuyên về phân tích thống kê và...
# question      Cung cấp phân tích định lượng chi tiết về đặc ...
# answer        Nghiên cứu đã cung cấp cái nhìn định lượng chi...
# Name: 2283, dtype: object
# intruction    Chatbot y khoa chuyên về sản phụ khoa và nghiê...
# question      Xin vui lòng phân tích mức độ nặng của tình tr...
# answer        Theo nghiên cứu của Quách Hữu Dương đăng trên ...
# Name: 2284, dtype: object
# intruction    Chatbot y khoa chuyên về tiết niệu, phụ khoa v...
# question      Các loại tiểu không kiểm soát nào phổ biến nhấ...
# answer        Theo nghiên cứu được thực hiện trên 202 thai p...
# Name: 2285, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học và so sán...
# question      Tỷ lệ tiểu không kiểm soát ở thai phụ trong ba...
# answer        Tỷ lệ tiểu không kiểm soát (TNKKS) ở thai phụ ...
# Name: 2286, dtype: object
# intruction    Chatbot y khoa chuyên phân tích dữ liệu nghiên...
# question      Làm thế nào để tổng hợp các loại tiểu không ki...
# answer        Nghiên cứu của Quách Hữu Dương đã phân loại ti...
# Name: 2287, dtype: object
# intruction    Chatbot y khoa chuyên về đánh giá chất lượng c...
# question      Nghiên cứu đã đánh giá mức độ nặng của tiểu kh...
# answer        Trong nghiên cứu về tiểu không kiểm soát (TNKK...
# Name: 2288, dtype: object
# intruction    Chatbot y khoa chuyên về Sản Phụ khoa, cung cấ...
# question      Xin chào chatbot, tôi muốn tìm hiểu về tình tr...
# answer        Chào bạn, tiểu không kiểm soát (Urinary Incont...
# Name: 2289, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng v...
# question      Nghiên cứu của bạn đã sử dụng phương pháp nào ...
# answer        Để đánh giá tình trạng tiểu không kiểm soát ở ...
# Name: 2290, dtype: object
# intruction    Chatbot y khoa chuyên về tổng quan bệnh học và...
# question      Điều gì làm cho nghiên cứu này đáng tin cậy và...
# answer        Nghiên cứu về tiểu không kiểm soát ở thai phụ ...
# Name: 2291, dtype: object
# intruction    Chatbot y khoa chuyên về phân loại bệnh lý và ...
# question      Theo nghiên cứu, các loại tiểu không kiểm soát...
# answer        Trong nghiên cứu về tiểu không kiểm soát ở tha...
# Name: 2292, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y tế và dịch...
# question      Mức độ nặng của tiểu không kiểm soát và ảnh hư...
# answer        Trong nghiên cứu này, mức độ nặng của tiểu khô...
# Name: 2293, dtype: object
# intruction    Chatbot y khoa chuyên về sản phụ khoa, cung cấ...
# question      Dựa trên nghiên cứu được đề cập, xin cho biết ...
# answer        Theo nghiên cứu được thực hiện tại Bệnh viện H...
# Name: 2294, dtype: object
# intruction    Chatbot y khoa chuyên về y học chứng cứ, tổng ...
# question      Xin vui lòng liệt kê các kết luận chính và khu...
# answer        Nghiên cứu về tiểu không kiểm soát ở thai phụ ...
# Name: 2295, dtype: object
# intruction    Chatbot hỗ trợ nghiên cứu y học, phân tích kết...
# question      Nghiên cứu về tiểu không kiểm soát ở thai phụ ...
# answer        Nghiên cứu đã sử dụng một bảng câu hỏi chuyên ...
# Name: 2296, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và quản lý l...
# question      Bác sĩ có thể cung cấp thông tin tổng quan về ...
# answer        Tiểu không kiểm soát (Urinary Incontinence - U...
# Name: 2297, dtype: object
# intruction    Chatbot chuyên sâu về dịch tễ học và đánh giá ...
# question      Vui lòng trình bày các chỉ số đánh giá độ tin ...
# answer        Nghiên cứu về tiểu không kiểm soát ở thai phụ ...
# Name: 2298, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ thiếu máu não...
# question      Xin vui lòng trình bày vấn đề nghiên cứu chính...
# answer        Bài báo này đặt ra vấn đề nghiên cứu chính xuấ...
# Name: 2299, dtype: object
# intruction    Chatbot y khoa chuyên về phương pháp nghiên cứ...
# question      Đề tài nghiên cứu này được thực hiện như thế n...
# answer        Nghiên cứu này được tiến hành với phương pháp ...
# Name: 2300, dtype: object
# intruction    Chatbot y khoa chuyên về kết quả và ý nghĩa lâ...
# question      Tổng kết lại, kết luận chính của nghiên cứu về...
# answer        Nghiên cứu đã đưa ra kết luận quan trọng về va...
# Name: 2301, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh th...
# question      Hãy giải thích và so sánh các loại thang điểm ...
# answer        Thang điểm ASPECTS (Alberta Stroke Program Ear...
# Name: 2302, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y học và phâ...
# question      Phân tích mức độ đồng thuận (Hệ số tương quan ...
# answer        Hệ số tương quan nội lớp (Interclass Correlati...
# Name: 2303, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh lý thần kinh, cu...
# question      Xin vui lòng giải thích đột quỵ thiếu máu não ...
# answer        Đột quỵ thiếu máu não cục bộ là một tình trạng...
# Name: 2304, dtype: object
# intruction    Chatbot y khoa chuyên về hình ảnh học thần kin...
# question      Trong đánh giá đột quỵ thiếu máu não cấp tính,...
# answer        Thang điểm ASPECTS (Alberta Stroke Program Ear...
# Name: 2305, dtype: object
# intruction    Chatbot y khoa chuyên về công nghệ trong y học...
# question      Những tiến bộ công nghệ gần đây nào đã được ph...
# answer        Thang điểm ASPECTS, mặc dù hữu ích, nhưng gặp ...
# Name: 2306, dtype: object
# intruction    Chatbot y khoa chuyên về hướng dẫn điều trị và...
# question      Vui lòng tổng hợp các tiêu chí can thiệp đột q...
# answer        Việc lựa chọn phương pháp và thời điểm can thi...
# Name: 2307, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu hình ảnh h...
# question      Hãy trình bày kết quả nghiên cứu so sánh Rapid...
# answer        Nghiên cứu hồi cứu được thực hiện tại Bệnh việ...
# Name: 2308, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng v...
# question      Tóm tắt giúp tôi về thiết kế nghiên cứu và các...
# answer        Nghiên cứu về ứng dụng Rapid ASPECTS trên X-qu...
# Name: 2309, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh th...
# question      Trong bối cảnh chẩn đoán nhồi máu não cấp, tha...
# answer        Trong nghiên cứu này, thang điểm ASPECTS (Albe...
# Name: 2310, dtype: object
# intruction    Chatbot y khoa chuyên về phương pháp nghiên cứ...
# question      Xin vui lòng cho biết các phương pháp xử lý số...
# answer        Trong nghiên cứu này, các số liệu thu thập đượ...
# Name: 2311, dtype: object
# intruction    Chatbot y khoa chuyên về cấp cứu thần kinh và ...
# question      Để đảm bảo tính khách quan và khoa học, một ng...
# answer        Trong các nghiên cứu lâm sàng về nhồi máu não ...
# Name: 2312, dtype: object
# intruction    Chatbot y khoa chuyên về đặc điểm lâm sàng và ...
# question      Nghiên cứu đã ghi nhận đặc điểm phân bố theo đ...
# answer        Dựa trên kết quả thu thập được từ 188 bệnh nhâ...
# Name: 2313, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ não, cung cấp...
# question      Xin vui lòng mô tả chi tiết về phân bố tuổi củ...
# answer        Phân bố tuổi của nhóm bệnh nhân trong nghiên c...
# Name: 2314, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ não, cung cấp...
# question      Dựa trên dữ liệu, xin vui lòng tóm tắt phân bố...
# answer        Phân bố giới tính trong nghiên cứu về đột quỵ ...
# Name: 2315, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ não, cung cấp...
# question      Hãy giải thích ý nghĩa của thang điểm NIHSS tr...
# answer        Thang điểm NIHSS (National Institutes of Healt...
# Name: 2316, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ não, cung cấp...
# question      Thời gian từ lúc khởi phát triệu chứng đến lúc...
# answer        Thời gian từ khi khởi phát triệu chứng đột quỵ...
# Name: 2317, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ não, cung cấp...
# question      Vui lòng cung cấp bảng phân bố điểm NIHSS trướ...
# answer        Thang điểm NIHSS là công cụ chuẩn hóa để đánh ...
# Name: 2318, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu, cung cấp ...
# question      Xin vui lòng tóm tắt kết quả về điểm ASPECTS t...
# answer        Điểm ASPECTS (Alberta Stroke Program Early CT ...
# Name: 2319, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học thần kinh, c...
# question      Phân tích độ phù hợp giữa Rapid ASPECTS và ASP...
# answer        Độ phù hợp giữa Rapid ASPECTS (điểm ASPECTS đư...
# Name: 2320, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh, c...
# question      Nghiên cứu này đánh giá như thế nào về sự đồng...
# answer        Nghiên cứu đã tập trung vào việc đánh giá mức ...
# Name: 2321, dtype: object
# intruction    Chatbot y khoa chuyên về phương pháp nghiên cứ...
# question      Có thể cung cấp một bảng tổng hợp chi tiết về ...
# answer        Hệ số tương quan nội lớp (Intraclass Correlati...
# Name: 2322, dtype: object
# intruction    Chatbot y khoa chuyên về y học cấp cứu, cung c...
# question      Dựa trên kết quả hệ số Kappa, sự đồng thuận gi...
# answer        Hệ số Kappa Cohen là một thước đo thống kê đượ...
# Name: 2323, dtype: object
# intruction                                                 None
# question      Đâu là những yếu tố nhân khẩu học và các tình ...
# answer        Các yếu tố nhân khẩu học và tình trạng bệnh lý...
# Name: 2324, dtype: object
# intruction                                                 None
# question      Độ nặng của đột quỵ thiếu máu não cấp thường đ...
# answer        Độ nặng của đột quỵ thiếu máu não cấp (ICD-10 ...
# Name: 2325, dtype: object
# intruction                                                 None
# question      Vui lòng tóm tắt mức độ đồng thuận giữa các ph...
# answer        Trong đánh giá đột quỵ thiếu máu não cấp (ICD-...
# Name: 2326, dtype: object
# intruction                                                 None
# question      Đâu là những yếu tố sinh học và lối sống chính...
# answer        Tỷ lệ mắc đột quỵ thiếu máu não cấp (ICD-10 I6...
# Name: 2327, dtype: object
# intruction                                                 None
# question      Vui lòng cung cấp phân tích chi tiết các hệ số...
# answer        Để đánh giá độ tin cậy và sự nhất quán giữa cá...
# Name: 2328, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ thần kinh, cu...
# question      Bác sĩ có thể giải thích về vai trò của thang ...
# answer        Thang điểm NIHSS (National Institutes of Healt...
# Name: 2329, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh th...
# question      Xin vui lòng tóm tắt các mốc thời gian quan tr...
# answer        Dựa trên các nghiên cứu và phân tích, các mốc ...
# Name: 2330, dtype: object
# intruction    Chatbot y khoa chuyên về đánh giá đột quỵ cấp,...
# question      So sánh điểm ASPECTS của nghiên cứu của bạn vớ...
# answer        Nghiên cứu của chúng tôi đã so sánh điểm ASPEC...
# Name: 2331, dtype: object
# intruction    Chatbot y khoa chuyên về đánh giá mức độ đồng ...
# question      Vui lòng mô tả mức độ đồng thuận giữa các phươ...
# answer        Mức độ đồng thuận giữa các phương pháp đánh gi...
# Name: 2332, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng đ...
# question      Dựa trên nghiên cứu, hãy trình bày các chỉ số ...
# answer        Nghiên cứu đã cung cấp những thông tin quan tr...
# Name: 2333, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ cấp, cung cấp...
# question      ASPECTS là gì và vai trò của Rapid ASPECTS tro...
# answer        ASPECTS (Alberta Stroke Program Early CT Score...
# Name: 2334, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh th...
# question      Hãy so sánh sự khác biệt giữa việc đánh giá đi...
# answer        Trong chẩn đoán đột quỵ thiếu máu não cấp tính...
# Name: 2335, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu y học và đ...
# question      Những hạn chế chính của công cụ Rapid ASPECTS ...
# answer        Mặc dù Rapid ASPECTS là một công cụ tự động hữ...
# Name: 2336, dtype: object
# intruction    Chatbot y khoa chuyên về các công cụ hỗ trợ ch...
# question      Vui lòng cho biết những ưu điểm chính của phần...
# answer        Phần mềm Rapid ASPECTS đại diện cho một bước t...
# Name: 2337, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ thiếu máu não...
# question      Khi đánh giá đột quỵ thiếu máu não cấp tính, R...
# answer        Khi đánh giá đột quỵ thiếu máu não cấp tính, v...
# Name: 2338, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ và chẩn đoán ...
# question      Xin chào, tôi muốn tìm hiểu chi tiết về vai tr...
# answer        Chào bạn, thang điểm ASPECTS (Alberta Stroke P...
# Name: 2339, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh lý mạch máu não,...
# question      Thang điểm NIHSS được sử dụng như thế nào tron...
# answer        Thang điểm NIHSS (National Institutes of Healt...
# Name: 2340, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu y học, tổn...
# question      Các yếu tố nguy cơ của đột quỵ, đặc biệt là li...
# answer        Dựa trên các nghiên cứu khoa học, đột quỵ là m...
# Name: 2341, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ, cung cấp thô...
# question      Có thể tổng hợp các phương pháp và công cụ hìn...
# answer        Trong chẩn đoán và quản lý nhồi máu não cấp tí...
# Name: 2342, dtype: object
# intruction    Chatbot y khoa chuyên về ứng dụng công nghệ tr...
# question      Các nghiên cứu đã đánh giá hiệu suất của phần ...
# answer        Phần mềm ASPECTS tự động là một ứng dụng đột p...
# Name: 2343, dtype: object
# intruction    Chatbot y khoa chuyên về thần kinh học và cấp ...
# question      Xin hãy tóm tắt các phương pháp đánh giá ban đ...
# answer        Trong đột quỵ thiếu máu não cấp (ICD-10: I63),...
# Name: 2344, dtype: object
# intruction    Chatbot y khoa chuyên về hình ảnh học thần kin...
# question      NIH Stroke Scale (NIHSS) và ASPECTS đóng vai t...
# answer        NIH Stroke Scale (NIHSS) và Thang điểm ASPECT ...
# Name: 2345, dtype: object
# intruction    Chatbot y khoa chuyên về dược lý lâm sàng và c...
# question      Trong đột quỵ thiếu máu não cấp, sự khác biệt ...
# answer        Trong bối cảnh cấp cứu đột quỵ thiếu máu não (...
# Name: 2346, dtype: object
# intruction    Chatbot y khoa chuyên về tổng hợp nghiên cứu v...
# question      Liệt kê các chủ đề nghiên cứu chính liên quan ...
# answer        Các tài liệu tham khảo đã cung cấp cái nhìn tổ...
# Name: 2347, dtype: object
# intruction    Chatbot y khoa chuyên về tiêu chuẩn đánh giá v...
# question      Trình bày tóm tắt về vai trò và các ngưỡng giá...
# answer        Thang điểm NIH Stroke Scale (NIHSS) là một côn...
# Name: 2348, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh và...
# question      Thang điểm ASPECTS là gì và tại sao nó lại qua...
# answer        Thang điểm ASPECTS (Alberta Stroke Program Ear...
# Name: 2349, dtype: object
# intruction    Chatbot y khoa chuyên về phương pháp nghiên cứ...
# question      Nghiên cứu này đã sử dụng những phương pháp nà...
# answer        Nghiên cứu về ứng dụng thang điểm Rapid ASPECT...
# Name: 2350, dtype: object
# intruction    Chatbot y khoa cung cấp thông tin tóm tắt về c...
# question      Tóm tắt các kết luận chính từ nghiên cứu về ứn...
# answer        Nghiên cứu về ứng dụng thang điểm Rapid ASPECT...
# Name: 2351, dtype: object
# intruction    Chatbot y khoa chuyên về các công cụ và thang ...
# question      Vui lòng cung cấp một cái nhìn tổng quan về cá...
# answer        Trong nghiên cứu về ứng dụng thang điểm Rapid ...
# Name: 2352, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y học, phân ...
# question      Phân tích mức độ đồng thuận của thang điểm Rap...
# answer        Mức độ đồng thuận giữa các phương pháp đánh gi...
# Name: 2353, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ não, cung cấp...
# question      Đột quỵ thiếu máu não là gì? Xin hãy cung cấp ...
# answer        Đột quỵ thiếu máu não (ICD-10: I63 - Nhồi máu ...
# Name: 2354, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ não, cung cấp...
# question      Xin hãy trình bày chi tiết về thang điểm ASPEC...
# answer        Thang điểm ASPECTS (Alberta Stroke Program Ear...
# Name: 2355, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ não, hỗ trợ đ...
# question      Thách thức chính của thang điểm ASPECTS truyền...
# answer        Thang điểm ASPECTS truyền thống, mặc dù có giá...
# Name: 2356, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ não, tổng hợp...
# question      Hãy tóm tắt phương pháp và kết quả chính của n...
# answer        Nghiên cứu về Rapid ASPECTS được thực hiện tại...
# Name: 2357, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ não, cung cấp...
# question      Dựa trên nghiên cứu, hãy so sánh mức độ tương ...
# answer        Nghiên cứu đã sử dụng hệ số tương quan nội nhó...
# Name: 2358, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng, ...
# question      Một sinh viên y khoa hỏi: "Nghiên cứu này được...
# answer        Nghiên cứu này được thiết kế theo phương pháp ...
# Name: 2359, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học thần kinh, c...
# question      Một bác sĩ lâm sàng hỏi: "Những tiêu chuẩn nào...
# answer        Trong nghiên cứu này, việc lựa chọn và loại tr...
# Name: 2360, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh, c...
# question      Một kỹ thuật viên chẩn đoán hình ảnh hỏi: "Các...
# answer        Trong nghiên cứu này, có ba phương pháp chính ...
# Name: 2361, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y học và dịc...
# question      Một nhà nghiên cứu y học hỏi: "Vui lòng cho tô...
# answer        Đặc điểm phân bố tuổi của 188 bệnh nhân nhồi m...
# Name: 2362, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học thần kinh và...
# question      Tôi cần hiểu rõ hơn về đối tượng nghiên cứu và...
# answer        Đối tượng nghiên cứu chính là tất cả các bệnh ...
# Name: 2363, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học thần kinh, c...
# question      Xin hãy phân tích chi tiết đặc điểm về tuổi củ...
# answer        Dựa trên dữ liệu nghiên cứu, nhóm bệnh nhân có...
# Name: 2364, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng v...
# question      Anh/chị có thể tóm tắt các đặc điểm về giới tí...
# answer        Nghiên cứu này cho thấy một số đặc điểm nhân k...
# Name: 2365, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh và...
# question      Trong bối cảnh cấp cứu đột quỵ, thời gian từ k...
# answer        Trong cấp cứu đột quỵ, 'thời gian là não', do ...
# Name: 2366, dtype: object
# intruction    Chatbot y khoa chuyên về thống kê y tế và dịch...
# question      Xin vui lòng tổng hợp phân bố theo giới tính c...
# answer        Đặc điểm phân bố theo giới tính là một yếu tố ...
# Name: 2367, dtype: object
# intruction    Chatbot y khoa chuyên về đánh giá mức độ đột q...
# question      Xin vui lòng cung cấp thông tin chi tiết về ph...
# answer        Thang điểm Đột quỵ của Viện Sức khỏe Quốc gia ...
# Name: 2368, dtype: object
# intruction                                                 None
# question      Dựa trên nghiên cứu này, anh/chị có thể cho bi...
# answer        Nghiên cứu đã cung cấp cái nhìn chi tiết về đi...
# Name: 2369, dtype: object
# intruction                                                 None
# question      Vai trò của thang điểm ASPECTS trong đánh giá ...
# answer        Thang điểm ASPECTS (Alberta Stroke Program Ear...
# Name: 2370, dtype: object
# intruction                                                 None
# question      Tóm tắt các kết luận chính của nghiên cứu này ...
# answer        Nghiên cứu đã đánh giá mức độ đồng thuận của đ...
# Name: 2371, dtype: object
# intruction                                                 None
# question      Anh/chị có thể mô tả các phương pháp đánh giá ...
# answer        Trong chẩn đoán đột quỵ nhồi máu não cấp, việc...
# Name: 2372, dtype: object
# intruction                                                 None
# question      Nghiên cứu đã sử dụng những hệ số thống kê nào...
# answer        Để đánh giá mức độ đồng thuận và độ phù hợp gi...
# Name: 2373, dtype: object
# intruction    Chatbot y khoa chuyên về hình ảnh học thần kin...
# question      Xin chào. Tôi muốn tìm hiểu về các kết quả đồn...
# answer        Dựa trên nghiên cứu, sự đồng thuận giữa Rapid ...
# Name: 2374, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học đột quỵ v...
# question      Phân tích cụ thể hơn về sự khác biệt về tuổi t...
# answer        Trong nghiên cứu của chúng tôi, tuổi trung bìn...
# Name: 2375, dtype: object
# intruction    Chatbot y khoa chuyên về đánh giá mức độ nặng ...
# question      Tóm tắt về mức độ nặng của đột quỵ thiếu máu n...
# answer        Trong nghiên cứu được trình bày, độ nặng của đ...
# Name: 2376, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và phòng ngừ...
# question      Tổng hợp các yếu tố nguy cơ chính gây đột quỵ ...
# answer        Đột quỵ thiếu máu não cấp (ICD-10: I63) là một...
# Name: 2377, dtype: object
# intruction    Chatbot y khoa chuyên về so sánh các phương ph...
# question      Cung cấp một bảng so sánh chi tiết về hệ số Ka...
# answer        Để đánh giá mức độ đồng thuận giữa các phương ...
# Name: 2378, dtype: object
# intruction    Chatbot y khoa chuyên về thần kinh học, cung c...
# question      Xin vui lòng giải thích vai trò của thang điểm...
# answer        Thang điểm NIHSS (National Institutes of Healt...
# Name: 2379, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh th...
# question      Các nghiên cứu đã ghi nhận những điểm ASPECTS ...
# answer        Trong đánh giá đột quỵ nhồi máu cấp, các thang...
# Name: 2380, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng đ...
# question      Những phát hiện chính về mức độ đồng thuận giữ...
# answer        Nghiên cứu đã cho thấy những kết quả đáng chú ...
# Name: 2381, dtype: object
# intruction    Chatbot y khoa chuyên về các tiêu chuẩn chẩn đ...
# question      Thang điểm ASPECTS và các biến thể của nó (như...
# answer        Thang điểm ASPECTS (Alberta Stroke Program Ear...
# Name: 2382, dtype: object
# intruction    Chatbot y khoa chuyên về quy trình chẩn đoán đ...
# question      Vui lòng trình bày tổng quan về các mốc thời g...
# answer        Trong quy trình cấp cứu đột quỵ, thời gian là ...
# Name: 2383, dtype: object
# intruction    Chatbot y khoa chuyên về hình ảnh học thần kin...
# question      Xin hãy giải thích về công cụ Rapid ASPECTS và...
# answer        Rapid ASPECTS là một công cụ tự động được thiế...
# Name: 2384, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học thần kinh, h...
# question      So sánh ưu nhược điểm của Rapid ASPECTS so với...
# answer        Trong chẩn đoán đột quỵ thiếu máu não cấp tính...
# Name: 2385, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu y học, hỗ ...
# question      Tổng kết lại mức độ phù hợp của phần mềm Rapid...
# answer        Kết quả nghiên cứu đã chỉ ra rằng phần mềm tín...
# Name: 2386, dtype: object
# intruction    Chatbot y khoa chuyên về can thiệp mạch máu nã...
# question      Mặc dù Rapid ASPECTS hữu ích, nhưng cần lưu ý ...
# answer        Mặc dù Rapid ASPECTS là một công cụ tự động hữ...
# Name: 2387, dtype: object
# intruction    Chatbot y khoa chuyên về y học cấp cứu, cung c...
# question      Để đánh giá đột quỵ thiếu máu não cấp tính, có...
# answer        Trong bối cảnh cấp cứu đột quỵ thiếu máu não, ...
# Name: 2388, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh lý thần kinh, cu...
# question      Trình bày về thang điểm ASPECTS và tầm quan tr...
# answer        Thang điểm ASPECTS (Alberta Stroke Program Ear...
# Name: 2389, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh th...
# question      Các công nghệ tự động hóa và trí tuệ nhân tạo ...
# answer        Các công nghệ tự động hóa và trí tuệ nhân tạo ...
# Name: 2390, dtype: object
# intruction    Chatbot y khoa chuyên về dược lý và phác đồ đi...
# question      Thang điểm NIHSS (National Institutes of Healt...
# answer        Thang điểm NIHSS là một công cụ đánh giá thần ...
# Name: 2391, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng, ...
# question      Vui lòng tổng hợp các nghiên cứu nổi bật về hi...
# answer        Các nghiên cứu gần đây đã liên tục đánh giá hi...
# Name: 2392, dtype: object
# intruction    Chatbot y khoa chuyên về y học cấp cứu, cung c...
# question      Phân tích các yếu tố liên quan đến thang điểm ...
# answer        Thang điểm ASPECTS là một công cụ thiết yếu để...
# Name: 2393, dtype: object
# intruction    Chatbot y khoa chuyên về đột quỵ cấp, cung cấp...
# question      Xin chào Chatbot, tôi là sinh viên y khoa năm ...
# answer        Thang điểm NIH Stroke Scale (NIHSS) là một côn...
# Name: 2394, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh th...
# question      Tôi đang làm nghiên cứu về đột quỵ nhồi máu cấ...
# answer        Để đánh giá những thay đổi thiếu máu não sớm t...
# Name: 2395, dtype: object
# intruction    Chatbot y khoa chuyên về quản lý và điều trị đ...
# question      Đối với bệnh nhân đột quỵ nhồi máu cấp được đi...
# answer        Đối với bệnh nhân đột quỵ nhồi máu cấp được đi...
# Name: 2396, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu đột quỵ, t...
# question      Tôi cần tổng quan về một số nghiên cứu gần đây...
# answer        Chắc chắn rồi. Các nghiên cứu về đột quỵ nhồi ...
# Name: 2397, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán hình ảnh và...
# question      Về thang điểm ASPECTS trong đột quỵ nhồi máu n...
# answer        Thang điểm Alberta Stroke Program Early CT Sco...
# Name: 2398, dtype: object
# intruction                                                 None
# question      Nghiên cứu về hoạt động thể lực ở sinh viên Y ...
# answer        Nghiên cứu mô tả cắt ngang trên 416 sinh viên ...
# Name: 2399, dtype: object
# intruction                                                 None
# question      Vui lòng mô tả chi tiết đối tượng và phương ph...
# answer        Nghiên cứu về thực trạng hoạt động thể lực và ...
# Name: 2400, dtype: object
# intruction                                                 None
# question      Từ kết quả nghiên cứu về hoạt động thể lực của...
# answer        Dựa trên kết quả nghiên cứu về thực trạng hoạt...
# Name: 2401, dtype: object
# intruction                                                 None
# question      Nghiên cứu về hoạt động thể lực của sinh viên ...
# answer        Nghiên cứu đã chỉ ra những khác biệt rõ rệt về...
# Name: 2402, dtype: object
# intruction                                                 None
# ...
# answer        Để nâng cao an toàn trong tiêm truyền và giảm ...
# Name: 4702, dtype: object
# intruction    Chatbot y khoa chuyên về chẩn đoán, phân loại ...
# question      Trong trường hợp bệnh nhân SVT chi trên liên q...
# answer        Trong trường hợp ca lâm sàng về huyết khối tĩn...
# Name: 4703, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question      Xin hãy cho biết các biện pháp chính để giảm t...
# answer        Để giảm thiểu các biến chứng liên quan đến tiê...
# Name: 4704, dtype: object
# intruction    Chatbot y khoa chuyên về dược học và nghiên cứ...
# question      Các tài liệu tham khảo nào được sử dụng để xây...
# answer        Dựa trên các tài liệu tham khảo được trích dẫn...
# Name: 4705, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và điều trị,...
# question      Viêm tĩnh mạch và huyết khối tĩnh mạch nông có...
# answer        Viêm tĩnh mạch (phlebitis) và huyết khối tĩnh ...
# Name: 4706, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu y học, cun...
# question      Xin hãy trình bày về các vai trò và đóng góp c...
# answer        Nghiên cứu được hoàn thành nhờ sự đóng góp đa ...
# Name: 4707, dtype: object
# intruction    Chatbot y khoa chuyên về quản lý chất lượng bệ...
# question      Thông tin về hệ thống đào tạo định kỳ và các t...
# answer        Hệ thống đào tạo định kỳ đóng vai trò cốt yếu ...
# Name: 4708, dtype: object
# intruction    Chatbot y khoa chuyên về y học, cung cấp thông...
# question      Dựa trên nghiên cứu tại Bệnh viện Hữu Nghị, đâ...
# answer        Nghiên cứu mô tả cắt ngang tại khoa Hồi sức tí...
# Name: 4709, dtype: object
# intruction    Chatbot y khoa chuyên về y học, cung cấp thông...
# question      Theo nghiên cứu được đề cập, các tác nhân vi k...
# answer        Theo nghiên cứu từ Bệnh viện Hữu Nghị, các tác...
# Name: 4710, dtype: object
# intruction    Chatbot y khoa chuyên về y học, cung cấp thông...
# question      Đặc điểm hình ảnh nội soi phế quản ở bệnh nhân...
# answer        Trong nghiên cứu tại Bệnh viện Hữu Nghị trên 3...
# Name: 4711, dtype: object
# intruction    Chatbot y khoa chuyên về y học, cung cấp thông...
# question      Bạn có thể tóm tắt các đặc điểm về hình ảnh nộ...
# answer        Dưới đây là bảng tổng hợp các đặc điểm chính v...
# Name: 4712, dtype: object
# intruction    Chatbot y khoa chuyên về y học, cung cấp thông...
# question      Vui lòng liệt kê các vi khuẩn cụ thể gây Viêm ...
# answer        Dựa trên kết quả nuôi cấy dịch phế quản và khá...
# Name: 4713, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh lý hô hấp, vi si...
# question      Theo nghiên cứu được trình bày, xin vui lòng m...
# answer        Viêm phổi bệnh viện (VPBV) là một nhiễm trùng ...
# Name: 4714, dtype: object
# intruction    Chatbot y khoa chuyên về dược lý lâm sàng, vi ...
# question      Đối với *Pseudomonas aeruginosa*, một trong nh...
# answer        Vi khuẩn *Pseudomonas aeruginosa* là một mầm b...
# Name: 4715, dtype: object
# intruction    Chatbot y khoa chuyên về triệu chứng học, sinh...
# question      Phân tích các đặc điểm của dịch tiết đường hô ...
# answer        Trong nghiên cứu này, các đặc điểm của dịch ti...
# Name: 4716, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học vi sinh, ...
# question      Để có cái nhìn tổng quan về tình hình vi khuẩn...
# answer        Dưới đây là bảng tổng hợp chi tiết về các tác ...
# Name: 4717, dtype: object
# intruction    Chatbot y khoa chuyên về dược lý lâm sàng, quả...
# question      Với dữ liệu về đề kháng kháng sinh của *Pseudo...
# answer        Hiểu rõ hồ sơ đề kháng kháng sinh của *Pseudom...
# Name: 4718, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh truyền nhiễm và ...
# question      Dựa trên nghiên cứu này, anh/chị có thể cho bi...
# answer        Trong nghiên cứu được thực hiện trên 39 bệnh n...
# Name: 4719, dtype: object
# intruction    Chatbot y khoa chuyên về dược lý kháng sinh và...
# question      Xin hãy tổng hợp mức độ đề kháng kháng sinh củ...
# answer        Vi khuẩn Acinetobacter baumannii cho thấy mức ...
# Name: 4720, dtype: object
# intruction    Chatbot y khoa chuyên về vi sinh lâm sàng và đ...
# question      So với Acinetobacter baumannii, mức độ đề khán...
# answer        Vi khuẩn Klebsiella pneumoniae cũng là một tác...
# Name: 4721, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học bệnh viện...
# question      Anh/chị có thể cung cấp một bảng tổng hợp các ...
# answer        Nghiên cứu về các tác nhân gây viêm phổi bệnh ...
# Name: 4722, dtype: object
# intruction    Chatbot y khoa chuyên về dược lâm sàng và vi s...
# question      Vui lòng cung cấp một phân tích chi tiết về mứ...
# answer        Phân tích mức độ đề kháng kháng sinh của Acine...
# Name: 4723, dtype: object
# intruction    Chatbot y khoa chuyên về vi sinh lâm sàng, dượ...
# question      Bác sĩ có thể cho biết về tình hình đề kháng k...
# answer        Tình trạng đề kháng kháng sinh (Antimicrobial ...
# Name: 4724, dtype: object
# intruction    Chatbot y khoa chuyên về lão khoa, chấn thương...
# question      Xin vui lòng tổng hợp kết quả của nghiên cứu v...
# answer        Nghiên cứu đã đánh giá cụ thể kết quả điều trị...
# Name: 4725, dtype: object
# intruction    Chatbot y khoa chuyên về hô hấp, hồi sức tích ...
# question      Bác sĩ có thể tóm tắt các điểm chính về viêm p...
# answer        Viêm phổi bệnh viện (Hospital-acquired pneumon...
# Name: 4726, dtype: object
# intruction    Chatbot y khoa chuyên về thủ thuật can thiệp h...
# question      Tôi muốn biết vai trò và lợi ích của nội soi p...
# answer        Nội soi phế quản ống mềm (flexible bronchoscop...
# Name: 4727, dtype: object
# intruction    Chatbot y khoa chuyên về quản lý bệnh mạn tính...
# question      Dựa trên các nghiên cứu đã được thảo luận, đâu...
# answer        Từ hai nghiên cứu chính được đề cập, có thể rú...
# Name: 4728, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học hô hấp, cung...
# question      Xin chào, tôi muốn tìm hiểu tổng quan về Viêm ...
# answer        Viêm phổi bệnh viện (VPBV), theo phân loại ICD...
# Name: 4729, dtype: object
# intruction    Chatbot y khoa chuyên về dược học lâm sàng, cu...
# question      Dựa trên các nghiên cứu mới nhất, đặc điểm đề ...
# answer        Dựa trên các nghiên cứu gần đây về Viêm phổi b...
# Name: 4730, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng, ...
# question      Nghiên cứu về Viêm phổi bệnh viện trên bệnh nh...
# answer        Nghiên cứu về Viêm phổi bệnh viện (VPBV) trên ...
# Name: 4731, dtype: object
# intruction    Chatbot y khoa chuyên về nội soi và hình ảnh h...
# question      Trong chẩn đoán Viêm phổi bệnh viện, các loại ...
# answer        Trong quá trình chẩn đoán Viêm phổi bệnh viện ...
# Name: 4732, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học lâm sàng,...
# question      Có thể cung cấp thông tin chi tiết về tình hìn...
# answer        Tình hình đề kháng kháng sinh của vi khuẩn Gra...
# Name: 4733, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học hô hấp và vi...
# question      Xin hãy tóm tắt các tác nhân vi khuẩn chủ yếu ...
# answer        Theo nghiên cứu, tác nhân vi khuẩn chính gây v...
# Name: 4734, dtype: object
# intruction    Chatbot y khoa chuyên về triệu chứng học và bệ...
# question      Dịch tiết đường hô hấp của bệnh nhân viêm phổi...
# answer        Dựa trên nghiên cứu được cung cấp, dịch tiết đ...
# Name: 4735, dtype: object
# intruction    Chatbot y khoa chuyên về vi sinh lâm sàng và d...
# question      Tôi muốn biết các nhóm vi khuẩn chính gây viêm...
# answer        Nghiên cứu đã chỉ ra sự phân bố rõ rệt của các...
# Name: 4736, dtype: object
# intruction    Chatbot y khoa chuyên về dược lý lâm sàng và đ...
# question      Mức độ đề kháng của trực khuẩn mủ xanh (Pseudo...
# answer        Trực khuẩn mủ xanh (Pseudomonas aeruginosa) tr...
# Name: 4737, dtype: object
# intruction    Chatbot y khoa chuyên về dược học và kháng sin...
# question      Có thể cung cấp một bảng tổng hợp về tỷ lệ đề ...
# answer        Chắc chắn rồi. Dưới đây là bảng tổng hợp chi t...
# Name: 4738, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và vi sinh l...
# question      Bác sĩ có thể cho tôi biết về mức độ đề kháng ...
# answer        Vi khuẩn Acinetobacter baumannii được biết đến...
# Name: 4739, dtype: object
# intruction    Chatbot y khoa chuyên về điều trị nhiễm khuẩn ...
# question      Với các trường hợp viêm phổi bệnh viện do Kleb...
# answer        Vi khuẩn Klebsiella pneumoniae là một trong nh...
# Name: 4740, dtype: object
# intruction    Chatbot y khoa chuyên về dịch tễ học nhiễm khu...
# question      Theo nghiên cứu được đề cập, các vi khuẩn Gram...
# answer        Trong số các trường hợp viêm phổi bệnh viện ở ...
# Name: 4741, dtype: object
# intruction    Chatbot y khoa chuyên về vi sinh lâm sàng và d...
# question      Hãy tổng hợp các đặc điểm đề kháng kháng sinh ...
# answer        Dựa trên nghiên cứu đã trình bày và kiến thức ...
# Name: 4742, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học hô hấp và hồ...
# question      Xin vui lòng cung cấp phân bố tỷ lệ cụ thể của...
# answer        Nghiên cứu được thực hiện trên 39 bệnh nhân th...
# Name: 4743, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và điều trị,...
# question      Xin hãy tóm tắt những phát hiện chính về tình ...
# answer        Nghiên cứu đã chỉ ra rằng tình trạng đề kháng ...
# Name: 4744, dtype: object
# intruction    Chatbot y khoa chuyên về dược học và chiến lượ...
# question      Đối với bệnh nhân viêm phổi bệnh viện do vi kh...
# answer        Dựa trên kết quả nghiên cứu và kiến thức y kho...
# Name: 4745, dtype: object
# intruction    Chatbot y khoa chuyên về y học lão khoa và xươ...
# question      Nghiên cứu về loãng xương sau thay khớp háng đ...
# answer        Nghiên cứu tại Bệnh viện Thống Nhất đã khẳng đ...
# Name: 4746, dtype: object
# intruction    Chatbot y khoa chuyên về nghiên cứu lâm sàng v...
# question      Xin vui lòng trình bày các vi khuẩn chính và m...
# answer        Trong nghiên cứu về tình hình đề kháng kháng s...
# Name: 4747, dtype: object
# intruction    Chatbot y khoa chuyên về y học lâm sàng và quả...
# question      Nghiên cứu tại Bệnh viện Thống Nhất về điều tr...
# answer        Nghiên cứu hồi cứu mô tả tại Bệnh viện Thống N...
# Name: 4748, dtype: object
# intruction    Chatbot y khoa chuyên về y học lâm sàng, cung ...
# question      Xin hãy mô tả chi tiết ca lâm sàng huyết khối ...
# answer        Báo cáo ca lâm sàng mô tả một trường hợp hiếm ...
# Name: 4749, dtype: object
# intruction    Chatbot y khoa chuyên về quản lý chất lượng và...
# question      Theo báo cáo ca lâm sàng, những sai sót điều d...
# answer        Theo báo cáo ca lâm sàng, có hai sai sót điều ...
# Name: 4750, dtype: object
# intruction    Chatbot y khoa chuyên về quy trình lâm sàng và...
# question      Để nâng cao an toàn tiêm truyền và phòng ngừa ...
# answer        Nhằm nâng cao an toàn tiêm truyền và chủ động ...
# Name: 4751, dtype: object
# intruction    Chatbot y khoa chuyên về bệnh học và chẩn đoán...
# question      Huyết khối tĩnh mạch nông chi trên là gì và nh...
# answer        Huyết khối tĩnh mạch nông (SVT) chi trên là tì...
# Name: 4752, dtype: object
# intruction    Chatbot y khoa chuyên về dược lý lâm sàng và p...
# question      Vui lòng cung cấp thông tin tổng hợp về ca bện...
# answer        Ca bệnh được báo cáo là một ví dụ điển hình về...
# Name: 4753, dtype: object
# intruction    Chatbot y khoa chuyên về nội khoa, cung cấp th...
# question      Xin hãy phân tích chi tiết về diễn tiến lâm sà...
# answer        Diễn tiến lâm sàng của ca bệnh huyết khối tĩnh...
# Name: 4754, dtype: object
# intruction    Chatbot y khoa chuyên về dược lý lâm sàng và b...
# question      Theo tam chứng Virchow, những yếu tố nào đã gó...
# answer        Theo tam chứng Virchow, ba yếu tố chính góp ph...
# Name: 4755, dtype: object
# intruction    Chatbot y khoa chuyên về quản lý phản ứng có h...
# question      Mức độ liên hệ nhân-quả giữa Esomeprazole và b...
# answer        Trong ca bệnh này, mối liên hệ nhân-quả giữa E...
# Name: 4756, dtype: object
# intruction    Chatbot y khoa chuyên về hồ sơ bệnh án và nghi...
# question      Xin vui lòng tổng hợp các sự kiện lâm sàng và ...
# answer        Để thuận tiện cho việc theo dõi diễn biến của ...
# Name: 4757, dtype: object
# intruction    Chatbot y khoa chuyên về đánh giá phản ứng có ...
# question      Hãy trình bày chi tiết về quá trình đánh giá m...
# answer        Quá trình đánh giá mối liên hệ nhân-quả giữa E...
# Name: 4758, dtype: object
# intruction    Chatbot y khoa chuyên về điều dưỡng lâm sàng, ...
# question      Vai trò của điều dưỡng trong việc phát hiện sớ...
# answer        Điều dưỡng đóng vai trò then chốt trong việc đ...
# Name: 4759, dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 76
#      69     new_rows.append({
#      70         "intruction": row["intruction"],
#      71         "question": pq,
#      72         "answer": row["answer"]
#      73     })
#      75 new_df = pd.DataFrame(new_rows)
# ---> 76 with pd.ExcelWriter(output_file, mode="a", engine="openpyxl", if_sheet_exists="overlay") as writer:
#      77     sheet = writer.sheets["Sheet1"]
#      78     start_row = sheet.max_row
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\pandas\io\excel\_openpyxl.py:75, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      72 from openpyxl import load_workbook
#      74 try:
# ---> 75     self._book = load_workbook(self._handles.handle, **engine_kwargs)
#      76 except TypeError:
#      77     self._handles.handle.close()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\reader\excel.py:348, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     318 """Open the given filename and return the workbook
#     319
#     320 :param filename: the path to open or a file-like object
#    (...)
#     344
#     345 """
#     346 reader = ExcelReader(filename, read_only, keep_vba,
#     347                      data_only, keep_links, rich_text)
# --> 348 reader.read()
#     349 return reader.wb
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\reader\excel.py:303, in ExcelReader.read(self)
#     301 apply_stylesheet(self.archive, self.wb)
#     302 action = "read worksheets"
# --> 303 self.read_worksheets()
#     304 action = "assign names"
#     305 self.parser.assign_names()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\reader\excel.py:237, in ExcelReader.read_worksheets(self)
#     235     ws._rels = rels
#     236     ws_parser = WorksheetReader(ws, fh, self.shared_strings, self.data_only, self.rich_text)
# --> 237     ws_parser.bind_all()
#     238     fh.close()
#     240 # assign any comments to cells
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\worksheet\_reader.py:465, in openpyxl.worksheet._reader.WorksheetReader.bind_all()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\worksheet\_reader.py:368, in openpyxl.worksheet._reader.WorksheetReader.bind_cells()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\worksheet\_reader.py:156, in parse()
#
# File c:\Users\PC\.conda\envs\AI\Lib\xml\etree\ElementTree.py:1238, in iterparse.<locals>.iterator(source)
#    1236 yield from pullparser.read_events()
#    1237 # load event buffer
# -> 1238 data = source.read(16 * 1024)
#    1239 if not data:
#    1240     break
#
# File c:\Users\PC\.conda\envs\AI\Lib\zipfile\__init__.py:1015, in ZipExtFile.read(self, n)
#    1013 self._offset = 0
#    1014 while n > 0 and not self._eof:
# -> 1015     data = self._read1(n)
#    1016     if n < len(data):
#    1017         self._readbuffer = data
#
# File c:\Users\PC\.conda\envs\AI\Lib\zipfile\__init__.py:1091, in ZipExtFile._read1(self, n)
#    1089 elif self._compress_type == ZIP_DEFLATED:
#    1090     n = max(n, self.MIN_READ_SIZE)
# -> 1091     data = self._decompressor.decompress(data, n)
#    1092     self._eof = (self._decompressor.eof or
#    1093                  self._compress_left <= 0 and
#    1094                  not self._decompressor.unconsumed_tail)
#    1095     if self._eof:
#
# KeyboardInterrupt:
