# %%
from datasets import load_dataset
from transformers import MT5Tokenizer, MT5ForConditionalGeneration
from tqdm import tqdm
import pandas as pd
import torch
import os

# Kiểm tra GPU
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cuda" )
print(f"💻 Đang sử dụng thiết bị: {device}")

# Load model paraphrase và đưa lên GPU
CKPT = 'chieunq/vietnamese-sentence-paraphase'
tokenizer = MT5Tokenizer.from_pretrained(CKPT)
model = MT5ForConditionalGeneration.from_pretrained(CKPT).to(device)

# Hàm tạo paraphrase
def paraphrase(text, num_return_sequences=5):
    inputs = tokenizer(text, padding='longest', max_length=512, truncation=True, return_tensors='pt')
    inputs = {key: val.to(device) for key, val in inputs.items()}
    output = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_length=512,
        num_return_sequences=num_return_sequences,
        do_sample=True,
        top_p=0.95
    )
    return [tokenizer.decode(o, skip_special_tokens=True) for o in output]

# Load dataset
dataset = pd.read_parquet("../generate_dataset/SVYKHOA_dataset_diagnosis.parquet", engine="fastparquet")

# File Excel đầu ra
output_file = "SVYKHOA_dataset_diagnosis.xlsx"

# Tạo file Excel rỗng nếu chưa có
if not os.path.exists(output_file):
    df_empty = pd.DataFrame(columns=["STT CHƯƠNG", "MÃ CHƯƠNG", "TÊN NHÓM CHÍNH", "MÃ BỆNH", "TÊN BỆNH", "intruction", "question", "symptom", "diagnosis", "document/title", "document/description", "cme/title", "cme/description"])
    df_empty.to_excel(output_file, index=False)

# Đọc số dòng đã có để tiếp tục từ đó
existing_df = pd.read_excel(output_file)
# start_index = len(existing_df)
start_index = 0
print(f"🚀 Bắt đầu từ dòng {start_index}")

# Số lượng mẫu muốn xử lý thêm
max_samples = 273500  # Có thể chỉnh: 10, 100, 500...

# Duyệt dataset từ start_index
for i, row in dataset.iterrows():
    if i < start_index:
        continue
    if i >= start_index + max_samples:
        break
    print(row)

    question = row["question"]   # row là Series
    try:
        paraphrases = paraphrase(question, num_return_sequences=10)
    except Exception as e:
        print(f"Lỗi paraphrase tại mẫu {i}: {e}")
        paraphrases = [question]

    new_rows = []
    for pq in paraphrases:
        new_rows.append({
            "STT CHƯƠNG": row["STT CHƯƠNG"],
            "MÃ CHƯƠNG": row["MÃ CHƯƠNG"],
            "TÊN NHÓM CHÍNH": row["TÊN NHÓM CHÍNH"],
            "MÃ BỆNH": row["MÃ BỆNH"],
            "TÊN BỆNH": row["TÊN BỆNH"],
            "intruction": row["intruction"],
            "question": pq,
            "symptom": row["symptom"],
            "diagnosis": row["diagnosis"],
            "document/title": row["document/title"],
            "document/description": row["document/description"],
            "cme/title": row["cme/title"],
            "cme/description": row["cme/description"]
        })

    new_df = pd.DataFrame(new_rows)
    with pd.ExcelWriter(output_file, mode="a", engine="openpyxl", if_sheet_exists="overlay") as writer:
        sheet = writer.sheets["Sheet1"]
        start_row = sheet.max_row
        new_df.to_excel(writer, header=False, index=False, startrow=start_row)


print("✅ Đã lưu toàn bộ dữ liệu paraphrase vào file Excel.")
# Out:
# 💻 Đang sử dụng thiết bị: cuda
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'T5Tokenizer'.
# The class this function is called from is 'MT5Tokenizer'.
# You are using the default legacy behaviour of the <class 'transformers.models.mt5.tokenization_mt5.MT5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# 🚀 Bắt đầu từ dòng 0
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                               A00
# TÊN BỆNH                                                          Bệnh tả
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Một bệnh nhân đến khám với triệu chứng tiêu ch...
# symptom                 Bệnh nhân có khởi phát đột ngột tiêu chảy nhiề...
# diagnosis               Nghi ngờ lâm sàng Bệnh tả (ICD-10 A00 - Choler...
# document/title          Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# document/description    Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# cme/title               Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# cme/description         Khóa học đào tạo y khoa liên tục (CME) dành ch...
# Name: 0, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                               A00
# TÊN BỆNH                                                          Bệnh tả
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để nhận biết và chẩn đoán bệnh tả ...
# symptom                 Bệnh nhân có tiêu chảy liên tục (>5 lần/giờ), ...
# diagnosis               Bệnh tả có mất nước nặng (ICD-10 A00.0 - Chole...
# document/title          Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# document/description    Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# cme/title               Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# cme/description         Khóa học đào tạo y khoa liên tục (CME) dành ch...
# Name: 1, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                               A00
# TÊN BỆNH                                                          Bệnh tả
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những xét nghiệm cận lâm sàng nào cần được thự...
# symptom                 Bệnh nhân có triệu chứng lâm sàng nghi ngờ tả ...
# diagnosis               Xác định chẩn đoán Bệnh tả (ICD-10 A00) bằng p...
# document/title          Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# document/description    Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# cme/title               Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# cme/description         Khóa học đào tạo y khoa liên tục (CME) dành ch...
# Name: 2, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                               A00
# TÊN BỆNH                                                          Bệnh tả
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Nguyên tắc điều trị bệnh tả là gì, đặc biệt tr...
# symptom                 Bệnh nhân được chẩn đoán xác định hoặc nghi ng...
# diagnosis               Nguyên tắc điều trị Bệnh tả (ICD-10 A00) bao g...
# document/title          Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# document/description    Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# cme/title               Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# cme/description         Khóa học đào tạo y khoa liên tục (CME) dành ch...
# Name: 3, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                               A00
# TÊN BỆNH                                                          Bệnh tả
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các biện pháp phòng ngừa và kiểm soát dịch bện...
# symptom                 Không có triệu chứng lâm sàng cụ thể của bệnh ...
# diagnosis               Các biện pháp phòng ngừa và kiểm soát Bệnh tả ...
# document/title          Hướng dẫn chẩn đoán, điều trị và phòng chống B...
# document/description    Tài liệu chuyên sâu về dịch tễ học, cơ chế bện...
# cme/title               Cập nhật quản lý Bệnh tả: Từ chẩn đoán đến kiể...
# cme/description         Khóa học đào tạo y khoa liên tục (CME) dành ch...
# Name: 4, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A00.0
# TÊN BỆNH                Bệnh tả do Vibrio cholerae 01, typ sinh học ch...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để nhận biết sớm các triệu chứng c...
# symptom                 Khởi phát đột ngột tiêu chảy nước ồ ạt, không ...
# diagnosis               Chẩn đoán ban đầu dựa trên lâm sàng: tiêu chảy...
# document/title          Hướng dẫn chẩn đoán và điều trị bệnh tả của Bộ...
# document/description    Tài liệu này cung cấp các tiêu chuẩn chẩn đoán...
# cme/title               Cập nhật chẩn đoán và quản lý ban đầu bệnh tả ...
# cme/description         Khóa học trang bị kiến thức mới nhất về nhận d...
# Name: 5, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A00.0
# TÊN BỆNH                Bệnh tả do Vibrio cholerae 01, typ sinh học ch...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các dấu hiệu và chỉ số lâm sàng nào cho thấy b...
# symptom                 Mất nước nghiêm trọng được biểu hiện bằng các ...
# diagnosis               Chẩn đoán mất nước nặng dựa trên tiêu chuẩn củ...
# document/title          Sổ tay quản lý ca bệnh tiêu chảy cấp có mất nư...
# document/description    Sổ tay này cung cấp hướng dẫn toàn diện cho cá...
# cme/title               Quản lý cấp cứu bệnh nhân tả bị sốc giảm thể t...
# cme/description         Khóa học tập trung vào các kỹ thuật bù dịch tĩ...
# Name: 6, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A00.0
# TÊN BỆNH                Bệnh tả do Vibrio cholerae 01, typ sinh học ch...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các phương pháp cận lâm sàng nào được sử dụng ...
# symptom                 Bệnh nhân có thể có các triệu chứng lâm sàng đ...
# diagnosis               Chẩn đoán xác định bệnh tả (A00.0) dựa vào: 1....
# document/title          Hướng dẫn kỹ thuật xét nghiệm vi khuẩn tả của ...
# document/description    Tài liệu này trình bày chi tiết các quy trình ...
# cme/title               Kỹ thuật chẩn đoán vi sinh và sinh học phân tử...
# cme/description         Khóa học đào tạo chuyên sâu về các phương pháp...
# Name: 7, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A00.0
# TÊN BỆNH                Bệnh tả do Vibrio cholerae 01, typ sinh học ch...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Phác đồ điều trị bệnh tả (A00.0) tập trung vào...
# symptom                 Bệnh nhân mắc bệnh tả có các mức độ mất nước k...
# diagnosis               Chẩn đoán xác định bệnh tả (A00.0) và phân loạ...
# document/title          Phác đồ điều trị tiêu chảy cấp có mất nước và ...
# document/description    Đây là tài liệu hướng dẫn chuẩn hóa về việc bù...
# cme/title               Quản lý điều trị toàn diện bệnh tả: Từ bù dịch...
# cme/description         Khóa học cung cấp kiến thức thực hành về các p...
# Name: 8, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A00.0
# TÊN BỆNH                Bệnh tả do Vibrio cholerae 01, typ sinh học ch...
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các biện pháp phòng ngừa bệnh tả (A00.0) hiệu ...
# symptom                 Mặc dù không trực tiếp là triệu chứng lâm sàng...
# diagnosis               Chẩn đoán tình hình dịch tễ và nguy cơ lây nhi...
# document/title          Hướng dẫn quốc gia về vệ sinh môi trường và ph...
# document/description    Tài liệu cung cấp các khuyến nghị về vệ sinh n...
# cme/title               Vắc-xin tả và vai trò trong chiến lược phòng c...
# cme/description         Khóa học thảo luận về các loại vắc-xin tả hiện...
# Name: 9, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A00.1
# TÊN BỆNH                Bệnh tả do Vibrio cholerae 01, typ sinh học eltor
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các dấu hiệu và triệu chứng điển hình của bệnh...
# symptom                 Bệnh khởi phát cấp tính với tiêu chảy dữ dội, ...
# diagnosis               Nghi ngờ bệnh tả do Vibrio cholerae O1, typ si...
# document/title          Hướng dẫn nhận biết sớm triệu chứng bệnh tả và...
# document/description    Tài liệu này cung cấp thông tin chi tiết về cá...
# cme/title               Tiếp cận chẩn đoán lâm sàng tiêu chảy cấp nghi...
# cme/description         Khóa học CME này tập trung vào kỹ năng hỏi bện...
# Name: 10, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A00.1
# TÊN BỆNH                Bệnh tả do Vibrio cholerae 01, typ sinh học eltor
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Đối với bệnh nhân bệnh tả do Vibrio cholerae O...
# symptom                 Mất nước nặng biểu hiện qua các dấu hiệu: Mắt ...
# diagnosis               Chẩn đoán bệnh tả do Vibrio cholerae O1, typ s...
# document/title          Phác đồ cấp cứu và điều trị mất nước nặng, sốc...
# document/description    Tài liệu hướng dẫn chi tiết về các bước cấp cứ...
# cme/title               Quản lý cấp cứu bệnh nhân tả có biến chứng mất...
# cme/description         Khóa học CME này trang bị kiến thức và kỹ năng...
# Name: 11, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A00.1
# TÊN BỆNH                Bệnh tả do Vibrio cholerae 01, typ sinh học eltor
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Để xác định chính xác bệnh tả do Vibrio choler...
# symptom                 Bệnh nhân có tiền sử tiêu chảy cấp tính, phân ...
# diagnosis               Chẩn đoán xác định bệnh tả do Vibrio cholerae ...
# document/title          Hướng dẫn chẩn đoán phòng thí nghiệm bệnh tả c...
# document/description    Tài liệu này mô tả chi tiết các kỹ thuật phòng...
# cme/title               Các kỹ thuật chẩn đoán vi sinh hiện đại trong ...
# cme/description         Khóa học CME này cung cấp kiến thức chuyên sâu...
# Name: 12, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A00.1
# TÊN BỆNH                Bệnh tả do Vibrio cholerae 01, typ sinh học eltor
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Hãy trình bày phác đồ điều trị đầy đủ cho bệnh...
# symptom                 Bệnh nhân mắc bệnh tả thường có triệu chứng ti...
# diagnosis               Điều trị bệnh tả do Vibrio cholerae O1, typ si...
# document/title          Phác đồ chẩn đoán, điều trị và phòng ngừa bệnh...
# document/description    Tài liệu này cung cấp hướng dẫn toàn diện về c...
# cme/title               Cập nhật phác đồ điều trị bệnh tả: Từ bù dịch ...
# cme/description         Khóa học CME này tập trung vào việc tối ưu hóa...
# Name: 13, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A00.1
# TÊN BỆNH                Bệnh tả do Vibrio cholerae 01, typ sinh học eltor
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những biện pháp nào là quan trọng nhất để phòn...
# symptom                 Không có triệu chứng lâm sàng cá thể trực tiếp...
# diagnosis               Chẩn đoán tình hình dịch tễ và nguy cơ lây lan...
# document/title           Chiến lược toàn cầu về kiểm soát bệnh tả của WHO
# document/description    Tài liệu này trình bày các chiến lược và hành ...
# cme/title                      Y tế công cộng và phòng chống dịch bệnh tả
# cme/description         Khóa học CME này tập trung vào các nguyên tắc ...
# Name: 14, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A00.9
# TÊN BỆNH                                          Bệnh tả, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi muốn biết về các triệu chứng và dấu hiệu n...
# symptom                 Bệnh tả, không đặc hiệu (A00.9), thường khởi p...
# diagnosis               Chẩn đoán ban đầu bệnh tả không đặc hiệu (A00....
# document/title          Hướng dẫn chẩn đoán và điều trị bệnh tả của Bộ...
# document/description    Tài liệu chính thức cung cấp các tiêu chuẩn ch...
# cme/title               Cập nhật kiến thức về dịch tễ học và lâm sàng ...
# cme/description         Khóa học nhằm nâng cao năng lực cho cán bộ y t...
# Name: 15, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A00.9
# TÊN BỆNH                                          Bệnh tả, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để chẩn đoán xác định bệnh tả khôn...
# symptom                 Bệnh nhân thường trình bày với tiêu chảy nước ...
# diagnosis               Chẩn đoán xác định bệnh tả, không đặc hiệu (A0...
# document/title          Phác đồ chẩn đoán và điều trị bệnh truyền nhiễ...
# document/description    Cẩm nang chuyên sâu về các phương pháp chẩn đo...
# cme/title               Kỹ thuật lấy mẫu và chẩn đoán vi sinh vật gây ...
# cme/description         Tập huấn về các quy trình lấy mẫu, vận chuyển ...
# Name: 16, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A00.9
# TÊN BỆNH                                          Bệnh tả, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Bệnh tả A00.9 được điều trị như thế nào, và li...
# symptom                 Bệnh nhân bị tả không đặc hiệu (A00.9) thường ...
# diagnosis               Điều trị bệnh tả, không đặc hiệu (A00.9), tập ...
# document/title          Khuyến nghị của WHO về điều trị và phòng ngừa ...
# document/description    Tài liệu hướng dẫn toàn cầu của Tổ chức Y tế T...
# cme/title               Quản lý bù dịch cấp cứu trong tiêu chảy cấp và...
# cme/description         Khóa học thực hành về kỹ thuật bù dịch đường u...
# Name: 17, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A00.9
# TÊN BỆNH                                          Bệnh tả, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những biến chứng nguy hiểm của bệnh tả (A00.9)...
# symptom                 Bệnh nhân tả không đặc hiệu (A00.9) có nguy cơ...
# diagnosis               Chẩn đoán biến chứng của bệnh tả, không đặc hi...
# document/title          Sổ tay hướng dẫn phòng chống dịch bệnh tả và c...
# document/description    Tài liệu dành cho cộng đồng và cán bộ y tế về ...
# cme/title               Phòng ngừa và kiểm soát lây nhiễm các bệnh tru...
# cme/description         Khóa học cung cấp kiến thức toàn diện về các c...
# Name: 18, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A00.9
# TÊN BỆNH                                          Bệnh tả, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Bệnh tả (A00.9) lây truyền qua đường nào và va...
# symptom                 Mặc dù A00.9 là 'không đặc hiệu', các triệu ch...
# diagnosis               Bệnh tả, không đặc hiệu (A00.9), lây truyền ch...
# document/title          Hướng dẫn quốc gia về giám sát và phòng chống ...
# document/description    Tài liệu chi tiết về hệ thống giám sát dịch tễ...
# cme/title               Quản lý dịch bệnh và ứng phó khẩn cấp trong y ...
# cme/description         Khóa học trang bị cho các chuyên gia y tế công...
# Name: 19, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                               A01
# TÊN BỆNH                                Bệnh thương hàn và phó thương hàn
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Người bệnh có các triệu chứng sốt cao, đau đầu...
# symptom                 Sốt cao liên tục (thường 39-40°C, dạng hình bậ...
# diagnosis               Chẩn đoán xác định bệnh thương hàn và phó thươ...
# document/title          Hướng dẫn chẩn đoán và điều trị bệnh thương hà...
# document/description    Tài liệu chuyên sâu từ Bộ Y tế Việt Nam về địn...
# cme/title               Cập nhật chẩn đoán và quản lý bệnh nhiễm trùng...
# cme/description         Khóa học dành cho bác sĩ nội khoa và bác sĩ đa...
# Name: 20, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                               A01
# TÊN BỆNH                                Bệnh thương hàn và phó thương hàn
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những biến chứng nguy hiểm nào có thể xảy ra ở...
# symptom                 Ngoài các triệu chứng cơ bản của bệnh thương h...
# diagnosis               Chẩn đoán biến chứng của bệnh thương hàn (Mã I...
# document/title          Quản lý biến chứng trong bệnh thương hàn: Hướn...
# document/description    Tài liệu này cung cấp hướng dẫn chi tiết về nh...
# cme/title               Tiếp cận cấp cứu và xử trí biến chứng nặng của...
# cme/description         Khóa học tập trung vào kỹ năng cấp cứu, chẩn đ...
# Name: 21, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                               A01
# TÊN BỆNH                                Bệnh thương hàn và phó thương hàn
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để phân biệt bệnh thương hàn với c...
# symptom                 Bệnh thương hàn cần phân biệt với các bệnh sốt...
# diagnosis               Phân biệt xác định bệnh thương hàn (Mã ICD-10:...
# document/title          Khuyến cáo phân biệt chẩn đoán các bệnh sốt cấ...
# document/description    Tài liệu hướng dẫn lâm sàng giúp các bác sĩ ph...
# cme/title               Phân biệt chẩn đoán và quản lý yếu tố nguy cơ ...
# cme/description         Khóa học này trang bị kiến thức chuyên sâu về ...
# Name: 22, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                               A01
# TÊN BỆNH                                Bệnh thương hàn và phó thương hàn
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những phương pháp điều trị chính cho bệnh thươ...
# symptom                 Trong quá trình điều trị, các triệu chứng như ...
# diagnosis               Điều trị bệnh thương hàn và phó thương hàn (Mã...
# document/title          Phác đồ điều trị bệnh thương hàn và phó thương...
# document/description    Tài liệu này cung cấp các phác đồ điều trị chu...
# cme/title               Sử dụng kháng sinh hợp lý trong điều trị bệnh ...
# cme/description         Khóa học đào tạo chuyên sâu về lựa chọn kháng ...
# Name: 23, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                               A01
# TÊN BỆNH                                Bệnh thương hàn và phó thương hàn
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Để phòng ngừa bệnh thương hàn và phó thương hà...
# symptom                 Không có triệu chứng lâm sàng trực tiếp liên q...
# diagnosis               Các biện pháp phòng ngừa bệnh thương hàn và ph...
# document/title          Chương trình tiêm chủng và vệ sinh phòng chống...
# document/description    Tài liệu của Bộ Y tế hướng dẫn các biện pháp p...
# cme/title               Y tế công cộng và vai trò trong phòng chống bệ...
# cme/description         Khóa học dành cho cán bộ y tế dự phòng và y tế...
# Name: 24, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.0
# TÊN BỆNH                                                       Thương hàn
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Triệu chứng ban đầu của bệnh thương hàn là gì ...
# symptom                 Các triệu chứng ban đầu của bệnh thương hàn (I...
# diagnosis               Dựa trên ICD-10: A01.0 - Thương hàn. Chẩn đoán...
# document/title          Hướng dẫn chẩn đoán và điều trị bệnh Thương hà...
# document/description    Tài liệu chính thức của Bộ Y tế Việt Nam cung ...
# cme/title               Tiếp cận chẩn đoán sớm và quản lý ban đầu bệnh...
# cme/description         Khóa học đào tạo y khoa liên tục tập trung vào...
# Name: 25, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.0
# TÊN BỆNH                                                       Thương hàn
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để chẩn đoán xác định bệnh thương ...
# symptom                 Để chẩn đoán xác định bệnh thương hàn (ICD-10:...
# diagnosis               Chẩn đoán xác định bệnh thương hàn (ICD-10: A0...
# document/title          Phác đồ điều trị và chẩn đoán bệnh Thương hàn ...
# document/description    Tài liệu chuyên sâu về các phương pháp chẩn đo...
# cme/title               Kỹ thuật cấy máu và xét nghiệm vi sinh trong c...
# cme/description         Khóa học cung cấp kiến thức và kỹ năng thực hà...
# Name: 26, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.0
# TÊN BỆNH                                                       Thương hàn
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những biến chứng nguy hiểm nào có thể xảy ra ở...
# symptom                 Các biến chứng của bệnh thương hàn (ICD-10: A0...
# diagnosis               Dựa trên ICD-10: A01.0 - Thương hàn. Các biến ...
# document/title          Biến chứng và xử trí khẩn cấp trong bệnh Thươn...
# document/description    Bài báo khoa học đánh giá các biến chứng thườn...
# cme/title                     Quản lý biến chứng nặng của bệnh Thương hàn
# cme/description         Khóa học tập trung vào việc nhận diện, đánh gi...
# Name: 27, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.0
# TÊN BỆNH                                                       Thương hàn
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Phác đồ điều trị bệnh thương hàn hiện nay theo...
# symptom                 Trước khi điều trị thương hàn (ICD-10: A01.0),...
# diagnosis               Dựa trên ICD-10: A01.0 - Thương hàn. Phác đồ đ...
# document/title          Hướng dẫn chẩn đoán, điều trị và phòng bệnh Th...
# document/description    Văn bản pháp quy của Bộ Y tế Việt Nam quy định...
# cme/title               Cập nhật phác đồ điều trị Thương hàn trong kỷ ...
# cme/description         Khóa học chuyên sâu về các phác đồ điều trị th...
# Name: 28, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.0
# TÊN BỆNH                                                       Thương hàn
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Biện pháp phòng ngừa bệnh thương hàn (A01.0) h...
# symptom                 Các biện pháp phòng ngừa thương hàn (ICD-10: A...
# diagnosis               Dựa trên ICD-10: A01.0 - Thương hàn. Phòng ngừ...
# document/title          Khuyến cáo về phòng ngừa bệnh Thương hàn từ Tổ...
# document/description    Tài liệu tổng hợp các khuyến nghị toàn cầu và ...
# cme/title               Chương trình tiêm chủng và chiến lược phòng ch...
# cme/description         Khóa học cung cấp kiến thức về vai trò của tiê...
# Name: 29, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.1
# TÊN BỆNH                                            Bệnh phó thương hàn A
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Xin chào, tôi muốn tìm hiểu về bệnh phó thương...
# symptom                 Bệnh nhân thường có sốt cao kéo dài, khởi phát...
# diagnosis               Chẩn đoán ban đầu dựa trên lâm sàng với các tr...
# document/title          Hướng dẫn chẩn đoán và điều trị bệnh thương hà...
# document/description    Tài liệu chính thức của Bộ Y tế Việt Nam cung ...
# cme/title               Cập nhật chẩn đoán và quản lý bệnh thương hàn,...
# cme/description         Khóa học CME này tập trung vào các phương pháp...
# Name: 30, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.1
# TÊN BỆNH                                            Bệnh phó thương hàn A
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Bệnh phó thương hàn A (A01.1) có thể gây ra nh...
# symptom                 Ngoài các triệu chứng cơ bản như sốt cao liên ...
# diagnosis               Các biến chứng nghiêm trọng của bệnh phó thươn...
# document/title          Nhận diện và xử trí các biến chứng của bệnh nh...
# document/description    Bài báo khoa học này phân tích sâu về cơ chế b...
# cme/title               Cấp cứu nội khoa các bệnh truyền nhiễm đường t...
# cme/description         Khóa học này trang bị kiến thức và kỹ năng cho...
# Name: 31, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.1
# TÊN BỆNH                                            Bệnh phó thương hàn A
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Để chẩn đoán xác định bệnh phó thương hàn A (A...
# symptom                 Bệnh nhân thường có sốt cao liên tục (nhiệt độ...
# diagnosis               Chẩn đoán xác định bệnh phó thương hàn A (ICD-...
# document/title          Giá trị chẩn đoán của các xét nghiệm vi sinh t...
# document/description    Tài liệu này cung cấp một cái nhìn tổng quan v...
# cme/title               Các kỹ thuật chẩn đoán vi sinh hiện đại trong ...
# cme/description         Khóa học này tập trung vào các kỹ thuật chẩn đ...
# Name: 32, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.1
# TÊN BỆNH                                            Bệnh phó thương hàn A
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Phác đồ điều trị kháng sinh hiện tại cho bệnh ...
# symptom                 Bệnh nhân thường trình bày với sốt cao liên tụ...
# diagnosis               Sau khi xác định chẩn đoán phó thương hàn A (I...
# document/title          Khuyến cáo điều trị bệnh thương hàn và phó thư...
# document/description    Tài liệu này tổng hợp các khuyến nghị quốc tế ...
# cme/title               Chiến lược quản lý kháng kháng sinh trong các ...
# cme/description         Khóa học này cung cấp kiến thức chuyên sâu về ...
# Name: 33, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.1
# TÊN BỆNH                                            Bệnh phó thương hàn A
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để phòng ngừa bệnh phó thương hàn ...
# symptom                 Mặc dù đây là câu hỏi về phòng ngừa, nhưng các...
# diagnosis               Phòng ngừa bệnh phó thương hàn A (ICD-10 A01.1...
# document/title          Hướng dẫn thực hành vệ sinh an toàn thực phẩm ...
# document/description    Tài liệu của Tổ chức Y tế Thế giới (WHO) và Bộ...
# cme/title               Y tế công cộng và các biện pháp can thiệp phòn...
# cme/description         Khóa học này đi sâu vào vai trò của y tế công ...
# Name: 34, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.2
# TÊN BỆNH                                            Bệnh phó thương hàn B
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Bệnh phó thương hàn B là gì và có những triệu ...
# symptom                 Bệnh nhân thường khởi phát với sốt cao liên tụ...
# diagnosis               Chẩn đoán lâm sàng ban đầu nghi ngờ Phó thương...
# document/title          Hướng dẫn chẩn đoán và điều trị bệnh phó thươn...
# document/description    Tài liệu chuyên ngành của Bộ Y tế Việt Nam cun...
# cme/title               Cập nhật chẩn đoán và điều trị bệnh sốt thương...
# cme/description         Khóa học đào tạo y khoa liên tục (CME) dành ch...
# Name: 35, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.2
# TÊN BỆNH                                            Bệnh phó thương hàn B
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Làm thế nào để chẩn đoán xác định bệnh phó thư...
# symptom                 Bệnh nhân thường có tiền sử sốt kéo dài trên 5...
# diagnosis               Chẩn đoán xác định Phó thương hàn B (ICD-10: A...
# document/title          Vai trò của cấy máu trong chẩn đoán sớm bệnh s...
# document/description    Bài báo khoa học đánh giá độ nhạy và độ đặc hi...
# cme/title               Kỹ thuật lấy mẫu và cấy máu trong chẩn đoán bệ...
# cme/description         Khóa học thực hành chuyên sâu dành cho kỹ thuậ...
# Name: 36, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.2
# TÊN BỆNH                                            Bệnh phó thương hàn B
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Phương pháp điều trị hiệu quả cho bệnh phó thư...
# symptom                 Bệnh nhân thường nhập viện với tình trạng sốt ...
# diagnosis               Điều trị Phó thương hàn B (ICD-10: A01.2) chủ ...
# document/title          Phác đồ điều trị bệnh nhiễm trùng đường ruột d...
# document/description    Tài liệu chính thức của Bộ Y tế Việt Nam hướng...
# cme/title               Quản lý kháng sinh trong điều trị các bệnh nhi...
# cme/description         Khóa học nhằm nâng cao năng lực cho bác sĩ tro...
# Name: 37, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.2
# TÊN BỆNH                                            Bệnh phó thương hàn B
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những biến chứng nguy hiểm nào có thể xảy ra d...
# symptom                 Ở giai đoạn muộn hoặc không được điều trị kịp ...
# diagnosis               Phó thương hàn B (ICD-10: A01.2) có thể gây ra...
# document/title          Phòng ngừa và kiểm soát các bệnh truyền nhiễm ...
# document/description    Tài liệu hướng dẫn của Tổ chức Y tế Thế giới (...
# cme/title               Nhận biết sớm và xử trí các biến chứng của bện...
# cme/description         Khóa học chuyên sâu dành cho bác sĩ cấp cứu, n...
# Name: 38, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.2
# TÊN BỆNH                                            Bệnh phó thương hàn B
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Cần phân biệt bệnh phó thương hàn B với những ...
# symptom                 Bệnh nhân có thể xuất hiện sốt kéo dài trên 7 ...
# diagnosis               Chẩn đoán phân biệt Phó thương hàn B (ICD-10: ...
# document/title          Hướng dẫn chẩn đoán phân biệt sốt cấp tính tại...
# document/description    Tài liệu y khoa toàn diện cung cấp các tiêu ch...
# cme/title               Tiếp cận bệnh nhân sốt ở trẻ em và phụ nữ có t...
# cme/description         Khóa học tập trung vào cách tiếp cận chẩn đoán...
# Name: 39, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.3
# TÊN BỆNH                                            Bệnh phó thương hàn C
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Triệu chứng điển hình của bệnh phó thương hàn ...
# symptom                 Các triệu chứng của bệnh phó thương hàn C (A01...
# diagnosis               Chẩn đoán ban đầu dựa trên lâm sàng và yếu tố ...
# document/title          Hướng dẫn chẩn đoán và điều trị bệnh nhiễm trù...
# document/description    Tài liệu này cung cấp các hướng dẫn chi tiết v...
# cme/title               Cập nhật kiến thức về sốt thương hàn và phó th...
# cme/description         Khóa học này cung cấp cái nhìn tổng quan về dị...
# Name: 40, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.3
# TÊN BỆNH                                            Bệnh phó thương hàn C
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Các phương pháp xét nghiệm nào được sử dụng để...
# symptom                 Bệnh nhân có biểu hiện nghi ngờ phó thương hàn...
# diagnosis               Chẩn đoán xác định bệnh phó thương hàn C (A01....
# document/title          Quy trình chuẩn xét nghiệm vi sinh chẩn đoán b...
# document/description    Tài liệu này mô tả các kỹ thuật lấy mẫu, nuôi ...
# cme/title               Phân tích và diễn giải kết quả xét nghiệm tron...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về các ...
# Name: 41, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.3
# TÊN BỆNH                                            Bệnh phó thương hàn C
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Phác đồ điều trị khuyến nghị cho bệnh phó thươ...
# symptom                 Bệnh nhân đã được chẩn đoán xác định phó thươn...
# diagnosis               Chẩn đoán phó thương hàn C (A01.3) đã được xác...
# document/title          Phác đồ điều trị bệnh nhiễm trùng đường ruột d...
# document/description    Tài liệu này cung cấp các phác đồ điều trị chu...
# cme/title               Quản lý kháng sinh trong điều trị nhiễm trùng ...
# cme/description         Khóa học tập trung vào việc lựa chọn kháng sin...
# Name: 42, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.3
# TÊN BỆNH                                            Bệnh phó thương hàn C
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những biến chứng nguy hiểm nào có thể xảy ra d...
# symptom                 Các biến chứng có thể xảy ra ở bệnh nhân sốt p...
# diagnosis               Chẩn đoán biến chứng phó thương hàn C (A01.3) ...
# document/title          Biến chứng của nhiễm Salmonella và chiến lược ...
# document/description    Tài liệu này tập trung vào các biến chứng thườ...
# cme/title               Dự phòng và kiểm soát các bệnh truyền nhiễm qu...
# cme/description         Khóa học này trang bị kiến thức về các chiến l...
# Name: 43, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.3
# TÊN BỆNH                                            Bệnh phó thương hàn C
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Ý nghĩa dịch tễ học của bệnh phó thương hàn C ...
# symptom                 Các trường hợp sốt kéo dài, rối loạn tiêu hóa ...
# diagnosis               Trong bối cảnh dịch tễ, chẩn đoán không chỉ tậ...
# document/title          Báo cáo dịch tễ học các bệnh nhiễm trùng đường...
# document/description    Tài liệu này cung cấp dữ liệu về xu hướng mắc ...
# cme/title               Giám sát dịch tễ học và ứng phó với dịch bệnh ...
# cme/description         Khóa học này trang bị kỹ năng về thu thập, phâ...
# Name: 44, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.4
# TÊN BỆNH                              Bệnh phó thương hàn, không xác định
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tôi có các triệu chứng sốt cao liên tục, đau b...
# symptom                 Các triệu chứng bao gồm sốt cao liên tục (thườ...
# diagnosis               Dựa trên các triệu chứng lâm sàng như sốt kéo ...
# document/title          Hướng dẫn chẩn đoán và điều trị bệnh thương hà...
# document/description    Tài liệu chuyên sâu từ Bộ Y tế về các tiêu chu...
# cme/title               Cập nhật chẩn đoán và quản lý bệnh lý nhiễm tr...
# cme/description         Khóa học CME này cung cấp kiến thức cập nhật v...
# Name: 45, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.4
# TÊN BỆNH                              Bệnh phó thương hàn, không xác định
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Phương pháp chẩn đoán xác định bệnh phó thương...
# symptom                 Bệnh nhân có thể biểu hiện sốt bậc thang hoặc ...
# diagnosis               Chẩn đoán xác định bệnh phó thương hàn (ICD-10...
# document/title          Quyết định 1547/QĐ-BYT về việc ban hành Hướng ...
# document/description    Văn bản pháp quy của Bộ Y tế Việt Nam cung cấp...
# cme/title               Kỹ thuật vi sinh trong chẩn đoán các bệnh nhiễ...
# cme/description         Khóa học tập trung vào các phương pháp xét ngh...
# Name: 46, dtype: object
# STT CHƯƠNG                                                              I
# MÃ CHƯƠNG                                                         A00-B99
# TÊN NHÓM CHÍNH                                Bệnh nhiễm trùng đường ruột
# MÃ BỆNH                                                             A01.4
# TÊN BỆNH                              Bệnh phó thương hàn, không xác định
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những biến chứng nguy hiểm nào có thể xảy ra n...
# symptom                 Triệu chứng ban đầu của phó thương hàn (A01.4)...
# diagnosis               Nếu không được chẩn đoán và điều trị kịp thời,...
# document/title          Biến chứng của bệnh thương hàn và phó thương h...
# document/description    Một bài báo khoa học tổng quan về các biến chứ...
# ...
# cme/title               Nhận biết và xử trí tác dụng phụ trong liệu ph...
# cme/description         Khóa học đào tạo chuyên sâu về cách nhận diện,...
# Name: 3332, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Tỷ lệ đáp ứng điều trị của Ceritinib đối với u...
# symptom                 Các triệu chứng của ung thư phổi không tế bào ...
# diagnosis               Ung thư phổi không tế bào nhỏ (NSCLC) giai đoạ...
# document/title          Hiệu quả điều trị Ceritinib cho ung thư phổi k...
# document/description    Nghiên cứu đánh giá tỷ lệ đáp ứng điều trị (ho...
# cme/title               Cập nhật các phác đồ điều trị đích trong ung t...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về chẩn...
# Name: 3333, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Thời gian sống thêm không bệnh tiến triển (PFS...
# symptom                 Các dấu hiệu bệnh tiến triển của ung thư phổi ...
# diagnosis               Ung thư phổi không tế bào nhỏ (NSCLC) giai đoạ...
# document/title          Nghiên cứu thời gian sống thêm không bệnh tiến...
# document/description    Bài báo khoa học phân tích trung vị thời gian ...
# cme/title               Tối ưu hóa chiến lược điều trị để kéo dài thời...
# cme/description         Khóa học chuyên sâu về các yếu tố ảnh hưởng đế...
# Name: 3334, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Chỉ số viêm-miễn dịch hệ thống (SII) được định...
# symptom                 Bệnh nhân ung thư phổi không tế bào nhỏ (UTPKT...
# diagnosis               Ung thư phổi không tế bào nhỏ (NSCLC) giai đoạ...
# document/title          GIÁ TRỊ TIÊN LƯỢNG CỦA CHỈ SỐ VIÊM -MIỄN DỊCH ...
# document/description    Nghiên cứu mô tả cắt ngang có theo dõi dọc trê...
# cme/title               Cập nhật vai trò của chỉ số viêm-miễn dịch hệ ...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về cách...
# Name: 3335, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Kết quả nghiên cứu về mối liên quan giữa chỉ s...
# symptom                 Bệnh nhân ung thư phổi không tế bào nhỏ (UTPKT...
# diagnosis               Ở bệnh nhân ung thư phổi không tế bào nhỏ (NSC...
# document/title          GIÁ TRỊ TIÊN LƯỢNG CỦA CHỈ SỐ VIÊM -MIỄN DỊCH ...
# document/description    Nghiên cứu tập trung vào việc định lượng và so...
# cme/title               Phân tích thống kê và ứng dụng các yếu tố tiên...
# cme/description         Khóa học đào tạo về phương pháp phân tích thốn...
# Name: 3336, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Ngoài chỉ số SII, còn yếu tố tiên lượng độc lậ...
# symptom                 Bệnh nhân ung thư phổi không tế bào nhỏ (UTPKT...
# diagnosis               Trong ung thư phổi không tế bào nhỏ (NSCLC) gi...
# document/title          GIÁ TRỊ TIÊN LƯỢNG CỦA CHỈ SỐ VIÊM -MIỄN DỊCH ...
# document/description    Bài báo thảo luận về các yếu tố tiên lượng ảnh...
# cme/title               Chiến lược điều trị và các yếu tố tiên lượng t...
# cme/description         Khóa học cung cấp cái nhìn tổng quan về các ph...
# Name: 3337, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Chỉ số viêm - miễn dịch hệ thống (SII) được tí...
# symptom                 Bệnh nhân được chẩn đoán ung thư phổi không tế...
# diagnosis               Chẩn đoán ung thư phổi không tế bào nhỏ (UTPKT...
# document/title          Đánh giá giá trị tiên lượng của chỉ số viêm-mi...
# document/description    Bài báo nghiên cứu này đánh giá giá trị tiên l...
# cme/title               Ứng dụng chỉ số viêm - miễn dịch hệ thống (SII...
# cme/description         Khóa học này cung cấp kiến thức chuyên sâu về ...
# Name: 3338, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Đặc điểm lâm sàng và mô bệnh học của nhóm bệnh...
# symptom                 Nhóm bệnh nhân nghiên cứu bao gồm 51 người, độ...
# diagnosis               Chẩn đoán ung thư phổi không tế bào nhỏ (UTPKT...
# document/title          Đánh giá giá trị tiên lượng của chỉ số viêm-mi...
# document/description    Bài báo nghiên cứu này đánh giá giá trị tiên l...
# cme/title               Chẩn đoán và phân loại giai đoạn ung thư phổi ...
# cme/description         Khóa học này tập trung vào các phương pháp chẩ...
# Name: 3339, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Những phác đồ hóa chất bước một nào được áp dụ...
# symptom                 Tiêu chuẩn chọn bệnh nhân bao gồm: tuổi ≥ 18; ...
# diagnosis               Chẩn đoán ung thư phổi không tế bào nhỏ (UTPKT...
# document/title          Đánh giá giá trị tiên lượng của chỉ số viêm-mi...
# document/description    Bài báo nghiên cứu này đánh giá giá trị tiên l...
# cme/title               Cập nhật các phác đồ hóa trị bước một cho ung ...
# cme/description         Khóa học này cung cấp thông tin cập nhật về cá...
# Name: 3340, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Mối liên hệ giữa tình trạng viêm mãn tính và u...
# symptom                 Tình trạng viêm mãn tính đóng vai trò quan trọ...
# diagnosis               Ung thư phổi không tế bào nhỏ (UTPKTBN) có yếu...
# document/title          Vai trò của chỉ số viêm hệ thống (SII) trong t...
# document/description    Bài báo nghiên cứu về giá trị tiên lượng độc l...
# cme/title               Cập nhật vai trò của viêm và các chỉ số miễn d...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về cơ c...
# Name: 3341, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Theo các nghiên cứu, ngưỡng giá trị (cut-off) ...
# symptom                 Chỉ số SII (tiểu cầu x tỷ lệ bạch cầu đa nhân ...
# diagnosis               Ung thư phổi không tế bào nhỏ (UTPKTBN) giai đ...
# document/title          Các chỉ số viêm hệ thống trong tiên lượng ung ...
# document/description    Phân tích tổng hợp các nghiên cứu về giá trị t...
# cme/title               Ứng dụng các chỉ số viêm và miễn dịch trong th...
# cme/description         Khóa học tập trung vào việc diễn giải và áp dụ...
# Name: 3342, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Lympho bào, bạch cầu đa nhân trung tính và tiể...
# symptom                 Các tế bào máu như lympho bào, bạch cầu đa nhâ...
# diagnosis               Sinh bệnh học ung thư phổi và quá trình di căn...
# document/title          Cơ chế viêm và vai trò của tế bào máu trong si...
# document/description    Phân tích sâu về vai trò của các tế bào miễn d...
# cme/title               Cơ chế phân tử của di căn ung thư phổi và vai ...
# cme/description         Khóa học này khám phá các con đường phân tử và...
# Name: 3343, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về ung bướu, cung cấp th...
# question                Chỉ số viêm miễn dịch hệ thống (SII) có vai tr...
# symptom                 Bệnh nhân ung thư phổi không tế bào nhỏ (UTPKT...
# diagnosis               Chẩn đoán ung thư phổi không tế bào nhỏ (NSCLC...
# document/title          Giá trị tiên lượng của chỉ số viêm miễn dịch h...
# document/description    Nghiên cứu đăng trên Tạp chí Y học Việt Nam (T...
# cme/title               Cập nhật ứng dụng chỉ số viêm miễn dịch hệ thố...
# cme/description         Khóa học CME này cung cấp kiến thức chuyên sâu...
# Name: 3344, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về ung bướu, cung cấp th...
# question                Ngoài chỉ số viêm miễn dịch hệ thống (SII) và ...
# symptom                 Bệnh nhân ung thư phổi không tế bào nhỏ giai đ...
# diagnosis               Chẩn đoán ung thư phổi không tế bào nhỏ (NSCLC...
# document/title          Các yếu tố tiên lượng tiềm năng chưa được khảo...
# document/description    Phần hạn chế của một nghiên cứu về ung thư phổ...
# cme/title               Tầm quan trọng của phân tích đa yếu tố tiên lư...
# cme/description         Khóa học CME này nhấn mạnh sự cần thiết của vi...
# Name: 3345, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Chỉ số viêm-miễn dịch hệ thống (SII) là gì và ...
# symptom                 Bệnh nhân được chẩn đoán ung thư phổi không tế...
# diagnosis               Chỉ số viêm-miễn dịch hệ thống (SII) là một yế...
# document/title          GIÁ TRỊ TIÊN LƯỢNG CỦA CHỈ SỐ VIÊM -MIỄN DỊCH ...
# document/description    Nghiên cứu mô tả cắt ngang có theo dõi dọc, đá...
# cme/title               Cập nhật các chỉ số viêm hệ thống trong tiên l...
# cme/description         Khóa học cung cấp kiến thức chuyên sâu về cơ c...
# Name: 3346, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Chỉ số viêm-miễn dịch hệ thống (SII) ảnh hưởng...
# symptom                 Bệnh nhân ung thư phổi không tế bào nhỏ (UTPKT...
# diagnosis               Kết quả nghiên cứu cho thấy chỉ số viêm-miễn d...
# document/title          GIÁ TRỊ TIÊN LƯỢNG CỦA CHỈ SỐ VIÊM -MIỄN DỊCH ...
# document/description    Nghiên cứu đã chứng minh chỉ số SII trước điều...
# cme/title               Tiên lượng và quản lý ung thư phổi không tế bà...
# cme/description         Khóa học cung cấp cái nhìn tổng quan về các ph...
# Name: 3347, dtype: object
# STT CHƯƠNG                                                             II
# MÃ CHƯƠNG                                                         C00-D48
# TÊN NHÓM CHÍNH                                                  U ác tính
# MÃ BỆNH                                                             C34.9
# TÊN BỆNH                      U ác của khí quản hoặc phổi, không đặc hiệu
# intruction              Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                Ngoài chỉ số SII, còn yếu tố tiên lượng độc lậ...
# symptom                 Bệnh nhân ung thư phổi không tế bào nhỏ (UTPKT...
# diagnosis               Phân tích đa biến trong nghiên cứu đã chỉ ra r...
# document/title          GIÁ TRỊ TIÊN LƯỢNG CỦA CHỈ SỐ VIÊM -MIỄN DỊCH ...
# document/description    Bài báo khoa học này đã xác định chỉ số SII và...
# cme/title               Đánh giá các yếu tố tiên lượng trong điều trị ...
# cme/description         Khóa học này tập trung vào cách đánh giá và ứn...
# Name: 3348, dtype: object
