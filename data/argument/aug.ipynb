# %%
from datasets import load_dataset
from transformers import MT5Tokenizer, MT5ForConditionalGeneration
from tqdm import tqdm
import pandas as pd
import torch
import os

# Kiểm tra GPU
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("cuda" )
print(f"💻 Đang sử dụng thiết bị: {device}")

# Load model paraphrase và đưa lên GPU
CKPT = 'chieunq/vietnamese-sentence-paraphase'
tokenizer = MT5Tokenizer.from_pretrained(CKPT)
model = MT5ForConditionalGeneration.from_pretrained(CKPT).to(device)

# Hàm tạo paraphrase
def paraphrase(text, num_return_sequences=5):
    inputs = tokenizer(text, padding='longest', max_length=512, truncation=True, return_tensors='pt')
    inputs = {key: val.to(device) for key, val in inputs.items()}
    output = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_length=512,
        num_return_sequences=num_return_sequences,
        do_sample=True,
        top_p=0.95
    )
    return [tokenizer.decode(o, skip_special_tokens=True) for o in output]

# Load dataset
dataset = pd.read_parquet("../generate_dataset/SVYKHOA_dataset_smalltalk.parquet", engine="fastparquet")

# File Excel đầu ra
output_file = "SVYKHOA_dataset_smalltalk.xlsx"

# Tạo file Excel rỗng nếu chưa có
if not os.path.exists(output_file):
    df_empty = pd.DataFrame(columns=["intruction", "question", "answer"])
    df_empty.to_excel(output_file, index=False)

# Đọc số dòng đã có để tiếp tục từ đó
existing_df = pd.read_excel(output_file)
# start_index = len(existing_df)
start_index = 4780
print(f"🚀 Bắt đầu từ dòng {start_index}")

# Số lượng mẫu muốn xử lý thêm
max_samples = 216350-47800  # Có thể chỉnh: 10, 100, 500...

# Duyệt dataset từ start_index
for i, row in dataset.iterrows():
    if i < start_index:
        continue
    if i >= start_index + max_samples:
        break
    print(row)

    question = row["question"]   # row là Series
    try:
        paraphrases = paraphrase(question, num_return_sequences=10)
    except Exception as e:
        print(f"Lỗi paraphrase tại mẫu {i}: {e}")
        paraphrases = [question]

    new_rows = []
    for pq in paraphrases:
        new_rows.append({
            "intruction": row["intruction"],
            "question": pq,
            "answer": row["answer"],
        })

    new_df = pd.DataFrame(new_rows)
    with pd.ExcelWriter(output_file, mode="a", engine="openpyxl", if_sheet_exists="overlay") as writer:
        sheet = writer.sheets["Sheet1"]
        start_row = sheet.max_row
        new_df.to_excel(writer, header=False, index=False, startrow=start_row)


print("✅ Đã lưu toàn bộ dữ liệu paraphrase vào file Excel.")
# Out:
# 💻 Đang sử dụng thiết bị: cuda
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'T5Tokenizer'.
# The class this function is called from is 'MT5Tokenizer'.
# You are using the default legacy behaviour of the <class 'transformers.models.mt5.tokenization_mt5.MT5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# 🚀 Bắt đầu từ dòng 0
# intruction    Chatbot y khoa chuyên về y khoa, hãy giải thíc...
# question      Câu 'Vì trụ cầu nó to và rất vững chắc tầu đâm...
# answer        Câu này gợi ý đến các cấu trúc giải phẫu có va...
# Name: 0, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy chào hỏi ...
# question      Chào bạn! 👋 Dạo này tôi thấy khớp gối hơi đau ...
# answer        Chào bạn! 😊 Rất vui được trò chuyện với bạn. Đ...
# Name: 1, dtype: object
# intruction    Chatbot y khoa, hãy giải thích một cách đơn gi...
# question             Cột sống quan trọng như thế nào vậy bạn? 🤔
# answer        Bạn hỏi hay lắm! Cột sống giống như 'trụ cầu' ...
# Name: 2, dtype: object
# intruction    Chatbot y khoa, hãy tán gẫu vui vẻ và hỏi han ...
# question      Hôm nay bạn khỏe không? 😊 Thời tiết này dễ bị ...
# answer        Cảm ơn bạn đã quan tâm! 🤗 Mình vẫn khỏe. Thời ...
# Name: 3, dtype: object
# intruction    Chatbot y khoa, hãy đưa ra một câu đố vui liên...
# question      Đố bạn: Cái gì trong người bạn lúc nào cũng đi...
# answer        Hmm... câu này hơi khó à nha! 😁 Bạn có muốn mì...
# Name: 4, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn và ...
# question      Tôi thấy cầu thủ này sút 2 chân mượt quá, lại ...
# answer        Chào bạn! 😊 Đúng là kỹ thuật sút bóng điêu luy...
# Name: 5, dtype: object
# intruction    Chatbot y khoa đưa ra lời khuyên về việc khởi ...
# question      Vậy làm sao để hạn chế chấn thương khi chơi th...
# answer        Để giảm thiểu nguy cơ chấn thương, việc khởi đ...
# Name: 6, dtype: object
# intruction    Chatbot y khoa giải thích về tầm quan trọng củ...
# question      Đôi khi tôi thấy mệt mỏi và đau nhức sau khi đ...
# answer        Chào bạn! 🙋‍♂️ Lắng nghe cơ thể là một yếu tố ...
# Name: 7, dtype: object
# intruction    Chatbot y khoa đưa ra lời khuyên về việc tìm k...
# question      Nếu tôi bị chấn thương khi chơi thể thao thì n...
# answer        Khi bạn bị chấn thương, việc đầu tiên cần làm ...
# Name: 8, dtype: object
# intruction    Chatbot y khoa đưa ra lời khuyên về việc sử dụ...
# question      Có cách nào để phòng ngừa chấn thương hiệu quả...
# answer        Ngoài việc khởi động kỹ, lắng nghe cơ thể và n...
# Name: 9, dtype: object
# intruction                                                 None
# question      Coi cha nội này thiệt cười rớt nước mắt. Nhưng...
# answer        😂😂😂 Đúng rồi đó bạn! Nhiều khi mình xem lướt q...
# Name: 10, dtype: object
# intruction                                                 None
# question      Chào bạn! Mình thấy dạo này hay mệt mỏi, không...
# answer        Chào bạn! 😊 Mệt mỏi có thể do nhiều nguyên nhâ...
# Name: 11, dtype: object
# intruction                                                 None
# question      Mình bị hắt hơi, sổ mũi mấy ngày nay, chắc là ...
# answer        Chào bạn! 🤧 Hắt hơi, sổ mũi là triệu chứng thư...
# Name: 12, dtype: object
# intruction                                                 None
# question          Đố bạn: Cái gì càng lớn càng không nhìn thấy?
# answer        Hmm... Để mình đoán xem nào...🤔 Có phải là... ...
# Name: 13, dtype: object
# intruction                                                 None
# question      Mình biết là ăn uống healthy rất quan trọng, n...
# answer        Mình hiểu mà! 😔 Cuộc sống bận rộn đôi khi khiế...
# Name: 14, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy phản hồi ...
# question      Ủa tui tưởng lúc Cris vs cj jun đi tìm sẽ có n...
# answer        Chào bạn! Trong tình huống tìm kiếm và cứu hộ ...
# Name: 15, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy chào hỏi t...
# question                  Chào bạn, bạn có thể giúp gì cho tôi?
# answer        👋 Xin chào! Mình là chatbot y tế, rất vui được...
# Name: 16, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ với người dù...
# question      Hôm nay bạn khỏe không? Bạn có lời khuyên nào ...
# answer        Mình luôn trong trạng thái 'khỏe mạnh' vì mình...
# Name: 17, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy giải thích...
# question      Tại sao tôi phải uống thuốc đúng giờ và đủ liề...
# answer        Chào bạn! 💊 Việc tuân thủ phác đồ điều trị (uố...
# Name: 18, dtype: object
# intruction    Chatbot y khoa hãy đố vui và cung cấp thông ti...
# question      Đố bạn: Cái gì giúp chúng ta nhìn rõ mọi vật, ...
# answer        Câu đố hay quá! 🤔 Hmm... có lẽ là... ánh sáng?...
# Name: 19, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy phản hồi ...
# question      Tôi thấy nhạc rap Việt dạo này nghe cứ như chử...
# answer        Chào bạn 👋. Âm nhạc, đặc biệt là âm nhạc có cư...
# Name: 20, dtype: object
# intruction    Chatbot y khoa hãy chào hỏi thân thiện và đưa ...
# question      Chào chatbot, dạo này tôi hay nghe nhạc mạnh, ...
# answer        Xin chào! Rất vui được trò chuyện với bạn 🤗. N...
# Name: 21, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ và đưa ra mộ...
# question      Chatbot ơi, hôm nay bạn khỏe không? Đố vui một...
# answer        Mình khỏe re bạn ơi! 😄 Hôm nay trời đẹp, mình ...
# Name: 22, dtype: object
# intruction    Chatbot y khoa hãy đưa ra lời khuyên về cách l...
# question      Tôi đang bị stress quá, nghe nhạc gì cho đỡ că...
# answer        Chào bạn. Âm nhạc có thể là một liều thuốc tin...
# Name: 23, dtype: object
# intruction    Chatbot y khoa hãy giải thích về cơ chế gây hạ...
# question      Tại sao nghe nhạc lớn lại có hại cho tai vậy c...
# answer        À, để mình giải thích cho bạn nhé! Trong tai c...
# Name: 24, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy thể hiện ...
# question      Cảm ơn bạn đã nói ra nỗi lòng mình và tâm huyế...
# answer        Cảm ơn bạn đã chia sẻ với tôi. Chúc bạn luôn m...
# Name: 25, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy chào hỏi t...
# question              Chào bạn! Hôm nay bạn cảm thấy thế nào? 😊
# answer        Chào bạn! Rất vui được trò chuyện với bạn. Mìn...
# Name: 26, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tán gẫu vu...
# question      Đố bạn nhé: Cái gì mình mua về để ăn, nhưng kh...
# answer        Hmm, câu này khó quá! Để mình đoán xem... Có p...
# Name: 27, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn về ...
# question      Bạn có thể chia sẻ một vài lời khuyên về việc ...
# answer        Chắc chắn rồi! Một trong những điều quan trọng...
# Name: 28, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy động viên ...
# question            Mình đang cảm thấy rất mệt mỏi và chán nản.
# answer        Mình rất hiểu cảm giác của bạn. 😔 Đôi khi cuộc...
# Name: 29, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy phản hồi m...
# question      Nghe nhạc không thấy chill, có phải tôi cần đi...
# answer        😂 Nghe nhạc mà không thấy 'chill' thì có thể d...
# Name: 30, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn về ...
# question      Chào bạn, tôi hay nghe nhạc lớn bằng tai nghe,...
# answer        👋 Xin chào! Rất vui được trò chuyện với bạn. V...
# Name: 31, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy giải thích...
# question      Ngoài nghe nhạc lớn, còn yếu tố nào ảnh hưởng ...
# answer        🤔 Chắc chắn rồi! Thính giác của chúng ta rất n...
# Name: 32, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy đưa ra lời...
# question        Vậy làm sao để nghe nhạc an toàn bằng tai nghe?
# answer        👌 Tuyệt vời! Đây là một câu hỏi rất quan trọng...
# Name: 33, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy trò chuyện...
# question      Đố bạn, bộ phận nào trong cơ thể giúp chúng ta...
# answer        🧠 Hmm... Câu này có vẻ 'hack não' đây! 🤔 Chắc ...
# Name: 34, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy phản hồi m...
# question      Anh cris hài qué :D báu vât cua anh cris là đâ...
# answer        Chào bạn! 😄 Nghe bạn có vẻ đang rất vui vẻ và ...
# Name: 35, dtype: object
# intruction    Chatbot y khoa hãy chào hỏi người dùng một các...
# question                                              Xin chào!
# answer        Chào bạn! 👋 Rất vui được trò chuyện với bạn. 😊...
# Name: 36, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ với người dù...
# question                             Hôm nay thời tiết đẹp quá!
# answer        Đúng vậy! ☀️ Thời tiết đẹp rất thích hợp để vậ...
# Name: 37, dtype: object
# intruction    Chatbot y khoa hãy giải thích một khái niệm y ...
# question                                 Cholesterol là gì vậy?
# answer        Chào bạn! Cholesterol là một loại chất béo có ...
# Name: 38, dtype: object
# intruction    Chatbot y khoa hãy đố vui về sức khỏe cho ngườ...
# question      Đố bạn: Cái gì luôn đến nhưng không bao giờ đế...
# answer        Hmm... câu hỏi này khó quá! 🤔 Để mình đoán nhé...
# Name: 39, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn và ...
# question      Nguyễn Tấn Huy kkk không biết ai mới là người ...
# answer        Chào bạn Huy! Nghe bạn nói có vẻ không vui nhỉ...
# Name: 40, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy chào hỏi t...
# question                                          Chào chatbot!
# answer        Xin chào! 👋 Rất vui được trò chuyện với bạn. H...
# Name: 41, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tán gẫu vu...
# question          Chatbot ơi, kể cho tôi nghe chuyện gì vui đi!
# answer        😄 Chuyện vui hả? Để mình kể cho bạn nghe câu c...
# Name: 42, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy đưa ra một...
# question             Làm sao để có một cuộc sống khỏe mạnh hơn?
# answer        Để có một cuộc sống khỏe mạnh hơn, bạn nên kết...
# Name: 43, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy trò chuyện...
# question                            Đố vui về y học đi chatbot!
# answer        Okela! Mình đố bạn câu này nha: \n\nCái gì luô...
# Name: 44, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn và ...
# question      Bạn nghĩ sao về các dòng điện thoại Samsung A9...
# answer        Chào bạn! 😊 Theo ý kiến cá nhân, trong các dòn...
# Name: 45, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ với người dùng.
# question      Chào bạn! Dạo này bạn khỏe không? ☀️ Thời tiết...
# answer        Chào bạn! Mình khỏe ạ! Cảm ơn bạn đã nhắc nhở!...
# Name: 46, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn và ...
# question      Mùa hè này nhiều người bị ốm quá. Bạn có thể c...
# answer        Chào bạn! 🌞 Mùa hè là thời điểm các bệnh liên ...
# Name: 47, dtype: object
# intruction    Chatbot y khoa hãy đưa ra một câu đố vui về y ...
# question      Mình đố bạn một câu nha: Cái gì luôn đến nhưng...
# answer        Hmm, câu này khó nha! 🤔 Để mình đoán xem... Có...
# Name: 48, dtype: object
# intruction    Chatbot y khoa hãy tư vấn về chế độ ăn uống là...
# question      Bạn có thể tư vấn cho mình về một chế độ ăn uố...
# answer        Chào bạn! 😊 Để có một chế độ ăn uống lành mạnh...
# Name: 49, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy phản hồi ...
# question      khi chiều tắm bật nhạc xem hơn 6.5tr. bây giờ ...
# answer        😂 Chào bạn! Có vẻ như số lượt xem của bạn đang...
# Name: 50, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn và ...
# question      Chào bạn, tôi thấy mình đi tiểu nhiều hơn bình...
# answer        Chào bạn! 😊 Việc đi tiểu nhiều hơn bình thường...
# Name: 51, dtype: object
# intruction    Chatbot y khoa, hãy giải thích về một triệu ch...
# question      Tôi bị đau đầu âm ỉ suốt mấy ngày nay, liệu có...
# answer        Đau đầu âm ỉ kéo dài có thể do nhiều nguyên nh...
# Name: 52, dtype: object
# intruction    Chatbot y khoa, hãy tán gẫu vui vẻ với người d...
# question      Hôm nay thời tiết đẹp quá! Bạn có thích đi dạo...
# answer        Chào bạn! ☀️ Thời tiết hôm nay đúng là tuyệt v...
# Name: 53, dtype: object
# intruction    Chatbot y khoa, hãy đưa ra một câu đố vui về y...
# question      Tôi là một loại tế bào, giúp bảo vệ cơ thể khỏ...
# answer        Hmm... để mình đoán xem! 🤔 Có phải bạn là một....
# Name: 54, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn và ...
# question      Em là fan của BTS hàn quốc em rất ghét nhóm ze...
# answer        Chào bạn! Mình hiểu bạn đang rất yêu thích BTS...
# Name: 55, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy đưa ra lời...
# question      Em cảm thấy rất áp lực khi bạn bè em ai cũng c...
# answer        Chào bạn! Mình hiểu cảm giác của bạn. Áp lực đ...
# Name: 56, dtype: object
# intruction    Chatbot y khoa hãy đưa ra lời khuyên về chế độ...
# question      Dạo này em thấy mình tăng cân quá, em muốn giả...
# answer        Chào bạn! Việc giảm cân là một quá trình đòi h...
# Name: 57, dtype: object
# intruction    Chatbot y khoa hãy tư vấn về giấc ngủ và cách ...
# question      Em thường xuyên bị mất ngủ, khó ngủ và ngủ khô...
# answer        Chào bạn! Mất ngủ có thể ảnh hưởng rất lớn đến...
# Name: 58, dtype: object
# intruction    Chatbot y khoa hãy đưa ra lời khuyên về cách p...
# question      Dạo này em thấy nhiều người bị cúm quá, em sợ ...
# answer        Chào bạn! Đúng vậy, cúm mùa là một bệnh rất dễ...
# Name: 59, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa đưa ra lời khu...
# question      Thích đội chị Nhã Kỳ hơn, LDB Lâm chơi xấu quá...
# answer        Tôi hiểu bạn đang thể hiện sự ủng hộ với một b...
# Name: 60, dtype: object
# intruction    Chatbot y khoa chào hỏi người dùng mới một các...
# question      Chào bạn! Mình mới dùng chatbot lần đầu, bạn c...
# answer        Chào mừng bạn đến với chatbot y khoa! Rất vui ...
# Name: 61, dtype: object
# intruction    Chatbot y khoa đưa ra lời khuyên chung về việc...
# question      Mình muốn có một sức khỏe tốt hơn thì nên làm gì?
# answer        Để có một sức khỏe tốt, bạn nên chú ý đến nhữn...
# Name: 62, dtype: object
# intruction    Chatbot y khoa trò chuyện vui vẻ và kể một câu...
# question               Kể cho mình nghe một câu chuyện cười đi!
# answer        Okela! 😁 Có một bệnh nhân đến gặp bác sĩ và nó...
# Name: 63, dtype: object
# intruction    Chatbot y khoa đưa ra lời khuyên về việc tìm k...
# question      Mình thấy trên mạng có nhiều thông tin về bệnh...
# answer        Mình hiểu là bạn đang cảm thấy bối rối trước v...
# Name: 64, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, phản hồi câu ...
# question            P11 op po máy cũ đổi máy mới được k bù tiền
# answer        Chào bạn! Theo thông tin bạn cung cấp, bạn muố...
# Name: 65, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, tư vấn về máy...
# question      Chào bạn, tôi đang tìm hiểu về máy tạo oxy, bạ...
# answer        👋 Xin chào! Rất vui được hỗ trợ bạn. Máy tạo o...
# Name: 66, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, giải thích về...
# question      Máy tạo oxy hoạt động như thế nào vậy bạn? Ngh...
# answer        Đừng lo, không phức tạp như bạn nghĩ đâu! 😉 Má...
# Name: 67, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, tư vấn về các...
# question      Tôi mới mua máy tạo oxy, bạn có lời khuyên nào...
# answer        Tuyệt vời! 👍 Chúc mừng bạn đã có một thiết bị ...
# Name: 68, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, đưa ra một câ...
# question      Đố bạn: Cái gì mình mua về không bao giờ dùng ...
# answer        Hmm, câu đố này khó thật! 🤔 Để xem nào... Có p...
# Name: 69, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question        Hãy cho chúng tôi thấy Qũy Đỏ những năm 2000 lẽ
# answer        Chào bạn! Trong những năm 2000, phong trào Hiế...
# Name: 70, dtype: object
# intruction    Chatbot y khoa chào hỏi thân thiện và cung cấp...
# question      Chào bạn! 👋 Bạn có thể cho mình biết thêm về H...
# answer        Xin chào! 😊 Hội Chữ thập đỏ là một tổ chức nhâ...
# Name: 71, dtype: object
# intruction    Chatbot y khoa giải thích về tầm quan trọng củ...
# question      Tại sao hiến máu nhân đạo lại quan trọng vậy b...
# answer        Hiến máu nhân đạo có ý nghĩa vô cùng to lớn bạ...
# Name: 72, dtype: object
# intruction    Chatbot y khoa tư vấn về điều kiện để tham gia...
# question      Mình muốn tham gia hiến máu quá, nhưng không b...
# answer        Tuyệt vời! 🥰 Để tham gia hiến máu, bạn cần đáp...
# Name: 73, dtype: object
# intruction    Chatbot y khoa trò chuyện vui vẻ và đưa ra một...
# question      Hôm nay mình thấy hơi buồn chán... Bạn có thể ...
# answer        Mình hiểu mà! 😊 Để mình giúp bạn vui lên nhé! ...
# Name: 74, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn về ...
# question                       Có từ bao lâu rồi h mới mua vl ạ
# answer        Chào bạn! 😊 Cho mình hỏi bạn bị triệu chứng nà...
# Name: 75, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy hỏi thăm v...
# question      Chào bạn, tôi cảm thấy không khỏe mấy ngày nay...
# answer        Chào bạn! 💖 Rất tiếc khi bạn cảm thấy không kh...
# Name: 76, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy đưa ra lời...
# question      Tôi bị đau đầu quá, chắc ra hiệu thuốc mua viê...
# answer        Chào bạn! 💊 Đau đầu có thể do nhiều nguyên nhâ...
# Name: 77, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ với người dùng.
# question                                Hôm nay bạn khỏe không?
# answer        Mình là chatbot nên không biết mệt bạn ơi! 🤣 N...
# Name: 78, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn và ...
# question      Tôi thấy người ta uống thuốc này khỏi bệnh, ch...
# answer        Chào bạn! 🧐 Mình hiểu là bạn muốn nhanh chóng ...
# Name: 79, dtype: object
# intruction    Chatbot y khoa hãy phản hồi một bình luận bày ...
# question      Tiếc cho nữ chính quá có 3 bạn nam màu xanh mà...
# answer        Chào bạn! 😊 Mình hiểu bạn đang tiếc cho nữ chí...
# Name: 80, dtype: object
# intruction    Chatbot y khoa hãy chào hỏi người dùng một các...
# question                                              Chào bạn!
# answer        Xin chào! 👋 Rất vui được gặp bạn. 🤗 Hôm nay bạ...
# Name: 81, dtype: object
# intruction    Chatbot y khoa hãy đưa ra một lời khuyên về vi...
# question             Làm thế nào để có một cuộc sống khỏe mạnh?
# answer        Để có một cuộc sống khỏe mạnh, bạn nên chú ý đ...
# Name: 82, dtype: object
# intruction    Chatbot y khoa hãy giải thích về tầm quan trọn...
# question                                Tại sao cần tiêm phòng?
# answer        Tiêm phòng rất quan trọng vì nó giúp cơ thể bạ...
# Name: 83, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ với người dù...
# question                                   Hôm nay bạn thế nào?
# answer        Mình khỏe re! 😁 Vừa mới 'uống' xong một đống d...
# Name: 84, dtype: object
# intruction                                                 None
# question      Mình cùng quan điểm: Bánh Bảo Phương giờ bình ...
# answer        Chào bạn! Mình hiểu cảm giác của bạn. Đôi khi ...
# Name: 85, dtype: object
# intruction                                                 None
# question                                              Chào bạn!
# answer        Xin chào! 👋 Rất vui được trò chuyện với bạn. 😊...
# Name: 86, dtype: object
# intruction                                                 None
# question      Đố bạn: Cái gì giúp mắt sáng, da hồng, dáng xinh?
# answer        Câu trả lời là: Vitamin A! 😉 Vitamin A rất qua...
# Name: 87, dtype: object
# intruction                                                 None
# question                     Tại sao cần uống đủ nước mỗi ngày?
# answer        Uống đủ nước rất quan trọng vì nước chiếm khoả...
# Name: 88, dtype: object
# intruction                                                 None
# question              Làm thế nào để có một lối sống lành mạnh?
# answer        Để có một lối sống lành mạnh, bạn nên kết hợp ...
# Name: 89, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy phản hồi t...
# question                 Sau chiếu lại tập 3 , có ý đồ j hả ctr
# answer        Chào bạn, tôi hiểu bạn đang muốn hỏi về ý nghĩ...
# Name: 90, dtype: object
# intruction    Chatbot y khoa hãy tư vấn về sức khỏe tổng quá...
# question      Chào bác sĩ, dạo này em cảm thấy mệt mỏi và că...
# answer        Chào bạn! 😊 Rất hiểu cảm giác của bạn. Mệt mỏi...
# Name: 91, dtype: object
# intruction    Chatbot y khoa hãy giải thích các thuật ngữ y ...
# question      Bác sĩ ơi, em nghe nói nhiều về chỉ số BMI mà ...
# answer        Chào bạn! 😊 BMI (Body Mass Index) là chỉ số kh...
# Name: 92, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ và tạo không...
# question             Chào chatbot, hôm nay bạn có khỏe không? 😄
# answer        Chào bạn! 😊 Mình khỏe re và sẵn sàng trò chuyệ...
# Name: 93, dtype: object
# intruction    Chatbot y khoa hãy đưa ra lời khuyên về chế độ...
# question      Em muốn có một chế độ ăn uống lành mạnh hơn, c...
# answer        Chào bạn! 😊 Tuyệt vời! Chế độ ăn uống lành mạn...
# Name: 94, dtype: object
# intruction    Chatbot y khoa hãy đưa ra lời chúc thi tốt và ...
# question      tuần sau e thi r mong mn chúc e thi tốt chúc m...
# answer        Chào bạn! Chúc bạn thi thật tốt nha! 🎉 Để đạt ...
# Name: 95, dtype: object
# intruction    Chatbot y khoa hãy đưa ra lời chúc thi tốt ngh...
# question      Em sắp thi tốt nghiệp rồi, lo quá. Mn có lời k...
# answer        Chào bạn! 🤗 Chúc bạn thi tốt nghiệp đạt kết qu...
# Name: 96, dtype: object
# intruction    Chatbot y khoa hãy đưa ra lời chúc may mắn và ...
# question                         Mai em thi rồi, run quá mn ơi!
# answer        Đừng lo lắng quá bạn ơi! 🧘 Hít thở sâu và thư ...
# Name: 97, dtype: object
# intruction    Chatbot y khoa hãy đưa ra lời chúc thành công ...
# question      Chuẩn bị thi cử căng thẳng quá, làm sao để vượ...
# answer        Chào bạn! 💪 Cố lên bạn nhé! Chúc bạn thành côn...
# Name: 98, dtype: object
# intruction    Chatbot y khoa hãy đưa ra lời chúc tốt đẹp và ...
# question                    Thi cử đến gần, em thấy áp lực quá!
# answer        Mình hiểu mà! 😥 Áp lực thi cử là điều khó trán...
# Name: 99, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy phản hồi m...
# question            Lúc quay top top hội cj e vidwo ở đâu vậy ạ
# answer        Chào bạn! Câu hỏi của bạn có vẻ không liên qua...
# Name: 100, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ và thân thiệ...
# question      Hôm nay thời tiết đẹp quá! Bạn có kế hoạch gì ...
# answer        Chào bạn! ☀️ Thời tiết đẹp thật! Mình định cập...
# Name: 101, dtype: object
# intruction    Chatbot y khoa hãy đưa ra một lời khuyên sức k...
# question      Dạo này mình hay bị mệt mỏi, không biết có sao...
# answer        Chào bạn! Mệt mỏi có thể do nhiều nguyên nhân....
# Name: 102, dtype: object
# intruction    Chatbot y khoa hãy đưa ra một câu đố vui liên ...
# question      Đố bạn: Cái gì luôn đến nhưng không bao giờ đế...
# answer        Chào bạn! Để mình đoán nhé... Có phải là ngày ...
# Name: 103, dtype: object
# intruction    Chatbot y khoa hãy chào hỏi và giới thiệu bản ...
# question                                              Chào bạn!
# answer        Xin chào! 👋 Mình là chatbot y khoa, được thiết...
# Name: 104, dtype: object
# intruction                                                 None
# question      Chào bạn, tôi là Chủ tịch Hoàng Đức, hôm nay t...
# answer        Chào Chủ tịch Hoàng Đức! 😊 Chiếc đồng hồ Speak...
# Name: 105, dtype: object
# intruction                                                 None
# question      Chào bạn! Tôi thấy dạo này sức khỏe có vẻ ổn, ...
# answer        Chào bạn! 👍 Việc bạn cảm thấy khỏe mạnh là rất...
# Name: 106, dtype: object
# intruction                                                 None
# question      Hôm nay thời tiết đẹp quá! Bạn có kế hoạch gì ...
# answer        Chào bạn! 🌞 Đúng là thời tiết hôm nay rất tuyệ...
# Name: 107, dtype: object
# intruction                                                 None
# question      Tôi dạo này hay bị mất ngủ, bạn có lời khuyên ...
# answer        Chào bạn! 😴 Mất ngủ có thể ảnh hưởng nhiều đến...
# Name: 108, dtype: object
# intruction                                                 None
# question                Kể cho tôi một câu đố vui về y khoa đi!
# answer        Chào bạn! 😂 Đây là một câu đố vui nè: \n\nCái ...
# Name: 109, dtype: object
# intruction                                                 None
# question      Chào bạn, tôi thấy bạn nói về việc dùng điện t...
# answer        Chào bạn! 😊 Rất vui được trò chuyện với bạn. M...
# Name: 110, dtype: object
# intruction                                                 None
# question      Hôm nay bạn khỏe không? Mình vừa mới đổi điện ...
# answer        Tuyệt vời! 🎉 Mình rất vui khi bạn cảm thấy vui...
# Name: 111, dtype: object
# intruction                                                 None
# question      Mình hay bị đau đầu và mỏi mắt khi dùng điện t...
# answer        Chào bạn! 🤔 Việc sử dụng điện thoại lâu có thể...
# Name: 112, dtype: object
# intruction                                                 None
# question      Mình nghe nói dùng điện thoại nhiều có thể bị ...
# answer        Chào bạn! 👋 Hội chứng ống cổ tay (Carpal Tunne...
# Name: 113, dtype: object
# intruction                                                 None
# question      Đố bạn, cái gì luôn đến nhưng không bao giờ đế...
# answer        Hmm, câu này khó quá à nha! 🤔 Để mình đoán xem...
# Name: 114, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn và ...
# question      Chào bạn, mình vừa mua điện thoại mới được tặn...
# answer        Chào bạn! Chúc mừng bạn có điện thoại và đồng ...
# Name: 115, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tán gẫu vu...
# question      Dạo này thời tiết thay đổi thất thường quá, dễ...
# answer        Đúng rồi bạn ơi! 😥 Thời tiết dở chứng làm mình...
# Name: 116, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy đưa ra lời...
# question      Mình hay bị đau đầu, không biết có phải do căn...
# answer        Chào bạn! Đau đầu có nhiều nguyên nhân, trong ...
# Name: 117, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy giải thích...
# question                             Cholesterol là gì vậy bạn?
# answer        Chào bạn! 😊 Cholesterol là một loại chất béo c...
# Name: 118, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy đố vui liê...
# question      Đố bạn: Cái gì luôn đến nhưng không bao giờ đế...
# answer        Hmm... 🤔 Câu này khó à nha! Để mình đoán... Có...
# Name: 119, dtype: object
# intruction    Chatbot y khoa chuyên về tâm lý, nhận diện và ...
# question      Tôi cảm thấy lo sợ và bất an mỗi khi Ferd thi ...
# answer        Chào bạn, tôi hiểu rằng bạn đang cảm thấy lo l...
# Name: 120, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn và ...
# question              Chào bạn! Hôm nay bạn cảm thấy thế nào? 😊
# answer        Chào bạn! 👋 Mình là chatbot y khoa, rất vui đư...
# Name: 121, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ với người dùng.
# question      Bạn có biết câu chuyện cười nào về bác sĩ khôn...
# answer        Để mình kể cho bạn nghe nhé: 'Tại sao bác sĩ l...
# Name: 122, dtype: object
# intruction    Chatbot y khoa đưa ra lời khuyên về sức khỏe t...
# question          Làm thế nào để có một lối sống lành mạnh hơn?
# answer        Để có một lối sống lành mạnh hơn, bạn nên chú ...
# Name: 123, dtype: object
# intruction    Chatbot y khoa giải thích về một thuật ngữ y k...
# question      Bạn có thể giải thích 'tăng huyết áp' là gì kh...
# answer        Chào bạn! Tăng huyết áp, hay còn gọi là cao hu...
# Name: 124, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa. Tư vấn về khả...
# question      Tan Vu Hoang iphone thì màn hình cũng ss sx bạ...
# answer        Chào bạn! Về cơ bản, màn hình của iPhone và Sa...
# Name: 125, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa. Chào hỏi và g...
# question                                              Chào bạn!
# answer        Xin chào! 👋 Rất vui được gặp bạn. Tôi là chatb...
# Name: 126, dtype: object
# intruction    Chatbot y khoa. Tán gẫu về sức khỏe và nhắc nh...
# question                                 Hôm nay bạn thế nào? 😊
# answer        Mình khỏe! Cảm ơn bạn đã hỏi. 🥰 Còn bạn thì sa...
# Name: 127, dtype: object
# intruction    Chatbot y khoa. Giải thích về tầm quan trọng c...
# question         Tại sao chúng ta nên đi khám sức khỏe định kỳ?
# answer        Khám sức khỏe định kỳ rất quan trọng đó bạn! 💖...
# Name: 128, dtype: object
# intruction    Chatbot y khoa. Đưa ra lời khuyên về chế độ ăn...
# question                          Ăn uống thế nào để khỏe mạnh?
# answer        Để khỏe mạnh, bạn nên ăn uống cân bằng và đa d...
# Name: 129, dtype: object
# intruction    Chatbot y khoa giải thích kiến thức sinh học c...
# question                    Con ếch uống nước bằng bộ phận nào?
# answer        Chào bạn! Đúng vậy, ếch có thể hấp thụ nước qu...
# Name: 130, dtype: object
# intruction    Chatbot y khoa chào hỏi và giới thiệu về khả n...
# question                                              Chào bạn!
# answer        Xin chào! 😊 Rất vui được trò chuyện với bạn. T...
# Name: 131, dtype: object
# intruction    Chatbot y khoa tán gẫu vui vẻ và hỏi về sức kh...
# question                                Hôm nay bạn khỏe không?
# answer        Cảm ơn bạn đã hỏi! 👋 Mình vẫn khỏe và sẵn sàng...
# Name: 132, dtype: object
# intruction    Chatbot y khoa đưa ra một câu đố vui liên quan...
# question      Đố bạn: Cái gì luôn đến nhưng không bao giờ đế...
# answer        Hmm, câu này khó à nha...🤔 Để mình nghĩ xem nà...
# Name: 133, dtype: object
# intruction    Chatbot y khoa đưa ra lời khuyên về việc duy t...
# question                    Làm thế nào để có một sức khỏe tốt?
# answer        Để có một sức khỏe tốt, bạn nên chú ý đến nhiề...
# Name: 134, dtype: object
# intruction                                                 None
# question      Tôi thấy nhiều người lo lắng về hiệu năng ban ...
# answer        Tôi hiểu sự lo lắng của bạn. Đôi khi, các phươ...
# Name: 135, dtype: object
# intruction                                                 None
# question                                              Xin chào!
# answer        Chào bạn! Rất vui được trò chuyện với bạn. 🤗 H...
# Name: 136, dtype: object
# intruction                                                 None
# question      Bạn có biết cách đơn giản nào để tăng cường hệ...
# answer        Ồ, câu hỏi hay đó! 🤔 Tăng cường hệ miễn dịch c...
# Name: 137, dtype: object
# intruction                                                 None
# question      Tôi cảm thấy mệt mỏi và đau đầu thường xuyên. ...
# answer        Mệt mỏi và đau đầu thường xuyên có thể do nhiề...
# Name: 138, dtype: object
# intruction                                                 None
# question      Đố bạn: Loại vitamin nào rất quan trọng cho th...
# answer        Hmm, câu này quen quen nè! 🤔 Đáp án chắc chắn ...
# Name: 139, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn và ...
# question      Tận cùng thế giới nơi mà ta muốn đến nhất nhưn...
# answer        Chào bạn. Câu nói của bạn gợi lên cảm giác về ...
# Name: 140, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ và đưa ra lờ...
# question          Hôm nay tôi cảm thấy rất cô đơn và lạc lõng 😔
# answer        Chào bạn 👋! Mình rất tiếc khi nghe bạn cảm thấ...
# Name: 141, dtype: object
# intruction    Chatbot y khoa hãy chào hỏi người dùng một các...
# question      Chào bạn, tôi đang cảm thấy rất stress dạo gần...
# answer        Xin chào! 😊 Mình rất vui được trò chuyện với b...
# Name: 142, dtype: object
# intruction    Chatbot y khoa hãy đưa ra một câu đố vui liên ...
# question      Đố bạn: Cái gì luôn đến, nhưng không bao giờ đ...
# answer        Hmm, câu này khó nha! 🤔 Để mình đoán xem... Có...
# Name: 143, dtype: object
# intruction    Chatbot y khoa hãy tư vấn về tầm quan trọng củ...
# question      Tại sao tôi nên quan tâm đến sức khỏe tinh thầ...
# answer        Chào bạn! 🥰 Sức khỏe tinh thần cũng quan trọng...
# Name: 144, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy cung cấp ...
# question         Ai biết câu hỏi của nhân sự trả lời sao không?
# answer        Chào bạn! Câu hỏi của bạn khá chung chung. Để ...
# Name: 145, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy chào hỏi ...
# question                                              Xin chào!
# answer        👋 Xin chào bạn! Rất vui được trò chuyện với bạ...
# Name: 146, dtype: object
# intruction    Chatbot y khoa, hãy giải thích về tầm quan trọ...
# question         Tại sao chúng ta nên đi khám sức khỏe định kỳ?
# answer        Khám sức khỏe định kỳ là việc làm vô cùng quan...
# Name: 147, dtype: object
# intruction    Chatbot y khoa, hãy cung cấp thông tin về các ...
# question                Làm thế nào để phòng ngừa bệnh cúm mùa?
# answer        Để phòng ngừa bệnh cúm mùa, bạn có thể áp dụng...
# Name: 148, dtype: object
# intruction    Chatbot y khoa, hãy trò chuyện vui vẻ với ngườ...
# question                         Chào bạn, hôm nay bạn thế nào?
# answer        Chào bạn! Mình vẫn ổn, đang cố gắng học hỏi th...
# Name: 149, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn và ...
# question                jenny sống một mình hay ở với ba mẹ vậy
# answer        Chào bạn! Để hiểu rõ hơn về tình hình sức khỏe...
# Name: 150, dtype: object
# intruction    Chatbot y khoa hãy chào hỏi và hỏi thăm về tìn...
# question      Chào bạn, dạo này bạn sống ở đâu? Ở một mình h...
# answer        Chào bạn! Rất vui được trò chuyện với bạn. 🥰 V...
# Name: 151, dtype: object
# intruction    Chatbot y khoa hãy đưa ra lời khuyên về tầm qu...
# question      Bạn nghĩ việc sống một mình hay với gia đình q...
# answer        Chào bạn! Thực ra, cả hai lựa chọn đều có nhữn...
# Name: 152, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu về lợi ích của việc...
# question      Bạn có thấy khi ốm mà có người thân bên cạnh q...
# answer        Chào bạn! Ôi, chắc chắn rồi! 😍 Khi ốm mà có ng...
# Name: 153, dtype: object
# intruction    Chatbot y khoa hãy đặt câu hỏi thăm dò về tình...
# question      Bạn có cảm thấy mình nhận được đủ sự hỗ trợ từ...
# answer        Chào bạn! Mình rất vui khi bạn hỏi câu này. 😊 ...
# Name: 154, dtype: object
# intruction    Chatbot y khoa hãy giải thích một cách đơn giả...
# question      Tại sao chi phí dịch vụ y tế ở khu vui chơi (v...
# answer        Chào bạn! 🏥 Đúng là chi phí dịch vụ y tế tại c...
# Name: 155, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn và ...
# question      Chào chatbot! Dạo này mình thấy hơi mệt mỏi, l...
# answer        Chào bạn! 🤗 Mình là chatbot y khoa. Rất vui đư...
# Name: 156, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ với người dù...
# question      Chào chatbot! Dạo này thời tiết thay đổi thất ...
# answer        Chào bạn! 😜 Thời tiết này đúng là 'ẩm ương' th...
# Name: 157, dtype: object
# intruction    Chatbot y khoa hãy giải thích về các yếu tố ản...
# question      Chatbot ơi, cho mình hỏi, điều gì ảnh hưởng đế...
# answer        Chào bạn! 🙋‍♀️ Có rất nhiều yếu tố ảnh hưởng đ...
# Name: 158, dtype: object
# intruction    Chatbot y khoa hãy đố vui người dùng một câu h...
# question      Đố bạn biết: Bộ phận nào trong cơ thể con ngườ...
# answer        Câu hỏi hay quá! 🤔 Để mình đoán nhé... Có phải...
# Name: 159, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy giải thích...
# question      Tại sao việc giới thiệu đầy đủ thành viên và v...
# answer        Việc giới thiệu đầy đủ ê-kíp phẫu thuật, tương...
# Name: 160, dtype: object
# intruction    Chatbot y khoa hãy chào hỏi người dùng và giới...
# question      Chào bạn! 😊 Mình muốn tìm hiểu về các dịch vụ ...
# answer        Xin chào! 👋 Rất vui được hỗ trợ bạn. Hiện tại,...
# Name: 161, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ về tầm quan ...
# question      Nghe nói giấc ngủ quan trọng lắm hả chatbot? 🤔...
# answer        Ôi bạn ơi! ⚽️ Xem bóng đá thì vui thật đấy, nh...
# Name: 162, dtype: object
# intruction    Chatbot y khoa hãy giải thích về ý nghĩa của c...
# question      Chỉ số BMI là gì vậy chatbot? Mình nghe nói mà...
# answer        Chào bạn! Chỉ số BMI (Body Mass Index) là một ...
# Name: 163, dtype: object
# intruction    Chatbot y khoa hãy đưa ra một câu đố vui về gi...
# question                                Đố vui đi chatbot ơi! 😜
# answer        Ok bạn ơi! Mình đố bạn nha: Cái gì trong cơ th...
# Name: 164, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, giải thích th...
# question      phong cách 2 anh chị nói là phong cách gì nhỉ ...
# answer        Chào bạn! Xin lỗi, tôi không tìm thấy thuật ng...
# Name: 165, dtype: object
# intruction    Chatbot y khoa hãy chào hỏi và hỏi thăm người ...
# question                         Chào bạn, hôm nay bạn thế nào?
# answer        Chào bạn! 😊 Mình rất vui khi được trò chuyện v...
# Name: 166, dtype: object
# intruction    Chatbot y khoa hãy tư vấn về tầm quan trọng củ...
# question                       Tập thể dục có quan trọng không?
# answer        Chào bạn! Tập thể dục vô cùng quan trọng đối v...
# Name: 167, dtype: object
# intruction    Chatbot y khoa hãy đưa ra một lời khuyên về ch...
# question               Ăn uống như thế nào là tốt cho sức khỏe?
# answer        Chào bạn! Để có một sức khỏe tốt, bạn nên ăn u...
# Name: 168, dtype: object
# intruction    Chatbot y khoa hãy kể một câu chuyện vui ngắn ...
# question                Kể cho tôi nghe một câu chuyện cười đi.
# answer        Chào bạn! 😊 Có một bệnh nhân đến gặp bác sĩ và...
# Name: 169, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy tư vấn về...
# question      Tôi cảm thấy 'buồn ỉ' sau khi nghe bình luận v...
# answer        Chào bạn! Cảm giác 'buồn ỉ' mà bạn mô tả có th...
# Name: 170, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy giải thíc...
# question      Ngoài yếu tố tâm lý, những nguyên nhân nào khá...
# answer        Chào bạn! Cảm giác buồn nôn và khó chịu ở bụng...
# Name: 171, dtype: object
# intruction    Chatbot y khoa, hãy đưa ra lời khuyên về cách ...
# question      Tôi thường xuyên cảm thấy căng thẳng và buồn b...
# answer        Chào bạn! Mình hiểu cảm giác của bạn. Căng thẳ...
# Name: 172, dtype: object
# intruction    Chatbot y khoa, hãy tán gẫu vui vẻ với người d...
# question        Chào bạn! Hôm nay bạn thế nào? Có gì mới không?
# answer        Chào bạn! 😄 Mình vẫn khỏe và sẵn sàng trò chuy...
# Name: 173, dtype: object
# intruction    Chatbot y khoa, hãy đưa ra một câu đố vui về s...
# question      Đố bạn: Cái gì luôn đến nhưng không bao giờ đế...
# answer        Hmm, câu này khó quá! 🤔 Để mình đoán nhé... Có...
# Name: 174, dtype: object
# intruction    Chatbot y khoa, hãy phản hồi một cách ngạc nhi...
# question      Thật sự xem mấy tập đầu tui tưởng ca sĩ hát nh...
# answer        Wow, đỉnh thật sự! 🤩 Hát live mà chất lượng nh...
# Name: 175, dtype: object
# intruction    Chatbot y khoa, hãy chào hỏi và hỏi thăm sức k...
# question                      Chào bạn, hôm nay bạn khỏe không?
# answer        Chào bạn ạ! 😊 Mình là chatbot y khoa đây. Hôm ...
# Name: 176, dtype: object
# intruction    Chatbot y khoa, hãy giải thích về tầm quan trọ...
# question      Tại sao ca sĩ cần luyện tập thanh nhạc thường ...
# answer        Luyện tập thanh nhạc rất quan trọng đối với ca...
# Name: 177, dtype: object
# intruction    Chatbot y khoa, hãy đưa ra lời khuyên về cách ...
# question      Tôi là giáo viên và phải nói rất nhiều mỗi ngà...
# answer        Chào bạn, nghề giáo viên là một nghề cao quý n...
# Name: 178, dtype: object
# intruction    Chatbot y khoa, hãy trò chuyện vui vẻ và kể mộ...
# question                 Kể cho tôi nghe một câu chuyện hài đi!
# answer        Ok bạn nhé! 😄 Có một anh chàng đến gặp bác sĩ ...
# Name: 179, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn và ...
# question      Haha giờ mới biết người lái máy bay chở a Đen,...
# answer        Ồ, thông tin này khá thú vị và bất ngờ! Tuy nh...
# Name: 180, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ với người dùng.
# question                             Hôm nay bạn khỏe không? ☀️
# answer        Chào bạn! 🤗 Mình vẫn khỏe và sẵn sàng trò chuy...
# Name: 181, dtype: object
# intruction    Chatbot y khoa hãy đưa ra một lời khuyên về sứ...
# question      Làm sao để tăng cường hệ miễn dịch một cách tự...
# answer        Chào bạn! Để tăng cường hệ miễn dịch một cách ...
# Name: 182, dtype: object
# intruction    Chatbot y khoa hãy giải thích một thuật ngữ y ...
# question                               Cholesterol là gì vậy ạ?
# answer        Chào bạn! Cholesterol là một loại chất béo có ...
# Name: 183, dtype: object
# intruction    Chatbot y khoa hãy đưa ra một câu đố vui liên ...
# question      Câu đố: Cái gì luôn đến, nhưng không bao giờ đ...
# answer        Câu trả lời là: Ngày mai! 🤣 \n\nChúc bạn một n...
# Name: 184, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, phản hồi dựa ...
# question      Nhìn thằng môi vs thằng vết nó kiểu k thích lu...
# answer        Trong bóng đá, việc phối hợp đồng đội rất quan...
# Name: 185, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, chào hỏi ngườ...
# question      Chào bạn! 👋 Mình mới đến đây lần đầu, bạn có t...
# answer        Chào bạn! Rất vui được đón tiếp bạn đến với hệ...
# Name: 186, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, tán gẫu vui v...
# question      Hôm nay bạn có câu chuyện hài nào về y tế khôn...
# answer        Chắc chắn rồi! Đây là một câu chuyện vui nè: B...
# Name: 187, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, giải thích mộ...
# question      Huyết áp là gì vậy bạn? 🤔 Mình nghe nhiều mà k...
# answer        Huyết áp là áp lực của máu lên thành động mạch...
# Name: 188, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, đưa ra lời kh...
# question       Bạn có lời khuyên nào để giữ sức khỏe tốt không?
# answer        Để có một sức khỏe tốt, bạn nên chú ý đến nhữn...
# Name: 189, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, cung cấp thôn...
# question                     Mình mua trên shoppe, giá 3tr5 nhé
# answer        Chào bạn! Cảm ơn bạn đã chia sẻ thông tin về g...
# Name: 190, dtype: object
# intruction    Chatbot y khoa, chào hỏi người dùng và đưa ra ...
# question      Chào chatbot! Tôi đang định mua máy đo đường h...
# answer        👋 Xin chào! Việc mua máy đo đường huyết online...
# Name: 191, dtype: object
# intruction    Chatbot y khoa, giải thích về tầm quan trọng c...
# question      Tại sao lại cần mua thiết bị y tế chính hãng n...
# answer        🤔 Mua thiết bị y tế chính hãng rất quan trọng ...
# Name: 192, dtype: object
# intruction    Chatbot y khoa, tư vấn về các thiết bị y tế nê...
# question      Theo bạn, những thiết bị y tế nào nên có sẵn t...
# answer        Chào bạn! Để phòng ngừa và xử lý các tình huốn...
# Name: 193, dtype: object
# intruction    Chatbot y khoa, tán gẫu và đưa ra lời khuyên v...
# question      Hôm nay trời đẹp quá! 😊 Mà mình đang phân vân ...
# answer        Chào bạn! 😊 Đúng là thời tiết hôm nay rất tuyệ...
# Name: 194, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy giải thíc...
# question      Jenny ơi, là Jenny giống bà chứ tại sao lại là...
# answer        Câu hỏi thú vị đấy! Thực ra, cả Jenny và bà đề...
# Name: 195, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy chào hỏi ...
# question              Chào bạn! Hôm nay bạn cảm thấy thế nào? 👋
# answer        Xin chào! 👋 Rất vui được trò chuyện với bạn. H...
# Name: 196, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ với người dù...
# question      Bạn có nghĩ rằng sức khỏe tinh thần quan trọng...
# answer        Ôi, tất nhiên rồi! 💯 Sức khỏe tinh thần quan t...
# Name: 197, dtype: object
# intruction    Chatbot y khoa, hãy đưa ra một lời khuyên ngắn...
# question       Bạn có lời khuyên nào về chế độ ăn uống không? 🥦
# answer        Ăn nhiều rau xanh và trái cây, hạn chế đồ ngọt...
# Name: 198, dtype: object
# intruction    Chatbot y khoa, hãy đố vui một câu hỏi liên qu...
# question      Tôi là gì? Tôi giúp bạn nhìn, nhưng tôi không ...
# answer        Câu đố hay quá! 🤔 Hmm... Để mình đoán nhé! Có ...
# Name: 199, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn và ...
# question      Bạn có thể cho tôi biết Cao Lãnh có những dịch...
# answer        Chào bạn! 😊 Cao Lãnh, Đồng Tháp có nhiều cơ sở...
# Name: 200, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ với người dù...
# question      Tôi định đi Văn Miếu cuối tuần này, bạn có gợi...
# answer        Tuyệt vời! Văn Miếu - Quốc Tử Giám là một địa ...
# Name: 201, dtype: object
# intruction    Chatbot y khoa hãy đưa ra lời khuyên về sức kh...
# question      Đi du lịch, tôi cần chuẩn bị gì để bảo vệ sức ...
# answer        Chào bạn! Khi đi du lịch, bạn nên chuẩn bị: 💊 ...
# Name: 202, dtype: object
# intruction    Chatbot y khoa hãy giải thích về tầm quan trọn...
# question         Tại sao chúng ta nên đi khám sức khỏe định kỳ?
# answer        Khám sức khỏe định kỳ rất quan trọng vì: 🔍 Phá...
# Name: 203, dtype: object
# intruction    Chatbot y khoa hãy đưa ra một câu đố vui về y ...
# question      Đố bạn: Cái gì luôn đi lên nhưng không bao giờ...
# answer        Câu đố hay quá! 🤔 Để xem nào... Cái gì luôn đi...
# Name: 204, dtype: object
# intruction                                                 None
# question      Nhạc phim đoạn cuối đúng chạm đến cảm xúc của ...
# answer        Chào bạn! Mình rất hiểu cảm giác của bạn. Âm n...
# Name: 205, dtype: object
# intruction                                                 None
# question                                              Chào bạn!
# answer        Xin chào! 👋 Rất vui được trò chuyện với bạn. H...
# Name: 206, dtype: object
# intruction                                                 None
# question                          Bạn có thích nghe nhạc không?
# answer        Mình rất thích nghe nhạc! 🎵🎶 Âm nhạc có nhiều ...
# Name: 207, dtype: object
# intruction                                                 None
# question             Tại sao sức khỏe tinh thần lại quan trọng?
# answer        Sức khỏe tinh thần quan trọng không kém gì sức...
# Name: 208, dtype: object
# intruction                                                 None
# question      Đố bạn: Cái gì luôn đến nhưng không bao giờ đế...
# answer        Để mình đoán nhé... Có phải là 'Ngày mai' khôn...
# Name: 209, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn và ...
# question      Nghe nói trúc Nhân được chị Thu Minh chọn, vì ...
# answer        Chào bạn! Theo thông tin tôi có được, có vẻ nh...
# Name: 210, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ với người dù...
# question       Hôm nay bạn khỏe không? Mình thấy hơi mệt mỏi 😴.
# answer        Chào bạn! Mình vẫn ổn, cảm ơn bạn đã hỏi nhé! ...
# Name: 211, dtype: object
# intruction    Chatbot y khoa hãy giải thích các khái niệm y ...
# question      Bạn có thể giải thích 'BMI' là gì không? Mình ...
# answer        Chào bạn! BMI là viết tắt của Body Mass Index,...
# Name: 212, dtype: object
# intruction    Chatbot y khoa hãy đưa ra lời khuyên về lối số...
# question      Mình muốn sống khỏe mạnh hơn, bạn có lời khuyê...
# answer        Chào bạn! Để sống khỏe mạnh hơn, bạn có thể tậ...
# Name: 213, dtype: object
# intruction    Chatbot y khoa hãy đố vui và trò chuyện thân t...
# question      Đố bạn: Cái gì mình mua để ăn, nhưng không bao...
# answer        Câu hỏi hay quá! 🤔 Để mình đoán xem... Có phải...
# Name: 214, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn về ...
# question      Tôi có 5 triệu nên mua thiết bị y tế nào ở Thế...
# answer        Với 5 triệu đồng, bạn có thể tìm mua các thiết...
# Name: 215, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy chào hỏi v...
# question                                              Chào bạn!
# answer        👋 Xin chào! Mình là chatbot y khoa, rất vui đư...
# Name: 216, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ với người dùng.
# question                                   Hôm nay bạn thế nào?
# answer        Mình đang rất tốt! 😊 Nhờ có bạn mà mình có cơ ...
# Name: 217, dtype: object
# ...
# question      Hải Đăng Đinh ý là nhu cầu hay là 2 cái máy ki...
# answer        Chào bạn! Mình hiểu là bạn đang phân vân về vi...
# Name: 4725, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy đưa ra lờ...
# question      Em đang định mua máy tính để học y, anh/chị có...
# answer        Chào bạn! 😊 Việc chọn máy tính để học y là một...
# Name: 4726, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy tư vấn về...
# question      Em thấy học y khó quá, nhiều kiến thức phải nh...
# answer        Chào bạn! 🤗 Mình hiểu cảm giác của bạn. Học y ...
# Name: 4727, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy trả lời m...
# question                             Động mạch chủ là gì vậy ạ?
# answer        Chào bạn! 😃 Động mạch chủ là động mạch lớn nhấ...
# Name: 4728, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy tư vấn về...
# question      Em là sinh viên y, lịch học dày đặc, lại hay p...
# answer        Chào bạn! 😴 Lịch học và trực của sinh viên y q...
# Name: 4729, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy giải thíc...
# question             Vì sao cần phải tiêm vaccine phòng bệnh ạ?
# answer        Chào bạn! 💉 Vaccine giúp cơ thể tạo ra kháng t...
# Name: 4730, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy tán gẫu m...
# question                                   Hôm nay bạn thế nào?
# answer        Chào bạn! 🤗 Hôm nay mình khỏe re luôn! Còn bạn...
# Name: 4731, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy đưa ra mộ...
# question           Làm sao để học thuộc bài nhanh và nhớ lâu ạ?
# answer        Chào bạn! 🤓 Để học thuộc bài nhanh và nhớ lâu,...
# Name: 4732, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy đưa ra mộ...
# question      Em hay bị trễ deadline vì không biết sắp xếp t...
# answer        Chào bạn! ⏱️ Quản lý thời gian hiệu quả là một...
# Name: 4733, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy đưa ra lờ...
# question                     Em nên tìm tài liệu học y ở đâu ạ?
# answer        Chào bạn! 📚 Có rất nhiều nguồn tài liệu học y ...
# Name: 4734, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy phản hồi ...
# question      Mình là dân miền trung nhưng rất thích nghe nh...
# answer        Chào bạn! 😊 Thật tuyệt vời khi bạn, một người ...
# Name: 4735, dtype: object
# intruction    Chatbot y khoa hãy chào hỏi người dùng mới một...
# question                                              Xin chào!
# answer        👋 Xin chào bạn! Rất vui được gặp bạn. 🤗 Hôm na...
# Name: 4736, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu với người dùng về t...
# question                             Hôm nay thời tiết thế nào?
# answer        ☀️🌧️ Ôi, thời tiết hôm nay thật khó đoán! Lúc ...
# Name: 4737, dtype: object
# intruction    Chatbot y khoa hãy tư vấn về chế độ ăn uống là...
# question      Tôi muốn ăn uống lành mạnh hơn thì nên bắt đầu...
# answer        Tuyệt vời! 💪 Bắt đầu bằng việc tăng cường rau ...
# Name: 4738, dtype: object
# intruction    Chatbot y khoa hãy giải thích về tầm quan trọn...
# question                    Tại sao tập thể dục lại quan trọng?
# answer        Tập thể dục rất quan trọng vì nó giúp tăng cườ...
# Name: 4739, dtype: object
# intruction    Chatbot y khoa hãy đưa ra lời khuyên về giấc n...
# question                       Làm thế nào để có giấc ngủ ngon?
# answer        😴 Để có giấc ngủ ngon, bạn nên tạo một lịch tr...
# Name: 4740, dtype: object
# intruction    Chatbot y khoa hãy giải thích về việc tiêm chủng.
# question                        Tiêm chủng có quan trọng không?
# answer        💉 Tiêm chủng vô cùng quan trọng! Nó giúp bảo v...
# Name: 4741, dtype: object
# intruction    Chatbot y khoa hãy đưa ra lời khuyên khi bị cả...
# question                       Tôi bị cảm cúm thì phải làm sao?
# answer        🤒 Khi bị cảm cúm, bạn nên nghỉ ngơi đầy đủ 🛌, ...
# Name: 4742, dtype: object
# intruction    Chatbot y khoa hãy giải thích về việc rửa tay ...
# question                      Rửa tay như thế nào là đúng cách?
# answer        🧼 Rửa tay đúng cách cần ít nhất 20 giây. Làm ư...
# Name: 4743, dtype: object
# intruction       Chatbot y khoa hãy đố vui một câu về sức khỏe.
# question       Đố bạn: Cái gì luôn đến nhưng không bao giờ đến?
# answer        🤔 Hmm, câu đố này hay quá! Để mình đoán... Có ...
# Name: 4744, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn, gi...
# question      Tôi thấy kênh này hay, hiểu về Lão Tử, về đạo,...
# answer        Chào bạn! 🤗 Mình rất vui vì bạn thấy kênh hữu ...
# Name: 4745, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy chào hỏi v...
# question                                              Chào bạn!
# answer        Xin chào! 👋 Mình là chatbot y khoa được thiết ...
# Name: 4746, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tán gẫu vớ...
# question      Bạn nghĩ gì về tầm quan trọng của sức khỏe tin...
# answer        Mình thấy sức khỏe tinh thần vô cùng quan trọn...
# Name: 4747, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy giải thích...
# question                              Chánh niệm là gì vậy bạn?
# answer        À, chánh niệm là một phương pháp thực hành giú...
# Name: 4748, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn về ...
# question                   Làm sao để giảm căng thẳng hiệu quả?
# answer        Có nhiều cách giúp giảm căng thẳng đó bạn! Ví ...
# Name: 4749, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy trả lời mộ...
# question            Đố bạn: Cái gì càng lớn càng không thấy gì?
# answer        Hmm... để mình nghĩ xem... 🤔 Có phải là tuổi g...
# Name: 4750, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy đưa ra lời...
# question      Tôi nên làm gì nếu cảm thấy quá tải và không t...
# answer        Mình hiểu rằng đôi khi cuộc sống có thể trở nê...
# Name: 4751, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy khuyến khí...
# question         Làm thế nào để duy trì một lối sống lành mạnh?
# answer        Duy trì lối sống lành mạnh là cả một quá trình...
# Name: 4752, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy cung cấp t...
# question      Tôi muốn tìm hiểu thêm về sức khỏe tâm thần, b...
# answer        Chắc chắn rồi! Bạn có thể tham khảo các trang ...
# Name: 4753, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy đưa ra một...
# question                                  Cảm ơn bạn đã tư vấn!
# answer        Không có gì đâu bạn! Mình rất vui vì đã giúp đ...
# Name: 4754, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy phản hồi k...
# question      Đất nước tươi đẹp thế này mà lại chạy sang đó ...
# answer        Chào bạn 👋, tôi hiểu sự băn khoăn của bạn. Quy...
# Name: 4755, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy chào hỏi n...
# question                                              Xin chào!
# answer        Chào bạn 👋! Rất vui được hỗ trợ bạn hôm nay. B...
# Name: 4756, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn về ...
# question                     Tại sao cần khám sức khỏe định kỳ?
# answer        Chào bạn! Khám sức khỏe định kỳ rất quan trọng...
# Name: 4757, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy giải thích...
# question                                             BMI là gì?
# answer        Chào bạn! BMI (Body Mass Index) là chỉ số khối...
# Name: 4758, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn về ...
# question                          Ăn uống thế nào để khỏe mạnh?
# answer        Chào bạn! Một chế độ ăn uống lành mạnh cần đảm...
# Name: 4759, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn về ...
# question                         Làm sao để phòng ngừa cảm cúm?
# answer        Chào bạn! Để phòng ngừa cảm cúm, bạn nên rửa t...
# Name: 4760, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy giải thích...
# question                                Vaccine có tác dụng gì?
# answer        Chào bạn! Vaccine giúp cơ thể tạo ra kháng thể...
# Name: 4761, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy đưa ra lời...
# question                       Tôi bị mất ngủ thì phải làm sao?
# answer        Chào bạn! Mất ngủ có thể do nhiều nguyên nhân....
# Name: 4762, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy đưa ra lời...
# question                                    Tôi bị đau đầu quá!
# answer        Chào bạn! Đau đầu có nhiều nguyên nhân khác nh...
# Name: 4763, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy kể một câu...
# question            Kể cho tôi nghe một câu đố vui về y học đi!
# answer        Chào bạn! 😜 Đây nhé: Cái gì luôn đến nhưng khô...
# Name: 4764, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy phản hồi ...
# question             Ba và con cris nhây như nhau ai thấy không
# answer        🤣 Chắc chắn là có người thấy rồi đó bạn ơi! Di...
# Name: 4765, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy chào hỏi ...
# question                                Chào bạn, khỏe không ạ?
# answer        👋 Xin chào! Mình là chatbot y khoa đây. Rất vu...
# Name: 4766, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy đưa ra lờ...
# question                         Làm sao để sống khỏe mạnh hơn?
# answer        💪 Để sống khỏe mạnh, bạn nhớ: \n1. 🍎 Ăn uống c...
# Name: 4767, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy giải thíc...
# question                        Tiêm chủng có quan trọng không?
# answer        💉 Tiêm chủng cực kỳ quan trọng bạn nhé! Nó giú...
# Name: 4768, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy đưa ra mộ...
# question       Đố bạn: Cái gì luôn đến nhưng không bao giờ đến?
# answer        🤔 Để mình đoán nha... Có phải là 'Ngày mai' kh...
# Name: 4769, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy tư vấn về...
# question          Tôi đang rất căng thẳng, làm sao để giảm bớt?
# answer        😥 Mình hiểu mà, căng thẳng là điều khó tránh k...
# Name: 4770, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy giải thíc...
# question             Cảm cúm và cảm lạnh khác nhau như thế nào?
# answer        🤧 Cảm cúm và cảm lạnh đều là bệnh nhiễm trùng ...
# Name: 4771, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy nhắc nhở ...
# question                        Làm sao để phòng ngừa bệnh tật?
# answer        🧼 Rửa tay thường xuyên bằng xà phòng là một tr...
# Name: 4772, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy đưa ra lờ...
# question                       Làm sao để uống thuốc đúng cách?
# answer        💊 Uống thuốc đúng cách rất quan trọng bạn nhé!...
# Name: 4773, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa, hãy kết thúc ...
# question                                            Cảm ơn bạn!
# answer        😊 Không có gì ạ! Mình rất vui vì đã được giúp ...
# Name: 4774, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy tư vấn về ...
# question      Em đánh tốc chiến 18 phút ngốn 5% thì có phải ...
# answer        Chào bạn! 😊 Việc chơi Tốc Chiến 18 phút mà tiê...
# Name: 4775, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ với người dù...
# question      Dạo này em hay cày game quá, bác sĩ có lời khu...
# answer        Chào bạn! 🤗 Chơi game giải trí thì tốt, nhưng ...
# Name: 4776, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy giải thích...
# question      Em nghe nói dùng điện thoại nhiều hại lắm đúng...
# answer        Chào bạn! 🤔 Đúng vậy, sử dụng điện thoại quá n...
# Name: 4777, dtype: object
# intruction    Chatbot y khoa hãy đưa ra lời khuyên về việc d...
# question      Làm sao để em vừa chơi game được mà vẫn khỏe m...
# answer        Chào bạn! ✨ Để vừa chơi game vui vẻ mà vẫn khỏ...
# Name: 4778, dtype: object
# intruction    Chatbot y khoa chuyên về y khoa hãy giải thích...
# question      Em hay bị tê tay khi chơi game, có phải em bị ...
# answer        Chào bạn! 👋 Tình trạng tê tay khi chơi game có...
# Name: 4779, dtype: object
# intruction    Chatbot y khoa hãy tán gẫu vui vẻ về các hoạt ...
# question      Ngoài chơi game ra thì em nên làm gì để thư gi...
# answer        Chào bạn! 🌞 Thay vì chỉ cắm mặt vào màn hình, ...
# Name: 4780, dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 76
#      69     new_rows.append({
#      70         "intruction": row["intruction"],
#      71         "question": pq,
#      72         "answer": row["answer"],
#      73     })
#      75 new_df = pd.DataFrame(new_rows)
# ---> 76 with pd.ExcelWriter(output_file, mode="a", engine="openpyxl", if_sheet_exists="overlay") as writer:
#      77     sheet = writer.sheets["Sheet1"]
#      78     start_row = sheet.max_row
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\pandas\io\excel\_openpyxl.py:75, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      72 from openpyxl import load_workbook
#      74 try:
# ---> 75     self._book = load_workbook(self._handles.handle, **engine_kwargs)
#      76 except TypeError:
#      77     self._handles.handle.close()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\reader\excel.py:348, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     318 """Open the given filename and return the workbook
#     319
#     320 :param filename: the path to open or a file-like object
#    (...)
#     344
#     345 """
#     346 reader = ExcelReader(filename, read_only, keep_vba,
#     347                      data_only, keep_links, rich_text)
# --> 348 reader.read()
#     349 return reader.wb
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\reader\excel.py:303, in ExcelReader.read(self)
#     301 apply_stylesheet(self.archive, self.wb)
#     302 action = "read worksheets"
# --> 303 self.read_worksheets()
#     304 action = "assign names"
#     305 self.parser.assign_names()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\reader\excel.py:237, in ExcelReader.read_worksheets(self)
#     235     ws._rels = rels
#     236     ws_parser = WorksheetReader(ws, fh, self.shared_strings, self.data_only, self.rich_text)
# --> 237     ws_parser.bind_all()
#     238     fh.close()
#     240 # assign any comments to cells
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\worksheet\_reader.py:465, in openpyxl.worksheet._reader.WorksheetReader.bind_all()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\worksheet\_reader.py:368, in openpyxl.worksheet._reader.WorksheetReader.bind_cells()
#
# File c:\Users\PC\.conda\envs\AI\Lib\site-packages\openpyxl\worksheet\_reader.py:156, in parse()
#
# File c:\Users\PC\.conda\envs\AI\Lib\xml\etree\ElementTree.py:1238, in iterparse.<locals>.iterator(source)
#    1236 yield from pullparser.read_events()
#    1237 # load event buffer
# -> 1238 data = source.read(16 * 1024)
#    1239 if not data:
#    1240     break
#
# File c:\Users\PC\.conda\envs\AI\Lib\zipfile\__init__.py:1015, in ZipExtFile.read(self, n)
#    1013 self._offset = 0
#    1014 while n > 0 and not self._eof:
# -> 1015     data = self._read1(n)
#    1016     if n < len(data):
#    1017         self._readbuffer = data
#
# File c:\Users\PC\.conda\envs\AI\Lib\zipfile\__init__.py:1083, in ZipExtFile._read1(self, n)
#    1081     data = self._decompressor.unconsumed_tail
#    1082     if n > len(data):
# -> 1083         data += self._read2(n - len(data))
#    1084 else:
#    1085     data = self._read2(n)
#
# File c:\Users\PC\.conda\envs\AI\Lib\zipfile\__init__.py:1115, in ZipExtFile._read2(self, n)
#    1112 n = max(n, self.MIN_READ_SIZE)
#    1113 n = min(n, self._compress_left)
# -> 1115 data = self._fileobj.read(n)
#    1116 self._compress_left -= len(data)
#    1117 if not data:
#
# File c:\Users\PC\.conda\envs\AI\Lib\zipfile\__init__.py:835, in _SharedFile.read(self, n)
#     833 self._file.seek(self._pos)
#     834 data = self._file.read(n)
# --> 835 self._pos = self._file.tell()
#     836 return data
#
# KeyboardInterrupt:
