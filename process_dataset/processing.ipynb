# %%
import pandas as pd
df = pd.read_excel("../generate_dataset/SVYKHOA_dataset.xlsx")
df
# Out:
#     icd_10                                           question  \
# 0    I67.6  Các triệu chứng thường gặp của huyết khối tĩnh...
# 1    I67.6  Làm thế nào để chẩn đoán huyết khối tĩnh mạch ...
# 2    I67.6  Các phương pháp điều trị huyết khối tĩnh mạch ...
# 3    I67.6  Người bệnh Huyết khối tĩnh mạch não (CVT) thườ...
# 4    I67.6  Đặc điểm dịch tễ học và kiểu khởi phát bệnh củ...
# ..     ...                                                ...
# 445  I11.0  Suy tim do tăng huyết áp được chẩn đoán như th...
# 446  I25.5  NT-proBNP có giá trị gì trong chẩn đoán và tiê...
# 447  L98.8  Phương pháp vạt tại chỗ có cuống mạch được sử ...
# 448  L98.8  Ưu điểm của phương pháp vạt da đầu tại chỗ có ...
# 449  L98.8  Trong nghiên cứu về tái tạo khuyết hổng da đầu...
#
#                                                symptom  \
# 0    Các triệu chứng thường gặp nhất của huyết khối...
# 1    Các dấu hiệu gợi ý huyết khối tĩnh mạch não (H...
# ...

# %%
df = df.dropna()

# %%
df.to_excel("SVYKHOA_dataset_cleaned.xlsx", index=False)
